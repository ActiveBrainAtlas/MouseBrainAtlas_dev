# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import time

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *
from registration_utilities import *
from annotation_utilities import *
from metadata import *
from data_manager import *
# Out:
# Setting environment for Precision WorkStation
# No vtk

# %%
from aligner_v3 import Aligner

# %%
lauren_brains = ['LM42_LM37', 'LM94_LM96_LM25', 'LM38', 'LM30new', 'LM27', 'LM37', 'LM22', 'LM32', 'LM17', 'LM48', 'LM31', 'LM95', 'LM41', 'LM84', 'LM40new', 'LM86', 'LM54', 'LM46']

# %%
# for brain_name in lauren_brains:
for brain_name in ['LM38']:

    brain_f_spec = dict(name=brain_name, vol_type='annotationAsScore', structure='SNR_L', resolution='10.0um')
    brain_m_spec = dict(name='atlasV6', vol_type='score', structure='SNR_L', resolution='10.0um')
    alignment_spec = dict(stack_m=brain_m_spec, stack_f=brain_f_spec, warp_setting=7)

    aligner_parameters = generate_aligner_parameters_v2(alignment_spec=alignment_spec, 
                                                        structures_m=['SNR_L'],
                                                       fixed_structures_are_sided=True,
                                                       fixed_surroundings_have_positive_value=True,
                                                       fixed_use_surround=True)
    
    aligner = Aligner(aligner_parameters['volume_fixed'], 
                      aligner_parameters['volume_moving'], 
                      labelIndexMap_m2f=aligner_parameters['label_mapping_m2f'])

    aligner.set_centroid(centroid_m='structure_centroid', 
                         centroid_f='structure_centroid', 
#                          indices_m=[aligner_parameters['structure_to_label_moving']['SNR_L']]
                        )

    aligner.compute_gradient(smooth_first=True)

    aligner.set_label_weights(label_weights=aligner_parameters['label_weights_m'])

    _, _ = aligner.optimize(tf_type=aligner_parameters['transform_type'], 
                                 max_iter_num=5000,
                                 history_len=100, 
                                 terminate_thresh_trans=.01,
                                terminate_thresh_rot=0.01,
                                 full_lr=np.array([1,1,1,.01,.01,.01]),
                                )

    plot_alignment_results(traj=aligner.Ts, scores=aligner.scores, select_best='max_value')
    
#     DataManager.save_alignment_results_v3(aligner=aligner, 
#                                           select_best='max_value',
#                                           alignment_spec=alignment_spec,
#                                           )
# Out:
# upstream_warp_id                                                               None
# transform_type                                                                rigid
# terminate_thresh                                                              1e-06
# grad_computation_sample_number                                               100000
# grid_search_sample_number                                                      1000
# std_tx_um                                                                        50
# std_ty_um                                                                        50
# std_tz_um                                                                        50
# std_theta_xy_degree                                                              10
# surround_weight                                                             inverse
# regularization_weight                                                           NaN
# comment                           structure registration with surround, no initi...
# max_iter_num                                                                    NaN
# Unnamed: 14                                                                     NaN
# Name: 7, dtype: object
# surround inverse True
# loaded_cropbox_resolution 10.0um
# loaded_cropbox_resolution 10.0um
# voxel size for moving = 10.00 um
# voxel size for fixed = 10.00 um
# label_mapping_m2f {1: 1, 2: 2}
# {1: 0.4092068609276033, 2: 1.0}
# Prior structure/index map not found. Generating a new one.
# Loaded moving volumes: ['SNR_L', 'SNR_L_surround_200um'].
# Prior structure/index map not found. Generating a new one.
# Loaded fixed volumes: ['SNR_L', 'SNR_L_surround_200um'].
# Computing structure sizes: 0.01 s
# Label weights not set, default to 1 for all structures.
# Regularization weights not set, default to 0.
# centroid_m: [-196.9841152  -23.238024  -137.7273612], centroid_f: [  46.49793843  702.51718906 8152.11063272]
# indices_f: set([1, 2])
# 1: 1042555 valid, 73504 out-of-bound voxels after transform.
# 2: 990446 valid, 393495 out-of-bound voxels after transform.
#
# iteration 0
# 1: 1042555 valid, 73504 out-of-bound voxels after transform.
# 2: 990446 valid, 393495 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.732051
# Norm of gradient (rotation) = 1.732051
# around x=0.57; around y=-0.58; around z=0.57
# step: 0.79 seconds
# current score: 0.256738
# new_T: [ 0.9999     -0.0100495  -0.0099495  -0.99993333  0.0099495   0.9999
#  -0.0100495  -1.00996642  0.0100495   0.0099495   0.9999      0.98996692]
# det: 1.00
#
# iteration 1
# 1: 1036821 valid, 79238 out-of-bound voxels after transform.
# 2: 989720 valid, 394221 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.434002
# Norm of gradient (rotation) = 0.572187
# around x=0.55; around y=-0.81; around z=0.79
# step: 0.79 seconds
# current score: 0.251707
# new_T: [ 0.99980294 -0.01399456 -0.01407964 -1.41966059  0.01385777  0.99985628
#  -0.00976672 -0.97795357  0.01421429  0.00956968  0.99985318  1.091303  ]
# det: 1.00
#
# iteration 2
# 1: 1034342 valid, 81717 out-of-bound voxels after transform.
# 2: 988870 valid, 395071 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.358727
# Norm of gradient (rotation) = 0.441853
# around x=0.44; around y=-0.98; around z=0.95
# step: 0.79 seconds
# current score: 0.248192
# new_T: [ 0.99971557 -0.01668619 -0.01703969 -1.72142197  0.01655288  0.9998315
#  -0.00793529 -0.78581404  0.01716922  0.00765098  0.99982332  1.10943789]
# det: 1.00
#
# iteration 3
# 1: 1032226 valid, 83833 out-of-bound voxels after transform.
# 2: 988034 valid, 395907 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.332604
# Norm of gradient (rotation) = 0.396077
# around x=0.32; around y=-1.13; around z=1.08
# step: 0.79 seconds
# current score: 0.245429
# new_T: [ 0.99962808 -0.01895806 -0.01960339 -1.98302916  0.01884393  0.99980449
#  -0.00599052 -0.58167522  0.01971313  0.00561889  0.99978989  1.12632299]
# det: 1.00
#
# iteration 4
# 1: 1030000 valid, 86059 out-of-bound voxels after transform.
# 2: 987826 valid, 396115 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.319292
# Norm of gradient (rotation) = 0.370125
# around x=0.20; around y=-1.26; around z=1.20
# step: 0.81 seconds
# current score: 0.243547
# new_T: [ 0.99953946 -0.02097627 -0.02192847 -2.22040676  0.02089386  0.99977378
#  -0.00398032 -0.37022753  0.022007    0.00352032  0.99975162  1.1523369 ]
# det: 1.00
#
# iteration 5
# 1: 1028003 valid, 88056 out-of-bound voxels after transform.
# 2: 987227 valid, 396714 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.292287
# Norm of gradient (rotation) = 0.345825
# around x=0.11; around y=-1.39; around z=1.31
# step: 0.79 seconds
# current score: 0.241109
# new_T: [ 9.99441612e-01 -2.29881848e-02 -2.42488579e-02 -2.45712752e+00
#   2.29357020e-02  9.99733964e-01 -2.44028525e-03 -2.07496046e-01
#   2.42985046e-02  1.88275805e-03  9.99702975e-01  1.20216757e+00]
# det: 1.00
#
# iteration 6
# 1: 1026539 valid, 89520 out-of-bound voxels after transform.
# 2: 986424 valid, 397517 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.285194
# Norm of gradient (rotation) = 0.335552
# around x=0.01; around y=-1.52; around z=1.43
# step: 0.79 seconds
# current score: 0.239050
# new_T: [ 9.99338819e-01 -2.49124905e-02 -2.64819477e-02 -2.68504425e+00
#   2.48976563e-02  9.99689609e-01 -8.89796071e-04 -4.38796499e-02
#   2.64958950e-02  2.29869324e-04  9.99648896e-01  1.24922842e+00]
# det: 1.00
#
# iteration 7
# 1: 1024982 valid, 91077 out-of-bound voxels after transform.
# 2: 985481 valid, 398460 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.262354
# Norm of gradient (rotation) = 0.304262
# around x=-0.08; around y=-1.63; around z=1.53
# step: 0.79 seconds
# current score: 0.237084
# new_T: [ 9.99240324e-01 -2.65877695e-02 -2.84932642e-02 -2.89064061e+00
#   2.66159853e-02  9.99645545e-01  6.11389116e-04  1.13904529e-01
#   2.84669091e-02 -1.36930096e-03  9.99593798e-01  1.28677573e+00]
# det: 1.00
#
# iteration 8
# 1: 1023575 valid, 92484 out-of-bound voxels after transform.
# 2: 985033 valid, 398908 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.240394
# Norm of gradient (rotation) = 0.270133
# around x=-0.16; around y=-1.73; around z=1.61
# step: 0.79 seconds
# current score: 0.235667
# new_T: [ 9.99147487e-01 -2.80343198e-02 -3.03047135e-02 -3.07602479e+00
#   2.81063028e-02  9.99603034e-01  1.95186362e-03  2.55544632e-01
#   3.02379644e-02 -2.80195308e-03  9.99538801e-01  1.34126074e+00]
# det: 1.00
#
# iteration 9
# 1: 1022059 valid, 94000 out-of-bound voxels after transform.
# 2: 984288 valid, 399653 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.216944
# Norm of gradient (rotation) = 0.240281
# around x=-0.23; around y=-1.83; around z=1.69
# step: 0.79 seconds
# current score: 0.233501
# new_T: [ 9.99059733e-01 -2.92975989e-02 -3.19577882e-02 -3.24541263e+00
#   2.94118458e-02  9.99562538e-01  3.11062074e-03  3.77905121e-01
#   3.18526742e-02 -4.04763347e-03  9.99484379e-01  1.39656609e+00]
# det: 1.00
#
# iteration 10
# 1: 1020731 valid, 95328 out-of-bound voxels after transform.
# 2: 983605 valid, 400336 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.205649
# Norm of gradient (rotation) = 0.229541
# around x=-0.30; around y=-1.91; around z=1.76
# step: 0.78 seconds
# current score: 0.231548
# new_T: [ 0.99897237 -0.03048758 -0.03353686 -3.4073647   0.03064645  0.99952132
#   0.00423341  0.49585008  0.03339174 -0.00525685  0.99942852  1.44063113]
# det: 1.00
#
# iteration 11
# 1: 1019569 valid, 96490 out-of-bound voxels after transform.
# 2: 983073 valid, 400868 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.201443
# Norm of gradient (rotation) = 0.223113
# around x=-0.37; around y=-2.00; around z=1.82
# step: 0.78 seconds
# current score: 0.229875
# new_T: [ 0.99888598 -0.03160412 -0.03504246 -3.5619376   0.03181237  0.99947926
#   0.00540113  0.61833354  0.03485352 -0.00650989  0.99937123  1.47960366]
# det: 1.00
#
# iteration 12
# 1: 1018408 valid, 97651 out-of-bound voxels after transform.
# 2: 982529 valid, 401412 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.192881
# Norm of gradient (rotation) = 0.212398
# around x=-0.44; around y=-2.08; around z=1.89
# step: 0.78 seconds
# current score: 0.228384
# new_T: [ 0.99880194 -0.0326308  -0.03646809 -3.70847224  0.03289086  0.99943746
#   0.00655395  0.73893149  0.03623371 -0.00774557  0.99931333  1.51267257]
# det: 1.00
#
# iteration 13
# 1: 1017354 valid, 98705 out-of-bound voxels after transform.
# 2: 982133 valid, 401808 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.182641
# Norm of gradient (rotation) = 0.200544
# around x=-0.51; around y=-2.15; around z=1.94
# step: 0.79 seconds
# current score: 0.227215
# new_T: [ 0.99871862 -0.03359952 -0.03784438 -3.85003002  0.03391045  0.99939595
#   0.00760404  0.84871369  0.03756602 -0.00887762  0.99925471  1.54687912]
# det: 1.00
#
# iteration 14
# 1: 1016367 valid, 99692 out-of-bound voxels after transform.
# 2: 981672 valid, 402269 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.173816
# Norm of gradient (rotation) = 0.188714
# around x=-0.57; around y=-2.23; around z=2.00
# step: 0.78 seconds
# current score: 0.226054
# new_T: [ 0.99863672 -0.03450547 -0.03916726 -3.98617427  0.03486602  0.99935534
#   0.00855976  0.94875358  0.03884665 -0.0099137   0.999196    1.58591888]
# det: 1.00
#
# iteration 15
# 1: 1015333 valid, 100726 out-of-bound voxels after transform.
# 2: 981159 valid, 402782 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.165549
# Norm of gradient (rotation) = 0.178308
# around x=-0.63; around y=-2.30; around z=2.05
# step: 0.78 seconds
# current score: 0.224840
# new_T: [ 0.99855745 -0.0353381  -0.04042576 -4.11581244  0.0357484   0.99931593
#   0.00947187  1.04407299  0.04006339 -0.01090336  0.99913765  1.62324359]
# det: 1.00
#
# iteration 16
# 1: 1014353 valid, 101706 out-of-bound voxels after transform.
# 2: 980710 valid, 403231 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.155117
# Norm of gradient (rotation) = 0.165537
# around x=-0.68; around y=-2.36; around z=2.10
# step: 0.78 seconds
# current score: 0.223646
# new_T: [ 0.99848298 -0.03607278 -0.04159912 -4.23685127  0.03653253  0.99927892
#   0.01034488  1.13499509  0.04119596 -0.01184891  0.99908083  1.65606041]
# det: 1.00
#
# iteration 17
# 1: 1013527 valid, 102532 out-of-bound voxels after transform.
# 2: 980313 valid, 403628 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.146231
# Norm of gradient (rotation) = 0.154447
# around x=-0.73; around y=-2.42; around z=2.14
# step: 0.78 seconds
# current score: 0.222531
# new_T: [ 0.99841353 -0.03671411 -0.04269062 -4.3496222   0.03722348  0.99924422
#   0.01119843  1.22361963  0.04224722 -0.01276975  0.99902558  1.68425947]
# det: 1.00
#
# iteration 18
# 1: 1012758 valid, 103301 out-of-bound voxels after transform.
# 2: 979917 valid, 404024 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.138739
# Norm of gradient (rotation) = 0.145073
# around x=-0.78; around y=-2.48; around z=2.17
# step: 0.78 seconds
# current score: 0.221452
# new_T: [ 0.99834824 -0.03727928 -0.04371548 -4.45565928  0.03783816  0.9992115
#   0.0120273   1.3095051   0.04323264 -0.01366155  0.99897162  1.70958659]
# det: 1.00
#
# iteration 19
# 1: 1011976 valid, 104083 out-of-bound voxels after transform.
# 2: 979538 valid, 404403 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.132573
# Norm of gradient (rotation) = 0.137438
# around x=-0.83; around y=-2.53; around z=2.20
# step: 0.78 seconds
# current score: 0.220401
# new_T: [ 0.99828597 -0.03778737 -0.04469038 -4.5566457   0.03839539  0.99918031
#   0.01282582  1.39213644  0.0441691  -0.01451974  0.99891855  1.73356014]
# det: 1.00
#
# iteration 20
# 1: 1011249 valid, 104810 out-of-bound voxels after transform.
# 2: 979132 valid, 404809 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.127028
# Norm of gradient (rotation) = 0.130830
# around x=-0.88; around y=-2.58; around z=2.23
# step: 0.78 seconds
# current score: 0.219385
# new_T: [ 0.99822603 -0.03825005 -0.04562591 -4.65365046  0.03890663  0.99915043
#   0.01359003  1.47111123  0.04506733 -0.01534107  0.99886615  1.75644284]
# det: 1.00
#
# iteration 21
# 1: 1010553 valid, 105506 out-of-bound voxels after transform.
# 2: 978738 valid, 405203 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.122025
# Norm of gradient (rotation) = 0.125326
# around x=-0.92; around y=-2.63; around z=2.26
# step: 0.78 seconds
# current score: 0.218448
# new_T: [ 0.99816773 -0.03867832 -0.04653136 -4.74761629  0.03938282  0.99912158
#   0.01431975  1.54636545  0.04593662 -0.01612605  0.99881419  1.77758524]
# det: 1.00
#
# iteration 22
# 1: 1009905 valid, 106154 out-of-bound voxels after transform.
# 2: 978340 valid, 405601 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.116874
# Norm of gradient (rotation) = 0.119735
# around x=-0.97; around y=-2.68; around z=2.29
# step: 0.78 seconds
# current score: 0.217566
# new_T: [ 0.99811085 -0.03907641 -0.04741059 -4.83893068  0.03982768  0.99909388
#   0.01500582  1.61694557  0.04678126 -0.01686573  0.99876277  1.79753296]
# det: 1.00
#
# iteration 23
# 1: 1009287 valid, 106772 out-of-bound voxels after transform.
# 2: 977964 valid, 405977 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.111631
# Norm of gradient (rotation) = 0.113684
# around x=-1.01; around y=-2.73; around z=2.31
# step: 0.78 seconds
# current score: 0.216754
# new_T: [ 0.99805618 -0.03943565 -0.04825661 -4.92688148  0.0402325   0.99906772
#   0.01565388  1.68345812  0.0475943  -0.01756494  0.9987123   1.81662611]
# det: 1.00
#
# iteration 24
# 1: 1008671 valid, 107388 out-of-bound voxels after transform.
# 2: 977618 valid, 406323 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.106193
# Norm of gradient (rotation) = 0.107283
# around x=-1.05; around y=-2.77; around z=2.33
# step: 0.78 seconds
# current score: 0.215993
# new_T: [ 0.99800458 -0.03974685 -0.04906163 -5.01068056  0.04058816  0.99904345
#   0.01627234  1.74676637  0.04836792 -0.01823119  0.99866319  1.83442363]
# det: 1.00
#
# iteration 25
# 1: 1008078 valid, 107981 out-of-bound voxels after transform.
# 2: 977298 valid, 406643 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.100504
# Norm of gradient (rotation) = 0.100458
# around x=-1.08; around y=-2.81; around z=2.35
# step: 0.78 seconds
# current score: 0.215269
# new_T: [ 0.99795675 -0.04000343 -0.04982028 -5.08978185  0.04088793  0.99902143
#   0.01686269  1.80704421  0.04909696 -0.01886529  0.99861584  1.85127894]
# det: 1.00
#
# iteration 26
# 1: 1007551 valid, 108508 out-of-bound voxels after transform.
# 2: 977011 valid, 406930 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.094823
# Norm of gradient (rotation) = 0.093839
# around x=-1.12; around y=-2.85; around z=2.36
# step: 0.78 seconds
# current score: 0.214567
# new_T: [ 0.99791274 -0.04020625 -0.05053335 -5.16426579  0.04113249  0.99900175
#   0.01742463  1.86424845  0.04978233 -0.01946682  0.99857036  1.86705853]
# det: 1.00
#
# iteration 27
# 1: 1007062 valid, 108997 out-of-bound voxels after transform.
# 2: 976750 valid, 407191 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.089573
# Norm of gradient (rotation) = 0.087750
# around x=-1.15; around y=-2.89; around z=2.37
# step: 0.78 seconds
# current score: 0.213921
# new_T: [ 0.99787235 -0.0403596  -0.05120417 -5.2344659   0.04132608  0.99898431
#   0.01795837  1.91843823  0.05042737 -0.02003623  0.99852673  1.88237599]
# det: 1.00
#
# iteration 28
# 1: 1006627 valid, 109432 out-of-bound voxels after transform.
# 2: 976499 valid, 407442 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.084928
# Norm of gradient (rotation) = 0.082556
# around x=-1.18; around y=-2.93; around z=2.38
# step: 0.78 seconds
# current score: 0.213292
# new_T: [ 0.99783538 -0.04046728 -0.05183581 -5.30069488  0.04147277  0.99896889
#   0.01847062  1.97031641  0.05103491 -0.02058041  0.99848479  1.8969578 ]
# det: 1.00
#
# iteration 29
# 1: 1006245 valid, 109814 out-of-bound voxels after transform.
# 2: 976232 valid, 407709 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.080486
# Norm of gradient (rotation) = 0.077828
# around x=-1.21; around y=-2.96; around z=2.39
# step: 0.78 seconds
# current score: 0.212720
# new_T: [ 0.99780169 -0.04053181 -0.05243055 -5.36318394  0.04157508  0.99895542
#   0.01896254  2.01999569  0.05160719 -0.02110066  0.99844452  1.91059929]
# det: 1.00
#
# iteration 30
# 1: 1005892 valid, 110167 out-of-bound voxels after transform.
# 2: 975983 valid, 407958 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.076359
# Norm of gradient (rotation) = 0.073583
# around x=-1.24; around y=-2.99; around z=2.39
# step: 0.78 seconds
# current score: 0.212192
# new_T: [ 0.99777113 -0.04055571 -0.05299054 -5.42215364  0.04163558  0.99894381
#   0.01943565  2.06764735  0.05214635 -0.02159863  0.99840586  1.92347352]
# det: 1.00
#
# iteration 31
# 1: 1005552 valid, 110507 out-of-bound voxels after transform.
# 2: 975749 valid, 408192 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.072674
# Norm of gradient (rotation) = 0.069926
# around x=-1.27; around y=-3.02; around z=2.39
# step: 0.78 seconds
# current score: 0.211695
# new_T: [ 0.99774338 -0.04054381 -0.05351966 -5.4779944   0.04165916  0.99893386
#   0.01989111  2.11341003  0.05265613 -0.02207581  0.99836866  1.93582118]
# det: 1.00
#
# iteration 32
# 1: 1005222 valid, 110837 out-of-bound voxels after transform.
# 2: 975536 valid, 408405 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.069008
# Norm of gradient (rotation) = 0.066564
# around x=-1.29; around y=-3.05; around z=2.39
# step: 0.78 seconds
# current score: 0.211231
# new_T: [ 0.99771825 -0.04049853 -0.05401998 -5.53092023  0.04164818  0.99892552
#   0.02032819  2.15718389  0.05313867 -0.02253164  0.99833291  1.94725596]
# det: 1.00
#
# iteration 33
# 1: 1004913 valid, 111146 out-of-bound voxels after transform.
# 2: 975347 valid, 408594 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.065646
# Norm of gradient (rotation) = 0.063564
# around x=-1.32; around y=-3.07; around z=2.39
# step: 0.77 seconds
# current score: 0.210851
# new_T: [ 0.99769534 -0.04042535 -0.05449594 -5.58137821  0.04160805  0.99891862
#   0.02074515  2.19879934  0.05359838 -0.02296481  0.99829847  1.95805795]
# det: 1.00
#
# iteration 34
# 1: 1004625 valid, 111434 out-of-bound voxels after transform.
# 2: 975154 valid, 408787 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.062252
# Norm of gradient (rotation) = 0.060693
# around x=-1.34; around y=-3.10; around z=2.38
# step: 0.78 seconds
# current score: 0.210497
# new_T: [ 0.99767485 -0.04032197 -0.05494577 -5.62918959  0.04153646  0.99891325
#   0.02114315  2.23838415  0.05403352 -0.02337624  0.99826546  1.9683596 ]
# det: 1.00
#
# iteration 35
# 1: 1004360 valid, 111699 out-of-bound voxels after transform.
# 2: 975011 valid, 408930 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.059298
# Norm of gradient (rotation) = 0.058362
# around x=-1.36; around y=-3.12; around z=2.38
# step: 0.78 seconds
# current score: 0.210211
# new_T: [ 0.99765644 -0.04019282 -0.05537295 -5.67470612  0.04143797  0.9989092
#   0.02152472  2.27621021  0.05444741 -0.02376882  0.9982337   1.97816342]
# det: 1.00
#
# iteration 36
# 1: 1004113 valid, 111946 out-of-bound voxels after transform.
# 2: 974880 valid, 409061 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.056050
# Norm of gradient (rotation) = 0.055930
# around x=-1.39; around y=-3.14; around z=2.37
# step: 0.78 seconds
# current score: 0.209978
# new_T: [ 0.9976404  -0.04003476 -0.05577503 -5.71767948  0.04130922  0.99890665
#   0.02188718  2.31200497  0.0548378  -0.02413956  0.99820343  1.98776037]
# det: 1.00
#
# iteration 37
# 1: 1003900 valid, 112159 out-of-bound voxels after transform.
# 2: 974761 valid, 409180 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.053048
# Norm of gradient (rotation) = 0.053911
# around x=-1.41; around y=-3.16; around z=2.36
# step: 0.78 seconds
# current score: 0.209776
# new_T: [ 0.99762657 -0.03984991 -0.05615355 -5.75826563  0.04115241  0.9989055
#   0.02223257  2.34598317  0.05520612 -0.02449065  0.99817458  1.99711532]
# det: 1.00
#
# iteration 38
# 1: 1003696 valid, 112363 out-of-bound voxels after transform.
# 2: 974654 valid, 409287 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.050124
# Norm of gradient (rotation) = 0.052203
# around x=-1.42; around y=-3.18; around z=2.35
# step: 0.78 seconds
# current score: 0.209611
# new_T: [ 0.99761495 -0.03963841 -0.05650847 -5.79646073  0.04096771  0.9989057
#   0.02256228  2.37829373  0.0555523  -0.02482349  0.99814715  2.00618544]
# det: 1.00
#
# iteration 39
# 1: 1003525 valid, 112534 out-of-bound voxels after transform.
# 2: 974568 valid, 409373 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.047214
# Norm of gradient (rotation) = 0.050574
# around x=-1.44; around y=-3.20; around z=2.34
# step: 0.78 seconds
# current score: 0.209469
# new_T: [ 0.99760547 -0.03940128 -0.05684064 -5.83234986  0.04075594  0.99890729
#   0.02287321  2.40863282  0.05587729 -0.02513503  0.99812121  2.01548663]
# det: 1.00
#
# iteration 40
# 1: 1003369 valid, 112690 out-of-bound voxels after transform.
# 2: 974488 valid, 409453 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.044320
# Norm of gradient (rotation) = 0.049366
# around x=-1.46; around y=-3.22; around z=2.33
# step: 0.77 seconds
# current score: 0.209368
# new_T: [ 0.9975982  -0.039138   -0.0571494  -5.86586711  0.04051672  0.99891022
#   0.02316831  2.43729079  0.05618036 -0.02542817  0.99809678  2.02456823]
# det: 1.00
#
# iteration 41
# 1: 1003244 valid, 112815 out-of-bound voxels after transform.
# 2: 974421 valid, 409520 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.041495
# Norm of gradient (rotation) = 0.048581
# around x=-1.48; around y=-3.24; around z=2.31
# step: 0.77 seconds
# current score: 0.209277
# new_T: [ 0.99759307 -0.03884917 -0.05743522 -5.89705943  0.04025074  0.9989144
#   0.02345015  2.46451693  0.05646185 -0.02570551  0.99807379  2.03298067]
# det: 1.00
#
# iteration 42
# 1: 1003134 valid, 112925 out-of-bound voxels after transform.
# 2: 974347 valid, 409594 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.038607
# Norm of gradient (rotation) = 0.047931
# around x=-1.49; around y=-3.25; around z=2.29
# step: 0.78 seconds
# current score: 0.209201
# new_T: [ 0.99759007 -0.03853515 -0.05769833 -5.92594905  0.0399582   0.99891986
#   0.02371615  2.49005175  0.0567221  -0.02596452  0.99805233  2.04100975]
# det: 1.00
#
# iteration 43
# 1: 1003053 valid, 113006 out-of-bound voxels after transform.
# 2: 974292 valid, 409649 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.035988
# Norm of gradient (rotation) = 0.047722
# around x=-1.50; around y=-3.27; around z=2.28
# step: 0.78 seconds
# current score: 0.209161
# new_T: [ 0.99758903 -0.03819787 -0.05794009 -5.95267612  0.03964129  0.99892642
#   0.02397049  2.51432131  0.05696226 -0.02620951  0.99803224  2.0482949 ]
# det: 1.00
#
# iteration 44
# 1: 1002985 valid, 113074 out-of-bound voxels after transform.
# 2: 974244 valid, 409697 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.033365
# Norm of gradient (rotation) = 0.047588
# around x=-1.52; around y=-3.28; around z=2.26
# step: 0.77 seconds
# current score: 0.209139
# new_T: [ 0.9975898  -0.0378391  -0.05816181 -5.97737105  0.03930164  0.99893404
#   0.02421097  2.53709715  0.05718369 -0.02643847  0.99801354  2.05495242]
# det: 1.00
#
# iteration 45
# 1: 1002934 valid, 113125 out-of-bound voxels after transform.
# 2: 974214 valid, 409727 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.030777
# Norm of gradient (rotation) = 0.047789
# around x=-1.53; around y=-3.29; around z=2.24
# step: 0.78 seconds
# current score: 0.209163
# new_T: [ 0.99759246 -0.03745792 -0.05836262 -5.9999458   0.03893839  0.9989427
#   0.0244392   2.55855084  0.05738547 -0.02665291  0.99799626  2.06097953]
# det: 1.00
#
# iteration 46
# 1: 1002902 valid, 113157 out-of-bound voxels after transform.
# 2: 974196 valid, 409745 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.028473
# Norm of gradient (rotation) = 0.047974
# around x=-1.54; around y=-3.30; around z=2.21
# step: 0.78 seconds
# current score: 0.209222
# new_T: [ 0.99759663 -0.03705846 -0.05854592 -6.02074412  0.0385557   0.99895227
#   0.02465418  2.57858964  0.05757093 -0.0268522   0.99798023  2.06666787]
# det: 1.00
#
# iteration 47
# 1: 1002880 valid, 113179 out-of-bound voxels after transform.
# 2: 974178 valid, 409763 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.026223
# Norm of gradient (rotation) = 0.048516
# around x=-1.55; around y=-3.31; around z=2.19
# step: 0.78 seconds
# current score: 0.209268
# new_T: [ 0.99760245 -0.03663943 -0.05871036 -6.03963111  0.03815237  0.99896268
#   0.02485898  2.5975351   0.05773864 -0.02703932  0.99796549  2.0718738 ]
# det: 1.00
#
# iteration 48
# 1: 1002863 valid, 113196 out-of-bound voxels after transform.
# 2: 974163 valid, 409778 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.024070
# Norm of gradient (rotation) = 0.049224
# around x=-1.56; around y=-3.32; around z=2.17
# step: 0.78 seconds
# current score: 0.209333
# new_T: [ 0.99760985 -0.03620124 -0.05885623 -6.05663363  0.03772888  0.99897388
#   0.02505436  2.61547141  0.05788883 -0.02721506  0.99795201  2.07668806]
# det: 1.00
#
# iteration 49
# 1: 1002864 valid, 113195 out-of-bound voxels after transform.
# 2: 974183 valid, 409758 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.022017
# Norm of gradient (rotation) = 0.049925
# around x=-1.57; around y=-3.33; around z=2.14
# step: 0.78 seconds
# current score: 0.209460
# new_T: [ 0.9976187  -0.03574543 -0.05898477 -6.07187845  0.03728665  0.99898585
#   0.02523844  2.6322202   0.05802279 -0.02737769  0.99793979  2.0815204 ]
# det: 1.00
#
# iteration 50
# 1: 1002879 valid, 113180 out-of-bound voxels after transform.
# 2: 974196 valid, 409745 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.020095
# Norm of gradient (rotation) = 0.050888
# around x=-1.58; around y=-3.33; around z=2.11
# step: 0.78 seconds
# current score: 0.209617
# new_T: [ 0.99762898 -0.03527208 -0.05909573 -6.08534108  0.03682603  0.99899844
#   0.02541581  2.64824608  0.05814008 -0.02753181  0.99792872  2.08583762]
# det: 1.00
#
# iteration 51
# 1: 1002896 valid, 113163 out-of-bound voxels after transform.
# 2: 974229 valid, 409712 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.018319
# Norm of gradient (rotation) = 0.051620
# around x=-1.59; around y=-3.34; around z=2.09
# step: 0.78 seconds
# current score: 0.209775
# new_T: [ 0.99764042 -0.0347841  -0.05919163 -6.09727375  0.03634974  0.99901164
#   0.02558215  2.66312732  0.05824327 -0.02767339  0.99791879  2.09040598]
# det: 1.00
#
# iteration 52
# 1: 1002934 valid, 113125 out-of-bound voxels after transform.
# 2: 974267 valid, 409674 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.016667
# Norm of gradient (rotation) = 0.052492
# around x=-1.60; around y=-3.34; around z=2.06
# step: 0.78 seconds
# current score: 0.209962
# new_T: [ 0.997653   -0.03428197 -0.05927252 -6.10768565  0.03585844  0.99902532
#   0.02574074  2.67719813  0.05833231 -0.02780574  0.99790991  2.09485739]
# det: 1.00
#
# iteration 53
# 1: 1002987 valid, 113072 out-of-bound voxels after transform.
# 2: 974314 valid, 409627 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.015063
# Norm of gradient (rotation) = 0.053425
# around x=-1.60; around y=-3.35; around z=2.03
# step: 0.78 seconds
# current score: 0.210176
# new_T: [ 0.9976667  -0.03376554 -0.05933834 -6.11656759  0.03535188  0.99903951
#   0.0258902   2.69032892  0.05840715 -0.02792751  0.99790213  2.09954587]
# det: 1.00
#
# iteration 54
# 1: 1003051 valid, 113008 out-of-bound voxels after transform.
# 2: 974370 valid, 409571 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.013520
# Norm of gradient (rotation) = 0.054444
# around x=-1.61; around y=-3.35; around z=2.00
# step: 0.78 seconds
# current score: 0.210409
# new_T: [ 0.99768146 -0.03323543 -0.05938942 -6.12395613  0.03483087  0.99905409
#   0.02603349  2.7028114   0.05846801 -0.02804171  0.99789536  2.10397479]
# det: 1.00
#
# iteration 55
# 1: 1003128 valid, 112931 out-of-bound voxels after transform.
# 2: 974432 valid, 409509 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.012212
# Norm of gradient (rotation) = 0.055268
# around x=-1.62; around y=-3.35; around z=1.97
# step: 0.78 seconds
# current score: 0.210661
# new_T: [ 0.99769706 -0.03269415 -0.05942778 -6.13005388  0.03429787  0.99906898
#   0.02616908  2.71450364  0.05851687 -0.02814706  0.99788953  2.10856634]
# det: 1.00
#
# iteration 56
# 1: 1003212 valid, 112847 out-of-bound voxels after transform.
# 2: 974513 valid, 409428 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.010662
# Norm of gradient (rotation) = 0.056188
# around x=-1.62; around y=-3.36; around z=1.94
# step: 0.78 seconds
# current score: 0.210917
# new_T: [ 0.99771355 -0.03214103 -0.05945272 -6.13479238  0.03375214  0.99908424
#   0.02629594  2.72527947  0.0585531  -0.02824248  0.99788471  2.11297454]
# det: 1.00
#
# iteration 57
# 1: 1003315 valid, 112744 out-of-bound voxels after transform.
# 2: 974603 valid, 409338 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.009507
# Norm of gradient (rotation) = 0.057098
# around x=-1.63; around y=-3.36; around z=1.91
# step: 0.78 seconds
# current score: 0.211230
# new_T: [ 0.99773081 -0.03157718 -0.05946519 -6.1382657   0.03319495  0.99909972
#   0.02641668  2.73542803  0.05857749 -0.02833068  0.99788078  2.11741853]
# det: 1.00
#
# iteration 58
# 1: 1003425 valid, 112634 out-of-bound voxels after transform.
# 2: 974688 valid, 409253 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.008093
# Norm of gradient (rotation) = 0.057915
# around x=-1.63; around y=-3.36; around z=1.87
# step: 0.78 seconds
# current score: 0.211535
# new_T: [ 0.99774876 -0.0310037  -0.05946574 -6.14053264  0.03262731  0.99911543
#   0.02652939  2.74472708  0.05859063 -0.02840987  0.99787776  2.1215258 ]
# det: 1.00
#
# iteration 59
# 1: 1003534 valid, 112525 out-of-bound voxels after transform.
# 2: 974802 valid, 409139 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.006837
# Norm of gradient (rotation) = 0.058532
# around x=-1.63; around y=-3.36; around z=1.84
# step: 0.78 seconds
# current score: 0.211857
# new_T: [ 0.99776722 -0.03042248 -0.05945621 -6.14177783  0.03205092  0.99913142
#   0.02662979  2.75274533  0.05859443 -0.02847596  0.99787565  2.12580044]
# det: 1.00
#
# iteration 60
# 1: 1003663 valid, 112396 out-of-bound voxels after transform.
# 2: 974909 valid, 409032 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.006127
# Norm of gradient (rotation) = 0.059031
# around x=-1.64; around y=-3.36; around z=1.81
# step: 0.78 seconds
# current score: 0.212199
# new_T: [ 0.99778602 -0.02983562 -0.0594382  -6.14216353  0.0314682   0.99914746
#   0.0267227   2.75999876  0.05859024 -0.02853395  0.99787424  2.13024734]
# det: 1.00
#
# iteration 61
# 1: 1003802 valid, 112257 out-of-bound voxels after transform.
# 2: 975026 valid, 408915 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.004998
# Norm of gradient (rotation) = 0.059881
# around x=-1.64; around y=-3.36; around z=1.77
# step: 0.78 seconds
# current score: 0.212559
# new_T: [ 0.99780539 -0.02923997 -0.059409   -6.14141691  0.03087595  0.99916364
#   0.02680852  2.76649854  0.05857543 -0.02858399  0.99787368  2.13427224]
# det: 1.00
#
# iteration 62
# 1: 1003932 valid, 112127 out-of-bound voxels after transform.
# 2: 975140 valid, 408801 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.004062
# Norm of gradient (rotation) = 0.060780
# around x=-1.64; around y=-3.36; around z=1.74
# step: 0.78 seconds
# current score: 0.212899
# new_T: [ 0.99782535 -0.02863531 -0.05936826 -6.1395008   0.03027385  0.99917998
#   0.02688622  2.77213773  0.05854968 -0.02862506  0.99787401  2.1379289 ]
# det: 1.00
#
# iteration 63
# 1: 1004083 valid, 111976 out-of-bound voxels after transform.
# 2: 975261 valid, 408680 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.003634
# Norm of gradient (rotation) = 0.061399
# around x=-1.64; around y=-3.35; around z=1.70
# step: 0.77 seconds
# current score: 0.213276
# new_T: [ 0.99784565 -0.02802454 -0.05931856 -6.13667885  0.02966487  0.99919639
#   0.02695511  2.77685239  0.05851549 -0.02865672  0.99787511  2.14140575]
# det: 1.00
#
# iteration 64
# 1: 1004248 valid, 111811 out-of-bound voxels after transform.
# 2: 975380 valid, 408561 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.003757
# Norm of gradient (rotation) = 0.061963
# around x=-1.65; around y=-3.35; around z=1.67
# step: 0.77 seconds
# current score: 0.213659
# new_T: [ 0.99786621 -0.02740838 -0.05926045 -6.13300548  0.02904964  0.99921288
#   0.02701376  2.78049745  0.0584734  -0.02867761  0.99787697  2.14485324]
# det: 1.00
#
# iteration 65
# 1: 1004412 valid, 111647 out-of-bound voxels after transform.
# 2: 975513 valid, 408428 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.004005
# Norm of gradient (rotation) = 0.062763
# around x=-1.65; around y=-3.35; around z=1.63
# step: 0.77 seconds
# current score: 0.214051
# new_T: [ 0.99788719 -0.02678498 -0.05919229 -6.1283154   0.02842644  0.99922941
#   0.02706516  2.78336744  0.05842174 -0.0286906   0.99787963  2.1477714 ]
# det: 1.00
#
# iteration 66
# 1: 1004590 valid, 111469 out-of-bound voxels after transform.
# 2: 975657 valid, 408284 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.004792
# Norm of gradient (rotation) = 0.063345
# around x=-1.65; around y=-3.35; around z=1.60
# step: 0.78 seconds
# current score: 0.214470
# new_T: [ 0.99790839 -0.02615656 -0.05911578 -6.12277879  0.02779757  0.9992459
#   0.02710944  2.78550421  0.05836211 -0.02869601  0.99788296  2.15068458]
# det: 1.00
#
# iteration 67
# 1: 1004763 valid, 111296 out-of-bound voxels after transform.
# 2: 975794 valid, 408147 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.006199
# Norm of gradient (rotation) = 0.064266
# around x=-1.65; around y=-3.34; around z=1.56
# step: 0.78 seconds
# current score: 0.214881
# new_T: [ 0.99793003 -0.02552022 -0.05902865 -6.11616504  0.02715982  0.99926254
#   0.02714268  2.78650427  0.05829243 -0.0286897   0.99788721  2.15396917]
# det: 1.00
#
# iteration 68
# 1: 1004973 valid, 111086 out-of-bound voxels after transform.
# 2: 975911 valid, 408030 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.006473
# Norm of gradient (rotation) = 0.064852
# around x=-1.65; around y=-3.34; around z=1.52
# step: 0.77 seconds
# current score: 0.215310
# new_T: [ 0.99795186 -0.02487916 -0.05893319 -6.10871032  0.02651707  0.9992789
#   0.02717566  2.78745104  0.05821459 -0.02868273  0.99789196  2.15615543]
# det: 1.00
#
# iteration 69
# 1: 1005165 valid, 110894 out-of-bound voxels after transform.
# 2: 976098 valid, 407843 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.007524
# Norm of gradient (rotation) = 0.065628
# around x=-1.65; around y=-3.33; around z=1.48
# step: 0.77 seconds
# current score: 0.215747
# new_T: [ 0.99797398 -0.02423181 -0.05882826 -6.10029448  0.02586739  0.99929522
#   0.02720204  2.78770582  0.05812764 -0.02866866  0.99789743  2.15808643]
# det: 1.00
#
# iteration 70
# 1: 1005366 valid, 110693 out-of-bound voxels after transform.
# 2: 976262 valid, 407679 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.008638
# Norm of gradient (rotation) = 0.065669
# around x=-1.64; around y=-3.33; around z=1.45
# step: 0.78 seconds
# current score: 0.216215
# new_T: [ 0.99799587 -0.02358504 -0.05871961 -6.09150325  0.02521738  0.99931148
#   0.0272148   2.78655824  0.05803732 -0.02864101  0.99790348  2.16046192]
# det: 1.00
#
# iteration 71
# 1: 1005586 valid, 110473 out-of-bound voxels after transform.
# 2: 976427 valid, 407514 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.009145
# Norm of gradient (rotation) = 0.066119
# around x=-1.64; around y=-3.32; around z=1.41
# step: 0.78 seconds
# current score: 0.216693
# new_T: [ 0.99801783 -0.02293494 -0.05860383 -6.08198965  0.02456384  0.99932742
#   0.02722747  2.78541763  0.05793995 -0.02861304  0.99790994  2.1625633 ]
# det: 1.00
#
# iteration 72
# 1: 1005800 valid, 110259 out-of-bound voxels after transform.
# 2: 976583 valid, 407358 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.009881
# Norm of gradient (rotation) = 0.066650
# around x=-1.64; around y=-3.32; around z=1.37
# step: 0.78 seconds
# current score: 0.217156
# new_T: [ 0.99803989 -0.022281   -0.05848023 -6.07168251  0.02390608  0.99934309
#   0.02723753  2.78401214  0.05783493 -0.02858218  0.99791692  2.16433743]
# det: 1.00
#
# iteration 73
# 1: 1006015 valid, 110044 out-of-bound voxels after transform.
# 2: 976738 valid, 407203 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.010537
# Norm of gradient (rotation) = 0.066853
# around x=-1.64; around y=-3.31; around z=1.33
# step: 0.78 seconds
# current score: 0.217625
# new_T: [ 0.99806183 -0.02162618 -0.05835145 -6.06085018  0.02324704  0.99935849
#   0.02724302  2.78213814  0.05772485 -0.02854672  0.99792431  2.16593837]
# det: 1.00
#
# iteration 74
# 1: 1006229 valid, 109830 out-of-bound voxels after transform.
# 2: 976902 valid, 407039 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.011227
# Norm of gradient (rotation) = 0.067045
# around x=-1.64; around y=-3.30; around z=1.30
# step: 0.78 seconds
# current score: 0.218108
# new_T: [ 0.99808363 -0.02097068 -0.05821771 -6.04951437  0.02258687  0.99937362
#   0.02724331  2.77974044  0.05760993 -0.02850606  0.99793211  2.16758127]
# det: 1.00
#
# iteration 75
# 1: 1006447 valid, 109612 out-of-bound voxels after transform.
# 2: 977072 valid, 406869 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.011889
# Norm of gradient (rotation) = 0.067318
# around x=-1.63; around y=-3.30; around z=1.26
# step: 0.78 seconds
# current score: 0.218601
# new_T: [ 0.99810534 -0.02031379 -0.05807828 -6.03760215  0.02192495  0.99938846
#   0.02723987  2.77697425  0.05748942 -0.02846163  0.99794033  2.16920387]
# det: 1.00
#
# iteration 76
# 1: 1006674 valid, 109385 out-of-bound voxels after transform.
# 2: 977242 valid, 406699 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.012609
# Norm of gradient (rotation) = 0.067672
# around x=-1.63; around y=-3.29; around z=1.22
# step: 0.78 seconds
# current score: 0.219075
# new_T: [ 0.99812699 -0.01965488 -0.05793274 -6.02507025  0.02126061  0.99940302
#   0.02723228  2.77377947  0.05736291 -0.02841296  0.997949    2.17056572]
# det: 1.00
#
# iteration 77
# 1: 1006914 valid, 109145 out-of-bound voxels after transform.
# 2: 977402 valid, 406539 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.013253
# Norm of gradient (rotation) = 0.067919
# around x=-1.63; around y=-3.28; around z=1.18
# step: 0.78 seconds
# current score: 0.219552
# new_T: [ 0.99814851 -0.01899489 -0.05778186 -6.0119965   0.02059483  0.99941727
#   0.02722084  2.77020429  0.05723113 -0.02836045  0.99795806  2.17191431]
# det: 1.00
#
# iteration 78
# 1: 1007153 valid, 108906 out-of-bound voxels after transform.
# 2: 977602 valid, 406339 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.013686
# Norm of gradient (rotation) = 0.067938
# around x=-1.62; around y=-3.27; around z=1.14
# step: 0.78 seconds
# current score: 0.220081
# new_T: [ 0.99816977 -0.01833574 -0.05762732 -5.99855175  0.01992964  0.99943114
#   0.02720682  2.76636988  0.05709568 -0.02830551  0.99796737  2.173001  ]
# det: 1.00
#
# iteration 79
# 1: 1007404 valid, 108655 out-of-bound voxels after transform.
# 2: 977786 valid, 406155 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.014275
# Norm of gradient (rotation) = 0.068024
# around x=-1.62; around y=-3.27; around z=1.11
# step: 0.78 seconds
# current score: 0.220574
# new_T: [ 0.9981908  -0.01767705 -0.05746872 -5.98469462  0.01926455  0.99944469
#   0.02718804  2.76207845  0.0569562  -0.02824596  0.99797703  2.17445305]
# det: 1.00
#
# iteration 80
# 1: 1007654 valid, 108405 out-of-bound voxels after transform.
# 2: 977970 valid, 405971 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.014728
# Norm of gradient (rotation) = 0.068144
# around x=-1.62; around y=-3.26; around z=1.07
# step: 0.78 seconds
# current score: 0.221066
# new_T: [ 0.99821162 -0.01701834 -0.05730565 -5.970384    0.01859924  0.99945785
#   0.02716757  2.75761123  0.05681223 -0.02818483  0.99798697  2.17540711]
# det: 1.00
#
# iteration 81
# 1: 1007897 valid, 108162 out-of-bound voxels after transform.
# 2: 978139 valid, 405802 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.015079
# Norm of gradient (rotation) = 0.068025
# around x=-1.61; around y=-3.25; around z=1.03
# step: 0.78 seconds
# current score: 0.221550
# new_T: [ 0.9982321  -0.0163617  -0.05713999 -5.95581246  0.0179358   0.9994706
#   0.0271447   2.75289673  0.05666561 -0.02812157  0.99799709  2.17595956]
# det: 1.00
#
# iteration 82
# 1: 1008144 valid, 107915 out-of-bound voxels after transform.
# 2: 978322 valid, 405619 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.015457
# Norm of gradient (rotation) = 0.067962
# around x=-1.61; around y=-3.24; around z=0.99
# step: 0.78 seconds
# current score: 0.222040
# new_T: [ 0.99825225 -0.01570674 -0.05697137 -5.94093738  0.0172738   0.99948296
#   0.02711872  2.74792075  0.05651597 -0.02805544  0.99800743  2.17727175]
# det: 1.00
#
# iteration 83
# 1: 1008403 valid, 107656 out-of-bound voxels after transform.
# 2: 978496 valid, 405445 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.015766
# Norm of gradient (rotation) = 0.067846
# around x=-1.61; around y=-3.23; around z=0.95
# step: 0.78 seconds
# current score: 0.222541
# new_T: [ 0.99827208 -0.01505384 -0.05680002 -5.92578516  0.01661371  0.99949491
#   0.02709092  2.74277713  0.05636351 -0.02798777  0.99801796  2.17846604]
# det: 1.00
#
# iteration 84
# 1: 1008656 valid, 107403 out-of-bound voxels after transform.
# 2: 978665 valid, 405276 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.016002
# Norm of gradient (rotation) = 0.067681
# around x=-1.60; around y=-3.22; around z=0.92
# step: 0.78 seconds
# current score: 0.223031
# new_T: [ 0.99829153 -0.01440331 -0.05662651 -5.91041376  0.01595588  0.99950641
#   0.02706189  2.73751899  0.05620878 -0.02791919  0.9980286   2.17941457]
# det: 1.00
#
# iteration 85
# 1: 1008916 valid, 107143 out-of-bound voxels after transform.
# 2: 978842 valid, 405099 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.016326
# Norm of gradient (rotation) = 0.067437
# around x=-1.60; around y=-3.21; around z=0.88
# step: 0.78 seconds
# current score: 0.223524
# new_T: [ 0.99831057 -0.01375609 -0.05645161 -5.89489921  0.01530112  0.99951755
#   0.02702875  2.73187285  0.05605256 -0.02784685  0.99803941  2.18075451]
# det: 1.00
#
# iteration 86
# 1: 1009159 valid, 106900 out-of-bound voxels after transform.
# 2: 979029 valid, 404912 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.016611
# Norm of gradient (rotation) = 0.067196
# around x=-1.59; around y=-3.20; around z=0.84
# step: 0.78 seconds
# current score: 0.224040
# new_T: [ 0.9983292  -0.01311205 -0.05627515 -5.87922676  0.01464937  0.99952828
#   0.02699284  2.72593632  0.05589467 -0.02777213  0.99805035  2.18158202]
# det: 1.00
#
# iteration 87
# 1: 1009410 valid, 106649 out-of-bound voxels after transform.
# 2: 979229 valid, 404712 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.016974
# Norm of gradient (rotation) = 0.067190
# around x=-1.59; around y=-3.19; around z=0.80
# step: 0.78 seconds
# current score: 0.224551
# new_T: [ 0.99834755 -0.01246913 -0.05609545 -5.86322552  0.01399859  0.99953862
#   0.02695543  2.7198433   0.05573346 -0.02769614  0.99806147  2.18195167]
# det: 1.00
#
# iteration 88
# 1: 1009654 valid, 106405 out-of-bound voxels after transform.
# 2: 979418 valid, 404523 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.017546
# Norm of gradient (rotation) = 0.067137
# around x=-1.58; around y=-3.19; around z=0.77
# step: 0.78 seconds
# current score: 0.225048
# new_T: [ 0.99836556 -0.01182818 -0.05591341 -5.84698397  0.01334937  0.99954868
#   0.0269114   2.71307341  0.05556986 -0.02761383  0.99807288  2.18235638]
# det: 1.00
#
# iteration 89
# 1: 1009890 valid, 106169 out-of-bound voxels after transform.
# 2: 979574 valid, 404367 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.018022
# Norm of gradient (rotation) = 0.067293
# around x=-1.58; around y=-3.18; around z=0.73
# step: 0.78 seconds
# current score: 0.225527
# new_T: [ 0.99838337 -0.01118707 -0.05572703 -5.8303021   0.01269979  0.99955838
#   0.02686543  2.70610636  0.05540188 -0.02752972  0.99808454  2.18244745]
# det: 1.00
#
# iteration 90
# 1: 1010121 valid, 105938 out-of-bound voxels after transform.
# 2: 979765 valid, 404176 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.018491
# Norm of gradient (rotation) = 0.067113
# around x=-1.57; around y=-3.17; around z=0.69
# step: 0.78 seconds
# current score: 0.226031
# new_T: [ 0.99840077 -0.01054892 -0.0555393  -5.81348118  0.01205287  0.99956778
#   0.02681394  2.69855816  0.05523244 -0.02744047  0.99809639  2.18216764]
# det: 1.00
#
# iteration 91
# 1: 1010351 valid, 105708 out-of-bound voxels after transform.
# 2: 979975 valid, 403966 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.019019
# Norm of gradient (rotation) = 0.067283
# around x=-1.57; around y=-3.16; around z=0.65
# step: 0.78 seconds
# current score: 0.226561
# new_T: [ 0.99841797 -0.00991062 -0.05534735 -5.79623138  0.01140554  0.99957683
#   0.02675964  2.69072219  0.05505873 -0.02734857  0.99810851  2.18161183]
# det: 1.00
#
# iteration 92
# 1: 1010585 valid, 105474 out-of-bound voxels after transform.
# 2: 980182 valid, 403759 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.019179
# Norm of gradient (rotation) = 0.066935
# around x=-1.56; around y=-3.15; around z=0.62
# step: 0.78 seconds
# current score: 0.227083
# new_T: [ 0.99843471 -0.00927645 -0.055155   -5.77893855  0.01076223  0.99958549
#   0.02670247  2.68262168  0.05488443 -0.02725427  0.99812069  2.18129511]
# det: 1.00
#
# iteration 93
# 1: 1010832 valid, 105227 out-of-bound voxels after transform.
# 2: 980367 valid, 403574 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.019708
# Norm of gradient (rotation) = 0.067056
# around x=-1.56; around y=-3.14; around z=0.58
# step: 0.79 seconds
# current score: 0.227576
# new_T: [ 0.99845122 -0.00864247 -0.05495884 -5.76126036  0.01011891  0.99959379
#   0.02664308  2.67426788  0.05470626 -0.02715794  0.99813309  2.18018389]
# det: 1.00
#
# iteration 94
# 1: 1011086 valid, 104973 out-of-bound voxels after transform.
# 2: 980578 valid, 403363 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.019938
# Norm of gradient (rotation) = 0.066768
# around x=-1.55; around y=-3.13; around z=0.54
# step: 0.78 seconds
# current score: 0.228112
# new_T: [ 0.99846728 -0.00801237 -0.05476224 -5.74353491  0.00947923  0.99960178
#   0.02657883  2.66546001  0.05452747 -0.0270572   0.99814561  2.17974213]
# det: 1.00
#
# iteration 95
# 1: 1011354 valid, 104705 out-of-bound voxels after transform.
# 2: 980777 valid, 403164 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.020121
# Norm of gradient (rotation) = 0.066525
# around x=-1.55; around y=-3.12; around z=0.51
# step: 0.78 seconds
# current score: 0.228612
# new_T: [ 0.99848294 -0.00738526 -0.05456434 -5.72567856  0.00884252  0.99960933
#   0.02651422  2.65661017  0.05434721 -0.02695649  0.99815817  2.17868034]
# det: 1.00
#
# iteration 96
# 1: 1011629 valid, 104430 out-of-bound voxels after transform.
# 2: 980967 valid, 402974 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.020248
# Norm of gradient (rotation) = 0.066363
# around x=-1.54; around y=-3.10; around z=0.47
# step: 0.78 seconds
# current score: 0.229131
# new_T: [ 0.99849827 -0.00676045 -0.05436456 -5.70763103  0.00820809  0.99961646
#   0.02644935  2.64776531  0.0541649  -0.02685586  0.99817079  2.17772584]
# det: 1.00
#
# iteration 97
# ...
# current score: 0.296419
# new_T: [ 0.99669185  0.08104651 -0.00606818 -2.32393235 -0.08107228  0.99669967
#  -0.00412929  0.30547732  0.00571348  0.0046076   0.99997306  1.91684824]
# det: 1.00
#
# iteration 967
# 1: 1052708 valid, 63351 out-of-bound voxels after transform.
# 2: 1007133 valid, 376808 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000899
# Norm of gradient (rotation) = 0.003112
# around x=0.27; around y=-0.33; around z=-4.65
# step: 0.80 seconds
# current score: 0.296436
# new_T: [ 0.9966912   0.08105615 -0.00604641 -2.32330281 -0.08108194  0.9966988
#  -0.00414927  0.30477959  0.00569013  0.0046258   0.99997311  1.91693752]
# det: 1.00
#
# iteration 968
# 1: 1052714 valid, 63345 out-of-bound voxels after transform.
# 2: 1007135 valid, 376806 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000937
# Norm of gradient (rotation) = 0.003145
# around x=0.27; around y=-0.32; around z=-4.65
# step: 0.80 seconds
# current score: 0.296450
# new_T: [ 0.99669054  0.08106587 -0.00602457 -2.3226644  -0.08109168  0.99669793
#  -0.00416963  0.30403813  0.00566666  0.00464437  0.99997316  1.91697303]
# det: 1.00
#
# iteration 969
# 1: 1052721 valid, 63338 out-of-bound voxels after transform.
# 2: 1007143 valid, 376798 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000913
# Norm of gradient (rotation) = 0.003122
# around x=0.27; around y=-0.32; around z=-4.65
# step: 0.80 seconds
# current score: 0.296472
# new_T: [ 0.99668988  0.08107558 -0.00600273 -2.32202779 -0.0811014   0.99669705
#  -0.00418965  0.30332972  0.00564323  0.00466261  0.99997321  1.91696632]
# det: 1.00
#
# iteration 970
# 1: 1052734 valid, 63325 out-of-bound voxels after transform.
# 2: 1007156 valid, 376785 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000923
# Norm of gradient (rotation) = 0.003120
# around x=0.27; around y=-0.32; around z=-4.65
# step: 0.80 seconds
# current score: 0.296499
# new_T: [ 0.99668924  0.0810851  -0.00598108 -2.32140984 -0.08111093  0.99669619
#  -0.00420992  0.3025928   0.00561996  0.00468111  0.99997325  1.91694981]
# det: 1.00
#
# iteration 971
# 1: 1052742 valid, 63317 out-of-bound voxels after transform.
# 2: 1007154 valid, 376787 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000903
# Norm of gradient (rotation) = 0.003100
# around x=0.27; around y=-0.32; around z=-4.65
# step: 0.80 seconds
# current score: 0.296504
# new_T: [ 0.99668859  0.08109461 -0.00595942 -2.32079034 -0.08112045  0.99669533
#  -0.00422989  0.3018871   0.0055967   0.00469931  0.9999733   1.91690592]
# det: 1.00
#
# iteration 972
# 1: 1052748 valid, 63311 out-of-bound voxels after transform.
# 2: 1007159 valid, 376782 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000885
# Norm of gradient (rotation) = 0.003088
# around x=0.27; around y=-0.32; around z=-4.65
# step: 0.80 seconds
# current score: 0.296519
# new_T: [ 0.99668793  0.08110436 -0.00593751 -2.32014664 -0.08113021  0.99669445
#  -0.00424928  0.30123956  0.00557325  0.00471691  0.99997334  1.91680532]
# det: 1.00
#
# iteration 973
# 1: 1052758 valid, 63301 out-of-bound voxels after transform.
# 2: 1007167 valid, 376774 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000915
# Norm of gradient (rotation) = 0.003114
# around x=0.27; around y=-0.32; around z=-4.65
# step: 0.80 seconds
# current score: 0.296534
# new_T: [ 0.99668728  0.08111398 -0.00591576 -2.3195184  -0.08113983  0.99669358
#  -0.00426931  0.30052551  0.0055499   0.00473518  0.99997339  1.91675918]
# det: 1.00
#
# iteration 974
# 1: 1052767 valid, 63292 out-of-bound voxels after transform.
# 2: 1007173 valid, 376768 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000871
# Norm of gradient (rotation) = 0.003057
# around x=0.27; around y=-0.32; around z=-4.65
# step: 0.80 seconds
# current score: 0.296550
# new_T: [ 0.99668665  0.08112319 -0.00589436 -2.31892676 -0.08114905  0.99669275
#  -0.00428905  0.29984213  0.00552693  0.00475316  0.99997343  1.9166977 ]
# det: 1.00
#
# iteration 975
# 1: 1052772 valid, 63287 out-of-bound voxels after transform.
# 2: 1007178 valid, 376763 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000847
# Norm of gradient (rotation) = 0.003034
# around x=0.27; around y=-0.32; around z=-4.66
# step: 0.81 seconds
# current score: 0.296567
# new_T: [ 0.99668603  0.08113237 -0.00587299 -2.31833707 -0.08115823  0.99669192
#  -0.00430846  0.29919169  0.005504    0.00477083  0.99997347  1.91662223]
# det: 1.00
#
# iteration 976
# 1: 1052782 valid, 63277 out-of-bound voxels after transform.
# 2: 1007180 valid, 376761 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000854
# Norm of gradient (rotation) = 0.003051
# around x=0.27; around y=-0.31; around z=-4.66
# step: 0.81 seconds
# current score: 0.296587
# new_T: [ 0.99668538  0.0811419  -0.0058513  -2.31771555 -0.08116776  0.99669106
#  -0.00432763  0.29856675  0.00548078  0.00478822  0.99997352  1.91652212]
# det: 1.00
#
# iteration 977
# 1: 1052787 valid, 63272 out-of-bound voxels after transform.
# 2: 1007197 valid, 376744 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000827
# Norm of gradient (rotation) = 0.003019
# around x=0.28; around y=-0.31; around z=-4.66
# step: 0.80 seconds
# current score: 0.296606
# new_T: [ 0.99668476  0.08115108 -0.00582992 -2.31712598 -0.08117695  0.99669023
#  -0.00434681  0.29794117  0.00545787  0.00480565  0.99997356  1.91645874]
# det: 1.00
#
# iteration 978
# 1: 1052786 valid, 63273 out-of-bound voxels after transform.
# 2: 1007201 valid, 376740 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000813
# Norm of gradient (rotation) = 0.003012
# around x=0.28; around y=-0.31; around z=-4.66
# step: 0.81 seconds
# current score: 0.296614
# new_T: [ 0.99668414  0.08116022 -0.00580855 -2.31653809 -0.08118609  0.9966894
#  -0.00436591  0.2973259   0.00543499  0.00482301  0.9999736   1.91643751]
# det: 1.00
#
# iteration 979
# 1: 1052800 valid, 63259 out-of-bound voxels after transform.
# 2: 1007209 valid, 376732 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000867
# Norm of gradient (rotation) = 0.003062
# around x=0.28; around y=-0.31; around z=-4.66
# step: 0.80 seconds
# current score: 0.296638
# new_T: [ 0.99668351  0.08116949 -0.00578708 -2.31593931 -0.08119537  0.99668856
#  -0.00438561  0.296647    0.00541194  0.00484095  0.99997364  1.91642193]
# det: 1.00
#
# iteration 980
# 1: 1052813 valid, 63246 out-of-bound voxels after transform.
# 2: 1007214 valid, 376727 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000848
# Norm of gradient (rotation) = 0.003048
# around x=0.28; around y=-0.31; around z=-4.66
# step: 0.80 seconds
# current score: 0.296654
# new_T: [ 0.99668286  0.081179   -0.00576539 -2.31531816 -0.08120487  0.9966877
#  -0.00440474  0.29602584  0.00538872  0.00485831  0.99997368  1.91633841]
# det: 1.00
#
# iteration 981
# 1: 1052816 valid, 63243 out-of-bound voxels after transform.
# 2: 1007209 valid, 376732 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000809
# Norm of gradient (rotation) = 0.003005
# around x=0.28; around y=-0.31; around z=-4.66
# step: 0.80 seconds
# current score: 0.296655
# new_T: [ 0.99668224  0.08118814 -0.00574402 -2.31472963 -0.08121402  0.99668687
#  -0.00442372  0.2954213   0.00536584  0.00487554  0.99997372  1.91629356]
# det: 1.00
#
# iteration 982
# 1: 1052827 valid, 63232 out-of-bound voxels after transform.
# 2: 1007216 valid, 376725 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000798
# Norm of gradient (rotation) = 0.002994
# around x=0.28; around y=-0.31; around z=-4.66
# step: 0.80 seconds
# current score: 0.296673
# new_T: [ 0.99668161  0.08119737 -0.00572257 -2.31413266 -0.08122324  0.99668603
#  -0.00444239  0.29484836  0.00534289  0.00489246  0.99997376  1.91621031]
# det: 1.00
#
# iteration 983
# 1: 1052832 valid, 63227 out-of-bound voxels after transform.
# 2: 1007220 valid, 376721 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000836
# Norm of gradient (rotation) = 0.003023
# around x=0.28; around y=-0.30; around z=-4.66
# step: 0.80 seconds
# current score: 0.296690
# new_T: [ 0.99668099  0.08120655 -0.00570118 -2.31354297 -0.08123241  0.9966852
#  -0.00446162  0.29421524  0.00531997  0.00490993  0.99997379  1.91612325]
# det: 1.00
#
# iteration 984
# 1: 1052839 valid, 63220 out-of-bound voxels after transform.
# 2: 1007227 valid, 376714 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000832
# Norm of gradient (rotation) = 0.003022
# around x=0.28; around y=-0.30; around z=-4.66
# step: 0.81 seconds
# current score: 0.296702
# new_T: [ 0.99668036  0.08121579 -0.00567974 -2.31294817 -0.08124165  0.99668436
#  -0.00448074  0.29359352  0.005297    0.0049273   0.99997383  1.91603345]
# det: 1.00
#
# iteration 985
# 1: 1052848 valid, 63211 out-of-bound voxels after transform.
# 2: 1007233 valid, 376708 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000839
# Norm of gradient (rotation) = 0.003020
# around x=0.28; around y=-0.30; around z=-4.66
# step: 0.81 seconds
# current score: 0.296720
# new_T: [ 0.99667972  0.08122509 -0.00565823 -2.31234616 -0.08125095  0.99668352
#  -0.00449973  0.29298314  0.00527398  0.00494452  0.99997387  1.91589192]
# det: 1.00
#
# iteration 986
# 1: 1052857 valid, 63202 out-of-bound voxels after transform.
# 2: 1007240 valid, 376701 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000852
# Norm of gradient (rotation) = 0.003034
# around x=0.28; around y=-0.30; around z=-4.66
# step: 0.81 seconds
# current score: 0.296739
# new_T: [ 0.9966791   0.08123426 -0.00563687 -2.31175878 -0.08126011  0.99668268
#  -0.00451916  0.29232767  0.00525106  0.0049622   0.9999739   1.91579896]
# det: 1.00
#
# iteration 987
# 1: 1052865 valid, 63194 out-of-bound voxels after transform.
# 2: 1007244 valid, 376697 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000861
# Norm of gradient (rotation) = 0.003024
# around x=0.29; around y=-0.30; around z=-4.66
# step: 0.80 seconds
# current score: 0.296759
# new_T: [ 0.99667845  0.08124368 -0.00561524 -2.31114536 -0.08126952  0.99668183
#  -0.00453802  0.29172648  0.00522792  0.00497929  0.99997394  1.91558231]
# det: 1.00
#
# iteration 988
# 1: 1052871 valid, 63188 out-of-bound voxels after transform.
# 2: 1007252 valid, 376689 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000884
# Norm of gradient (rotation) = 0.003031
# around x=0.29; around y=-0.30; around z=-4.66
# step: 0.80 seconds
# current score: 0.296779
# new_T: [ 0.99667783  0.0812528  -0.0055939  -2.31056055 -0.08127864  0.996681
#  -0.00455745  0.29106468  0.00520503  0.00499697  0.99997397  1.91537027]
# det: 1.00
#
# iteration 989
# 1: 1052881 valid, 63178 out-of-bound voxels after transform.
# 2: 1007257 valid, 376684 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000870
# Norm of gradient (rotation) = 0.003012
# around x=0.29; around y=-0.30; around z=-4.66
# step: 0.80 seconds
# current score: 0.296787
# new_T: [ 0.99667721  0.08126179 -0.0055727  -2.3099912  -0.08128762  0.99668018
#  -0.00457681  0.29040908  0.00518228  0.0050146   0.999974    1.91515676]
# det: 1.00
#
# iteration 990
# 1: 1052891 valid, 63168 out-of-bound voxels after transform.
# 2: 1007264 valid, 376677 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000924
# Norm of gradient (rotation) = 0.003005
# around x=0.29; around y=-0.30; around z=-4.66
# step: 0.80 seconds
# current score: 0.296815
# new_T: [ 0.99667659  0.08127088 -0.00555135 -2.30940711 -0.08129671  0.99667935
#  -0.00459585  0.28978022  0.00515941  0.00503188  0.99997403  1.91478152]
# det: 1.00
#
# iteration 991
# 1: 1052896 valid, 63163 out-of-bound voxels after transform.
# 2: 1007277 valid, 376664 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000849
# Norm of gradient (rotation) = 0.002989
# around x=0.29; around y=-0.29; around z=-4.66
# step: 0.80 seconds
# current score: 0.296832
# new_T: [ 0.99667599  0.08127964 -0.00553035 -2.30885805 -0.08130546  0.99667855
#  -0.00461517  0.28912935  0.00513687  0.00504948  0.99997406  1.91458677]
# det: 1.00
#
# iteration 992
# 1: 1052906 valid, 63153 out-of-bound voxels after transform.
# 2: 1007281 valid, 376660 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000895
# Norm of gradient (rotation) = 0.002999
# around x=0.29; around y=-0.29; around z=-4.66
# step: 0.80 seconds
# current score: 0.296848
# new_T: [ 0.99667536  0.0812888  -0.00550893 -2.30826632 -0.08131461  0.99667771
#  -0.004634    0.28852522  0.00511394  0.00506655  0.99997409  1.91425022]
# det: 1.00
#
# iteration 993
# 1: 1052916 valid, 63143 out-of-bound voxels after transform.
# 2: 1007287 valid, 376654 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000857
# Norm of gradient (rotation) = 0.002980
# around x=0.29; around y=-0.29; around z=-4.66
# step: 0.80 seconds
# current score: 0.296874
# new_T: [ 0.99667476  0.08129763 -0.00548786 -2.30770997 -0.08132343  0.9966769
#  -0.00465306  0.28789868  0.00509134  0.00508388  0.99997412  1.91398924]
# det: 1.00
#
# iteration 994
# 1: 1052920 valid, 63139 out-of-bound voxels after transform.
# 2: 1007275 valid, 376666 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001210
# Norm of gradient (rotation) = 0.003024
# around x=0.29; around y=-0.29; around z=-4.67
# step: 0.80 seconds
# current score: 0.296854
# new_T: [ 0.9966742   0.08130583 -0.0054674  -2.30721774 -0.08133163  0.99667614
#  -0.00467371  0.28707625  0.00506923  0.00510284  0.99997413  1.91325624]
# det: 1.00
#
# iteration 995
# 1: 1052927 valid, 63132 out-of-bound voxels after transform.
# 2: 1007293 valid, 376648 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001256
# Norm of gradient (rotation) = 0.003063
# around x=0.29; around y=-0.29; around z=-4.67
# step: 0.80 seconds
# current score: 0.296882
# new_T: [ 0.99667353  0.08131555 -0.00544544 -2.30657195 -0.08134132  0.99667526
#  -0.00469266  0.2864328   0.00504575  0.00511999  0.99997416  1.91240643]
# det: 1.00
#
# iteration 996
# 1: 1052935 valid, 63124 out-of-bound voxels after transform.
# 2: 1007313 valid, 376628 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001037
# Norm of gradient (rotation) = 0.003160
# around x=0.29; around y=-0.29; around z=-4.67
# step: 0.80 seconds
# current score: 0.296916
# new_T: [ 0.99667282  0.08132573 -0.00542312 -2.30588942 -0.0813515   0.99667433
#  -0.0047125   0.28571901  0.00502184  0.005138    0.99997419  1.91203912]
# det: 1.00
#
# iteration 997
# 1: 1052947 valid, 63112 out-of-bound voxels after transform.
# 2: 1007320 valid, 376621 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000984
# Norm of gradient (rotation) = 0.003030
# around x=0.30; around y=-0.29; around z=-4.67
# step: 0.80 seconds
# current score: 0.296936
# new_T: [ 0.9966722   0.0813348  -0.00540182 -2.30531056 -0.08136055  0.9966735
#  -0.00473199  0.28503807  0.00499897  0.00515574  0.99997421  1.91160386]
# det: 1.00
#
# iteration 998
# 1: 1052952 valid, 63107 out-of-bound voxels after transform.
# 2: 1007326 valid, 376615 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001040
# Norm of gradient (rotation) = 0.003072
# around x=0.30; around y=-0.29; around z=-4.67
# step: 0.82 seconds
# current score: 0.296947
# new_T: [ 0.99667154  0.08134435 -0.00538005 -2.30468474 -0.08137008  0.99667263
#  -0.00475138  0.2843642   0.00497565  0.00517334  0.99997424  1.91110307]
# det: 1.00
#
# iteration 999
# 1: 1052964 valid, 63095 out-of-bound voxels after transform.
# 2: 1007335 valid, 376606 out-of-bound voxels after transform.
# Best parameters =
# [[ 0.99667088  0.08135378 -0.00535837 -2.30406851]
#  [-0.08137951  0.99667177 -0.00477088  0.28367461]
#  [ 0.00495241  0.00519105  0.99997426  1.91050848]]
# Best score = 0.29696789207831836 , initial score = 0.256738382407951
# Norm of gradient (translation) = 0.001097
# Norm of gradient (rotation) = 0.003068
# around x=0.30; around y=-0.28; around z=-4.67
# step: 0.81 seconds
# current score: 0.296968
# new_T: [ 0.99667088  0.08135378 -0.00535837 -2.30406851 -0.08137951  0.99667177
#  -0.00477088  0.28367461  0.00495241  0.00519105  0.99997426  1.91050848]
# det: 1.00
