# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import time

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.ndimage.interpolation import map_coordinates
from skimage.exposure import rescale_intensity, adjust_gamma
from skimage.transform import rotate

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from metadata import *
from data_manager import *
from learning_utilities import *
from distributed_utilities import *
from visualization_utilities import *
# Out:
# Setting environment for Precision WorkStation for Alex Newberry
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD589/MD589_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD590/MD590_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD591/MD591_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD592/MD592_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD593/MD593_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD595/MD595_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD598/MD598_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD599/MD599_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD602/MD602_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD603/MD603_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD635/MD635_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD653/MD653_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD652/MD652_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD642/MD642_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD657/MD657_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD658/MD658_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD661/MD661_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/CHATM2/CHATM2_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_anchor.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_anchor.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_anchor.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_anchor.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/CHATM3/CHATM3_anchor.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_anchor.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_cropbox.txt"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_sorted_filenames.txt"
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD585
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD589/MD589_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD589
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD590/MD590_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD590
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD591/MD591_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD591
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD592/MD592_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD592
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD593/MD593_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD593
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# ...
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD603
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD635/MD635_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD635
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD653/MD653_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD653
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD652/MD652_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD652
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD642/MD642_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD642
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD657/MD657_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD657
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD658/MD658_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD658
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD661/MD661_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD661
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for CHATM2
# return code: 0
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt"
# KEY ERROR ADN 999111
# return code: 0
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_cropbox.json" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_cropbox.json" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_cropbox.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for CHATM3
# return code: 0
# KEY ERROR ADN 999111
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
stack = 'MD662'

# %%
# convert_frame_and_resolution(np.array([[1000, 400, 279], [1000, 401, 279]]), 
#                              in_wrt='alignedPadded', 
#                              in_resolution='image_image_section', 
#                              out_wrt='raw', 
#                              out_resolution='image_image_section',
#                              in_image_resolution='down32',
#                              out_image_resolution='down32',
#                             stack=stack)

# %%
# TEST
metadata_cache['valid_sections'][stack]
# Out:
# [100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  110,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  284,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  337,
#  338,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372]

# %%
# for section in set(metadata_cache['valid_sections_all'][stack]) - set(metadata_cache['valid_sections'][stack]):
#for section in metadata_cache['valid_sections'][stack]:
for section in [1]:
    
    print "Section", section
    
    t = time.time()
    
    img = DataManager.load_image_v2(stack=stack, prep_id=None, section=section, version='Ntb', resol='raw')

    sys.stderr.write('Load image: %.2f seconds.\n' % (time.time() - t))

    t = time.time()
    tb_mask = DataManager.load_thumbnail_mask_v3(stack=stack, prep_id=None, section=section)
#     raw_mask = rescale_by_resampling(tb_mask, new_shape=(img.shape[1], img.shape[0]))
    raw_mask = resize(tb_mask, img.shape) > .5
    
    save_data(raw_mask, 
          DataManager.get_image_filepath_v2(stack=stack, prep_id=None, section=section, version='mask', resol='raw', ext='bp'), 
          upload_s3=False)
    
    sys.stderr.write('Rescale mask: %.2f seconds.\n' % (time.time() - t))

    t = time.time()
    
    mean_std_all_regions = []
    cx_cy_all_regions = []
    region_size = 5000
    region_spacing = 3000
#     for cx in range(region_size/2, img.shape[1]-region_size/2+1, region_spacing):
#         for cy in range(region_size/2, img.shape[0]-region_size/2+1, region_spacing):
    for cx in range(0, img.shape[1], region_spacing):
        for cy in range(0, img.shape[0], region_spacing):
            region = img[max(cy-region_size/2, 0):min(cy+region_size/2+1, img.shape[0]-1), 
                         max(cx-region_size/2, 0):min(cx+region_size/2+1, img.shape[1]-1)]
            region_mask = raw_mask[max(cy-region_size/2, 0):min(cy+region_size/2+1, img.shape[0]-1), 
                                   max(cx-region_size/2, 0):min(cx+region_size/2+1, img.shape[1]-1)]
            if np.count_nonzero(region_mask) == 0:
                continue
            mean_std_all_regions.append((region[region_mask].mean(), region[region_mask].std()))
            cx_cy_all_regions.append((cx, cy))
            
    sys.stderr.write('Compute mean/std for sample regions: %.2f seconds.\n' % (time.time() - t))
    
    t = time.time()
    mean_map = resample_scoremap(sparse_scores=np.array(mean_std_all_regions)[:,0], 
                             sample_locations=cx_cy_all_regions,
                             gridspec=(region_size, region_spacing, img.shape[1], img.shape[0], (0,0)),
                            downscale=4, 
                                 interpolation_order=2)

    sys.stderr.write('Interpolate mean map: %.2f seconds.\n' % (time.time() - t)) #10s

    t = time.time()
    mean_map = rescale_by_resampling(mean_map, new_shape=(img.shape[1], img.shape[0]))
    sys.stderr.write('Scale up mean map: %.2f seconds.\n' % (time.time() - t)) #30s

    t = time.time()
    std_map = resample_scoremap(sparse_scores=np.array(mean_std_all_regions)[:,1], 
                             sample_locations=cx_cy_all_regions,
                             gridspec=(region_size, region_spacing, img.shape[1], img.shape[0], (0,0)),
                            downscale=4,
                               interpolation_order=2)
    sys.stderr.write('Interpolate std map: %.2f seconds.\n' % (time.time() - t)) #10s

    t = time.time()
    std_map = rescale_by_resampling(std_map, new_shape=(img.shape[1], img.shape[0]))
    sys.stderr.write('Scale up std map: %.2f seconds.\n' % (time.time() - t)) #30s
    
    # Save mean/std results.
    
    fp = DataManager.get_intensity_normalization_result_filepath(what='region_centers', stack=stack, section=section)
    create_parent_dir_if_not_exists(fp)    
    np.savetxt(fp, cx_cy_all_regions)
    
    fp = DataManager.get_intensity_normalization_result_filepath(what='mean_std_all_regions', stack=stack, section=section)
    create_parent_dir_if_not_exists(fp)
    np.savetxt(fp, mean_std_all_regions)
    
    fp = DataManager.get_intensity_normalization_result_filepath(what='mean_map', stack=stack, section=section)
    create_parent_dir_if_not_exists(fp)
    bp.pack_ndarray_file(mean_map.astype(np.float16), fp)
    
    fp = DataManager.get_intensity_normalization_result_filepath(what='std_map', stack=stack, section=section)
    create_parent_dir_if_not_exists(fp)
    bp.pack_ndarray_file(std_map.astype(np.float16), fp)

    # Export normalized image.
    
    t = time.time()
    raw_mask = raw_mask & (std_map > 0)
    img_normalized = np.zeros(img.shape, np.float32)
    img_normalized[raw_mask] = (img[raw_mask] - mean_map[raw_mask]) / std_map[raw_mask]
    sys.stderr.write('Normalize: %.2f seconds.\n' % (time.time() - t)) #30s

    t = time.time()
    # FIX THIS! THIS only save uint16, not float16. Need to save as bp instead.
#     img_fp = DataManager.get_image_filepath_v2(stack=stack, prep_id=None, version='NtbNormalizedFloat', resol='down8', section=section, )
#     create_parent_dir_if_not_exists(img_fp)
#     imsave(img_fp, img_normalized[::8, ::8].astype(np.float16))
    save_data(img_normalized.astype(np.float16), 
              DataManager.get_intensity_normalization_result_filepath(what='normalized_float_map', stack=stack, section=section),
             upload_s3=False)
    sys.stderr.write('Save float version: %.2f seconds.\n' % (time.time() - t)) #30s
        
#     t = time.time()
#     img_normalized_uint8 = rescale_intensity_v2(img_normalized, -1, 6)
#     sys.stderr.write('Rescale to uint8: %.2f seconds.\n' % (time.time() - t)) #30s
    
#     t = time.time()
#     img_fp = DataManager.get_image_filepath_v2(stack=stack, prep_id=None, version='NtbNormalized', resol='raw', section=section)
#     create_parent_dir_if_not_exists(img_fp)
#     imsave(img_fp, img_normalized_uint8)
#     sys.stderr.write('Save uint8 version: %.2f seconds.\n' % (time.time() - t)) #30s
    
    # Export histogram.
    
    plt.hist(img_normalized[raw_mask].flatten(), bins=100, log=True);
    fp = DataManager.get_intensity_normalization_result_filepath(what='float_histogram_png', stack=stack, section=section)
    create_parent_dir_if_not_exists(fp)
    plt.savefig(fp)
    plt.close();
    
#     hist_fp = DataManager.get_intensity_normalization_result_filepath(what='float_histogram', stack=stack, section=section)
#     create_parent_dir_if_not_exists(hist_fp)
    
#     hist, bin_edges = np.histogram(img_normalized[valid_mask].flatten(), bins=np.arange(0,201,5));

#     plt.bar(bin_edges[:-1], np.log(hist));
#     plt.xticks(np.arange(0, 200, 20), np.arange(0, 200, 20));
#     plt.xlabel('Normalized pixel value (float)');
#     plt.title(metadata_cache['sections_to_filenames'][stack][section])

#     plt.savefig(hist_fp)
#     plt.close();
# Out:
# Section 1
# Not using image_cache.
# /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_Ntb/MD662&661-F1-2017.06.02-17.07.55_MD662_1_0001_raw_Ntb.tif
# Load image: 10.54 seconds.
# rm -rf "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_thumbnail_mask/MD662&661-F1-2017.06.02-17.07.55_MD662_1_0001_thumbnail_mask.png" && mkdir -p "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_thumbnail_mask"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD662/MD662_thumbnail_mask/MD662&661-F1-2017.06.02-17.07.55_MD662_1_0001_thumbnail_mask.png" "/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_thumbnail_mask/MD662&661-F1-2017.06.02-17.07.55_MD662_1_0001_thumbnail_mask.png"
# return code: 1
# Cannot load mask MD662, section=1, fn=None, prep=None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-0dc04710a835> in <module>()
#      14     tb_mask = DataManager.load_thumbnail_mask_v3(stack=stack, prep_id=None, section=section)
#      15 #     raw_mask = rescale_by_resampling(tb_mask, new_shape=(img.shape[1], img.shape[0]))
# ---> 16     raw_mask = resize(tb_mask, img.shape) > .5
#      17
#      18     save_data(raw_mask,
#
# /usr/local/lib/python2.7/dist-packages/skimage/transform/_warps.pyc in resize(image, output_shape, order, mode, cval, clip, preserve_range)
#      86
#      87     rows, cols = output_shape[0], output_shape[1]
# ---> 88     orig_rows, orig_cols = image.shape[0], image.shape[1]
#      89
#      90     row_scale = float(orig_rows) / rows
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
for section in metadata_cache['valid_sections_all'][stack]:
# for section in [279]:
        
    print section
    
    raw_mask = load_data(DataManager.get_image_filepath_v2(stack=stack, prep_id=None, \
                                     section=section, version='mask', resol='raw', ext='bp'),download_s3=False)
    
    img_normalized = load_data(
              DataManager.get_intensity_normalization_result_filepath(what='normalized_float_map', \
                                     stack=stack, section=section), download_s3=False)
        
    q = img_normalized[raw_mask]
    
    save_data(np.percentile(q, range(101)), 
              DataManager.get_intensity_normalization_result_filepath(what='float_percentiles', \
                                                    stack=stack, section=section), upload_s3=False)
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372

# %%
perc1s = []
perc99s = []
for section in metadata_cache['valid_sections'][stack][:100]:
    try:
        q = load_data(DataManager.get_intensity_normalization_result_filepath(what='float_percentiles', \
                                                                              stack=stack, section=section))
    #     print q[0], q[1], q[2], q[98], q[99], q[100]
    #     perc1s.append(q[1])
    #     perc99s.append(q[99])
        perc1s.append(q[0])
        perc99s.append(q[100])
    except:
        pass
    
plt.figure(figsize=(8,3));
plt.hist(perc1s, bins=100);
plt.title('Min');
plt.xlabel('Normalized float point value');
plt.show();

plt.figure(figsize=(8,3));
plt.hist(perc99s, bins=100);
plt.title('Max');
plt.xlabel('Normalized float point value');
plt.show();

print np.percentile(perc1s, 25), np.percentile(perc99s, 75)
# Out:
# -1.98583984375 23.79296875

# %%
out_fp = DataManager.get_image_filepath_v2(stack=stack, prep_id=None,\
                                    section=100, version='NtbNormalizedAdaptive', resol='raw')
print stack
if os.path.isfile(out_fp):
    print 'is real file'
# Out:
# MD662
# is real file

# %%
metadata_cache['valid_sections'][stack]
# Out:
# [100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  110,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  284,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  337,
#  338,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372]

# %%
# Output: raw_NtbNormalizedAdaptive.tif

for section in metadata_cache['valid_sections'][stack]:
# for section in [279]:
    # Checks to see if there is already the output file present, if so skip the code
    out_fp = DataManager.get_image_filepath_v2(stack=stack, prep_id=None,\
                                    section=section, version='NtbNormalizedAdaptive', resol='raw')
    if os.path.isfile(out_fp):
        print('SKIPPING : '+out_fp)
        continue

    print section
    
    img_normalized = load_data(
              DataManager.get_intensity_normalization_result_filepath(what='normalized_float_map', stack=stack,\
                                                    section=section), download_s3=False)
    
    t = time.time()
    img_normalized_uint8 = rescale_intensity_v2(img_normalized, -2., 50.)
    sys.stderr.write('Rescale to uint8: %.2f seconds.\n' % (time.time() - t))

    t = time.time()
    raw_mask = load_data(DataManager.get_image_filepath_v2(stack=stack, prep_id=None, section=section,\
                                            version='mask', resol='raw', ext='bp'), download_s3=False)
    img_normalized_uint8[~raw_mask] = 0
    sys.stderr.write('Load mask: %.2f seconds.\n' % (time.time() - t))
    
    t = time.time()
    save_data(img_normalized_uint8, DataManager.get_image_filepath_v2(stack=stack, prep_id=None,\
                                    section=section, version='NtbNormalizedAdaptive', resol='raw'),
             upload_s3=False)
    sys.stderr.write('Save uint8 version: %.2f seconds.\n' % (time.time() - t))
# Out:
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F35-2017.06.05-17.08.18_MD662_1_0103_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F35-2017.06.05-17.08.18_MD662_2_0104_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F35-2017.06.05-17.08.18_MD662_3_0105_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F36-2017.06.05-17.38.33_MD662_1_0106_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F36-2017.06.05-17.38.33_MD662_2_0107_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F36-2017.06.05-17.38.33_MD662_3_0108_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F37-2017.06.05-18.09.08_MD662_1_0109_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-
raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F134-2017.06.07-21.04.24_MD662_2_0401_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F134-2017.06.07-21.04.24_MD662_3_0402_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F135-2017.06.07-21.33.10_MD662_1_0403_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F135-2017.06.07-21.33.10_MD662_2_0404_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F135-2017.06.07-21.33.10_MD662_3_0405_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F136-2017.06.07-22.02.11_MD662_1_0406_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F136-2017.06.07-22.02.11_MD662_2_0407_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F136-2017.06.07-22.02.11_MD662_3_0408_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F137-2017.06.07-22.31.13_MD662_1_0409_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F137-2017.06.07-22.31.13_MD662_2_0410_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F137-2017.06.07-22.31.13_MD662_3_0411_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F138-2017.06.07-23.00.07_MD662_1_0412_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F138-2017.06.07-23.00.07_MD662_2_0413_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F138-2017.06.07-23.00.07_MD662_3_0414_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F139-2017.06.07-23.28.09_MD662_1_0415_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F139-2017.06.07-23.28.09_MD662_2_0416_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F139-2017.06.07-23.28.09_MD662_3_0417_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F140-2017.06.07-23.55.43_MD662_1_0418_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F140-2017.06.07-23.55.43_MD662_2_0419_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F140-2017.06.07-23.55.43_MD662_3_0420_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F141-2017.06.08-00.23.35_MD662_1_0421_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F141-2017.06.08-00.23.35_MD662_2_0422_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F141-2017.06.08-00.23.35_MD662_3_0423_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F142-2017.06.08-19.12.20_MD662_1_0424_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F142-2017.06.08-19.12.20_MD662_2_0425_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F142-2017.06.08-19.12.20_MD662_3_0426_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F143-2017.06.08-00.52.06_MD662_1_0427_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F143-2017.06.08-00.52.06_MD662_2_0428_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F143-2017.06.08-00.52.06_MD662_3_0429_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F144-2017.06.08-01.17.04_MD662_1_0430_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F144-2017.06.08-01.17.04_MD662_2_0431_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F144-2017.06.08-01.17.04_MD662_3_0432_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F145-2017.06.08-01.42.12_MD662_1_0433_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F145-2017.06.08-01.42.12_MD662_2_0434_raw_NtbNormalizedAdaptive.tif
# SKIPPING : /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F145-2017.06.08-01.42.12_MD662_3_0435_raw_NtbNormalizedAdaptive.tif

# %%
img_normalized_uint8 = \
DataManager.load_image_v2(stack=stack, prep_id=None, section=279, version='NtbNormalizedAdaptive', resol='raw')
# Out:
# Not using image_cache.
# /media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_raw_NtbNormalizedAdaptive/MD662&661-F108-2017.06.07-01.10.56_MD662_2_0323_raw_NtbNormalizedAdaptive.tif

# %%
plt.imshow(img_normalized_uint8[::10, ::10], cmap=plt.cm.gray);

# %%
img = 255 - img_normalized_uint8[1000*10:2000*10, 3000*10:4000*10]

# %%
plt.figure(figsize=(20, 20));
plt.imshow(img, vmin=0, vmax=255, cmap=plt.cm.gray);
plt.axis('off');

# %%
gamma_map = img_as_ubyte(adjust_gamma(np.arange(0, 256, 1) / 255., 8.))
# Out:
# /usr/local/lib/python2.7/dist-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
plt.plot(gamma_map);

# %%
plt.hist(img.flatten(), bins=100, log=True);

# %%
plt.hist(gamma_map[img].flatten(), bins=100, log=True);

# %%
plt.figure(figsize=(20, 20));
plt.imshow(gamma_map[img], vmin=0, vmax=255, cmap=plt.cm.gray);
plt.axis('off');

# %%
gamma_map = img_as_ubyte(adjust_gamma(np.arange(0, 256, 1) / 255., 8.))

# %%
# Output: '*_raw_NtbNormalizedAdaptiveInvertedGamma.tif'

# Out:
# /usr/local/lib/python2.7/dist-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# stack = 'CHATM3'
stack = 'MD662'

for section in metadata_cache['valid_sections_all'][stack]:
# for section in [279]:

    print section
    
    img_normalized = load_data(
              DataManager.get_intensity_normalization_result_filepath(what='normalized_float_map', \
                                                        stack=stack, section=section), download_s3=False)
        
    t = time.time()
    img_normalized_uint8 = rescale_intensity_v2(img_normalized, -2., 50.)
    sys.stderr.write('Rescale to uint8: %.2f seconds.\n' % (time.time() - t))

    t = time.time()
    raw_mask = load_data(DataManager.get_image_filepath_v2(stack=stack, prep_id=None, section=section, \
                                                    version='mask', resol='raw', ext='bp'), download_s3=False)
    img_normalized_uint8[~raw_mask] = 0
    sys.stderr.write('Load mask: %.2f seconds.\n' % (time.time() - t))
    
#     t = time.time()
#     save_data(img_normalized_uint8, DataManager.get_image_filepath_v2(stack=stack, prep_id=None, \
#section=section, version='NtbNormalizedAdaptive', resol='raw'),
#              upload_s3=False)
#     sys.stderr.write('Save uint8 version: %.2f seconds.\n' % (time.time() - t))
    
#     img_normalized_uint8 = \
#     DataManager.load_image_v2(stack=stack, prep_id=None, section=section, version='NtbNormalizedAdaptive',\
#resol='raw')
    img = 255 - img_normalized_uint8
    save_data(gamma_map[img], 
              DataManager.get_image_filepath_v2(stack=stack, prep_id=None, section=section, \
                                    version='NtbNormalizedAdaptiveInvertedGamma', resol='raw'), upload_s3=False)
# Out:
# Setting environment for Precision WorkStation for Alex Newberry
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_cropbox.txt" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_cropbox.txt" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_cropbox.txt"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585"
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD585/MD585_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD585
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD589/MD589_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD589
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD590/MD590_alignedTo_MD590-N47-2015.09.12-05.32.06_MD590_2_0140_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD590
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD591/MD591_alignedTo_MD591-N57-2015.09.21-17.13.29_MD591_1_0169_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD591
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD592/MD592_alignedTo_MD592-IHC59-2015.08.26-00.06.25_MD592_2_0176_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD592
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD593/MD593_alignedTo_MD593-IHC54-2015.08.25-17.40.32_MD593_2_0161_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD593
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD594/MD594_alignedTo_MD594-IHC58-2015.08.26-18.48.50_MD594_1_0172_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD594
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD595/MD595_alignedTo_MD595-IHC48-2015.09.15-18.38.44_MD595_1_0142_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD595
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD598/MD598_alignedTo_MD598-N42-2015.09.29-19.26.12_MD598_2_0125_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD598
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD599/MD599_alignedTo_MD599-IHC40-2015.10.03-06.04.31_MD599_2_0119_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD599
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD602/MD602_alignedTo_MD602-N49-2015.12.01-18.41.46_MD602_2_0146_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD602
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD603/MD603_alignedTo_MD603-N60-2015.12.03-23.57.05_MD603_2_0179_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD603
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD635/MD635_alignedTo_MD635-F63-2016.05.19-08.39.03_MD635_2_0188_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD635
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD653/MD653_alignedTo_MD653-F64-2016.12.21-12.03.55_MD653_2_0191_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD653
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD652/MD652_alignedTo_MD652-F45-2016.12.17-05.56.31_MD652_2_0134_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD652
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD642/MD642_alignedTo_MD642-F53-2017.01.14-12.23.43_MD642_1_0157_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD642
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD657/MD657_alignedTo_MD657-F44-2017.02.18-06.06.27_MD657_1_0130_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD657
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD658/MD658_alignedTo_MD658-N58-2017.03.31-19.59.31_MD658_2_0173_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD658
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD661/MD661_alignedTo_MD662&661-F116-2017.06.07-04.39.41_MD661_1_0346_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for MD661
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM2/CHATM2_alignedTo_CHATM2_slide62_2018_02_14-S1_prep2_sectionLimits.json"
# return code: 1
# rm -rf "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_sectionLimits.json" && mkdir -p "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for CHATM2
# KEY ERROR ADN 999111
# return code: 0
# aws s3 cp "s3://mousebrainatlas-data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_sectionLimits.json" "/data/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/CHATM3/CHATM3_alignedTo_CHATM3_slide77_2018_01_26-S1_prep2_sectionLimits.json"
# An exception of type IOError occurred setting metadata_cache parameter section_limits. Arguments:
# (2, 'No such file or directory')
# Failed for CHATM3
# KEY ERROR ADN 999111
# 1
# return code: 1
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-38-b83d34835b88> in <module>()
#       9     img_normalized = load_data(
#      10               DataManager.get_intensity_normalization_result_filepath(what='normalized_float_map', \
# ---> 11                                                         stack=stack, section=section), download_s3=False)
#      12
#      13     t = time.time()
#
# /home/alexn/brain/utilities/utilities2015.pyc in load_data(fp, polydata_instead_of_face_vertex_list, download_s3)
#     104
#     105     if fp.endswith('.bp'):
# --> 106         data = bp.unpack_ndarray_file(fp)
#     107     elif fp.endswith('.json'):
#     108         data = load_json(fp)
#
# /usr/local/lib/python2.7/dist-packages/bloscpack/numpy_io.pyc in unpack_ndarray_file(filename)
#     231
#     232 def unpack_ndarray_file(filename):
# --> 233     source = CompressedFPSource(open(filename, 'rb'))
#     234     return unpack_ndarray(source)
#     235
#
# IOError: [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/CSHL_data_processed/MD662/MD662_intensity_normalization_results/normalizedFloatMap/MD662_MD662&661-F1-2017.06.02-17.07.55_MD662_1_0001_raw_normalizedFloatMap.bp'

# %%
plt.imshow(tb_mask);

# %%
plt.imshow(raw_mask[::10, ::10]);

# %%
plt.imshow(std_map[::10, ::10] > 0)

# %%
plt.imshow(img[::10, ::10]);

# %%
plt.imshow(mean_map[::10, ::10]);
# plt.colorbar();

# %%
plt.imshow(std_map[::10, ::10]);
# plt.colorbar();

# %%
plt.hist(img[raw_mask], log=True);

# %%
plt.hist(mean_map[raw_mask], log=True);

# %%
plt.hist(std_map[raw_mask], log=True);

# %%
img_normalized = np.zeros(img.shape, np.float32)
img_normalized[raw_mask] = (img[raw_mask] - mean_map[raw_mask]) / std_map[raw_mask]

# %%
plt.hist(img_normalized[raw_mask], log=True);

# %%
plt.figure(figsize=(10,10));
plt.imshow(img[::10, ::10], cmap=plt.cm.gray);

# %%
cx_cy_all_regions = np.array(cx_cy_all_regions)

# %%
plt.figure(figsize=(10,10));
plt.imshow(img_normalized[::10, ::10], cmap=plt.cm.gray);
plt.scatter(cx_cy_all_regions[:,0]/10, cx_cy_all_regions[:,1]/10);

# %%
img_normalized_uint8 = rescale_intensity_v2(img_normalized, -1, 6)

# %%
plt.figure(figsize=(10,10));
plt.imshow(img_normalized_uint8[::10, ::10], cmap=plt.cm.gray);
plt.scatter(cx_cy_all_regions[:,0]/10, cx_cy_all_regions[:,1]/10);
