# %%
! python a_import_test_script.py --train_stacks "[MD585]" --test_stacks "[MD585]" --win_id 7 --structures "[IC]"
# Out:
# Setting environment for Precision WorkStation for Alex Newberry
# {'MD589': 0.46, 'MD585': 0.46, 'UCSD001': 0.325, 'MD594': 0.46, 'DK17': 0.325}
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'MD589': 0.46, 'MD585': 0.46, 'UCSD001': 0.325, 'MD594': 0.46, 'DK17': 0.325}
# MD585
# MD585
# IC

# %%
import xgboost

# %%
DataManager.get_dnn_features_filepath_v2(stack="MD589", sec=92, fn=fn, prep_id=prep_id, win_id=win_id,
                              normalization_scheme=normalization_scheme,
                                             model_name=model_name, what='features')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ff8848a10dbf> in <module>()
# ----> 1 DataManager.get_dnn_features_filepath_v2(stack="MD589", sec=92, fn=fn, prep_id=prep_id, win_id=win_id,
#       2                               normalization_scheme=normalization_scheme,
#       3                                              model_name=model_name, what='features')
#
# NameError: name 'fn' is not defined

# %%
42576-42543
# Out:
# 33

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import time

import numpy as np
try:
    import mxnet as mx
except:
    sys.stderr.write("Cannot import mxnet.\n")
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.exposure import rescale_intensity
from skimage.transform import rotate

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from metadata import *
from data_manager import *
from learning_utilities import *
from distributed_utilities import *
from visualization_utilities import *
# Out:
# Cannot import mxnet.
# /home/alexn/brainDev/src//utilities/utilities2015.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python2.7/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/lib/python2.7/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-41-fc4079e49eb7>", line 14, in <module>
#     get_ipython().magic(u'matplotlib inline')
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'MD589': 0.46, 'MD585': 0.46, 'UCSD001': 0.325, 'MD594': 0.46, 'DK17': 0.325}
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD585/MD585_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD585/MD585_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD589/MD589_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD589/MD589_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# No module named mxnet
# ********************************************************************************************************************************
# Error, CANNOT PROCEED UNTIL THIS IS RESOLVED!
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD590 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/MD590_sorted_filenames.txt
# Failed to cache MD590 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/MD590_sorted_filenames.txt
# Failed to cache MD590 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD590 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD590 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD590 valid_sections/filenames: MD590
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD590 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/MD591_sorted_filenames.txt
# Failed to cache MD591 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/MD591_sorted_filenames.txt
# Failed to cache MD591 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD591 valid_sections/filenames: MD591
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/MD592_sorted_filenames.txt
# Failed to cache MD592 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/MD592_sorted_filenames.txt
# Failed to cache MD592 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD592 valid_sections/filenames: MD592
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/MD593_sorted_filenames.txt
# Failed to cache MD593 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/MD593_sorted_filenames.txt
# Failed to cache MD593 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD593 valid_sections/filenames: MD593
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/MD595_sorted_filenames.txt
# Failed to cache MD595 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/MD595_sorted_filenames.txt
# Failed to cache MD595 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD595 valid_sections/filenames: MD595
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/MD598_sorted_filenames.txt
# Failed to cache MD598 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/MD598_sorted_filenames.txt
# Failed to cache MD598 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD598 valid_sections/filenames: MD598
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/MD599_sorted_filenames.txt
# Failed to cache MD599 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/MD599_sorted_filenames.txt
# Failed to cache MD599 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD599 valid_sections/filenames: MD599
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/MD602_sorted_filenames.txt
# Failed to cache MD602 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/MD602_sorted_filenames.txt
# Failed to cache MD602 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD602 valid_sections/filenames: MD602
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/MD603_sorted_filenames.txt
# Failed to cache MD603 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/MD603_sorted_filenames.txt
# Failed to cache MD603 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD603 valid_sections/filenames: MD603
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/MD635_sorted_filenames.txt
# Failed to cache MD635 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/MD635_sorted_filenames.txt
# Failed to cache MD635 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD635 valid_sections/filenames: MD635
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/MD653_sorted_filenames.txt
# Failed to cache MD653 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/MD653_sorted_filenames.txt
# Failed to cache MD653 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD653 valid_sections/filenames: MD653
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/MD652_sorted_filenames.txt
# Failed to cache MD652 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/MD652_sorted_filenames.txt
# Failed to cache MD652 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD652 valid_sections/filenames: MD652
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/MD642_sorted_filenames.txt
# Failed to cache MD642 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/MD642_sorted_filenames.txt
# Failed to cache MD642 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD642 valid_sections/filenames: MD642
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/MD657_sorted_filenames.txt
# Failed to cache MD657 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/MD657_sorted_filenames.txt
# Failed to cache MD657 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD657 valid_sections/filenames: MD657
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/MD658_sorted_filenames.txt
# Failed to cache MD658 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/MD658_sorted_filenames.txt
# Failed to cache MD658 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD658 valid_sections/filenames: MD658
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/MD661_sorted_filenames.txt
# Failed to cache MD661 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/MD661_sorted_filenames.txt
# Failed to cache MD661 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD661 valid_sections/filenames: MD661
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD662 valid_sections/filenames: MD662
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt
# Failed to cache CHATM2 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt
# Failed to cache CHATM2 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache CHATM2 valid_sections/filenames: CHATM2
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt
# Failed to cache CHATM3 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt
# Failed to cache CHATM3 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache CHATM3 valid_sections/filenames: CHATM3
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# UNABLE TO LOAD MXNET
# /src/utilities/learning_utilities.py
# ********************************************************************************************************************************
# Cannot import mxnet.
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
! python a_train_and_test_classifier_performance_v5.py
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'MD589': 0.46, 'MD585': 0.46, 'UCSD001': 0.325, 'MD594': 0.46, 'DK17': 0.325}
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD585/MD585_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD585/MD585_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD589/MD589_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD589/MD589_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/alexn/brainDev/src//utilities/data_manager.py:5506: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s anchor: %s\n" % (stack, e.message))
# Failed to cache MD590 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/MD590_sorted_filenames.txt
# /home/alexn/brainDev/src//utilities/data_manager.py:5512: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s sections_to_filenames: %s\n" % (stack, e.message))
# Failed to cache MD590 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/MD590_sorted_filenames.txt
# /home/alexn/brainDev/src//utilities/data_manager.py:5523: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s filenames_to_sections: %s\n" % (stack, e.message))
# Failed to cache MD590 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/alexn/brainDev/src//utilities/data_manager.py:5528: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s section_limits: %s\n" % (stack, e.message))
# Failed to cache MD590 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/alexn/brainDev/src//utilities/data_manager.py:5534: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s cropbox: %s\n" % (stack, e.message))
# Failed to cache MD590 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# /home/alexn/brainDev/src//utilities/data_manager.py:5544: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s valid_sections/filenames: %s\n" % (stack, e.message))
# Failed to cache MD590 valid_sections/filenames: MD590
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/alexn/brainDev/src//utilities/data_manager.py:5555: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s image_shape: %s\n" % (stack, e.message))
# Failed to cache MD590 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD590/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/MD591_sorted_filenames.txt
# Failed to cache MD591 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/MD591_sorted_filenames.txt
# Failed to cache MD591 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD591 valid_sections/filenames: MD591
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD591 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD591/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/MD592_sorted_filenames.txt
# Failed to cache MD592 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/MD592_sorted_filenames.txt
# Failed to cache MD592 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD592 valid_sections/filenames: MD592
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD592 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD592/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/MD593_sorted_filenames.txt
# Failed to cache MD593 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/MD593_sorted_filenames.txt
# Failed to cache MD593 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD593 valid_sections/filenames: MD593
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD593 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD593/operation_configs/from_none_to_aligned.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/MD595_sorted_filenames.txt
# Failed to cache MD595 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/MD595_sorted_filenames.txt
# Failed to cache MD595 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD595 valid_sections/filenames: MD595
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD595 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD595/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/MD598_sorted_filenames.txt
# Failed to cache MD598 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/MD598_sorted_filenames.txt
# Failed to cache MD598 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD598 valid_sections/filenames: MD598
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD598 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD598/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/MD599_sorted_filenames.txt
# Failed to cache MD599 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/MD599_sorted_filenames.txt
# Failed to cache MD599 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD599 valid_sections/filenames: MD599
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD599 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD599/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/MD602_sorted_filenames.txt
# Failed to cache MD602 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/MD602_sorted_filenames.txt
# Failed to cache MD602 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD602 valid_sections/filenames: MD602
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD602 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD602/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/MD603_sorted_filenames.txt
# Failed to cache MD603 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/MD603_sorted_filenames.txt
# Failed to cache MD603 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD603 valid_sections/filenames: MD603
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD603 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD603/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/MD635_sorted_filenames.txt
# Failed to cache MD635 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/MD635_sorted_filenames.txt
# Failed to cache MD635 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD635 valid_sections/filenames: MD635
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD635 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD635/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/MD653_sorted_filenames.txt
# Failed to cache MD653 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/MD653_sorted_filenames.txt
# Failed to cache MD653 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD653 valid_sections/filenames: MD653
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD653 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD653/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/MD652_sorted_filenames.txt
# Failed to cache MD652 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/MD652_sorted_filenames.txt
# Failed to cache MD652 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD652 valid_sections/filenames: MD652
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD652 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD652/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/MD642_sorted_filenames.txt
# Failed to cache MD642 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/MD642_sorted_filenames.txt
# Failed to cache MD642 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD642 valid_sections/filenames: MD642
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD642 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD642/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/MD657_sorted_filenames.txt
# Failed to cache MD657 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/MD657_sorted_filenames.txt
# Failed to cache MD657 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD657 valid_sections/filenames: MD657
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD657 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD657/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/MD658_sorted_filenames.txt
# Failed to cache MD658 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/MD658_sorted_filenames.txt
# Failed to cache MD658 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD658 valid_sections/filenames: MD658
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD658 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD658/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/MD661_sorted_filenames.txt
# Failed to cache MD661 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/MD661_sorted_filenames.txt
# Failed to cache MD661 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD661 valid_sections/filenames: MD661
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD661 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD661/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD662 valid_sections/filenames: MD662
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt
# Failed to cache CHATM2 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/CHATM2_sorted_filenames.txt
# Failed to cache CHATM2 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache CHATM2 valid_sections/filenames: CHATM2
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM2 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM2/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt
# Failed to cache CHATM3 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/CHATM3_sorted_filenames.txt
# Failed to cache CHATM3 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache CHATM3 valid_sections/filenames: CHATM3
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache CHATM3 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/CHATM3/operation_configs/from_none_to_aligned.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# xgboost is not loaded.
# xgboost is not loaded.ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# [17:04:46] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.9.4. Attempting to upgrade...
# [17:04:46] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/mxnet/module/base_module.py:53: UserWarning: You created Module with Module(..., label_names=['softmax_label']) but input with name 'softmax_label' is not found in symbol.list_arguments(). Did you mean one of:
# 	data
#   warnings.warn(msg)
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/mxnet/module/base_module.py:65: UserWarning: Data provided by label_shapes don't match names specified by label_names ([] vs. ['softmax_label'])
#   warnings.warn(msg)
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# MD585_annotation_grid_indices.h5
# MD585_annotation_contours_05302018161849.hdf
# MD585_annotation_v3.h5
# MD585_annotation_win12_05302018161849_grid_indices_lookup.hdf
# MD585_annotation_win12_05302018161849_grid_indices_lookup.hdf None
# MD585_annotation_win1_05302018161849_grid_indices_lookup.hdf
# MD585_annotation_win1_05302018161849_grid_indices_lookup.hdf None
# MD585_annotation_win7_08012017212649_grid_indices_lookup.hdf
# latest timestamp:  08012017212649
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# ^C

# %%
metadata_cache['image_shape']
# Out:
# {u'MD603': (18144, 14112)}

# %%
from sklearn.externals import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC, SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import GradientBoostingClassifier 

sys.path.append('/home/yuncong/csd395/xgboost/python-package')
try:
    from xgboost.sklearn import XGBClassifier
except:
    sys.stderr.write('xgboost is not loaded.')

# %%
batch_size = 256
model_dir_name = 'inception-bn-blue'
model_name = 'inception-bn-blue'
model, mean_img = load_mxnet_model(model_dir_name=model_dir_name, model_name=model_name, 
                                   num_gpus=1, batch_size=batch_size)
# Out:
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a4e2a40e6c5e> in <module>()
#       3 model_name = 'inception-bn-blue'
#       4 model, mean_img = load_mxnet_model(model_dir_name=model_dir_name, model_name=model_name,
# ----> 5                                    num_gpus=1, batch_size=batch_size)
#
# /home/alexn/brainDev/src//utilities/learning_utilities.pyc in load_mxnet_model(model_dir_name, model_name, num_gpus, batch_size, output_symbol_name)
#     278     # Reference on how to predict with mxnet model:
#     279     # https://github.com/dmlc/mxnet-notebooks/blob/master/python/how_to/predict.ipynb
# --> 280     model0, arg_params, aux_params = mx.model.load_checkpoint(os.path.join(MXNET_MODEL_ROOTDIR, model_dir_name, model_name), 0)
#     281     flatten_output = model0.get_internals()[output_symbol_name]
#     282     # if HOST_ID == 'workstation':
#
# NameError: global name 'mx' is not defined

# %%
train_stacks = ['MD589', 'MD585']
test_stacks = ['MD594']

# %%
train_stacks = ['MD589']
test_stacks = ['MD589']

# %%
stack_stain = {'MD585': 'N', 'MD589': 'N', 'MD594': 'N'}

# Number of sections on which to sample examples from.
stack_section_number = defaultdict(dict)

for name_u in all_known_structures:
    for st in train_stacks:
        stack_section_number[st][name_u] = 10
#         if name_u == '4N' or name_u == '10N':
#             stack_section_number[st][name_u] = 20
#         else:
#             stack_section_number[st][name_u] = 10
    for st in test_stacks:
        stack_section_number[st][name_u] = 10

stack_section_number.default_factory = None

# %%
stack_section_number
# Out:
# defaultdict(None,
#             {'MD585': {'10N': 10,
#               '12N': 10,
#               '3N': 10,
#               '4N': 10,
#               '5N': 10,
#               '6N': 10,
#               '7N': 10,
#               '7n': 10,
#               'AP': 10,
#               'Amb': 10,
#               'DC': 10,
#               'IC': 10,
#               'LC': 10,
#               'LRt': 10,
#               'PBG': 10,
#               'Pn': 10,
#               'RMC': 10,
#               'RtTg': 10,
#               'SC': 10,
#               'SNC': 10,
#               'SNR': 10,
#               'Sp5C': 10,
#               'Sp5I': 10,
#               'Sp5O': 10,
#               'Tz': 10,
#               'VCA': 10,
#               'VCP': 10,
#               'VLL': 10},
#              'MD589': {'10N': 10,
#               '12N': 10,
#               '3N': 10,
#               '4N': 10,
#               '5N': 10,
#               '6N': 10,
#               '7N': 10,
#               '7n': 10,
#               'AP': 10,
#               'Amb': 10,
#               'DC': 10,
#               'IC': 10,
#               'LC': 10,
#               'LRt': 10,
#               'PBG': 10,
#               'Pn': 10,
#               'RMC': 10,
#               'RtTg': 10,
#               'SC': 10,
#               'SNC': 10,
#               'SNR': 10,
#               'Sp5C': 10,
#               'Sp5I': 10,
#               'Sp5O': 10,
#               'Tz': 10,
#               'VCA': 10,
#               'VCP': 10,
#               'VLL': 10},
#              'MD594': {'10N': 10,
#               '12N': 10,
#               '3N': 10,
#               '4N': 10,
#               '5N': 10,
#               '6N': 10,
#               '7N': 10,
#               '7n': 10,
#               'AP': 10,
#               'Amb': 10,
#               'DC': 10,
#               'IC': 10,
#               'LC': 10,
#               'LRt': 10,
#               'PBG': 10,
#               'Pn': 10,
#               'RMC': 10,
#               'RtTg': 10,
#               'SC': 10,
#               'SNC': 10,
#               'SNR': 10,
#               'Sp5C': 10,
#               'Sp5I': 10,
#               'Sp5O': 10,
#               'Tz': 10,
#               'VCA': 10,
#               'VCP': 10,
#               'VLL': 10}})

# %%
windowing_settings
# Out:
# {1: {'patch_size': 224, 'spacing': 56},
#  2: {'comment': 'larger margin', 'patch_size': 224, 'spacing': 56},
#  3: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 32},
#  4: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 128},
#  5: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 64},
#  6: {'comment': 'twice as large patch', 'patch_size': 448, 'spacing': 64},
#  7: {'comment': 'specify size/spacing in terms of microns rather than pixels',
#   'patch_size_um': 103.04,
#   'spacing_um': 30},
#  8: {'comment': 'larger patch', 'patch_size_um': 206.08, 'spacing_um': 30},
#  9: {'comment': 'larger patch', 'patch_size_um': 412.16, 'spacing_um': 30},
#  10: {'comment': 'larger patch', 'patch_size_um': 824.32, 'spacing_um': 30},
#  11: {'comment': 'larger patch', 'patch_size_um': 51.52, 'spacing_um': 30},
#  12: {'comment': 'larger patch', 'patch_size_um': 25.76, 'spacing_um': 30}}

# %%
win_id = 7
# win_id = 8
# win_id = 9
# win_id = 11
# win_id = 8

# %%
grid_indices_lookup_allStacks = {}

for stack in train_stacks + test_stacks:
#     try:
#         grid_indices_lookup_allStacks[stack] = \
#         DataManager.load_annotation_to_grid_indices_lookup(stack=stack, win_id=win_id,
#                                                            by_human=False, timestamp='latest',
#                                                            detector_id_f=1,
#                                                           return_locations=True)            

#         grid_indices_lookup_allStacks[stack] = \
#         DataManager.load_annotation_to_grid_indices_lookup(stack=stack, win_id=win_id,
#                                                            by_human=True, timestamp='latest',
#                                                           return_locations=True, suffix='structures')            

    grid_indices_lookup_allStacks[stack] = \
    DataManager.load_annotation_to_grid_indices_lookup(stack=stack, win_id=win_id,
                                                       by_human=True, timestamp='latest',
                                                      return_locations=True)

#     except Exception as e:
#         sys.stderr.write("Fail to load annotation grid lookup for %s: %s\n" % (stack, e.message))
#         raise e
# Out:
# MD589_annotation_structures_10312017220057.hdf
# MD589_annotation_v3.h5
# MD589_annotation_v3_09252016160841.h5
# MD589_annotation_v3_09252016172320.h5
# MD589_annotation_v3_09252016195300.h5
# MD589_annotation_contours_05302018164231.hdf
# MD589_annotation_grid_indices.h5
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-33-65fdef8a1371> in <module>()
#      16     grid_indices_lookup_allStacks[stack] =     DataManager.load_annotation_to_grid_indices_lookup(stack=stack, win_id=win_id,
#      17                                                        by_human=True, timestamp='latest',
# ---> 18                                                       return_locations=True)
#      19
#      20 #     except Exception as e:
#
# /home/alexn/brainDev/src//utilities/data_manager.pyc in load_annotation_to_grid_indices_lookup(stack, win_id, by_human, stack_m, detector_id_m, detector_id_f, prep_id_m, prep_id_f, warp_setting, trial_idx, timestamp, return_locations, suffix)
#     781         from learning_utilities import grid_parameters_to_sample_locations
#     782
# --> 783         grid_indices_lookup_fp = DataManager.get_annotation_to_grid_indices_lookup_filepath(**locals())
#     784         download_from_s3(grid_indices_lookup_fp)
#     785
#
# /home/alexn/brainDev/src//utilities/data_manager.pyc in get_annotation_to_grid_indices_lookup_filepath(stack, win_id, by_human, stack_m, detector_id_m, detector_id_f, prep_id_m, prep_id_f, warp_setting, trial_idx, timestamp, suffix, **kwargs)
#     843                     else:
#     844                         timestamps.append((datetime.strptime(ts, '%m%d%Y%H%M%S'), ts))
# --> 845                 assert len(timestamps) > 0, 'No annotation files can be found.'
#     846                 timestamp = sorted(timestamps)[-1][1]
#     847                 print "latest timestamp: ", timestamp
#
# AssertionError: No annotation files can be found.

# %%
grid_indices_lookup_allStacks = {}
grid_indices_lookup_allStacks['MD589'] = DataManager.load_annotation_to_grid_indices_lookup(stack='MD585',win_id=1, by_human=True, timestamp='latest', return_locations=True)

print ''
print grid_indices_lookup_allStacks
# Out:
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# MD585_annotation_grid_indices.h5
# MD585_annotation_contours_05302018161849.hdf
# MD585_annotation_v3.h5
# MD585_annotation_win12_05302018161849_grid_indices_lookup.hdf
# MD585_annotation_win12_05302018161849_grid_indices_lookup.hdf None
# MD585_annotation_win1_05302018161849_grid_indices_lookup.hdf
# MD585_annotation_win7_08012017212649_grid_indices_lookup.hdf
# MD585_annotation_win7_08012017212649_grid_indices_lookup.hdf None
# latest timestamp:  05302018161849
#
# {'MD589':      10N 10N_negative 10N_surround_200um_12N 10N_surround_200um_AP  \
# 83   NaN          NaN                    NaN                   NaN
# 84   NaN          NaN                    NaN                   NaN
# 85   NaN          NaN                    NaN                   NaN
# 86   NaN          NaN                    NaN                   NaN
# 87   NaN          NaN                    NaN                   NaN
# 88   NaN          NaN                    NaN                   NaN
# 89   NaN          NaN                    NaN                   NaN
# 90   NaN          NaN                    NaN                   NaN
# 91   NaN          NaN                    NaN                   NaN
# 92   NaN          NaN                    NaN                   NaN
# 93   NaN          NaN                    NaN                   NaN
# 94   NaN          NaN                    NaN                   NaN
# 95   NaN          NaN                    NaN                   NaN
# 96   NaN          NaN                    NaN                   NaN
# 97   NaN          NaN                    NaN                   NaN
# 98   NaN          NaN                    NaN                   NaN
# 99   NaN          NaN                    NaN                   NaN
# 100  NaN          NaN                    NaN                   NaN
# 101  NaN          NaN                    NaN                   NaN
# 102  NaN          NaN                    NaN                   NaN
# 103  NaN          NaN                    NaN                   NaN
# 104  NaN          NaN                    NaN                   NaN
# 105  NaN          NaN                    NaN                   NaN
# 106  NaN          NaN                    NaN                   NaN
# 107  NaN          NaN                    NaN                   NaN
# 108  NaN          NaN                    NaN                   NaN
# 109  NaN          NaN                    NaN                   NaN
# 110  NaN          NaN                    NaN                   NaN
# 111  NaN          NaN                    NaN                   NaN
# 112  NaN          NaN                    NaN                   NaN
# ..   ...          ...                    ...                   ...
# 323  NaN          NaN                    NaN                   NaN
# 324  NaN          NaN                    NaN                   NaN
# 325  NaN          NaN                    NaN                   NaN
# 326  NaN          NaN                    NaN                   NaN
# 327  NaN          NaN                    NaN                   NaN
# 105                      NaN           ...                               NaN
# 106                      NaN           ...                               NaN
# 107                      NaN           ...                               NaN
# 108                      NaN           ...                               NaN
# 109                      NaN           ...                               NaN
# 110                      NaN           ...                               NaN
# 111                      NaN           ...                               NaN
# 112                      NaN           ...                               NaN
# ..                       ...           ...                               ...
# 323                      NaN           ...                               NaN
# 324                      NaN           ...                               NaN
# 325                      NaN           ...                               NaN
# 326                      NaN           ...                               NaN
# 327                      NaN           ...                               NaN
# 328                      NaN           ...                               NaN
# 329                      NaN           ...                               NaN
# 330                      NaN           ...                               NaN
# 331                      NaN           ...                               NaN
# 332                      NaN           ...                               NaN
# 333                      NaN           ...                               NaN
# 334                      NaN           ...                               NaN
# 335                      NaN           ...                               NaN
# 336                      NaN           ...                               NaN
# 337                      NaN           ...                               NaN
# 338                      NaN           ...                               NaN
# 339                      NaN           ...                               NaN
# 340                      NaN           ...                               NaN
# 341                      NaN           ...                               NaN
# 342                      NaN           ...                               NaN
# 343                      NaN           ...                               NaN
# 344                      NaN           ...                               NaN
# 345                      NaN           ...                               NaN
# 346                      NaN           ...                               NaN
# 347                      NaN           ...                               NaN
# 348                      NaN           ...                               NaN
# 349                      NaN           ...                               NaN
# 350                      NaN           ...                               NaN
# 351                      NaN           ...                               NaN
# 352                      NaN           ...                               NaN
#
#     VLL_surround_500um_noclass    X X_negative X_surround_200um_8n  \
# 83                         NaN  NaN        NaN                 NaN
# 84                         NaN  NaN        NaN                 NaN
# 85                         NaN  NaN        NaN                 NaN
# 86                         NaN  NaN        NaN                 NaN
# 87                         NaN  NaN        NaN                 NaN
# 88                         NaN  NaN        NaN                 NaN
# 89                         NaN  NaN        NaN                 NaN
# 90                         NaN  NaN        NaN                 NaN
# 91                         NaN  NaN        NaN                 NaN
# 92                         NaN  NaN        NaN                 NaN
# 93                         NaN  NaN        NaN                 NaN
# 94                         NaN  NaN        NaN                 NaN
# 95                         NaN  NaN        NaN                 NaN
# 96                         NaN  NaN        NaN                 NaN
# 97                         NaN  NaN        NaN                 NaN
# 98                         NaN  NaN        NaN                 NaN
# 99                         NaN  NaN        NaN                 NaN
# 100                        NaN  NaN        NaN                 NaN
# 101                        NaN  NaN        NaN                 NaN
# 102                        NaN  NaN        NaN                 NaN
# 103                        NaN  NaN        NaN                 NaN
# 104                        NaN  NaN        NaN                 NaN
# 105                        NaN  NaN        NaN                 NaN
# 106                        NaN  NaN        NaN                 NaN
# 107                        NaN  NaN        NaN                 NaN
# 108                        NaN  NaN        NaN                 NaN
# 109                        NaN  NaN        NaN                 NaN
# 110                        NaN  NaN        NaN                 NaN
# 111                        NaN  NaN        NaN                 NaN
# 112                        NaN  NaN        NaN                 NaN
# ..                         ...  ...        ...                 ...
# 323                        NaN  NaN        NaN                 NaN
# 324                        NaN  NaN        NaN                 NaN
# 325                        NaN  NaN        NaN                 NaN
# 326                        NaN  NaN        NaN                 NaN
# 327                        NaN  NaN        NaN                 NaN
# 328                        NaN  NaN        NaN                 NaN
# 329                        NaN  NaN        NaN                 NaN
# 343                      NaN                 NaN                 NaN
# 344                      NaN                 NaN                 NaN
# 345                      NaN                 NaN                 NaN
# 346                      NaN                 NaN                 NaN
# 347                      NaN                 NaN                 NaN
# 348                      NaN                 NaN                 NaN
# 349                      NaN                 NaN                 NaN
# 350                      NaN                 NaN                 NaN
# 351                      NaN                 NaN                 NaN
# 352                      NaN                 NaN                 NaN
#
#     X_surround_500um_Sp5O X_surround_500um_noclass
# 83                    NaN                      NaN
# 84                    NaN                      NaN
# 85                    NaN                      NaN
# 86                    NaN                      NaN
# 87                    NaN                      NaN
# 88                    NaN                      NaN
# 89                    NaN                      NaN
# 90                    NaN                      NaN
# 91                    NaN                      NaN
# 92                    NaN                      NaN
# 93                    NaN                      NaN
# 94                    NaN                      NaN
# 95                    NaN                      NaN
# 96                    NaN                      NaN
# 97                    NaN                      NaN
# 98                    NaN                      NaN
# 99                    NaN                      NaN
# 100                   NaN                      NaN
# 101                   NaN                      NaN
# 102                   NaN                      NaN
# 103                   NaN                      NaN
# 104                   NaN                      NaN
# 105                   NaN                      NaN
# 106                   NaN                      NaN
# 107                   NaN                      NaN
# 108                   NaN                      NaN
# 109                   NaN                      NaN
# 110                   NaN                      NaN
# 111                   NaN                      NaN
# 112                   NaN                      NaN
# ..                    ...                      ...
# 323                   NaN                      NaN
# 324                   NaN                      NaN
# 325                   NaN                      NaN
# 326                   NaN                      NaN
# 327                   NaN                      NaN
# 328                   NaN                      NaN
# 329                   NaN                      NaN
# 330                   NaN                      NaN
# 331                   NaN                      NaN
# 332                   NaN                      NaN
# 333                   NaN                      NaN
# 334                   NaN                      NaN
# 335                   NaN                      NaN
# 336                   NaN                      NaN
# 337                   NaN                      NaN
# 338                   NaN                      NaN
# 339                   NaN                      NaN
# 340                   NaN                      NaN
# 341                   NaN                      NaN
# 342                   NaN                      NaN
# 343                   NaN                      NaN
# 344                   NaN                      NaN
# 345                   NaN                      NaN
# 346                   NaN                      NaN
# 347                   NaN                      NaN
# 348                   NaN                      NaN
# 349                   NaN                      NaN
# 350                   NaN                      NaN
# 351                   NaN                      NaN
# 352                   NaN                      NaN
#
# [268 rows x 457 columns]}

# %%
sorted(list(set(chain.from_iterable(  set(grid_indices_lookup_allStacks[st].columns.tolist())   for st in train_stacks + test_stacks))))
# Out:
# ['10N',
#  '10N_negative',
#  '10N_surround_200um_12N',
#  '10N_surround_200um_AP',
#  '10N_surround_200um_SolIM',
#  '10N_surround_200um_noclass',
#  '10N_surround_500um_12N',
#  '10N_surround_500um_AP',
#  '10N_surround_500um_Gr',
#  '10N_surround_500um_SolIM',
#  '10N_surround_500um_noclass',
#  '12N',
#  '12N_negative',
#  '12N_surround_200um_10N',
#  '12N_surround_200um_AP',
#  '12N_surround_200um_noclass',
#  '12N_surround_500um_10N',
#  '12N_surround_500um_AP',
#  '12N_surround_500um_noclass',
#  '3N',
#  '3N_negative',
#  '3N_surround_200um_4N',
#  '3N_surround_200um_noclass',
#  '3N_surround_500um_4N',
#  '3N_surround_500um_RMC',
#  '3N_surround_500um_noclass',
#  '4N',
#  '4N_negative',
#  '4N_surround_200um_3N',
#  '4N_surround_200um_noclass',
#  '4N_surround_500um_3N',
#  '4N_surround_500um_noclass',
#  '5N',
#  '5N_negative',
#  '5N_surround_200um_noclass',
#  '5N_surround_500um_7n',
#  '5N_surround_500um_LPB',
#  '5N_surround_500um_MVeMC',
#  '5N_surround_500um_MVePC',
#  '5N_surround_500um_Sp5O',
#  '5N_surround_500um_SuVe',
#  '5N_surround_500um_VLL',
#  '5N_surround_500um_noclass',
#  '6N',
#  '6N_negative',
#  '6N_surround_200um_7n',
#  '6N_surround_200um_noclass',
#  '6N_surround_500um_7n',
#  '6N_surround_500um_noclass',
#  '7N',
#  '7N_negative',
#  '7N_surround_200um_Amb',
#  '7N_surround_200um_Sp5O',
#  '7N_surround_200um_noclass',
#  '7N_surround_500um_7n',
#  '7N_surround_500um_Amb',
#  '7N_surround_500um_LRt',
#  '7N_surround_500um_Sp5O',
#  '7N_surround_500um_noclass',
#  '7n',
#  '7n_negative',
#  '7n_surround_200um_6N',
#  '7n_surround_200um_MVeMC',
#  '7n_surround_200um_Sp5O',
#  '7n_surround_200um_noclass',
#  '7n_surround_500um_5N',
#  '7n_surround_500um_6N',
#  '7n_surround_500um_7N',
#  '7n_surround_500um_Bar',
#  '7n_surround_500um_LC',
#  '7n_surround_500um_MVeMC',
#  '7n_surround_500um_MVePC',
#  '7n_surround_500um_Sp5O',
#  '7n_surround_500um_noclass',
#  '8n',
#  '8n_negative',
#  '8n_surround_200um_Pr5DM',
#  '8n_surround_200um_Sp5O',
#  '8n_surround_200um_VCA',
#  '8n_surround_200um_VCP',
#  '8n_surround_200um_X',
#  '8n_surround_200um_noclass',
#  '8n_surround_500um_Cb',
#  '8n_surround_500um_DC',
#  '8n_surround_500um_Pr5DM',
#  '8n_surround_500um_Pr5VL',
#  '8n_surround_500um_Sp5O',
#  '8n_surround_500um_VCA',
#  '8n_surround_500um_VCP',
#  '8n_surround_500um_X',
#  '8n_surround_500um_noclass',
#  'AP',
#  'APT',
#  'APT_negative',
#  'APT_surround_200um_SC',
#  'APT_surround_200um_noclass',
#  'APT_surround_500um_SC',
#  'APT_surround_500um_noclass',
#  'AP_negative',
#  'AP_surround_200um_10N',
#  'AP_surround_200um_12N',
#  'AP_surround_200um_noclass',
#  'AP_surround_500um_10N',
#  'AP_surround_500um_12N',
#  'AP_surround_500um_noclass',
#  'Amb',
#  'Amb_negative',
#  'Amb_surround_200um_7N',
#  'Amb_surround_200um_LRt',
#  'Amb_surround_200um_noclass',
#  'Amb_surround_500um_7N',
#  'Amb_surround_500um_LRt',
#  'Amb_surround_500um_Sp5O',
#  'Amb_surround_500um_noclass',
#  'Bar',
#  'Bar_negative',
#  'Bar_surround_200um_noclass',
#  'Bar_surround_500um_7n',
#  'Bar_surround_500um_Cb',
#  'Bar_surround_500um_noclass',
#  'Cb',
#  'Cb_negative',
#  'Cb_surround_200um_DC',
#  'Cb_surround_200um_IC',
#  'Cb_surround_200um_Pr5DM',
#  'Cb_surround_200um_noclass',
#  'Cb_surround_500um_8n',
#  'Cb_surround_500um_Bar',
#  'Cb_surround_500um_DC',
#  'Cb_surround_500um_IC',
#  'Cb_surround_500um_Pr5DM',
#  'Cb_surround_500um_Sp5I',
#  'Cb_surround_500um_VCA',
#  'Cb_surround_500um_noclass',
#  'Cu',
#  'Cu_negative',
#  'Cu_surround_200um_Sol',
#  'Cu_surround_200um_SpVe',
#  'Cu_surround_200um_noclass',
#  'Cu_surround_500um_Sol',
#  'Cu_surround_500um_SpVe',
#  'Cu_surround_500um_noclass',
#  'DC',
#  'DC_negative',
#  'DC_surround_200um_Cb',
#  'DC_surround_200um_VCA',
#  'DC_surround_200um_VCP',
#  'DC_surround_200um_noclass',
#  'DC_surround_500um_8n',
#  'DC_surround_500um_Cb',
#  'DC_surround_500um_Sp5O',
#  'DC_surround_500um_VCA',
#  'DC_surround_500um_VCP',
#  'DC_surround_500um_X',
#  'DC_surround_500um_noclass',
#  'Gr',
#  'Gr_negative',
#  'Gr_surround_200um_SolIM',
#  'Gr_surround_200um_noclass',
#  'Gr_surround_500um_10N',
#  'Gr_surround_500um_SolIM',
#  'Gr_surround_500um_noclass',
#  'IC',
#  'IC_negative',
#  'IC_surround_200um_Cb',
#  'IC_surround_200um_SC',
#  'IC_surround_200um_noclass',
#  'IC_surround_500um_Cb',
#  'IC_surround_500um_PBG',
#  'IC_surround_500um_SC',
#  'IC_surround_500um_noclass',
#  'IO',
#  'IO_negative',
#  'IO_surround_200um_noclass',
#  'IO_surround_500um_noclass',
#  'LC',
#  'LC_negative',
#  'LC_surround_200um_MVeMC',
#  'LC_surround_200um_MVePC',
#  'LC_surround_200um_noclass',
#  'LC_surround_500um_7n',
#  'LC_surround_500um_MVeMC',
#  'LC_surround_500um_MVePC',
#  'LC_surround_500um_SpVe',
#  'LC_surround_500um_noclass',
#  'LPB',
#  'LPB_negative',
#  'LPB_surround_200um_noclass',
#  'LPB_surround_500um_5N',
#  'LPB_surround_500um_SuVe',
#  'LPB_surround_500um_noclass',
#  'LRt',
#  'LRt_negative',
#  'LRt_surround_200um_Amb',
#  'LRt_surround_200um_Sp5C',
#  'LRt_surround_200um_noclass',
#  'LRt_surround_500um_7N',
#  'LRt_surround_500um_Amb',
#  'LRt_surround_500um_Sp5C',
#  'LRt_surround_500um_Sp5I',
#  'LRt_surround_500um_noclass',
#  'LVe',
#  'LVe_negative',
#  'LVe_surround_200um_SuVe',
#  'LVe_surround_200um_noclass',
#  'LVe_surround_500um_Sp5O',
#  'LVe_surround_500um_SuVe',
#  'LVe_surround_500um_noclass',
#  'MVeMC',
#  'MVeMC_negative',
#  'MVeMC_surround_200um_7n',
#  'MVeMC_surround_200um_LC',
#  'MVeMC_surround_200um_MVePC',
#  'MVeMC_surround_200um_Sol',
#  'MVeMC_surround_200um_SpVe',
#  'MVeMC_surround_200um_SuVe',
#  'MVeMC_surround_200um_noclass',
#  'MVeMC_surround_500um_5N',
#  'MVeMC_surround_500um_7n',
#  'MVeMC_surround_500um_LC',
#  'MVeMC_surround_500um_MVePC',
#  'MVeMC_surround_500um_Sol',
#  'MVeMC_surround_500um_SpVe',
#  'MVeMC_surround_500um_SuVe',
#  'MVeMC_surround_500um_noclass',
#  'MVePC',
#  'MVePC_negative',
#  'MVePC_surround_200um_LC',
#  'MVePC_surround_200um_MVeMC',
#  'MVePC_surround_200um_SpVe',
#  'MVePC_surround_200um_SuVe',
#  'MVePC_surround_200um_noclass',
#  'MVePC_surround_500um_5N',
#  'MVePC_surround_500um_7n',
#  'MVePC_surround_500um_LC',
#  'MVePC_surround_500um_MVeMC',
#  'MVePC_surround_500um_SpVe',
#  'MVePC_surround_500um_SuVe',
#  'MVePC_surround_500um_noclass',
#  'PBG',
#  'PBG_negative',
#  'PBG_surround_200um_noclass',
#  'PBG_surround_500um_IC',
#  'PBG_surround_500um_SNR',
#  'PBG_surround_500um_VLL',
#  'PBG_surround_500um_noclass',
#  'Pn',
#  'Pn_negative',
#  'Pn_surround_200um_RtTg',
#  'Pn_surround_200um_noclass',
#  'Pn_surround_500um_RtTg',
#  'Pn_surround_500um_SNR',
#  'Pn_surround_500um_Tz',
#  'Pn_surround_500um_noclass',
#  'Pr5DM',
#  'Pr5DM_negative',
#  'Pr5DM_surround_200um_8n',
#  'Pr5DM_surround_200um_Cb',
#  'Pr5DM_surround_200um_Pr5VL',
#  'Pr5DM_surround_200um_Sp5O',
#  'Pr5DM_surround_200um_noclass',
#  'Pr5DM_surround_500um_8n',
#  'Pr5DM_surround_500um_Cb',
#  'Pr5DM_surround_500um_Pr5VL',
#  'Pr5DM_surround_500um_Sp5O',
#  'Pr5DM_surround_500um_VLL',
#  'Pr5DM_surround_500um_noclass',
#  'Pr5VL',
#  'Pr5VL_negative',
#  'Pr5VL_surround_200um_Pr5DM',
#  'Pr5VL_surround_200um_Sp5O',
#  'Pr5VL_surround_200um_VLL',
#  'Pr5VL_surround_200um_noclass',
#  'Pr5VL_surround_500um_8n',
#  'Pr5VL_surround_500um_Pr5DM',
#  'Pr5VL_surround_500um_Sp5O',
#  'Pr5VL_surround_500um_VLL',
#  'Pr5VL_surround_500um_noclass',
#  'RMC',
#  'RMC_negative',
#  'RMC_surround_200um_noclass',
#  'RMC_surround_500um_3N',
#  'RMC_surround_500um_4N',
#  'RMC_surround_500um_SNR',
#  'RMC_surround_500um_noclass',
#  'RR',
#  'RR_negative',
#  'RR_surround_200um_noclass',
#  'RR_surround_500um_SNR',
#  'RR_surround_500um_noclass',
#  'RtTg',
#  'RtTg_negative',
#  'RtTg_surround_200um_Pn',
#  'RtTg_surround_200um_Tz',
#  'RtTg_surround_200um_noclass',
#  'RtTg_surround_500um_Pn',
#  'RtTg_surround_500um_SNR',
#  'RtTg_surround_500um_Tz',
#  'RtTg_surround_500um_noclass',
#  'SC',
#  'SC_negative',
#  'SC_surround_200um_APT',
#  'SC_surround_200um_IC',
#  'SC_surround_200um_noclass',
#  'SC_surround_500um_APT',
#  'SC_surround_500um_IC',
#  'SC_surround_500um_noclass',
#  'SNC',
#  'SNC_negative',
#  'SNC_surround_200um_SNR',
#  'SNC_surround_200um_noclass',
#  'SNC_surround_500um_SNR',
#  'SNC_surround_500um_noclass',
#  'SNR',
#  'SNR_negative',
#  'SNR_surround_200um_SNC',
#  'SNR_surround_200um_noclass',
#  'SNR_surround_500um_PBG',
#  'SNR_surround_500um_Pn',
#  'SNR_surround_500um_RMC',
#  'SNR_surround_500um_RR',
#  'SNR_surround_500um_RtTg',
#  'SNR_surround_500um_SNC',
#  'SNR_surround_500um_VLL',
#  'SNR_surround_500um_noclass',
#  'Sol',
#  'SolIM',
#  'SolIM_negative',
#  'SolIM_surround_200um_10N',
#  'SolIM_surround_200um_Gr',
#  'SolIM_surround_200um_noclass',
#  'SolIM_surround_500um_10N',
#  'SolIM_surround_500um_Gr',
#  'SolIM_surround_500um_noclass',
#  'Sol_negative',
#  'Sol_surround_200um_Cu',
#  'Sol_surround_200um_MVeMC',
#  'Sol_surround_200um_SpVe',
#  'Sol_surround_200um_noclass',
#  'Sol_surround_500um_Cu',
#  'Sol_surround_500um_MVeMC',
#  'Sol_surround_500um_SpVe',
#  'Sol_surround_500um_noclass',
#  'Sp5C',
#  'Sp5C_negative',
#  'Sp5C_surround_200um_LRt',
#  'Sp5C_surround_200um_Sp5I',
#  'Sp5C_surround_200um_noclass',
#  'Sp5C_surround_500um_LRt',
#  'Sp5C_surround_500um_Sp5I',
#  'Sp5C_surround_500um_Sp5O',
#  'Sp5C_surround_500um_noclass',
#  'Sp5I',
#  'Sp5I_negative',
#  'Sp5I_surround_200um_Sp5C',
#  'Sp5I_surround_200um_Sp5O',
#  'Sp5I_surround_200um_noclass',
#  'Sp5I_surround_500um_Cb',
#  'Sp5I_surround_500um_LRt',
#  'Sp5I_surround_500um_Sp5C',
#  'Sp5I_surround_500um_Sp5O',
#  'Sp5I_surround_500um_noclass',
#  'Sp5O',
#  'Sp5O_negative',
#  'Sp5O_surround_200um_7N',
#  'Sp5O_surround_200um_7n',
#  'Sp5O_surround_200um_8n',
#  'Sp5O_surround_200um_Pr5DM',
#  'Sp5O_surround_200um_Pr5VL',
#  'Sp5O_surround_200um_Sp5I',
#  'Sp5O_surround_200um_noclass',
#  'Sp5O_surround_500um_5N',
#  'Sp5O_surround_500um_7N',
#  'Sp5O_surround_500um_7n',
#  'Sp5O_surround_500um_8n',
#  'Sp5O_surround_500um_Amb',
#  'Sp5O_surround_500um_DC',
#  'Sp5O_surround_500um_LVe',
#  'Sp5O_surround_500um_Pr5DM',
#  'Sp5O_surround_500um_Pr5VL',
#  'Sp5O_surround_500um_Sp5C',
#  'Sp5O_surround_500um_Sp5I',
#  'Sp5O_surround_500um_X',
#  'Sp5O_surround_500um_noclass',
#  'SpVe',
#  'SpVe_negative',
#  'SpVe_surround_200um_Cu',
#  'SpVe_surround_200um_MVeMC',
#  'SpVe_surround_200um_MVePC',
#  'SpVe_surround_200um_Sol',
#  'SpVe_surround_200um_noclass',
#  'SpVe_surround_500um_Cu',
#  'SpVe_surround_500um_LC',
#  'SpVe_surround_500um_MVeMC',
#  'SpVe_surround_500um_MVePC',
#  'SpVe_surround_500um_Sol',
#  'SpVe_surround_500um_SuVe',
#  'SpVe_surround_500um_noclass',
#  'SuVe',
#  'SuVe_negative',
#  'SuVe_surround_200um_LVe',
#  'SuVe_surround_200um_MVeMC',
#  'SuVe_surround_200um_MVePC',
#  'SuVe_surround_200um_noclass',
#  'SuVe_surround_500um_5N',
#  'SuVe_surround_500um_LPB',
#  'SuVe_surround_500um_LVe',
#  'SuVe_surround_500um_MVeMC',
#  'SuVe_surround_500um_MVePC',
#  'SuVe_surround_500um_SpVe',
#  'SuVe_surround_500um_noclass',
#  'Tz',
#  'Tz_negative',
#  'Tz_surround_200um_RtTg',
#  'Tz_surround_200um_noclass',
#  'Tz_surround_500um_Pn',
#  'Tz_surround_500um_RtTg',
#  'Tz_surround_500um_noclass',
#  'VCA',
#  'VCA_negative',
#  'VCA_surround_200um_8n',
#  'VCA_surround_200um_DC',
#  'VCA_surround_200um_VCP',
#  'VCA_surround_200um_noclass',
#  'VCA_surround_500um_8n',
#  'VCA_surround_500um_Cb',
#  'VCA_surround_500um_DC',
#  'VCA_surround_500um_VCP',
#  'VCA_surround_500um_noclass',
#  'VCP',
#  'VCP_negative',
#  'VCP_surround_200um_8n',
#  'VCP_surround_200um_DC',
#  'VCP_surround_200um_VCA',
#  'VCP_surround_200um_noclass',
#  'VCP_surround_500um_8n',
#  'VCP_surround_500um_DC',
#  'VCP_surround_500um_VCA',
#  'VCP_surround_500um_noclass',
#  'VLL',
#  'VLL_negative',
#  'VLL_surround_200um_Pr5VL',
#  'VLL_surround_200um_noclass',
#  'VLL_surround_500um_5N',
#  'VLL_surround_500um_PBG',
#  'VLL_surround_500um_Pr5DM',
#  'VLL_surround_500um_Pr5VL',
#  'VLL_surround_500um_SNR',
#  'VLL_surround_500um_noclass',
#  'X',
#  'X_negative',
#  'X_surround_200um_8n',
#  'X_surround_200um_noclass',
#  'X_surround_500um_8n',
#  'X_surround_500um_DC',
#  'X_surround_500um_Sp5O',
#  'X_surround_500um_noclass']

# %%
from itertools import chain
all_labels = sorted(list(set(chain.from_iterable(set(grid_indices_lookup_allStacks[st].columns.tolist()) 
                                                 for st in train_stacks + test_stacks))))

# %%
def sample_addresses(stacks, structure):
        
    positive_labels = [structure]
    negative_labels = get_negative_labels(structure, 'neg_has_all_surround', 
                                          margin='500um', labels_found=all_labels)

    positive_addresses_all_stacks = {}
    negative_addresses_all_stacks = {}
        
    for stack in stacks:

        candidate_sections = list(chain(*[grid_indices_lookup_allStacks[stack][pl].dropna(how='any').index.tolist() 
                                      for pl in positive_labels]))

        n_sections = stack_section_number[stack][structure]

        if stack_stain[stack] == 'F':
            neurotrace_sections = []
            nissl_sections = []
            for sec in candidate_sections:
                if (metadata_cache['sections_to_filenames'][stack][sec].split('-')[1][0] == 'F') \
                or stack in ['CHATM2', 'CHATM3']:
                    neurotrace_sections.append(sec)
                else:
                    nissl_sections.append(sec)
            print 'neurotrace_sections', neurotrace_sections
            print 'nissl_sections', nissl_sections
            sampled_sections = np.random.choice(neurotrace_sections, min(len(neurotrace_sections), n_sections), replace=False)
        else:
            sampled_sections = np.random.choice(candidate_sections, min(len(candidate_sections), n_sections), replace=False)
            
        positive_addresses_all_stacks[stack] = sorted([(stack, sec, tuple(loc))
for nl in set(positive_labels) & set(grid_indices_lookup_allStacks[stack].columns)
  for sec, locs in grid_indices_lookup_allStacks[stack][nl].loc[sampled_sections].dropna().iteritems()
  for loc in locs])

        negative_addresses_all_stacks[stack] = sorted([(stack, sec, tuple(loc))
for nl in set(negative_labels) & set(grid_indices_lookup_allStacks[stack].columns)
  for sec, locs in grid_indices_lookup_allStacks[stack][nl].loc[sampled_sections].dropna().iteritems()
  for loc in locs])

    positive_addresses = sum(positive_addresses_all_stacks.values(), [])
    negative_addresses = sum(negative_addresses_all_stacks.values(), [])

    del positive_addresses_all_stacks, negative_addresses_all_stacks

    return positive_addresses, negative_addresses

# %%
# train_scheme = 'stretch_min_max'
# train_scheme = 'normalize_mu_sigma_global_(-1,5)'
# train_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,5)'
# train_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,9)'
train_scheme = 'none'

# test_scheme = 'stretch_min_max'
# test_scheme = 'normalize_mu_sigma_global_(-1,5)'
# test_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,5)'
# test_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,9)'
test_scheme = 'none'

# %%
# existing_classifier_id = 998 # If set, not train from scratch
# existing_classifier_id = 990
# extract_train_features = True

# %%
existing_classifier_id = None
extract_train_features = True
# classifier_id = 990 # MD585/MD589 -> MD594, cnn
# classifier_id = 991 # MD585/MD589 -> MD594, lbp
# classifier_id = 992 # MD585/MD589 -> MD594, glcm
# classifier_id = 993 # MD585/MD589 -> MD594, mean greylevel
# classifier_id = 899 # CHATM2 -> CHATM2, cnn
# classifier_id = 898 # DEMO998 -> DEMO998, cnn, win7
# classifier_id = 897 # DEMO998 -> DEMO998, cnn, win8
# classifier_id = 896 # DEMO998 -> DEMO998, cnn, win9
# win10 is too large and no patch can be extracted from DEMO998 section 225 3N.
# classifier_id = 895 # DEMO998 -> DEMO998, cnn, win11
# classifier_id = 894 # MD585/MD589 -> MD594, cnn, win8
# classifier_id = 893 # MD585/MD589 -> MD594, cnn, win11
# classifier_id = 892 # MD585/MD589 -> MD594, cnn, concat 100um 200um
classifier_id = 891 # MD585/MD589 -> MD594, cnn, concat 100um 200um 50um

# %%
# method = 'mean_intensity'
method = 'cnn' #

# %%
prep_id = 'alignedBrainstemCrop'

# %%
for stack in ['MD594']:
    
    target_locations = grid_parameters_to_sample_locations(grid_spec=win_id_to_gridspec(win_id=7, stack=stack))
    source_locations = grid_parameters_to_sample_locations(grid_spec=win_id_to_gridspec(win_id=8, stack=stack))
    target_locations_mapped_to_source_locations, target_indices_to_source_indices_mapping = align_grid_specs(source_locations=source_locations, target_locations=target_locations, stack=stack)

    target_locations_to_source_locations_mapping = {tuple(tgt_loc): tuple(src_loc)
                        for tgt_loc, src_loc in zip(target_locations, target_locations_mapped_to_source_locations)}
    
    for sec in metadata_cache['valid_sections'][stack]:
        
        print stack, sec
        
        features_100um, locations_100um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                                           prep_id=prep_id, win_id=7,
                                                                           normalization_scheme='none',
                                                                           model_name=model_name)
        
        features_200um, locations_200um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                               prep_id=prep_id, win_id=8,
                                                               normalization_scheme='none',
                                                               model_name=model_name)

        locations_200um_to_indices_200um_in_loaded_pool_mapping = {tuple(loc_200um): idx_200um_in_loaded_pool
                                for idx_200um_in_loaded_pool, loc_200um in enumerate(locations_200um)}
        
        features = []
        locations = []
        for idx_100um_in_loaded_pool, loc_100um in enumerate(locations_100um):
            loc_200um = target_locations_to_source_locations_mapping[tuple(loc_100um)]
            if tuple(loc_200um) in locations_200um_to_indices_200um_in_loaded_pool_mapping:
                # check if the 100um grid mapped to a 200um grid that has features associated
                idx_200um_in_loaded_pool = locations_200um_to_indices_200um_in_loaded_pool_mapping[tuple(loc_200um)]

                f = np.concatenate([features_100um[idx_100um_in_loaded_pool], 
                                   features_200um[idx_200um_in_loaded_pool]], axis=-1)
                features.append(f)
                locations.append(locations_100um[idx_100um_in_loaded_pool])
                
        DataManager.save_dnn_features_v2(features=features, locations=locations,
                         stack=stack, sec=sec, prep_id=prep_id,
                         win_id=7, normalization_scheme='none',
                         model_name='concat_100um_200um')
# Out:
# MD594 92
# MD594 93
# MD594 94
# MD594 95
# MD594 96
# MD594 97
# MD594 98
# MD594 99
# MD594 100
# MD594 101
# MD594 102
# MD594 103
# MD594 104
# MD594 105
# MD594 106
# MD594 107
# MD594 108
# MD594 109
# MD594 110
# MD594 111
# MD594 112
# MD594 113
# MD594 114
# MD594 115
# MD594 116
# MD594 117
# MD594 118
# MD594 119
# MD594 120
# MD594 121
# MD594 122
# MD594 123
# MD594 124
# MD594 125
# MD594 126
# MD594 127
# MD594 128
# MD594 129
# MD594 130
# MD594 132
# MD594 133
# MD594 134
# MD594 135
# MD594 136
# MD594 137
# MD594 138
# MD594 139
# MD594 140
# MD594 141
# MD594 142
# MD594 143
# MD594 144
# MD594 145
# MD594 146
# MD594 147
# MD594 148
# MD594 149
# MD594 150
# MD594 151
# MD594 152
# MD594 153
# MD594 154
# MD594 155
# MD594 156
# MD594 157
# MD594 158
# MD594 159
# MD594 160
# MD594 161
# MD594 162
# MD594 163
# MD594 164
# MD594 165
# MD594 166
# MD594 167
# MD594 168
# MD594 169
# MD594 170
# MD594 171
# MD594 172
# MD594 173
# MD594 174
# MD594 175
# MD594 176
# MD594 177
# MD594 178
# MD594 179
# MD594 180
# MD594 181
# MD594 182
# MD594 183
# MD594 184
# MD594 185
# MD594 186
# MD594 188
# MD594 189
# MD594 190
# MD594 191
# MD594 192
# MD594 194
# MD594 195
# MD594 196
# MD594 197
# MD594 198
# MD594 199
# MD594 200
# MD594 201
# MD594 202
# MD594 203
# MD594 204
# MD594 205
# MD594 206
# MD594 207
# MD594 208
# MD594 209
# MD594 210
# MD594 211
# MD594 212
# MD594 213
# MD594 214
# MD594 215
# MD594 216
# MD594 217
# MD594 218
# MD594 219
# MD594 220
# MD594 221
# MD594 222
= DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                                           prep_id=prep_id, win_id=7,
                                                                           normalization_scheme='none',
                                                                           model_name=model_name)
        
        features_200um, locations_200um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                               prep_id=prep_id, win_id=8,
                                                               normalization_scheme='none',
                                                               model_name=model_name)

        features_50um, locations_50um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                               prep_id=prep_id, win_id=11,
                                                               normalization_scheme='none',
                                                               model_name=model_name)

        locations_200um_to_indices_200um_in_loaded_pool_mapping = {tuple(loc_200um): idx_200um_in_loaded_pool
                                for idx_200um_in_loaded_pool, loc_200um in enumerate(locations_200um)}

        locations_50um_to_indices_50um_in_loaded_pool_mapping = {tuple(loc_50um): idx_50um_in_loaded_pool
                        for idx_50um_in_loaded_pool, loc_50um in enumerate(locations_50um)}

        
        features = []
        locations = []
        for idx_100um_in_loaded_pool, loc_100um in enumerate(locations_100um):
            loc_200um = size100um_locations_to_size200um_locations_mapping[tuple(loc_100um)]
            loc_50um = size100um_locations_to_size50um_locations_mapping[tuple(loc_100um)]
            
            if tuple(loc_200um) in locations_200um_to_indices_200um_in_loaded_pool_mapping and \
            tuple(loc_50um) in locations_50um_to_indices_50um_in_loaded_pool_mapping:
                
                # check if the 100um grid mapped to a 200um grid that has features associated
                idx_200um_in_loaded_pool = locations_200um_to_indices_200um_in_loaded_pool_mapping[tuple(loc_200um)]
                
                idx_50um_in_loaded_pool = locations_50um_to_indices_50um_in_loaded_pool_mapping[tuple(loc_50um)]

                f = np.concatenate([features_100um[idx_100um_in_loaded_pool], 
                                   features_200um[idx_200um_in_loaded_pool],
                                   features_50um[idx_50um_in_loaded_pool]], axis=-1)
                features.append(f)
                locations.append(locations_100um[idx_100um_in_loaded_pool])
                
        DataManager.save_dnn_features_v2(features=features, locations=locations,
                         stack=stack, sec=sec, prep_id=prep_id,
                         win_id=7, normalization_scheme='none',
                         model_name='concat_100um_200um_50um')
# Out:
# MD585 83
# MD585 84
# MD585 85
# MD585 86
# MD585 87
# MD585 88
# MD585 89
# MD585 90
# MD585 91
# MD585 92
# MD585 93
# MD585 94
# MD585 95
# MD585 96
# MD585 97
# MD585 98
# MD585 99
# MD585 100
# MD585 101
# MD585 102
# MD585 103
# MD585 104
# MD585 105
# MD585 106
# MD585 107
# MD585 108
# MD585 109
# MD585 110
# MD585 111
# MD585 112
# MD585 113
# MD585 114
# MD585 115
# MD585 116
# MD585 117
# MD585 119
# MD585 120
# MD585 121
# MD585 122
# MD585 123
# MD585 124
# MD585 125
# MD585 126
# MD585 127
# MD585 128
# MD585 129
# MD585 130
# MD585 131
# MD585 132
# MD585 133
# MD585 134
# MD585 135
# MD585 136
# MD585 137
# MD585 138
# MD585 139
# MD585 140
# MD585 141
# MD585 142
# MD585 143
# MD585 144
# MD585 145
# MD585 146
# MD585 147
# MD585 148
# MD585 149
# MD585 150
# MD585 151
# MD585 152
# MD585 153
# MD585 154
# MD585 155
# MD585 156
# MD585 157
# MD585 158
# MD585 159
# MD585 160
# MD585 161
# MD585 162
# MD585 163
# MD585 164
# MD585 165
# MD585 166
# MD585 167
# MD585 168
# MD585 169
# MD585 170
# MD585 171
# MD585 172
# MD585 173
# MD594 295
# MD594 296
# MD594 297
# MD594 298
# MD594 299
# MD594 300
# MD594 301
# MD594 302
# MD594 303
# MD594 304
# MD594 305
# MD594 306
# MD594 307
# MD594 308
# MD594 309
# MD594 310
# MD594 311
# MD594 312
# MD594 313
# MD594 314
# MD594 315
# MD594 316
# MD594 317
# MD594 318
# MD594 319
# MD594 320
# MD594 321
# MD594 322
# MD594 323
# MD594 324
# MD594 325
# MD594 326
# MD594 327
# MD594 328
# MD594 329
# MD594 330
# MD594 331
# MD594 332
# MD594 333
# MD594 334
# MD594 335
# MD594 336
# MD594 337
# MD594 338
# MD594 339
# MD594 340
# MD594 342
# MD594 343
# MD594 344
# MD594 345
# MD594 346
# MD594 347
# MD594 348
# MD594 349
# MD594 350
# MD594 351
# MD594 352
# MD594 353
# MD594 354
# MD594 355
# MD594 356
# MD594 357
# MD594 358
# MD594 359
# MD594 360
# MD594 361
# MD594 362
# MD594 363
# MD594 364

# %%
compute_new_addresses = False

# %%
# model_name = 'concat_100um_200um'
model_name = 'concat_100um_200um_50um'

# %%
for structure in all_known_structures:
# for structure in ['3N']:

    # features_dict = {(scheme, tfv): {} for scheme in schemes for tfv in transforms}
    features_dict = defaultdict(dict)

    ############## Sample and Load training feature vectors #########################################

    if extract_train_features:
    
        positive_addresses_traindata, negative_addresses_traindata = \
        sample_addresses(train_stacks, structure)

        print '# positive train =', len(positive_addresses_traindata)
        print '# negative train =', len(negative_addresses_traindata)

        addresses_to_compute = positive_addresses_traindata + negative_addresses_traindata

        for variant in [0]:
            features_loaded = read_features(addresses=addresses_to_compute, 
                                            scheme=train_scheme, win_id=win_id, prep_id=prep_id, 
                                            model=model, mean_img=mean_img, model_name=model_name, 
                                            batch_size=batch_size,
                                           method=method,
                                           compute_new_addresses=compute_new_addresses
                                           )
            
            for addr, f in izip(addresses_to_compute, features_loaded):
                if f is not None:
                    features_dict[(train_scheme, variant)][addr] = f

            del features_loaded

    ############## Sample and Load test feature vectors #############################################
    
    positive_addresses_testdata, negative_addresses_testdata = \
    sample_addresses(test_stacks, structure)
    
    print '# positive test =', len(positive_addresses_testdata)
    print '# negative test =', len(negative_addresses_testdata)
    
    addresses_to_compute = positive_addresses_testdata + negative_addresses_testdata

    for variant in [0]:
        features_loaded = read_features(addresses=addresses_to_compute, 
                                        scheme=test_scheme, win_id=win_id, prep_id=prep_id, 
                                        model=model, mean_img=mean_img, model_name=model_name, 
                                        batch_size=batch_size,
                                           method=method,
                                       compute_new_addresses=compute_new_addresses
                                       )

        for addr, f in izip(addresses_to_compute, features_loaded):
            if f is not None:
                features_dict[(test_scheme, variant)][addr] = f

        del features_loaded
            
    ########################################################################################
    
    # n_train_list = [10, 100, 200, 500, 1000, 2000, 5000, 10000, 15000]
#     n_train_list = [10, 1000]
    n_train_list = [1000, 5000, 15000]
#     n_train_list = [1000, 5000]
#     n_train_list = [15000]
    test_metrics_all_ntrain = defaultdict(lambda: defaultdict(list))
    train_metrics_all_ntrain = defaultdict(lambda: defaultdict(list))

    for n_train in n_train_list:

        print "n_train", n_train
        
        for trial in range(3):
            print "Trial", trial
            
            ##### Sample from training pool the required number of examples ######

            # If train and test data are from different sets
            n_train_pos = min(n_train, len(positive_addresses_traindata))
#             if len(positive_addresses_traindata) < n_train_pos:
#                 continue
            training_pos_indices = np.random.choice(range(len(positive_addresses_traindata)), n_train_pos, replace=False)
            
            n_test_pos = min(len(positive_addresses_testdata), 1000)
            test_pos_indices = np.random.choice(range(len(positive_addresses_testdata)), n_test_pos, replace=False)

            # If train and test are from same set
        #     n_pos_total = len(positive_addresses)
        #     n_train_pos = 1000
        #     training_pos_indices = np.random.choice(range(n_pos_total), n_train_pos, replace=False)
        #     test_pos_indices = np.random.choice(np.setdiff1d(range(n_pos_total), training_pos_indices),
        #                                         size=min(2000, n_pos_total-n_train_pos), replace=False)
        #     n_test_pos = len(test_pos_indices)

            # If train and test data are from different sets
            n_train_neg = n_train_pos
            training_neg_indices = np.random.choice(range(len(negative_addresses_traindata)), n_train_neg, replace=False)
            
            n_test_neg = min(len(negative_addresses_testdata), 1000)
            test_neg_indices = np.random.choice(range(len(negative_addresses_testdata)), n_test_neg, replace=False)

            # If train and test are from same set
        #     n_neg_total = len(negative_addresses)
        #     n_train_neg = 1000
        #     training_neg_indices = np.random.choice(range(n_neg_total), n_train_neg, replace=False)
        #     test_neg_indices = np.random.choice(np.setdiff1d(range(n_neg_total), training_neg_indices), 
        #                                         size=min(2000, n_pos_total-n_train_pos), replace=False)
        #     n_test_neg = len(test_neg_indices)

            print "Training: %d positive, %d negative" % (n_train_pos, n_train_neg)
            print "Test: %d positive, %d negative" % (n_test_pos, n_test_neg)

            ################

            if extract_train_features:
                # If train and test data are from different sets
                addresses_train_pos = [positive_addresses_traindata[i] for i in training_pos_indices]
                addresses_train_neg = [negative_addresses_traindata[i] for i in training_neg_indices]

            addresses_test_pos = [positive_addresses_testdata[i] for i in test_pos_indices]
            addresses_test_neg = [negative_addresses_testdata[i] for i in test_neg_indices]

            #################

#             for augment_training in [True, False]:
            for augment_training in [False]:
        
                feature_classifier_alg = 'lr'
#                 feature_classifier_alg = 'xgb2'
        #             feature_classifier_alg = 'lin_svc'
        #             feature_classifier_alg = 'lin_svc_calib'
                sample_weights = None   

                if extract_train_features:
            
                    if augment_training:
                        train_transforms = range(8)
                    else:
                        train_transforms = range(1)
                    features_train_pos = {(train_scheme, tf_variant): 
                                          [features_dict[(train_scheme, tf_variant)][addr] 
                                           for addr in addresses_train_pos 
                                           if addr in features_dict[(train_scheme, tf_variant)]]
                                              for tf_variant in train_transforms}
                    features_train_neg = {(train_scheme, tf_variant): 
                                          [features_dict[(train_scheme, tf_variant)][addr] 
                                           for addr in addresses_train_neg
                                           if addr in features_dict[(train_scheme, tf_variant)]]
                                              for tf_variant in train_transforms}

                    train_data = np.concatenate([np.r_[features_train_pos[(train_scheme,tf)], 
                                                       features_train_neg[(train_scheme,tf)]] 
                                                    for tf in train_transforms])
                    train_labels = np.concatenate([np.r_[np.ones((len(features_train_pos[(train_scheme,tf)]), )), 
                                                        -np.ones((len(features_train_neg[(train_scheme,tf)]), ))]
                                                  for tf in train_transforms])

                if existing_classifier_id is None:
                    clf = train_binary_classifier(train_data, train_labels,
                                       alg=feature_classifier_alg, 
                                       sample_weights=sample_weights)

    #                 del train_data, features_train_pos, features_train_neg

                    clf_fp = DataManager.get_classifier_filepath(classifier_id=classifier_id, structure=structure)
                    save_data(clf, clf_fp)
#                     upload_to_s3(clf_fp)
                else:
                    sys.stderr.write('Load existing classifiers %d\n' % existing_classifier_id)
                    clf = DataManager.load_classifiers(classifier_id=existing_classifier_id)[structure]
                
                ######################### Compute train metrics #########################
                
                if extract_train_features:
                    train_metrics = compute_classification_metrics(clf.predict_proba(train_data)[:,1], train_labels)
                    train_metrics_all_ntrain[n_train][(train_scheme, 'augment' if augment_training else 'no-augment')].append(train_metrics)
                
                ######################### Test ###############################
                
                test_transforms = range(1)
                features_test_pos = {(test_scheme, tf_variant): 
                                      [features_dict[(test_scheme, tf_variant)][addr] 
                                       for addr in addresses_test_pos
                                      if addr in features_dict[(test_scheme, tf_variant)]]
                                          for tf_variant in test_transforms}
                features_test_neg = {(test_scheme, tf_variant): 
                                      [features_dict[(test_scheme, tf_variant)][addr] 
                                       for addr in addresses_test_neg
                                      if addr in features_dict[(test_scheme, tf_variant)]]
                                          for tf_variant in test_transforms}
                
                test_data = np.concatenate([np.r_[features_test_pos[(test_scheme,tf_variant)], 
                                  features_test_neg[(test_scheme,tf_variant)]]
                                            for tf_variant in train_transforms])
                test_labels = np.concatenate([np.r_[np.ones((len(features_test_pos[(test_scheme,tf_variant)]), )), 
                                     -np.ones((len(features_test_neg[(test_scheme,tf_variant)]), ))]
                                            for tf_variant in train_transforms])
                test_metrics = compute_classification_metrics(clf.predict_proba(test_data)[:,1], test_labels)
    #             print "acc@0.5 = %.3f, acc@opt = %.3f, opt_thresh = %.3f, auroc = %.3f, auprc = %.3f" % \
    #             (test_metrics['acc'][0.5], test_metrics['acc'][test_metrics['opt_thresh']], test_metrics['opt_thresh'], test_metrics['auroc'], test_metrics['auprc'])

                test_metrics_all_ntrain[n_train][(test_scheme, 'augment' if augment_training else 'no-augment')].append(test_metrics)

    train_metrics_all_ntrain.default_factory = None
    test_metrics_all_ntrain.default_factory = None
    
    plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'acc', 0.5), ylabel='Test accuracy@0.5 threshold');
    plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'auroc'), ylabel='Area under ROC');

    plot_roc_curve(test_metrics_all_ntrain[1000][(test_scheme,
                  'no-augment')][0]['fp'], 
                   test_metrics_all_ntrain[1000][(test_scheme,
                  'no-augment')][0]['tp'], 
                  test_metrics_all_ntrain[1000][(test_scheme,
                  'no-augment')][0]['opt_thresh']);
    
    import uuid

    result = {
        'n_sections': stack_section_number,
        'stain': stack_stain,
        'train_stacks': train_stacks,
        'test_stacks': test_stacks,
        'test_scheme': test_scheme,
        'train_scheme': train_scheme,
        'train_metrics_all_ntrain': train_metrics_all_ntrain,
        'test_metrics_all_ntrain': test_metrics_all_ntrain,
        'structure': structure,
        'method': method,
        'classifier_id': existing_classifier_id if existing_classifier_id is not None else classifier_id
    }

    create_if_not_exists(ROOT_DIR + '/assessment_results_v4/')
    save_pickle(result, ROOT_DIR + '/assessment_results_v4/assessment_result_%s.pkl' % str(uuid.uuid1()).split('-')[0])
# Out:
# # positive train = 4010
# # negative train = 34147
# ('MD585', 154)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-6f98e02e7b0b> in <module>()
#      22                                             batch_size=batch_size,
#      23                                            method=method,
# ---> 24                                            compute_new_addresses=compute_new_addresses
#      25                                            )
#      26
#
# /home/yuncong/MouseBrainAtlas/src/utilities/learning_utilities.pyc in read_features(addresses, scheme, win_id, prep_id, model, mean_img, model_name, batch_size, method, compute_new_addresses, version, return_nan_for_nonexistent)
#    2935                                                                              prep_id=prep_id, win_id=win_id,
#    2936                                                                              normalization_scheme=scheme,
# -> 2937                                                                              model_name=model_name)
#    2938             except Exception as e:
#    2939                 features_pool = []
#
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.pyc in load_dnn_features_v2(stack, prep_id, win_id, normalization_scheme, model_name, sec, fn)
#    4415             raise Exception("Features for %s, %s/%s does not exist." % (stack, sec, fn))
#    4416
# -> 4417         features = bp.unpack_ndarray_file(features_fp)
#    4418
#    4419         locations_fp = DataManager.get_dnn_features_filepath_v2(stack=stack, sec=sec, fn=fn, prep_id=prep_id, win_id=win_id,
#
# /usr/local/lib/python2.7/dist-packages/bloscpack/numpy_io.pyc in unpack_ndarray_file(filename)
#     232 def unpack_ndarray_file(filename):
#     233     source = CompressedFPSource(open(filename, 'rb'))
# --> 234     return unpack_ndarray(source)
#     235
#     236
#
# /usr/local/lib/python2.7/dist-packages/bloscpack/numpy_io.pyc in unpack_ndarray(source)
#     226
#     227     sink = PlainNumpySink(source.metadata)
# --> 228     unpack(source, sink)
#     229     return sink.ndarray
#     230
#
# /usr/local/lib/python2.7/dist-packages/bloscpack/abstract_io.pyc in unpack(source, sink)
#     179         raise TypeError
#     180     # read, decompress, write loop
# --> 181     for i, (compressed, digest) in enumerate(source):
#     182         if log.LEVEL == log.DEBUG:
#     183             log.debug("decompressing chunk '%d'%s" %
#
# /usr/local/lib/python2.7/dist-packages/bloscpack/file_io.pyc in __iter__(self)
#     365     def __iter__(self):
#     366         for i in xrange(self.nchunks):
# --> 367             compressed, header, digest = _read_compressed_chunk_fp(self.input_fp, self.checksum_impl)
#     368             yield compressed, digest
#     369
#
# /usr/local/lib/python2.7/dist-packages/bloscpack/file_io.pyc in _read_compressed_chunk_fp(input_fp, checksum_impl)
#     328     input_fp.seek(-BLOSC_HEADER_LENGTH, 1)
#     329     # read chunk
# --> 330     compressed = input_fp.read(ctbytes)
#     331     digest = input_fp.read(checksum_impl.size) \
#     332         if checksum_impl.size > 0 else None
#
# KeyboardInterrupt:

# %%
np.mean(extract_one_metric(test_metrics_all_ntrain, 'auroc')[15000][('none','no-augment')])
# Out:
# 0.9750078756917837

# %%
plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'acc', 0.5), ylabel='Test accuracy@0.5 threshold');
plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'auroc'), ylabel='Area under ROC');
