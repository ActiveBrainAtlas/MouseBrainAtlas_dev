# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import time

import numpy as np
try:
    import mxnet as mx
except:
    sys.stderr.write("Cannot import mxnet.\n")
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.exposure import rescale_intensity
from skimage.transform import rotate

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from metadata import *
from data_manager import *
from learning_utilities import *
from distributed_utilities import *
from visualization_utilities import *
# Out:
# /home/yuncong/MouseBrainAtlas/src/utilities/utilities2015.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python2.7/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/lib/python2.7/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-fc4079e49eb7>", line 14, in <module>
#     get_ipython().magic(u'matplotlib inline')
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation
# {'MD589': 0.46, 'MD585': 0.46, 'MD594': 0.46, 'DEMO998': 0.46}
# No vtk
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Seems you are using operation INIs to provide cropbox.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.py:5500: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s anchor: %s\n" % (stack, e.message))
# Failed to cache DEMO998 anchor: ini file /media/yuncong/BstemAtlasData/atlas_data/CSHL_data_processed/DEMO998/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/yuncong/BstemAtlasData/atlas_data/CSHL_data_processed/DEMO998/DEMO998_sorted_filenames.txt
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.py:5506: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s sections_to_filenames: %s\n" % (stack, e.message))
# Failed to cache DEMO998 sections_to_filenames:
# File does not exist: /media/yuncong/BstemAtlasData/atlas_data/CSHL_data_processed/DEMO998/DEMO998_sorted_filenames.txt
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.py:5517: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s filenames_to_sections: %s\n" % (stack, e.message))
# Failed to cache DEMO998 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.py:5522: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s section_limits: %s\n" % (stack, e.message))
# Failed to cache DEMO998 section_limits: ini file /media/yuncong/BstemAtlasData/atlas_data/CSHL_data_processed/DEMO998/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.py:5528: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s cropbox: %s\n" % (stack, e.message))
# Failed to cache DEMO998 cropbox: ini file /media/yuncong/BstemAtlasData/atlas_data/CSHL_data_processed/DEMO998/operation_configs/from_none_to_aligned.ini does not exist.
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.py:5538: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s valid_sections/filenames: %s\n" % (stack, e.message))
# Failed to cache DEMO998 valid_sections/filenames: DEMO998
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# /home/yuncong/MouseBrainAtlas/src/utilities/data_manager.py:5549: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   sys.stderr.write("Failed to cache %s image_shape: %s\n" % (stack, e.message))
# Failed to cache DEMO998 image_shape: ini file /media/yuncong/BstemAtlasData/atlas_data/CSHL_data_processed/DEMO998/operation_configs/from_none_to_aligned.ini does not exist.
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
metadata_cache['image_shape']
# Out:
# {'MD585': (16384, 12000), 'MD589': (15520, 11936), 'MD594': (17216, 11104)}

# %%
from sklearn.externals import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC, SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import GradientBoostingClassifier 

sys.path.append('/home/yuncong/csd395/xgboost/python-package')
try:
    from xgboost.sklearn import XGBClassifier
except:
    sys.stderr.write('xgboost is not loaded.')

# %%
batch_size = 256
model_dir_name = 'inception-bn-blue'
model_name = 'inception-bn-blue'
model, mean_img = load_mxnet_model(model_dir_name=model_dir_name, model_name=model_name, 
                                   num_gpus=1, batch_size=batch_size)
# Out:
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# /usr/local/lib/python2.7/dist-packages/mxnet/module/base_module.py:53: UserWarning: You created Module with Module(..., label_names=['softmax_label']) but input with name 'softmax_label' is not found in symbol.list_arguments(). Did you mean one of:
# 	data
#   warnings.warn(msg)
# /usr/local/lib/python2.7/dist-packages/mxnet/module/base_module.py:65: UserWarning: Data provided by label_shapes don't match names specified by label_names ([] vs. ['softmax_label'])
#   warnings.warn(msg)

# %%
train_stacks = ['MD589', 'MD585']
test_stacks = ['MD594']

# %%
stack_stain = {'MD585': 'N', 'MD589': 'N', 'MD594': 'N'}

# Number of sections on which to sample examples from.
stack_section_number = defaultdict(dict)

for name_u in all_known_structures:
    for st in train_stacks:
        stack_section_number[st][name_u] = 10
#         if name_u == '4N' or name_u == '10N':
#             stack_section_number[st][name_u] = 20
#         else:
#             stack_section_number[st][name_u] = 10
    for st in test_stacks:
        stack_section_number[st][name_u] = 10

stack_section_number.default_factory = None

# %%
windowing_settings
# Out:
# {1: {'patch_size': 224, 'spacing': 56},
#  2: {'comment': 'larger margin', 'patch_size': 224, 'spacing': 56},
#  3: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 32},
#  4: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 128},
#  5: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 64},
#  6: {'comment': 'twice as large patch', 'patch_size': 448, 'spacing': 64},
#  7: {'comment': 'specify size/spacing in terms of microns rather than pixels',
#   'patch_size_um': 103.04,
#   'spacing_um': 30},
#  8: {'comment': 'larger patch', 'patch_size_um': 206.08, 'spacing_um': 30},
#  9: {'comment': 'larger patch', 'patch_size_um': 412.16, 'spacing_um': 30},
#  10: {'comment': 'larger patch', 'patch_size_um': 824.32, 'spacing_um': 30},
#  11: {'comment': 'larger patch', 'patch_size_um': 51.52, 'spacing_um': 30},
#  12: {'comment': 'larger patch', 'patch_size_um': 25.76, 'spacing_um': 30}}

# %%
win_id = 7
# win_id = 8
# win_id = 9
# win_id = 11
# win_id = 8

# %%
grid_indices_lookup_allStacks = {}

for stack in train_stacks + test_stacks:
#     try:
#         grid_indices_lookup_allStacks[stack] = \
#         DataManager.load_annotation_to_grid_indices_lookup(stack=stack, win_id=win_id,
#                                                            by_human=False, timestamp='latest',
#                                                            detector_id_f=1,
#                                                           return_locations=True)            

#         grid_indices_lookup_allStacks[stack] = \
#         DataManager.load_annotation_to_grid_indices_lookup(stack=stack, win_id=win_id,
#                                                            by_human=True, timestamp='latest',
#                                                           return_locations=True, suffix='structures')            

    grid_indices_lookup_allStacks[stack] = \
    DataManager.load_annotation_to_grid_indices_lookup(stack=stack, win_id=win_id,
                                                       by_human=True, timestamp='latest',
                                                      return_locations=True)

#     except Exception as e:
#         sys.stderr.write("Fail to load annotation grid lookup for %s: %s\n" % (stack, e.message))
#         raise e
# Out:
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# MD589_annotation_contours_05302018171048.hdf
# MD589_annotation_win11_05302018171048_grid_indices_lookup.hdf
# MD589_annotation_win11_05302018171048_grid_indices_lookup.hdf None
# MD589_annotation_win7_05302018171048_grid_indices_lookup.hdf
# MD589_annotation_win8_05302018171048_grid_indices_lookup.hdf
# MD589_annotation_win8_05302018171048_grid_indices_lookup.hdf None
# latest timestamp:  05302018171048
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# MD585_annotation_contours_05302018161849.hdf
# MD585_annotation_win11_05302018161849_grid_indices_lookup.hdf
# MD585_annotation_win11_05302018161849_grid_indices_lookup.hdf None
# MD585_annotation_win7_05302018161849_grid_indices_lookup.hdf
# MD585_annotation_win8_05302018161849_grid_indices_lookup.hdf
# MD585_annotation_win8_05302018161849_grid_indices_lookup.hdf None
# latest timestamp:  05302018161849
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# MD594_annotation_contours_05302018203315.hdf
# MD594_annotation_win11_05302018203315_grid_indices_lookup.hdf
# MD594_annotation_win11_05302018203315_grid_indices_lookup.hdf None
# MD594_annotation_win7_05302018203315_grid_indices_lookup.hdf
# MD594_annotation_win8_05302018203315_grid_indices_lookup.hdf
# MD594_annotation_win8_05302018203315_grid_indices_lookup.hdf None
# latest timestamp:  05302018203315

# %%
from itertools import chain
all_labels = sorted(list(set(chain.from_iterable(set(grid_indices_lookup_allStacks[st].columns.tolist()) 
                                                 for st in train_stacks + test_stacks))))

# %%
def sample_addresses(stacks, structure):
        
    positive_labels = [structure]
    negative_labels = get_negative_labels(structure, 'neg_has_all_surround', 
                                          margin='500um', labels_found=all_labels)

    positive_addresses_all_stacks = {}
    negative_addresses_all_stacks = {}
        
    for stack in stacks:

        candidate_sections = list(chain(*[grid_indices_lookup_allStacks[stack][pl].dropna(how='any').index.tolist() 
                                      for pl in positive_labels]))

        n_sections = stack_section_number[stack][structure]

        if stack_stain[stack] == 'F':
            neurotrace_sections = []
            nissl_sections = []
            for sec in candidate_sections:
                if (metadata_cache['sections_to_filenames'][stack][sec].split('-')[1][0] == 'F') \
                or stack in ['CHATM2', 'CHATM3']:
                    neurotrace_sections.append(sec)
                else:
                    nissl_sections.append(sec)
            print 'neurotrace_sections', neurotrace_sections
            print 'nissl_sections', nissl_sections
            sampled_sections = np.random.choice(neurotrace_sections, min(len(neurotrace_sections), n_sections), replace=False)
        else:
            sampled_sections = np.random.choice(candidate_sections, min(len(candidate_sections), n_sections), replace=False)
            
        positive_addresses_all_stacks[stack] = sorted([(stack, sec, tuple(loc))
for nl in set(positive_labels) & set(grid_indices_lookup_allStacks[stack].columns)
  for sec, locs in grid_indices_lookup_allStacks[stack][nl].loc[sampled_sections].dropna().iteritems()
  for loc in locs])

        negative_addresses_all_stacks[stack] = sorted([(stack, sec, tuple(loc))
for nl in set(negative_labels) & set(grid_indices_lookup_allStacks[stack].columns)
  for sec, locs in grid_indices_lookup_allStacks[stack][nl].loc[sampled_sections].dropna().iteritems()
  for loc in locs])

    positive_addresses = sum(positive_addresses_all_stacks.values(), [])
    negative_addresses = sum(negative_addresses_all_stacks.values(), [])

    del positive_addresses_all_stacks, negative_addresses_all_stacks

    return positive_addresses, negative_addresses

# %%
# train_scheme = 'stretch_min_max'
# train_scheme = 'normalize_mu_sigma_global_(-1,5)'
# train_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,5)'
# train_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,9)'
train_scheme = 'none'

# test_scheme = 'stretch_min_max'
# test_scheme = 'normalize_mu_sigma_global_(-1,5)'
# test_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,5)'
# test_scheme = 'normalize_mu_region_sigma_wholeImage_(-1,9)'
test_scheme = 'none'

# %%
# existing_classifier_id = 998 # If set, not train from scratch
# existing_classifier_id = 990
# extract_train_features = True

# %%
existing_classifier_id = None
extract_train_features = True
# classifier_id = 990 # MD585/MD589 -> MD594, cnn
# classifier_id = 991 # MD585/MD589 -> MD594, lbp
# classifier_id = 992 # MD585/MD589 -> MD594, glcm
# classifier_id = 993 # MD585/MD589 -> MD594, mean greylevel
# classifier_id = 899 # CHATM2 -> CHATM2, cnn
# classifier_id = 898 # DEMO998 -> DEMO998, cnn, win7
# classifier_id = 897 # DEMO998 -> DEMO998, cnn, win8
# classifier_id = 896 # DEMO998 -> DEMO998, cnn, win9
# win10 is too large and no patch can be extracted from DEMO998 section 225 3N.
# classifier_id = 895 # DEMO998 -> DEMO998, cnn, win11
# classifier_id = 894 # MD585/MD589 -> MD594, cnn, win8
# classifier_id = 893 # MD585/MD589 -> MD594, cnn, win11
# classifier_id = 892 # MD585/MD589 -> MD594, cnn, concat 100um 200um
# classifier_id = 891 # MD585/MD589 -> MD594, cnn, win7
classifier_id = 890 # MD585/MD589 -> MD594, cnn, concat 100um 200um 50um

# %%
# method = 'mean_intensity'
method = 'cnn' #

# %%
prep_id = 'alignedBrainstemCrop'

# %%
for stack in ['MD585', 'MD589', 'MD594']:
    
    target_locations = grid_parameters_to_sample_locations(grid_spec=win_id_to_gridspec(win_id=7, stack=stack))
    source_locations = grid_parameters_to_sample_locations(grid_spec=win_id_to_gridspec(win_id=8, stack=stack))
    target_locations_mapped_to_source_locations, target_indices_to_source_indices_mapping = align_grid_specs(source_locations=source_locations, target_locations=target_locations, stack=stack)

    target_locations_to_source_locations_mapping = {tuple(tgt_loc): tuple(src_loc)
                        for tgt_loc, src_loc in zip(target_locations, target_locations_mapped_to_source_locations)}
    
    for sec in metadata_cache['valid_sections'][stack]:
        
        print stack, sec
        
        features_100um, locations_100um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                                           prep_id=prep_id, win_id=7,
                                                                           normalization_scheme='none',
                                                                           model_name=model_name)
        
        features_200um, locations_200um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                               prep_id=prep_id, win_id=8,
                                                               normalization_scheme='none',
                                                               model_name=model_name)

        locations_200um_to_indices_200um_in_loaded_pool_mapping = {tuple(loc_200um): idx_200um_in_loaded_pool
                                for idx_200um_in_loaded_pool, loc_200um in enumerate(locations_200um)}
        
        features = []
        locations = []
        for idx_100um_in_loaded_pool, loc_100um in enumerate(locations_100um):
            loc_200um = target_locations_to_source_locations_mapping[tuple(loc_100um)]
            if tuple(loc_200um) in locations_200um_to_indices_200um_in_loaded_pool_mapping:
                # check if the 100um grid mapped to a 200um grid that has features associated
                idx_200um_in_loaded_pool = locations_200um_to_indices_200um_in_loaded_pool_mapping[tuple(loc_200um)]

                f = np.concatenate([features_100um[idx_100um_in_loaded_pool], 
                                   features_200um[idx_200um_in_loaded_pool]], axis=-1)
                features.append(f)
                locations.append(locations_100um[idx_100um_in_loaded_pool])
                
        DataManager.save_dnn_features_v2(features=features, locations=locations,
                         stack=stack, sec=sec, prep_id=prep_id,
                         win_id=7, normalization_scheme='none',
                         model_name='concat_100um_200um')
# Out:
# MD594 92
# MD594 93
# MD594 94
# MD594 95
# MD594 96
# MD594 97
# MD594 98
# MD594 99
# MD594 100
# MD594 101
# MD594 102
# MD594 103
# MD594 104
# MD594 105
# MD594 106
# MD594 107
# MD594 108
# MD594 109
# MD594 110
# MD594 111
# MD594 112
# MD594 113
# MD594 114
# MD594 115
# MD594 116
# MD594 117
# MD594 118
# MD594 119
# MD594 120
# MD594 121
# MD594 122
# MD594 123
# MD594 124
# MD594 125
# MD594 126
# MD594 127
# MD594 128
# MD594 129
# MD594 130
# MD594 132
# MD594 133
# MD594 134
# MD594 135
# MD594 136
# MD594 137
# MD594 138
# MD594 139
# MD594 140
# MD594 141
# MD594 142
# MD594 143
# MD594 144
# MD594 145
# MD594 146
# MD594 147
# MD594 148
# MD594 149
# MD594 150
# MD594 151
# MD594 152
# MD594 153
# MD594 154
# MD594 155
# MD594 156
# MD594 157
# MD594 158
# MD594 159
# MD594 160
# MD594 161
# MD594 162
# MD594 163
# MD594 164
# MD594 165
# MD594 166
# MD594 167
# MD594 168
# MD594 169
# MD594 170
# MD594 171
# MD594 172
# MD594 173
# MD594 174
# MD594 175
# MD594 176
# MD594 177
# MD594 178
# MD594 179
# MD594 180
# MD594 181
# MD594 182
# MD594 183
# MD594 184
# MD594 185
# MD594 186
# MD594 188
# MD594 189
# MD594 190
# MD594 191
# MD594 192
# MD594 194
# MD594 195
# MD594 196
# MD594 197
# MD594 198
# MD594 199
# MD594 200
# MD594 201
# MD594 202
# MD594 203
# MD594 204
# MD594 205
# MD594 206
# MD594 207
# MD594 208
# MD594 209
# MD594 210
# MD594 211
# MD594 212
# MD594 213
# MD594 214
# MD594 215
# MD594 216
# MD594 217
# MD594 218
# MD594 219
# MD594 220
# MD594 221
# MD594 222
# MD594 223
# MD594 224
# MD594 225
# MD594 226
# MD594 227
# MD594 228
# MD594 229
# MD594 230
# MD594 231
# MD594 232
# MD594 233
# MD594 234
# MD594 235
# MD594 236
# MD594 237
# MD594 239
# MD594 240
# MD594 241
# MD594 242
# MD594 243
# MD594 244
# MD594 245
# MD594 246
# MD594 247
# MD594 248
# MD594 249
# MD594 250
# MD594 251
# MD594 252
# MD594 253
# MD594 254
# MD594 255
# MD594 256
# MD594 257
# MD594 258
# MD594 259
# MD594 260
# MD594 262
# MD594 263
# MD594 264
# MD594 265
# MD594 266
# MD594 267
# MD594 268
# MD594 269
# MD594 270
# MD594 271
# MD594 272
# MD594 273
# MD594 274
# MD594 275
# MD594 276
# MD594 277
# MD594 278
# MD594 279
# MD594 280
# MD594 281
# MD594 282
# MD594 283
# MD594 284
# MD594 285
# MD594 286
# MD594 287
# MD594 288
# MD594 289
# MD594 290
# MD594 291
# MD594 292
# MD594 293
# MD594 294
# MD594 295
# MD594 296
# MD594 297
# MD594 298
# MD594 299
# MD594 300
# MD594 301
# MD594 302
# MD594 303
# MD594 304
# MD594 305
# MD594 306
# MD594 307
# MD594 308
# MD594 309
# MD594 310
# MD594 311
# MD594 312
# MD594 313
# MD594 314
# MD594 315
# MD594 316
# MD594 317
# MD594 318
# MD594 319
# MD594 320
# MD594 321
# MD594 322
# MD594 323
# MD594 324
# MD594 325
# MD594 326
# MD594 327
# MD594 328
# MD594 329
# MD594 330
# MD594 331
# MD594 332
# MD594 333
# MD594 334
# MD594 335
# MD594 336
# MD594 337
# MD594 338
# MD594 339
# MD594 340
# MD594 342
# MD594 343
# MD594 344
# MD594 345
# MD594 346
# MD594 347
# MD594 348
# MD594 349
# MD594 350
# MD594 351
# MD594 352
# MD594 353
# MD594 354
# MD594 355
# MD594 356
# MD594 357
# MD594 358
# MD594 359
# MD594 360
# MD594 361
# MD594 362
# MD594 363
# MD594 364

# %%
for stack in ['MD585', 'MD589', 'MD594']:
    
    size100um_locations = grid_parameters_to_sample_locations(grid_spec=win_id_to_gridspec(win_id=7, stack=stack))
    size200um_locations = grid_parameters_to_sample_locations(grid_spec=win_id_to_gridspec(win_id=8, stack=stack))
    size50um_locations = grid_parameters_to_sample_locations(grid_spec=win_id_to_gridspec(win_id=11, stack=stack))
    
    size100um_locations_mapped_to_size200um_locations, \
    size100um_indices_to_size200um_indices_mapping = \
    align_grid_specs(source_locations=size200um_locations, 
                     target_locations=size100um_locations, 
                     stack=stack)

    size100um_locations_to_size200um_locations_mapping = {tuple(tgt_loc): tuple(src_loc)
                        for tgt_loc, src_loc in zip(size100um_locations, 
                                                    size100um_locations_mapped_to_size200um_locations)}
    
    size100um_locations_mapped_to_size50um_locations, \
    size100um_indices_to_size50um_indices_mapping = \
    align_grid_specs(source_locations=size50um_locations, 
                     target_locations=size100um_locations, 
                     stack=stack)
    size100um_locations_to_size50um_locations_mapping = {tuple(tgt_loc): tuple(src_loc)
                        for tgt_loc, src_loc in zip(size100um_locations, 
                                                    size100um_locations_mapped_to_size50um_locations)}
    
    for sec in metadata_cache['valid_sections'][stack]:
        
        print stack, sec
        
        features_100um, locations_100um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                                           prep_id=prep_id, win_id=7,
                                                                           normalization_scheme='none',
                                                                           model_name=model_name)
        
        features_200um, locations_200um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                               prep_id=prep_id, win_id=8,
                                                               normalization_scheme='none',
                                                               model_name=model_name)

        features_50um, locations_50um = DataManager.load_dnn_features_v2(stack=stack, sec=sec,
                                                               prep_id=prep_id, win_id=11,
                                                               normalization_scheme='none',
                                                               model_name=model_name)

        locations_200um_to_indices_200um_in_loaded_pool_mapping = {tuple(loc_200um): idx_200um_in_loaded_pool
                                for idx_200um_in_loaded_pool, loc_200um in enumerate(locations_200um)}

        locations_50um_to_indices_50um_in_loaded_pool_mapping = {tuple(loc_50um): idx_50um_in_loaded_pool
                        for idx_50um_in_loaded_pool, loc_50um in enumerate(locations_50um)}

        
        features = []
        locations = []
        for idx_100um_in_loaded_pool, loc_100um in enumerate(locations_100um):
            loc_200um = size100um_locations_to_size200um_locations_mapping[tuple(loc_100um)]
            loc_50um = size100um_locations_to_size50um_locations_mapping[tuple(loc_100um)]
            
            if tuple(loc_200um) in locations_200um_to_indices_200um_in_loaded_pool_mapping and \
            tuple(loc_50um) in locations_50um_to_indices_50um_in_loaded_pool_mapping:
                
                # check if the 100um grid mapped to a 200um grid that has features associated
                idx_200um_in_loaded_pool = locations_200um_to_indices_200um_in_loaded_pool_mapping[tuple(loc_200um)]
                
                idx_50um_in_loaded_pool = locations_50um_to_indices_50um_in_loaded_pool_mapping[tuple(loc_50um)]

                f = np.concatenate([features_100um[idx_100um_in_loaded_pool], 
                                   features_200um[idx_200um_in_loaded_pool],
                                   features_50um[idx_50um_in_loaded_pool]], axis=-1)
                features.append(f)
                locations.append(locations_100um[idx_100um_in_loaded_pool])
                
        DataManager.save_dnn_features_v2(features=features, locations=locations,
                         stack=stack, sec=sec, prep_id=prep_id,
                         win_id=7, normalization_scheme='none',
                         model_name='concat_100um_200um_50um')

# %%
compute_new_addresses = False

# %%
# model_name = 'concat_100um_200um'
model_name = 'concat_100um_200um_50um'

# %%
for structure in all_known_structures:
# for structure in ['3N']:

    # features_dict = {(scheme, tfv): {} for scheme in schemes for tfv in transforms}
    features_dict = defaultdict(dict)

    ############## Sample and Load training feature vectors #########################################

    if extract_train_features:
    
        positive_addresses_traindata, negative_addresses_traindata = \
        sample_addresses(train_stacks, structure)

        print '# positive train =', len(positive_addresses_traindata)
        print '# negative train =', len(negative_addresses_traindata)

        addresses_to_compute = positive_addresses_traindata + negative_addresses_traindata

        for variant in [0]:
            features_loaded = read_features(addresses=addresses_to_compute, 
                                            scheme=train_scheme, win_id=win_id, prep_id=prep_id, 
                                            model=model, mean_img=mean_img, model_name=model_name, 
                                            batch_size=batch_size,
                                           method=method,
                                           compute_new_addresses=compute_new_addresses
                                           )
            
            for addr, f in izip(addresses_to_compute, features_loaded):
                if f is not None:
                    features_dict[(train_scheme, variant)][addr] = f

            del features_loaded

    ############## Sample and Load test feature vectors #############################################
    
    positive_addresses_testdata, negative_addresses_testdata = \
    sample_addresses(test_stacks, structure)
    
    print '# positive test =', len(positive_addresses_testdata)
    print '# negative test =', len(negative_addresses_testdata)
    
    addresses_to_compute = positive_addresses_testdata + negative_addresses_testdata

    for variant in [0]:
        features_loaded = read_features(addresses=addresses_to_compute, 
                                        scheme=test_scheme, win_id=win_id, prep_id=prep_id, 
                                        model=model, mean_img=mean_img, model_name=model_name, 
                                        batch_size=batch_size,
                                           method=method,
                                       compute_new_addresses=compute_new_addresses
                                       )

        for addr, f in izip(addresses_to_compute, features_loaded):
            if f is not None:
                features_dict[(test_scheme, variant)][addr] = f

        del features_loaded
            
    ########################################################################################
    
    # n_train_list = [10, 100, 200, 500, 1000, 2000, 5000, 10000, 15000]
#     n_train_list = [10, 1000]
    n_train_list = [1000, 5000, 15000]
#     n_train_list = [1000, 5000]
#     n_train_list = [15000]
    test_metrics_all_ntrain = defaultdict(lambda: defaultdict(list))
    train_metrics_all_ntrain = defaultdict(lambda: defaultdict(list))

    for n_train in n_train_list:

        print "n_train", n_train
        
        for trial in range(3):
            print "Trial", trial
            
            ##### Sample from training pool the required number of examples ######

            # If train and test data are from different sets
            n_train_pos = min(n_train, len(positive_addresses_traindata))
#             if len(positive_addresses_traindata) < n_train_pos:
#                 continue
            training_pos_indices = np.random.choice(range(len(positive_addresses_traindata)), n_train_pos, replace=False)
            
            n_test_pos = min(len(positive_addresses_testdata), 1000)
            test_pos_indices = np.random.choice(range(len(positive_addresses_testdata)), n_test_pos, replace=False)

            # If train and test are from same set
        #     n_pos_total = len(positive_addresses)
        #     n_train_pos = 1000
        #     training_pos_indices = np.random.choice(range(n_pos_total), n_train_pos, replace=False)
        #     test_pos_indices = np.random.choice(np.setdiff1d(range(n_pos_total), training_pos_indices),
        #                                         size=min(2000, n_pos_total-n_train_pos), replace=False)
        #     n_test_pos = len(test_pos_indices)

            # If train and test data are from different sets
            n_train_neg = n_train_pos
            training_neg_indices = np.random.choice(range(len(negative_addresses_traindata)), n_train_neg, replace=False)
            
            n_test_neg = min(len(negative_addresses_testdata), 1000)
            test_neg_indices = np.random.choice(range(len(negative_addresses_testdata)), n_test_neg, replace=False)

            # If train and test are from same set
        #     n_neg_total = len(negative_addresses)
        #     n_train_neg = 1000
        #     training_neg_indices = np.random.choice(range(n_neg_total), n_train_neg, replace=False)
        #     test_neg_indices = np.random.choice(np.setdiff1d(range(n_neg_total), training_neg_indices), 
        #                                         size=min(2000, n_pos_total-n_train_pos), replace=False)
        #     n_test_neg = len(test_neg_indices)

            print "Training: %d positive, %d negative" % (n_train_pos, n_train_neg)
            print "Test: %d positive, %d negative" % (n_test_pos, n_test_neg)

            ################

            if extract_train_features:
                # If train and test data are from different sets
                addresses_train_pos = [positive_addresses_traindata[i] for i in training_pos_indices]
                addresses_train_neg = [negative_addresses_traindata[i] for i in training_neg_indices]

            addresses_test_pos = [positive_addresses_testdata[i] for i in test_pos_indices]
            addresses_test_neg = [negative_addresses_testdata[i] for i in test_neg_indices]

            #################

#             for augment_training in [True, False]:
            for augment_training in [False]:
        
                feature_classifier_alg = 'lr'
#                 feature_classifier_alg = 'xgb2'
        #             feature_classifier_alg = 'lin_svc'
        #             feature_classifier_alg = 'lin_svc_calib'
                sample_weights = None   

                if extract_train_features:
            
                    if augment_training:
                        train_transforms = range(8)
                    else:
                        train_transforms = range(1)
                    features_train_pos = {(train_scheme, tf_variant): 
                                          [features_dict[(train_scheme, tf_variant)][addr] 
                                           for addr in addresses_train_pos 
                                           if addr in features_dict[(train_scheme, tf_variant)]]
                                              for tf_variant in train_transforms}
                    features_train_neg = {(train_scheme, tf_variant): 
                                          [features_dict[(train_scheme, tf_variant)][addr] 
                                           for addr in addresses_train_neg
                                           if addr in features_dict[(train_scheme, tf_variant)]]
                                              for tf_variant in train_transforms}

                    train_data = np.concatenate([np.r_[features_train_pos[(train_scheme,tf)], 
                                                       features_train_neg[(train_scheme,tf)]] 
                                                    for tf in train_transforms])
                    train_labels = np.concatenate([np.r_[np.ones((len(features_train_pos[(train_scheme,tf)]), )), 
                                                        -np.ones((len(features_train_neg[(train_scheme,tf)]), ))]
                                                  for tf in train_transforms])

                if existing_classifier_id is None:
                    clf = train_binary_classifier(train_data, train_labels,
                                       alg=feature_classifier_alg, 
                                       sample_weights=sample_weights)

    #                 del train_data, features_train_pos, features_train_neg

                    clf_fp = DataManager.get_classifier_filepath(classifier_id=classifier_id, structure=structure)
                    save_data(clf, clf_fp)
#                     upload_to_s3(clf_fp)
                else:
                    sys.stderr.write('Load existing classifiers %d\n' % existing_classifier_id)
                    clf = DataManager.load_classifiers(classifier_id=existing_classifier_id)[structure]
                
                ######################### Compute train metrics #########################
                
                if extract_train_features:
                    train_metrics = compute_classification_metrics(clf.predict_proba(train_data)[:,1], train_labels)
                    train_metrics_all_ntrain[n_train][(train_scheme, 'augment' if augment_training else 'no-augment')].append(train_metrics)
                
                ######################### Test ###############################
                
                test_transforms = range(1)
                features_test_pos = {(test_scheme, tf_variant): 
                                      [features_dict[(test_scheme, tf_variant)][addr] 
                                       for addr in addresses_test_pos
                                      if addr in features_dict[(test_scheme, tf_variant)]]
                                          for tf_variant in test_transforms}
                features_test_neg = {(test_scheme, tf_variant): 
                                      [features_dict[(test_scheme, tf_variant)][addr] 
                                       for addr in addresses_test_neg
                                      if addr in features_dict[(test_scheme, tf_variant)]]
                                          for tf_variant in test_transforms}
                
                test_data = np.concatenate([np.r_[features_test_pos[(test_scheme,tf_variant)], 
                                  features_test_neg[(test_scheme,tf_variant)]]
                                            for tf_variant in train_transforms])
                test_labels = np.concatenate([np.r_[np.ones((len(features_test_pos[(test_scheme,tf_variant)]), )), 
                                     -np.ones((len(features_test_neg[(test_scheme,tf_variant)]), ))]
                                            for tf_variant in train_transforms])
                test_metrics = compute_classification_metrics(clf.predict_proba(test_data)[:,1], test_labels)
    #             print "acc@0.5 = %.3f, acc@opt = %.3f, opt_thresh = %.3f, auroc = %.3f, auprc = %.3f" % \
    #             (test_metrics['acc'][0.5], test_metrics['acc'][test_metrics['opt_thresh']], test_metrics['opt_thresh'], test_metrics['auroc'], test_metrics['auprc'])

                test_metrics_all_ntrain[n_train][(test_scheme, 'augment' if augment_training else 'no-augment')].append(test_metrics)

    train_metrics_all_ntrain.default_factory = None
    test_metrics_all_ntrain.default_factory = None
    
    plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'acc', 0.5), ylabel='Test accuracy@0.5 threshold');
    plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'auroc'), ylabel='Area under ROC');

    plot_roc_curve(test_metrics_all_ntrain[1000][(test_scheme,
                  'no-augment')][0]['fp'], 
                   test_metrics_all_ntrain[1000][(test_scheme,
                  'no-augment')][0]['tp'], 
                  test_metrics_all_ntrain[1000][(test_scheme,
                  'no-augment')][0]['opt_thresh']);
    
    import uuid

    result = {
        'n_sections': stack_section_number,
        'stain': stack_stain,
        'train_stacks': train_stacks,
        'test_stacks': test_stacks,
        'test_scheme': test_scheme,
        'train_scheme': train_scheme,
        'train_metrics_all_ntrain': train_metrics_all_ntrain,
        'test_metrics_all_ntrain': test_metrics_all_ntrain,
        'structure': structure,
        'method': method,
        'classifier_id': existing_classifier_id if existing_classifier_id is not None else classifier_id
    }

    create_if_not_exists(ROOT_DIR + '/assessment_results_v4/')
    save_pickle(result, ROOT_DIR + '/assessment_results_v4/assessment_result_%s.pkl' % str(uuid.uuid1()).split('-')[0])
# Out:
# # positive train = 3516
# # negative train = 32897
# ('MD589', 169)
# ('MD589', 153)
# ('MD589', 292)
# ('MD585', 281)
# ('MD585', 291)
# ('MD589', 166)
# ('MD585', 287)
# ('MD589', 290)
# ('MD585', 158)
# ('MD585', 139)
# ('MD585', 286)
# ('MD589', 150)
# ('MD589', 152)
# ('MD585', 294)
# ('MD585', 136)
# ('MD585', 146)
# ('MD589', 164)
# ('MD589', 309)
# ('MD585', 142)
# ('MD589', 162)
# # positive test = 1617
# # negative test = 15723
# ('MD594', 291)
# ('MD594', 281)
# ('MD594', 298)
# ('MD594', 280)
# ('MD594', 164)
# ('MD594', 295)
# ('MD594', 157)
# ('MD594', 171)
# ('MD594', 161)
# ('MD594', 170)
# n_train 1000
# Fitting classifier: 1.69 seconds
# Trial 0
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Trial 1
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 1.64 seconds
# Trial 2
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 1.59 seconds
# n_train 5000
# Trial 0
# Training: 3516 positive, 3516 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 10.12 seconds
# Trial 1
# Training: 3516 positive, 3516 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 10.81 seconds
# Trial 2
# Training: 3516 positive, 3516 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 8.79 seconds
# n_train 15000
# Trial 0
# Training: 3516 positive, 3516 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 9.07 seconds
# Trial 1
# Training: 3516 positive, 3516 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 8.03 seconds
# Trial 2
# Training: 3516 positive, 3516 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 9.00 seconds
# # positive train = 201
# # negative train = 15218
# ('MD585', 186)
# Feature for (MD585,186,(8237,6807)) is not in pool. Re-compute.
# Feature for (MD585,186,(8432,6807)) is not in pool. Re-compute.
# ('MD585', 227)
# ('MD589', 209)
# ('MD585', 225)
# ('MD585', 191)
# ('MD585', 193)
# Feature for (MD585,193,(8432,6807)) is not in pool. Re-compute.
# ('MD585', 192)
# ('MD589', 251)
# ('MD585', 229)
# ('MD589', 205)
# ('MD585', 230)
# ('MD585', 197)
# ('MD589', 214)
# ('MD589', 245)
# ('MD585', 223)
# # positive test = 115
# # negative test = 10072
# ('MD594', 217)
# ('MD594', 247)
# ('MD594', 248)
# ('MD594', 214)
# ('MD594', 219)
# ('MD594', 241)
# Feature for (MD594,241,(8237,6157)) is not in pool. Re-compute.
# Feature for (MD594,241,(8562,6287)) is not in pool. Re-compute.
# Feature for (MD594,241,(8887,6352)) is not in pool. Re-compute.
# Feature for (MD594,241,(8952,6352)) is not in pool. Re-compute.
# Feature for (MD594,241,(9147,6287)) is not in pool. Re-compute.
# ('MD594', 207)
# ('MD594', 249)
# ('MD594', 242)
# ('MD594', 213)
# n_train 1000
# Trial 0
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.17 seconds
# Trial 1
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.21 seconds
# Trial 2
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.18 seconds
# n_train 5000
# Trial 0
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.16 seconds
# Trial 1
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.15 seconds
# Trial 2
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.16 seconds
# n_train 15000
# Trial 0
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.19 seconds
# Trial 1
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.20 seconds
# Trial 2
# Training: 201 positive, 201 negative
# Test: 115 positive, 1000 negative
# Fitting classifier: 0.19 seconds
# # positive train = 3849
# # negative train = 27569
# ('MD589', 179)
# Feature for (MD589,179,(6807,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(6872,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(6937,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(7002,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(7132,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(7197,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(7262,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(7327,11162)) is not in pool. Re-compute.
# Feature for (MD589,179,(7392,11162)) is not in pool. Re-compute.
# Feature for (MD589,179,(7457,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(7587,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(7652,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(7717,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(7977,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(8042,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(8107,11227)) is not in pool. Re-compute.
# Feature for (MD589,179,(8302,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(8367,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(8432,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(8497,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(8562,11292)) is not in pool. Re-compute.
# Feature for (MD589,179,(8822,11487)) is not in pool. Re-compute.
# Feature for (MD589,179,(8887,11487)) is not in pool. Re-compute.
# Feature for (MD589,179,(8952,11487)) is not in pool. Re-compute.
# Feature for (MD589,179,(9082,11487)) is not in pool. Re-compute.
# ('MD589', 288)
# Feature for (MD589,288,(6807,11097)) is not in pool. Re-compute.
# Feature for (MD589,288,(6872,11097)) is not in pool. Re-compute.
# Feature for (MD589,288,(6937,11032)) is not in pool. Re-compute.
# Feature for (MD589,288,(7002,10967)) is not in pool. Re-compute.
# Feature for (MD589,288,(7197,11032)) is not in pool. Re-compute.
# Feature for (MD589,288,(7652,11227)) is not in pool. Re-compute.
# Feature for (MD589,288,(7717,11162)) is not in pool. Re-compute.
# Feature for (MD589,288,(7782,11227)) is not in pool. Re-compute.
# Feature for (MD589,288,(7847,11162)) is not in pool. Re-compute.
# Feature for (MD589,288,(8042,11162)) is not in pool. Re-compute.
# Feature for (MD589,288,(8107,11162)) is not in pool. Re-compute.
# Feature for (MD589,288,(8172,11227)) is not in pool. Re-compute.
# Feature for (MD589,288,(8302,11292)) is not in pool. Re-compute.
# Feature for (MD589,288,(8367,11032)) is not in pool. Re-compute.
# Feature for (MD589,288,(8432,11357)) is not in pool. Re-compute.
# Feature for (MD589,288,(8497,11357)) is not in pool. Re-compute.
# Feature for (MD589,288,(8562,10967)) is not in pool. Re-compute.
# Feature for (MD589,288,(8627,10967)) is not in pool. Re-compute.
# Feature for (MD589,288,(8887,11032)) is not in pool. Re-compute.
# Feature for (MD589,288,(8952,11032)) is not in pool. Re-compute.
# ('MD589', 304)
# ('MD589', 312)
# Feature for (MD589,312,(7262,10512)) is not in pool. Re-compute.
# Feature for (MD589,312,(7327,10447)) is not in pool. Re-compute.
# ('MD585', 287)
# Feature for (MD585,287,(8887,10057)) is not in pool. Re-compute.
# ('MD585', 264)
# Feature for (MD585,264,(7262,10577)) is not in pool. Re-compute.
# Feature for (MD585,264,(7392,10642)) is not in pool. Re-compute.
# ('MD585', 267)
# ('MD585', 288)
# Feature for (MD585,288,(8887,9992)) is not in pool. Re-compute.
# ('MD585', 253)
# Feature for (MD585,253,(7652,10707)) is not in pool. Re-compute.
# Feature for (MD585,253,(9017,10772)) is not in pool. Re-compute.
# ('MD585', 167)
# Feature for (MD585,167,(7327,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(7392,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(7457,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(7522,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(7652,11162)) is not in pool. Re-compute.
# Feature for (MD585,167,(7782,11227)) is not in pool. Re-compute.
# Feature for (MD585,167,(7847,11227)) is not in pool. Re-compute.
# Feature for (MD585,167,(7912,11227)) is not in pool. Re-compute.
# Feature for (MD585,167,(7977,11227)) is not in pool. Re-compute.
# Feature for (MD585,167,(8042,11227)) is not in pool. Re-compute.
# Feature for (MD585,167,(8367,11162)) is not in pool. Re-compute.
# Feature for (MD585,167,(8432,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(8497,11162)) is not in pool. Re-compute.
# Feature for (MD585,167,(8692,11162)) is not in pool. Re-compute.
# Feature for (MD585,167,(8822,11162)) is not in pool. Re-compute.
# Feature for (MD585,167,(8887,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(8952,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(9017,11097)) is not in pool. Re-compute.
# Feature for (MD585,167,(9407,11162)) is not in pool. Re-compute.
# ('MD589', 184)
# Feature for (MD589,184,(6417,11357)) is not in pool. Re-compute.
# Feature for (MD589,184,(6547,11292)) is not in pool. Re-compute.
# Feature for (MD589,184,(6677,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(6742,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(6807,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(6872,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(6937,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(7002,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(7067,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(7132,11162)) is not in pool. Re-compute.
# Feature for (MD589,184,(7197,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(7457,11292)) is not in pool. Re-compute.
# Feature for (MD589,184,(7522,11292)) is not in pool. Re-compute.
# Feature for (MD589,184,(7587,11292)) is not in pool. Re-compute.
# Feature for (MD589,184,(7652,11292)) is not in pool. Re-compute.
# Feature for (MD589,184,(7782,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(7847,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(7912,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(7977,11227)) is not in pool. Re-compute.
# Feature for (MD589,184,(8172,11292)) is not in pool. Re-compute.
# Feature for (MD589,184,(8237,11357)) is not in pool. Re-compute.
# Feature for (MD589,184,(8302,11422)) is not in pool. Re-compute.
# Feature for (MD589,184,(8497,11422)) is not in pool. Re-compute.
# Feature for (MD589,184,(8627,11422)) is not in pool. Re-compute.
# Feature for (MD589,184,(8822,11487)) is not in pool. Re-compute.
# Feature for (MD589,184,(8887,11487)) is not in pool. Re-compute.
# Feature for (MD589,184,(8952,11422)) is not in pool. Re-compute.
# Feature for (MD589,184,(9082,11422)) is not in pool. Re-compute.
# Feature for (MD589,184,(9147,11422)) is not in pool. Re-compute.
# Feature for (MD589,184,(9407,11487)) is not in pool. Re-compute.
# ('MD589', 175)
# Feature for (MD589,175,(6742,11357)) is not in pool. Re-compute.
# Feature for (MD589,175,(6807,11357)) is not in pool. Re-compute.
# Feature for (MD589,175,(6872,11357)) is not in pool. Re-compute.
# Feature for (MD589,175,(6937,11357)) is not in pool. Re-compute.
# Feature for (MD589,175,(7002,11357)) is not in pool. Re-compute.
# Feature for (MD589,175,(7132,11227)) is not in pool. Re-compute.
# Feature for (MD589,175,(7132,11357)) is not in pool. Re-compute.
# Feature for (MD589,175,(7327,11162)) is not in pool. Re-compute.
# Feature for (MD589,175,(7392,11162)) is not in pool. Re-compute.
# Feature for (MD589,175,(7587,11227)) is not in pool. Re-compute.
# Feature for (MD589,175,(7782,11227)) is not in pool. Re-compute.
# Feature for (MD589,175,(7847,11227)) is not in pool. Re-compute.
# Feature for (MD589,175,(7912,11227)) is not in pool. Re-compute.
# Feature for (MD589,175,(7977,11227)) is not in pool. Re-compute.
# Feature for (MD589,175,(8302,11227)) is not in pool. Re-compute.
# Feature for (MD589,175,(8367,11292)) is not in pool. Re-compute.
# Feature for (MD589,175,(8432,11292)) is not in pool. Re-compute.
# Feature for (MD589,175,(8497,11292)) is not in pool. Re-compute.
# Feature for (MD589,175,(8562,11292)) is not in pool. Re-compute.
# Feature for (MD589,175,(8887,11487)) is not in pool. Re-compute.
# ('MD585', 178)
# Feature for (MD585,178,(6677,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(6742,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(6807,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(7002,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(7392,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(7457,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(7522,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(7587,11097)) is not in pool. Re-compute.
# Feature for (MD585,178,(7782,11227)) is not in pool. Re-compute.
# Feature for (MD585,178,(7847,11227)) is not in pool. Re-compute.
# Feature for (MD585,178,(8042,11162)) is not in pool. Re-compute.
# Feature for (MD585,178,(8107,11162)) is not in pool. Re-compute.
# Feature for (MD585,178,(8432,11227)) is not in pool. Re-compute.
# Feature for (MD585,178,(8497,11227)) is not in pool. Re-compute.
# Feature for (MD585,178,(8822,11162)) is not in pool. Re-compute.
# Feature for (MD585,178,(8887,11162)) is not in pool. Re-compute.
# Feature for (MD585,178,(8952,11162)) is not in pool. Re-compute.
# Feature for (MD585,178,(9147,11162)) is not in pool. Re-compute.
# ('MD585', 146)
# Feature for (MD585,146,(8432,10837)) is not in pool. Re-compute.
# Feature for (MD585,146,(9277,10837)) is not in pool. Re-compute.
# Feature for (MD585,146,(9602,10837)) is not in pool. Re-compute.
# Feature for (MD585,146,(9797,10902)) is not in pool. Re-compute.
# ('MD585', 175)
# Feature for (MD585,175,(6807,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(6872,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(7002,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(7067,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(7132,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(7197,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(7262,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(7327,11097)) is not in pool. Re-compute.
# Feature for (MD585,175,(7782,11227)) is not in pool. Re-compute.
# Feature for (MD585,175,(8042,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(8302,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(8367,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(8757,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(8822,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(8887,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,9862)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,9927)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,9992)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,10122)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,10317)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,10382)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,10447)) is not in pool. Re-compute.
# Feature for (MD585,175,(8952,10512)) is not in pool. Re-compute.
# Feature for (MD585,175,(9017,9732)) is not in pool. Re-compute.
# Feature for (MD585,175,(9017,10772)) is not in pool. Re-compute.
# Feature for (MD585,175,(9082,9667)) is not in pool. Re-compute.
# Feature for (MD585,175,(9082,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(9147,9602)) is not in pool. Re-compute.
# Feature for (MD585,175,(9147,10837)) is not in pool. Re-compute.
# Feature for (MD585,175,(9147,10902)) is not in pool. Re-compute.
# Feature for (MD585,175,(9147,10967)) is not in pool. Re-compute.
# Feature for (MD585,175,(9147,11162)) is not in pool. Re-compute.
# Feature for (MD585,175,(9277,9537)) is not in pool. Re-compute.
# Feature for (MD585,175,(9407,11162)) is not in pool. Re-compute.
# ('MD589', 164)
# Feature for (MD589,164,(6612,11227)) is not in pool. Re-compute.
# Feature for (MD589,164,(6742,11227)) is not in pool. Re-compute.
# Feature for (MD589,164,(6807,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(6872,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(6937,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(7132,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(7197,11032)) is not in pool. Re-compute.
# Feature for (MD589,164,(7262,11032)) is not in pool. Re-compute.
# Feature for (MD589,164,(7327,11032)) is not in pool. Re-compute.
# Feature for (MD589,164,(7392,11032)) is not in pool. Re-compute.
# Feature for (MD589,164,(7457,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(7522,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(7587,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(7652,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(7717,11032)) is not in pool. Re-compute.
# Feature for (MD589,164,(7782,11032)) is not in pool. Re-compute.
# Feature for (MD589,164,(7977,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8107,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(8172,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(8302,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8367,11032)) is not in pool. Re-compute.
# Feature for (MD589,164,(8432,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8432,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(8432,11227)) is not in pool. Re-compute.
# Feature for (MD589,164,(8497,11227)) is not in pool. Re-compute.
# Feature for (MD589,164,(8562,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8627,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8757,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8822,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8887,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8952,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(9017,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(9472,11422)) is not in pool. Re-compute.
# Feature for (MD589,164,(9537,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(9602,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(9732,11227)) is not in pool. Re-compute.
# Feature for (MD589,164,(9797,11162)) is not in pool. Re-compute.
# ('MD585', 177)
# Feature for (MD585,177,(6677,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(6807,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(6872,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(6937,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7067,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7132,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7197,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7262,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7327,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7392,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7457,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7522,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7587,11097)) is not in pool. Re-compute.
# Feature for (MD585,177,(7717,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(7847,11227)) is not in pool. Re-compute.
# Feature for (MD585,177,(7912,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(7977,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(8042,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(8107,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(8172,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(8237,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(8562,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(8952,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(9017,11162)) is not in pool. Re-compute.
# Feature for (MD585,177,(9472,11227)) is not in pool. Re-compute.
# Feature for (MD585,177,(9537,11227)) is not in pool. Re-compute.
# ('MD589', 171)
# Feature for (MD589,171,(6742,11487)) is not in pool. Re-compute.
# Feature for (MD589,171,(6872,11487)) is not in pool. Re-compute.
# Feature for (MD589,171,(7067,11227)) is not in pool. Re-compute.
# Feature for (MD589,171,(7132,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(7132,11357)) is not in pool. Re-compute.
# Feature for (MD589,171,(7197,11357)) is not in pool. Re-compute.
# Feature for (MD589,171,(7262,11097)) is not in pool. Re-compute.
# Feature for (MD589,171,(7327,11097)) is not in pool. Re-compute.
# Feature for (MD589,171,(7457,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(7847,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(7912,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(7977,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(8042,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(8107,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(8172,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(8302,11162)) is not in pool. Re-compute.
# Feature for (MD589,171,(8367,11227)) is not in pool. Re-compute.
# Feature for (MD589,171,(8432,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(8497,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(8562,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(8757,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(8757,11422)) is not in pool. Re-compute.
# Feature for (MD589,171,(8822,11357)) is not in pool. Re-compute.
# Feature for (MD589,171,(8887,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(9277,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(9342,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(9407,11292)) is not in pool. Re-compute.
# Feature for (MD589,171,(9537,11357)) is not in pool. Re-compute.
# Feature for (MD589,171,(9602,11357)) is not in pool. Re-compute.
# ('MD589', 287)
# Feature for (MD589,287,(6612,11097)) is not in pool. Re-compute.
# Feature for (MD589,287,(6742,11032)) is not in pool. Re-compute.
# Feature for (MD589,287,(6807,11032)) is not in pool. Re-compute.
# Feature for (MD589,287,(7002,10967)) is not in pool. Re-compute.
# Feature for (MD589,287,(7327,11032)) is not in pool. Re-compute.
# Feature for (MD589,287,(7457,10967)) is not in pool. Re-compute.
# Feature for (MD589,287,(7782,10967)) is not in pool. Re-compute.
# Feature for (MD589,287,(7782,11032)) is not in pool. Re-compute.
# Feature for (MD589,287,(7977,11097)) is not in pool. Re-compute.
# Feature for (MD589,287,(8107,11162)) is not in pool. Re-compute.
# Feature for (MD589,287,(8172,11227)) is not in pool. Re-compute.
# Feature for (MD589,287,(8237,11292)) is not in pool. Re-compute.
# Feature for (MD589,287,(8302,11357)) is not in pool. Re-compute.
# Feature for (MD589,287,(8497,11422)) is not in pool. Re-compute.
# Feature for (MD589,287,(8627,11357)) is not in pool. Re-compute.
# Feature for (MD589,287,(8692,11357)) is not in pool. Re-compute.
# Feature for (MD589,287,(8757,11292)) is not in pool. Re-compute.
# Feature for (MD589,287,(8887,11032)) is not in pool. Re-compute.
# Feature for (MD589,287,(8952,11032)) is not in pool. Re-compute.
# Feature for (MD589,287,(9017,11032)) is not in pool. Re-compute.
# ('MD589', 308)
# Feature for (MD589,308,(6807,10837)) is not in pool. Re-compute.
# Feature for (MD589,308,(7002,10707)) is not in pool. Re-compute.
# Feature for (MD589,308,(7457,10707)) is not in pool. Re-compute.
# Feature for (MD589,308,(7587,10772)) is not in pool. Re-compute.
# Feature for (MD589,308,(9407,10512)) is not in pool. Re-compute.
# # positive test = 1832
# # negative test = 14188
# ('MD594', 162)
# Feature for (MD594,162,(9017,9992)) is not in pool. Re-compute.
# Feature for (MD594,162,(9602,9407)) is not in pool. Re-compute.
# Feature for (MD594,162,(9862,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(9927,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(9992,9212)) is not in pool. Re-compute.
# Feature for (MD594,162,(10057,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(10057,9342)) is not in pool. Re-compute.
# Feature for (MD594,162,(10122,9342)) is not in pool. Re-compute.
# Feature for (MD594,162,(10187,9342)) is not in pool. Re-compute.
# Feature for (MD594,162,(10252,9342)) is not in pool. Re-compute.
# Feature for (MD594,162,(10317,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(10512,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(10577,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(10642,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(10707,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(10772,9277)) is not in pool. Re-compute.
# Feature for (MD594,162,(10837,9212)) is not in pool. Re-compute.
# Feature for (MD594,162,(10902,9212)) is not in pool. Re-compute.
# Feature for (MD594,162,(10967,9212)) is not in pool. Re-compute.
# Feature for (MD594,162,(11032,9212)) is not in pool. Re-compute.
# Feature for (MD594,162,(11292,9277)) is not in pool. Re-compute.
# ('MD594', 152)
# Feature for (MD594,152,(9147,9732)) is not in pool. Re-compute.
# Feature for (MD594,152,(9407,9342)) is not in pool. Re-compute.
# Feature for (MD594,152,(9407,9407)) is not in pool. Re-compute.
# Feature for (MD594,152,(9407,9472)) is not in pool. Re-compute.
# Feature for (MD594,152,(9407,9537)) is not in pool. Re-compute.
# Feature for (MD594,152,(9472,9277)) is not in pool. Re-compute.
# Feature for (MD594,152,(9602,9277)) is not in pool. Re-compute.
# Feature for (MD594,152,(9667,9277)) is not in pool. Re-compute.
# Feature for (MD594,152,(9862,9212)) is not in pool. Re-compute.
# Feature for (MD594,152,(10317,9082)) is not in pool. Re-compute.
# Feature for (MD594,152,(10447,9017)) is not in pool. Re-compute.
# Feature for (MD594,152,(10707,8952)) is not in pool. Re-compute.
# ('MD594', 182)
# Feature for (MD594,182,(8237,10317)) is not in pool. Re-compute.
# Feature for (MD594,182,(9147,10252)) is not in pool. Re-compute.
# Feature for (MD594,182,(9212,10057)) is not in pool. Re-compute.
# Feature for (MD594,182,(9212,10122)) is not in pool. Re-compute.
# ('MD594', 175)
# Feature for (MD594,175,(8237,10252)) is not in pool. Re-compute.
# Feature for (MD594,175,(9212,9862)) is not in pool. Re-compute.
# Feature for (MD594,175,(9212,9927)) is not in pool. Re-compute.
# Feature for (MD594,175,(9407,9667)) is not in pool. Re-compute.
# Feature for (MD594,175,(10447,9407)) is not in pool. Re-compute.
# Feature for (MD594,175,(10512,9407)) is not in pool. Re-compute.
# Feature for (MD594,175,(10577,9407)) is not in pool. Re-compute.
# ('MD594', 280)
# Feature for (MD594,280,(8952,10317)) is not in pool. Re-compute.
# ('MD594', 179)
# Feature for (MD594,179,(9147,10057)) is not in pool. Re-compute.
# Feature for (MD594,179,(9212,9992)) is not in pool. Re-compute.
# Feature for (MD594,179,(9342,9927)) is not in pool. Re-compute.
# ('MD594', 284)
# Feature for (MD594,284,(9082,10252)) is not in pool. Re-compute.
# Feature for (MD594,284,(9342,10187)) is not in pool. Re-compute.
# ('MD594', 156)
# Feature for (MD594,156,(9017,9992)) is not in pool. Re-compute.
# Feature for (MD594,156,(9147,9927)) is not in pool. Re-compute.
# Feature for (MD594,156,(9212,9472)) is not in pool. Re-compute.
# Feature for (MD594,156,(9212,9537)) is not in pool. Re-compute.
# Feature for (MD594,156,(9212,9862)) is not in pool. Re-compute.
# Feature for (MD594,156,(9342,9407)) is not in pool. Re-compute.
# Feature for (MD594,156,(9407,9342)) is not in pool. Re-compute.
# Feature for (MD594,156,(9407,9537)) is not in pool. Re-compute.
# Feature for (MD594,156,(9407,9732)) is not in pool. Re-compute.
# Feature for (MD594,156,(9472,9342)) is not in pool. Re-compute.
# Feature for (MD594,156,(9667,9342)) is not in pool. Re-compute.
# Feature for (MD594,156,(9797,9277)) is not in pool. Re-compute.
# Feature for (MD594,156,(9862,9212)) is not in pool. Re-compute.
# Feature for (MD594,156,(9927,9212)) is not in pool. Re-compute.
# Feature for (MD594,156,(10122,9212)) is not in pool. Re-compute.
# Feature for (MD594,156,(10187,9212)) is not in pool. Re-compute.
# Feature for (MD594,156,(10317,9147)) is not in pool. Re-compute.
# Feature for (MD594,156,(10447,9082)) is not in pool. Re-compute.
# Feature for (MD594,156,(10577,9082)) is not in pool. Re-compute.
# Feature for (MD594,156,(10707,9082)) is not in pool. Re-compute.
# Feature for (MD594,156,(10772,9082)) is not in pool. Re-compute.
# Feature for (MD594,156,(10902,9017)) is not in pool. Re-compute.
# Feature for (MD594,156,(10967,8952)) is not in pool. Re-compute.
# ('MD594', 266)
# Feature for (MD594,266,(8497,10577)) is not in pool. Re-compute.
# Feature for (MD594,266,(8887,10382)) is not in pool. Re-compute.
# ('MD594', 158)
# Feature for (MD594,158,(8497,10057)) is not in pool. Re-compute.
# Feature for (MD594,158,(9017,9927)) is not in pool. Re-compute.
# Feature for (MD594,158,(9082,9992)) is not in pool. Re-compute.
# Feature for (MD594,158,(9147,9927)) is not in pool. Re-compute.
# Feature for (MD594,158,(9212,9797)) is not in pool. Re-compute.
# Feature for (MD594,158,(9667,9277)) is not in pool. Re-compute.
# Feature for (MD594,158,(9732,9277)) is not in pool. Re-compute.
# Feature for (MD594,158,(9797,9277)) is not in pool. Re-compute.
# Feature for (MD594,158,(9862,9277)) is not in pool. Re-compute.
# Feature for (MD594,158,(9927,9277)) is not in pool. Re-compute.
# Feature for (MD594,158,(10057,9342)) is not in pool. Re-compute.
# Feature for (MD594,158,(10187,9147)) is not in pool. Re-compute.
# Feature for (MD594,158,(10252,9147)) is not in pool. Re-compute.
# Feature for (MD594,158,(10317,9147)) is not in pool. Re-compute.
# Feature for (MD594,158,(10447,9082)) is not in pool. Re-compute.
# Feature for (MD594,158,(10512,9082)) is not in pool. Re-compute.
# Feature for (MD594,158,(10577,9082)) is not in pool. Re-compute.
# Feature for (MD594,158,(10707,9017)) is not in pool. Re-compute.
# Feature for (MD594,158,(10772,9017)) is not in pool. Re-compute.
# Feature for (MD594,158,(10837,9017)) is not in pool. Re-compute.
# Feature for (MD594,158,(10902,9017)) is not in pool. Re-compute.
# Feature for (MD594,158,(11032,9082)) is not in pool. Re-compute.
# Feature for (MD594,158,(11097,9082)) is not in pool. Re-compute.
# Feature for (MD594,158,(11227,9017)) is not in pool. Re-compute.
# Feature for (MD594,158,(11292,9017)) is not in pool. Re-compute.
# Feature for (MD594,158,(11357,9017)) is not in pool. Re-compute.
# n_train 1000
# Trial 0
# Training: 1000 positive, 1000 negative
# Fitting classifier: 1.72 seconds
# Test: 1000 positive, 1000 negative
# Trial 1
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 1.23 seconds
# Trial 2
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 1.32 seconds
# n_train 5000
# Trial 0
# Training: 3849 positive, 3849 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 7.26 seconds
# Trial 1
# Training: 3849 positive, 3849 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 10.29 seconds
# Trial 2
# Training: 3849 positive, 3849 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 8.29 seconds
# n_train 15000
# Trial 0
# Training: 3849 positive, 3849 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 9.03 seconds
# Trial 1
# Training: 3849 positive, 3849 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 7.63 seconds
# Trial 2
# Training: 3849 positive, 3849 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 8.87 seconds
# # positive train = 792
# # negative train = 23666
# ('MD589', 254)
# ('MD585', 279)
# ('MD585', 244)
# ('MD589', 307)
# ('MD585', 184)
# Feature for (MD585,184,(8952,6742)) is not in pool. Re-compute.
# ('MD585', 181)
# ('MD589', 155)
# Feature for (MD589,155,(5442,10447)) is not in pool. Re-compute.
# Feature for (MD589,155,(5767,10642)) is not in pool. Re-compute.
# Feature for (MD589,155,(5832,10707)) is not in pool. Re-compute.
# Feature for (MD589,155,(6092,10837)) is not in pool. Re-compute.
# ('MD585', 180)
# ('MD585', 158)
# ('MD585', 235)
# ('MD589', 298)
# ('MD589', 313)
# ('MD585', 234)
# ('MD589', 273)
# ('MD585', 134)
# Feature for (MD585,134,(5897,9992)) is not in pool. Re-compute.
# Feature for (MD585,134,(5962,10057)) is not in pool. Re-compute.
# Feature for (MD585,134,(5962,10122)) is not in pool. Re-compute.
# Feature for (MD585,134,(5962,10187)) is not in pool. Re-compute.
# ('MD589', 268)
# ('MD585', 274)
# ('MD589', 160)
# ('MD589', 271)
# ('MD589', 287)
# # positive test = 383
# # negative test = 11453
# ('MD594', 308)
# Feature for (MD594,308,(8302,9667)) is not in pool. Re-compute.
# Feature for (MD594,308,(8432,9602)) is not in pool. Re-compute.
# Feature for (MD594,308,(8497,9537)) is not in pool. Re-compute.
# ('MD594', 281)
# ('MD594', 247)
# ('MD594', 278)
# ('MD594', 154)
# ('MD594', 304)
# ('MD594', 210)
# ('MD594', 167)
# ('MD594', 157)
# ('MD594', 299)
# n_train 1000
# Trial 0
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.93 seconds
# Trial 1
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 1.01 seconds
# Trial 2
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.79 seconds
# n_train 5000
# Trial 0
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.90 seconds
# Trial 1
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.87 seconds
# Trial 2
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.90 seconds
# n_train 15000
# Trial 0
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.77 seconds
# Trial 1
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.94 seconds
# Trial 2
# Training: 792 positive, 792 negative
# Test: 383 positive, 1000 negative
# Fitting classifier: 0.89 seconds
# # positive train = 617
# # negative train = 24259
# ('MD589', 169)
# Feature for (MD589,169,(9537,11357)) is not in pool. Re-compute.
# Feature for (MD589,169,(9667,11357)) is not in pool. Re-compute.
# Feature for (MD589,169,(9732,11357)) is not in pool. Re-compute.
# Feature for (MD589,169,(9862,11357)) is not in pool. Re-compute.
# Feature for (MD589,169,(9992,11292)) is not in pool. Re-compute.
# Feature for (MD589,169,(10057,11292)) is not in pool. Re-compute.
# Feature for (MD589,169,(10057,11422)) is not in pool. Re-compute.
# Feature for (MD589,169,(10122,11357)) is not in pool. Re-compute.
# ('MD589', 297)
# ('MD589', 168)
# Feature for (MD589,168,(9147,11292)) is not in pool. Re-compute.
# Feature for (MD589,168,(9212,11292)) is not in pool. Re-compute.
# Feature for (MD589,168,(9342,11357)) is not in pool. Re-compute.
# Feature for (MD589,168,(9407,11357)) is not in pool. Re-compute.
# Feature for (MD589,168,(9472,11357)) is not in pool. Re-compute.
# Feature for (MD589,168,(9537,11357)) is not in pool. Re-compute.
# Feature for (MD589,168,(9667,11292)) is not in pool. Re-compute.
# ('MD589', 167)
# Feature for (MD589,167,(9212,11292)) is not in pool. Re-compute.
# Feature for (MD589,167,(9667,11227)) is not in pool. Re-compute.
# Feature for (MD589,167,(9797,11227)) is not in pool. Re-compute.
# Feature for (MD589,167,(9862,11227)) is not in pool. Re-compute.
# Feature for (MD589,167,(10187,11357)) is not in pool. Re-compute.
# ('MD585', 152)
# Feature for (MD585,152,(9147,10967)) is not in pool. Re-compute.
# Feature for (MD585,152,(9212,10967)) is not in pool. Re-compute.
# Feature for (MD585,152,(9667,11097)) is not in pool. Re-compute.
# Feature for (MD585,152,(9732,11097)) is not in pool. Re-compute.
# Feature for (MD585,152,(9992,11097)) is not in pool. Re-compute.
# Feature for (MD585,152,(10317,11162)) is not in pool. Re-compute.
# Feature for (MD585,152,(10382,11162)) is not in pool. Re-compute.
# Feature for (MD585,152,(10512,11227)) is not in pool. Re-compute.
# Feature for (MD585,152,(10577,11227)) is not in pool. Re-compute.
# Feature for (MD585,152,(10642,11227)) is not in pool. Re-compute.
# Feature for (MD585,152,(10707,11227)) is not in pool. Re-compute.
# Feature for (MD585,152,(10837,11292)) is not in pool. Re-compute.
# ('MD585', 149)
# Feature for (MD585,149,(9277,10902)) is not in pool. Re-compute.
# Feature for (MD585,149,(9472,10902)) is not in pool. Re-compute.
# Feature for (MD585,149,(9862,10967)) is not in pool. Re-compute.
# Feature for (MD585,149,(9927,10967)) is not in pool. Re-compute.
# Feature for (MD585,149,(10187,11032)) is not in pool. Re-compute.
# Feature for (MD585,149,(10252,11032)) is not in pool. Re-compute.
# ('MD589', 294)
# Feature for (MD589,294,(9797,10902)) is not in pool. Re-compute.
# ('MD585', 276)
# ('MD589', 165)
# Feature for (MD589,165,(8887,11162)) is not in pool. Re-compute.
# Feature for (MD589,165,(9082,11162)) is not in pool. Re-compute.
# Feature for (MD589,165,(9277,11292)) is not in pool. Re-compute.
# Feature for (MD589,165,(9407,11227)) is not in pool. Re-compute.
# Feature for (MD589,165,(9407,11292)) is not in pool. Re-compute.
# Feature for (MD589,165,(9472,11162)) is not in pool. Re-compute.
# Feature for (MD589,165,(9472,11357)) is not in pool. Re-compute.
# Feature for (MD589,165,(9537,11162)) is not in pool. Re-compute.
# Feature for (MD589,165,(9602,11162)) is not in pool. Re-compute.
# Feature for (MD589,165,(9797,11227)) is not in pool. Re-compute.
# Feature for (MD589,165,(9862,11227)) is not in pool. Re-compute.
# Feature for (MD589,165,(9992,11227)) is not in pool. Re-compute.
# ('MD589', 299)
# Feature for (MD589,299,(9537,10772)) is not in pool. Re-compute.
# ('MD589', 164)
# Feature for (MD589,164,(8757,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8822,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8887,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(8952,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(9017,11097)) is not in pool. Re-compute.
# Feature for (MD589,164,(9537,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(9602,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(9732,11227)) is not in pool. Re-compute.
# Feature for (MD589,164,(9797,11162)) is not in pool. Re-compute.
# Feature for (MD589,164,(9992,11227)) is not in pool. Re-compute.
# ('MD589', 296)
# Feature for (MD589,296,(9472,10837)) is not in pool. Re-compute.
# ('MD589', 298)
# Feature for (MD589,298,(9407,10772)) is not in pool. Re-compute.
# ('MD585', 275)
# ('MD585', 274)
# ('MD585', 271)
# ('MD585', 273)
# ('MD585', 270)
# ('MD585', 155)
# Feature for (MD585,155,(9342,10967)) is not in pool. Re-compute.
# Feature for (MD585,155,(9537,11097)) is not in pool. Re-compute.
# Feature for (MD585,155,(9602,11097)) is not in pool. Re-compute.
# Feature for (MD585,155,(9667,11097)) is not in pool. Re-compute.
# Feature for (MD585,155,(9927,11162)) is not in pool. Re-compute.
# Feature for (MD585,155,(9992,11162)) is not in pool. Re-compute.
# Feature for (MD585,155,(10447,11227)) is not in pool. Re-compute.
# Feature for (MD585,155,(10577,11292)) is not in pool. Re-compute.
# Feature for (MD585,155,(10642,11292)) is not in pool. Re-compute.
# Feature for (MD585,155,(10772,11357)) is not in pool. Re-compute.
# Feature for (MD585,155,(10837,11357)) is not in pool. Re-compute.
# Feature for (MD585,155,(11032,11357)) is not in pool. Re-compute.
# Feature for (MD585,155,(11097,11357)) is not in pool. Re-compute.
# Feature for (MD585,155,(11162,11357)) is not in pool. Re-compute.
# Feature for (MD585,155,(11227,11357)) is not in pool. Re-compute.
# ('MD585', 272)
# # positive test = 315
# # negative test = 12119
# ('MD594', 291)
# ('MD594', 290)
# ('MD594', 172)
# Feature for (MD594,172,(10642,9407)) is not in pool. Re-compute.
# Feature for (MD594,172,(10837,9407)) is not in pool. Re-compute.
# Feature for (MD594,172,(11487,9342)) is not in pool. Re-compute.
# Feature for (MD594,172,(11552,9342)) is not in pool. Re-compute.
# Feature for (MD594,172,(11617,9342)) is not in pool. Re-compute.
# Feature for (MD594,172,(11682,9342)) is not in pool. Re-compute.
# Feature for (MD594,172,(11747,9342)) is not in pool. Re-compute.
# Feature for (MD594,172,(11812,9342)) is not in pool. Re-compute.
# ('MD594', 292)
# ('MD594', 169)
# Feature for (MD594,169,(10512,9407)) is not in pool. Re-compute.
# Feature for (MD594,169,(10837,9342)) is not in pool. Re-compute.
# Feature for (MD594,169,(10967,9407)) is not in pool. Re-compute.
# Feature for (MD594,169,(11422,9342)) is not in pool. Re-compute.
# Feature for (MD594,169,(11487,9277)) is not in pool. Re-compute.
# Feature for (MD594,169,(11617,9277)) is not in pool. Re-compute.
# ('MD594', 167)
# Feature for (MD594,167,(10642,9277)) is not in pool. Re-compute.
# Feature for (MD594,167,(10707,9277)) is not in pool. Re-compute.
# Feature for (MD594,167,(10772,9277)) is not in pool. Re-compute.
# Feature for (MD594,167,(10837,9277)) is not in pool. Re-compute.
# Feature for (MD594,167,(10902,9342)) is not in pool. Re-compute.
# ('MD594', 168)
# Feature for (MD594,168,(10512,9277)) is not in pool. Re-compute.
# Feature for (MD594,168,(10577,9277)) is not in pool. Re-compute.
# Feature for (MD594,168,(10642,9277)) is not in pool. Re-compute.
# Feature for (MD594,168,(10837,9277)) is not in pool. Re-compute.
# Feature for (MD594,168,(10967,9342)) is not in pool. Re-compute.
# ('MD594', 289)
# ('MD594', 287)
# ('MD594', 288)
# n_train 1000
# Fitting classifier: 0.53 seconds
# Trial 0
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Trial 1
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.48 seconds
# Trial 2
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.60 seconds
# n_train 5000
# Trial 0
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.57 seconds
# Trial 1
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.59 seconds
# Trial 2
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.51 seconds
# n_train 15000
# Trial 0
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.60 seconds
# Trial 1
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.63 seconds
# Trial 2
# Training: 617 positive, 617 negative
# Test: 315 positive, 1000 negative
# Fitting classifier: 0.60 seconds
# # positive train = 2726
# # negative train = 33029
# ('MD589', 185)
# ('MD589', 263)
# ('MD585', 258)
# ('MD589', 272)
# ('MD585', 257)
# ('MD585', 254)
# ('MD585', 171)
# ('MD585', 253)
# ('MD585', 170)
# Feature for (MD585,170,(9277,6547)) is not in pool. Re-compute.
# ('MD589', 184)
# ('MD585', 169)
# ('MD589', 175)
# ('MD589', 183)
# ('MD589', 268)
# ('MD585', 261)
# ('MD589', 182)
# ('MD585', 260)
# ('MD589', 181)
# ('MD585', 174)
# ('MD589', 180)
# # positive test = 936
# # negative test = 14589
# ('MD594', 180)
# ('MD594', 184)
# ('MD594', 269)
# ('MD594', 272)
# ('MD594', 270)
# ('MD594', 263)
# ('MD594', 189)
# ('MD594', 267)
# Feature for (MD594,267,(8627,5507)) is not in pool. Re-compute.
# Feature for (MD594,267,(9017,5572)) is not in pool. Re-compute.
# Feature for (MD594,267,(9082,5572)) is not in pool. Re-compute.
# Feature for (MD594,267,(9147,5572)) is not in pool. Re-compute.
# ('MD594', 188)
# ('MD594', 190)
# n_train
# Fitting classifier: 1.21 seconds
# 1000
# Trial 0
# Training: 1000 positive, 1000 negative
# Test: 936 positive, 1000 negative
# Trial 1
# Training: 1000 positive, 1000 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 1.40 seconds
# Trial 2
# Training: 1000 positive, 1000 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 1.34 seconds
# n_train 5000
# Trial 0
# Training: 2726 positive, 2726 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 5.48 seconds
# Trial 1
# Training: 2726 positive, 2726 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 4.81 seconds
# Trial 2
# Training: 2726 positive, 2726 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 5.26 seconds
# n_train 15000
# Trial 0
# Training: 2726 positive, 2726 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 4.38 seconds
# Trial 1
# Training: 2726 positive, 2726 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 4.88 seconds
# Trial 2
# Training: 2726 positive, 2726 negative
# Test: 936 positive, 1000 negative
# Fitting classifier: 5.04 seconds
# # positive train = 2487
# # negative train = 29378
# ('MD585', 141)
# Feature for (MD585,141,(9797,10772)) is not in pool. Re-compute.
# Feature for (MD585,141,(9927,10837)) is not in pool. Re-compute.
# Feature for (MD585,141,(10512,11097)) is not in pool. Re-compute.
# Feature for (MD585,141,(10707,10967)) is not in pool. Re-compute.
# Feature for (MD585,141,(10772,10967)) is not in pool. Re-compute.
# Feature for (MD585,141,(10837,10967)) is not in pool. Re-compute.
# Feature for (MD585,141,(10837,11292)) is not in pool. Re-compute.
# Feature for (MD585,141,(10902,10967)) is not in pool. Re-compute.
# Feature for (MD585,141,(10902,11292)) is not in pool. Re-compute.
# Feature for (MD585,141,(10967,10967)) is not in pool. Re-compute.
# Feature for (MD585,141,(10967,11292)) is not in pool. Re-compute.
# Feature for (MD585,141,(11162,11292)) is not in pool. Re-compute.
# Feature for (MD585,141,(11227,11292)) is not in pool. Re-compute.
# Feature for (MD585,141,(11812,11227)) is not in pool. Re-compute.
# Feature for (MD585,141,(12137,11422)) is not in pool. Re-compute.
# ('MD585', 282)
# Feature for (MD585,282,(11227,10382)) is not in pool. Re-compute.
# Feature for (MD585,282,(12267,11032)) is not in pool. Re-compute.
# Feature for (MD585,282,(12267,11097)) is not in pool. Re-compute.
# Feature for (MD585,282,(12332,10902)) is not in pool. Re-compute.
# Feature for (MD585,282,(12332,10967)) is not in pool. Re-compute.
# Feature for (MD585,282,(12462,10577)) is not in pool. Re-compute.
# Feature for (MD585,282,(12462,10707)) is not in pool. Re-compute.
# Feature for (MD585,282,(12527,10967)) is not in pool. Re-compute.
# Feature for (MD585,282,(12657,10967)) is not in pool. Re-compute.
# Feature for (MD585,282,(12852,10967)) is not in pool. Re-compute.
# ('MD585', 279)
# Feature for (MD585,279,(11292,10642)) is not in pool. Re-compute.
# Feature for (MD585,279,(11357,10577)) is not in pool. Re-compute.
# Feature for (MD585,279,(11617,10642)) is not in pool. Re-compute.
# Feature for (MD585,279,(12267,11032)) is not in pool. Re-compute.
# Feature for (MD585,279,(12332,10902)) is not in pool. Re-compute.
# Feature for (MD585,279,(12527,10772)) is not in pool. Re-compute.
# Feature for (MD585,279,(12852,11097)) is not in pool. Re-compute.
# ('MD585', 281)
# Feature for (MD585,281,(11292,10512)) is not in pool. Re-compute.
# Feature for (MD585,281,(11487,10447)) is not in pool. Re-compute.
# Feature for (MD585,281,(12332,11032)) is not in pool. Re-compute.
# Feature for (MD585,281,(12397,11097)) is not in pool. Re-compute.
# Feature for (MD585,281,(12462,10772)) is not in pool. Re-compute.
# Feature for (MD585,281,(12527,10642)) is not in pool. Re-compute.
# Feature for (MD585,281,(12527,11097)) is not in pool. Re-compute.
# Feature for (MD585,281,(12657,11032)) is not in pool. Re-compute.
# ('MD589', 295)
# Feature for (MD589,295,(9927,10967)) is not in pool. Re-compute.
# Feature for (MD589,295,(9992,10967)) is not in pool. Re-compute.
# Feature for (MD589,295,(10057,10967)) is not in pool. Re-compute.
# Feature for (MD589,295,(10122,10967)) is not in pool. Re-compute.
# Feature for (MD589,295,(10902,10967)) is not in pool. Re-compute.
# Feature for (MD589,295,(11032,10967)) is not in pool. Re-compute.
# Feature for (MD589,295,(11097,10967)) is not in pool. Re-compute.
# Feature for (MD589,295,(11227,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(11552,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(11617,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(11682,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(11747,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(11812,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(11942,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(12007,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(12137,11032)) is not in pool. Re-compute.
# Feature for (MD589,295,(12267,11097)) is not in pool. Re-compute.
# Feature for (MD589,295,(12657,11097)) is not in pool. Re-compute.
# Feature for (MD589,295,(12722,11097)) is not in pool. Re-compute.
# Feature for (MD589,295,(12917,11097)) is not in pool. Re-compute.
# ('MD585', 280)
# Feature for (MD585,280,(10577,10512)) is not in pool. Re-compute.
# Feature for (MD585,280,(11292,10577)) is not in pool. Re-compute.
# Feature for (MD585,280,(12332,10967)) is not in pool. Re-compute.
# Feature for (MD585,280,(12332,11032)) is not in pool. Re-compute.
# Feature for (MD585,280,(12332,11097)) is not in pool. Re-compute.
# ...
# Feature for (MD594,196,(7587,112)) is not in pool. Re-compute.
# Feature for (MD594,196,(7587,177)) is not in pool. Re-compute.
# Feature for (MD594,196,(7587,242)) is not in pool. Re-compute.
# Feature for (MD594,196,(7652,112)) is not in pool. Re-compute.
# Feature for (MD594,196,(7652,177)) is not in pool. Re-compute.
# Feature for (MD594,196,(7652,242)) is not in pool. Re-compute.
# Feature for (MD594,196,(7717,112)) is not in pool. Re-compute.
# Feature for (MD594,196,(7717,177)) is not in pool. Re-compute.
# Feature for (MD594,196,(7717,242)) is not in pool. Re-compute.
# Feature for (MD594,196,(7782,112)) is not in pool. Re-compute.
# Feature for (MD594,196,(7782,177)) is not in pool. Re-compute.
# Feature for (MD594,196,(7782,242)) is not in pool. Re-compute.
# Feature for (MD594,196,(7847,112)) is not in pool. Re-compute.
# Feature for (MD594,196,(7847,177)) is not in pool. Re-compute.
# Feature for (MD594,196,(7847,242)) is not in pool. Re-compute.
# Feature for (MD594,196,(7912,177)) is not in pool. Re-compute.
# Feature for (MD594,196,(7912,242)) is not in pool. Re-compute.
# ('MD594', 263)
# Feature for (MD594,263,(4337,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4402,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4402,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4402,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4467,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4467,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4467,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4532,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4532,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4532,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4597,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4597,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4597,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4662,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4662,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4662,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4727,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4727,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4727,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4792,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4792,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4792,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4857,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4857,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4857,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4922,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4922,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4922,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(4987,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(4987,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(4987,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(5052,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(5052,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(5052,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(5117,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(5117,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(5117,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(5182,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(5182,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(5182,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(5247,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(5247,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(5247,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(5312,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(5312,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(5312,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(5637,372)) is not in pool. Re-compute.
# Feature for (MD594,263,(5767,372)) is not in pool. Re-compute.
# Feature for (MD594,263,(6287,307)) is not in pool. Re-compute.
# Feature for (MD594,263,(6547,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(6612,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(6612,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(6612,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(6677,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(6677,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(6677,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(6742,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(6742,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(6742,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(6807,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(6807,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(6807,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(6872,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(6872,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(6872,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(6937,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(6937,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(6937,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7002,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(7002,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(7002,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7067,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(7067,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(7067,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7132,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(7132,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(7132,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7197,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(7197,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(7197,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7262,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(7262,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(7262,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7327,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(7327,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(7327,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7392,112)) is not in pool. Re-compute.
# Feature for (MD594,263,(7392,177)) is not in pool. Re-compute.
# Feature for (MD594,263,(7392,242)) is not in pool. Re-compute.
# Feature for (MD594,263,(7457,242)) is not in pool. Re-compute.
# ('MD594', 220)
# Feature for (MD594,220,(4727,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(4727,632)) is not in pool. Re-compute.
# Feature for (MD594,220,(4792,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(4792,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(4792,567)) is not in pool. Re-compute.
# Feature for (MD594,220,(4857,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(4857,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(4857,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(4857,567)) is not in pool. Re-compute.
# Feature for (MD594,220,(4922,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(4922,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(4922,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(4987,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(4987,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(4987,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(4987,502)) is not in pool. Re-compute.
# Feature for (MD594,220,(5052,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(5052,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(5052,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(5052,437)) is not in pool. Re-compute.
# Feature for (MD594,220,(5117,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(5117,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(5117,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(5117,307)) is not in pool. Re-compute.
# Feature for (MD594,220,(5182,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(5182,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(5247,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(5247,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6027,502)) is not in pool. Re-compute.
# Feature for (MD594,220,(6157,437)) is not in pool. Re-compute.
# Feature for (MD594,220,(6417,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6482,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6482,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6547,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(6547,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6547,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6612,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(6612,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6612,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6677,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(6677,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6677,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6742,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(6742,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6742,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6807,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(6807,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6807,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6872,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(6872,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6872,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(6937,112)) is not in pool. Re-compute.
# Feature for (MD594,220,(6937,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(6937,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(7002,177)) is not in pool. Re-compute.
# Feature for (MD594,220,(7002,242)) is not in pool. Re-compute.
# Feature for (MD594,220,(7067,242)) is not in pool. Re-compute.
# ('MD594', 170)
# Feature for (MD594,170,(4792,372)) is not in pool. Re-compute.
# Feature for (MD594,170,(4857,437)) is not in pool. Re-compute.
# Feature for (MD594,170,(5312,307)) is not in pool. Re-compute.
# Feature for (MD594,170,(5572,437)) is not in pool. Re-compute.
# Feature for (MD594,170,(5572,502)) is not in pool. Re-compute.
# Feature for (MD594,170,(5572,697)) is not in pool. Re-compute.
# Feature for (MD594,170,(5637,827)) is not in pool. Re-compute.
# Feature for (MD594,170,(5702,762)) is not in pool. Re-compute.
# Feature for (MD594,170,(5767,697)) is not in pool. Re-compute.
# Feature for (MD594,170,(5897,567)) is not in pool. Re-compute.
# Feature for (MD594,170,(6092,437)) is not in pool. Re-compute.
# Feature for (MD594,170,(6287,372)) is not in pool. Re-compute.
# Feature for (MD594,170,(7392,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7392,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7457,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7457,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7522,112)) is not in pool. Re-compute.
# Feature for (MD594,170,(7522,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7522,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7587,112)) is not in pool. Re-compute.
# Feature for (MD594,170,(7587,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7587,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7652,112)) is not in pool. Re-compute.
# Feature for (MD594,170,(7652,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7652,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7717,112)) is not in pool. Re-compute.
# Feature for (MD594,170,(7717,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7717,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7782,112)) is not in pool. Re-compute.
# Feature for (MD594,170,(7782,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7782,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7847,112)) is not in pool. Re-compute.
# Feature for (MD594,170,(7847,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7847,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7912,112)) is not in pool. Re-compute.
# Feature for (MD594,170,(7912,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7912,242)) is not in pool. Re-compute.
# Feature for (MD594,170,(7977,177)) is not in pool. Re-compute.
# Feature for (MD594,170,(7977,242)) is not in pool. Re-compute.
# ('MD594', 190)
# Feature for (MD594,190,(4532,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(4597,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(4597,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(4597,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(4662,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(4662,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(4662,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(4727,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(4922,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(4987,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(5052,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(5117,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(5117,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(5182,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(5182,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(5182,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(5247,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(5247,177)) is not in pool. Re-compute.
# n_train 1000
# Trial 0
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Feature for (MD594,190,(5247,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(5312,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(5312,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(5312,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(5377,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(5377,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(5377,242)) is not in pool. Re-compute.
# Feature for (MD594,190,(5442,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(5442,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(5507,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(5507,177)) is not in pool. Re-compute.
# Feature for (MD594,190,(5572,112)) is not in pool. Re-compute.
# Feature for (MD594,190,(5637,502)) is not in pool. Re-compute.
# Feature for (MD594,190,(6352,307)) is not in pool. Re-compute.
# Fitting classifier: 2.25 seconds
# Trial 1
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 2.00 seconds
# Trial 2
# Training: 1000 positive, 1000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 1.86 seconds
# n_train 5000
# Trial 0
# Training: 5000 positive, 5000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 20.73 seconds
# Trial 1
# Training: 5000 positive, 5000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 22.23 seconds
# Trial 2
# Training: 5000 positive, 5000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 19.01 seconds
# n_train 15000
# Trial 0
# Training: 15000 positive, 15000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 84.83 seconds
# Trial 1
# Training: 15000 positive, 15000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 95.74 seconds
# Trial 2
# Training: 15000 positive, 15000 negative
# Test: 1000 positive, 1000 negative
# Fitting classifier: 86.82 seconds

# %%
np.mean(extract_one_metric(test_metrics_all_ntrain, 'auroc')[15000][('none','no-augment')])
# Out:
# 0.877852061131609

# %%
plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'acc', 0.5), ylabel='Test accuracy@0.5 threshold');
plot_result_wrt_ntrain(extract_one_metric(test_metrics_all_ntrain, 'auroc'), ylabel='Area under ROC');
