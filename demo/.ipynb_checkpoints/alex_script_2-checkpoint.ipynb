# %%
import os
import sys
import numpy as np

sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *
from metadata import *
from data_manager import *

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.46}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD662 valid_sections/filenames: MD662
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# /home/alexn/brainDev/src/
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# Seems you are using operation INIs to provide cropbox.

# %%
# metadata_cache['filenames_to_sections']['UCSD001'][filename]

# Creates input_spec.ini file
def create_input_spec_ini( name, image_name_list, stack, prep_id, version, resol  ):
    f = open(name, "w")
    
    f.write('[DEFAULT]\n')
    f.write('image_name_list = '+image_name_list[0]+'\n')
    for i in range ( 1 , len(image_name_list) ):
        f.write('    '+image_name_list[i]+'\n')
    f.write('stack = '+stack+'\n')
    f.write('prep_id = '+prep_id+'\n')
    f.write('version = '+version+'\n')
    f.write('resol = '+resol+'\n')
    
def create_input_spec_ini_all( name, stack, prep_id, version, resol  ):
    f = open(name, "w")
    
    f.write('[DEFAULT]\n')
    f.write('image_name_list = all\n')
    f.write('stack = '+stack+'\n')
    f.write('prep_id = '+prep_id+'\n')
    f.write('version = '+version+'\n')
    f.write('resol = '+resol+'\n')
    
def get_fn_list_from_sorted_filenames( stack='UCSD001' ):
    '''
        get_fn_list_from_sorted_filenames( stack ) returns a list of all the valid
        filenames for the current stack.
    '''
    stack = 'UCSD001'
    fp = os.environ['DATA_ROOTDIR']+'CSHL_data_processed/'+stack+'/'
    fn = stack+'_sorted_filenames.txt'
    
    file0 = open( fp+fn, 'r')
    section_names = []

    for line in file0: 
        if 'Placeholder' in line:
            #print line
            continue
        else:
            space_index = line.index(" ")
            section_name = line[ 0 : space_index ]
            section_number = line[ space_index+1 : ]
            section_names.append( section_name )
    return section_names

# %% [markdown]
# # Compute Patch Features
#
# - Create the following:
#     - STACK_anchor.txt
#     - STACK_alignedTo_ANCHOR_prep2_sectionLimits.json
#     - STACK_alignedTo_ANCHOR_prep2_cropbox.json
# - Download from S3:
#       CSHL_classifiers/
#         └── setting_899
#             └── classifiers
#                 ├── 12N_clf_setting_899.dump
#                 ├── 3N_clf_setting_899.dump
#                 └── 4N_clf_setting_899.dump
# - Create input_spec.ini as (alignedBrainstemCrop,NtbNormalizedAdaptiveInvertedGamma,raw).
# - `python demo_compute_features_v2.py input_spec.ini`
#
# (If using GPU, the demo for each section should finish in about 1 minute. If using CPU, this takes about 1 hour.)

# %%
# Fetch the anchor filename
stack = 'UCSD001'
anchor_fp = os.path.join(os.environ['DATA_ROOTDIR'],'CSHL_data_processed',stack,stack+'_anchor.txt')
anchor_fn = ! cat $anchor_fp

# %%
# OG
create_input_spec_ini_all( name='input_spec.ini', stack='UCSD001', \
           prep_id='alignedBrainstemCrop', version='NtbNormalizedAdaptiveInvertedGamma', resol='raw')

# %%
# f = open(fp+stack+'_anchor.txt', "w")
# f.write( anchor )

# f = open(fp+stack+'_alignedTo_'+anchor_fn+'_prep2_sectionLimits.json', "w")
# f.write('{"left_section_limit": 85, "right_section_limit": 356}')

# f = open(fp+stack+'_alignedTo_'+anchor_fn+'_prep2_cropbox.json', "w")
# f.write('{"rostral_limit": 468, "ventral_limit": 620, "caudal_limit": 1244, "dorsal_limit": 129}')

# %%
# Download pre-trained logistic regression classifiers.
# Downloads into CSHL_classifiers
classifier_id = 899
for name_u in ['3N', '4N', '12N']:
    fp = DataManager.get_classifier_filepath(structure=name_u, classifier_id=classifier_id)
    rel_fp = relative_to_local(fp, local_root=DATA_ROOTDIR)
    print 'downloading '+rel_fp
    demo_data_dir = DATA_ROOTDIR
    s3_http_prefix = 'https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/'
    url = s3_http_prefix + rel_fp
    demo_fp = os.path.join(demo_data_dir, rel_fp)
    print 'demo fp is  '+demo_fp
    execute_command('wget -N -P \"%s\" \"%s\"' % (os.path.dirname(demo_fp), url))
# Out:
# downloading CSHL_classifiers/setting_899/classifiers/3N_clf_setting_899.dump
# demo fp is  /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_classifiers/setting_899/classifiers/3N_clf_setting_899.dump
# wget -N -P "/media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_classifiers/setting_899/classifiers" "https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/CSHL_classifiers/setting_899/classifiers/3N_clf_setting_899.dump"
# return code: 0
# wget -N -P "/media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_classifiers/setting_899/classifiers" "https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/CSHL_classifiers/setting_899/classifiers/4N_clf_setting_899.dump"
# return code: 0
# wget -N -P "/media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_classifiers/setting_899/classifiers" "https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/CSHL_classifiers/setting_899/classifiers/12N_clf_setting_899.dump"
# downloading CSHL_classifiers/setting_899/classifiers/4N_clf_setting_899.dump
# demo fp is  /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_classifiers/setting_899/classifiers/4N_clf_setting_899.dump
# downloading CSHL_classifiers/setting_899/classifiers/12N_clf_setting_899.dump
# demo fp is  /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_classifiers/setting_899/classifiers/12N_clf_setting_899.dump
# return code: 0

# %%
s3_http_prefix + rel_fp
# Out:
# 'https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/CSHL_classifiers/setting_899/classifiers/12N_clf_setting_899.dump'

# %%
! wget ls url
# Out:
# --2018-11-08 13:49:41--  http://ls/
# Resolving ls (ls)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘ls’
# --2018-11-08 13:49:42--  http://url/
# Resolving url (url)... 132.239.68.11
# Connecting to url (url)|132.239.68.11|:80... ^C

# %%
# Download Inception-bn-blue stuff
inception_file_list = ['inception-bn-blue-0000.params','inception-bn-blue-symbol.json','mean_224.npy']

fp = os.environ['DATA_ROOTDIR']
rel_fp = 'mxnet_models/inception-bn-blue/'
s3_http_prefix = 'https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/'
url = s3_http_prefix + rel_fp
inception_fp = os.path.join(DATA_ROOTDIR, rel_fp)
for inception_file in inception_file_list:
    execute_command('wget -N -P \"%s\" \"%s\"' % (os.path.dirname(inception_fp), url+inception_file))
# Out:
# downloading mxnet_models/inception-bn-blue/
# demo fp is  /media/alexn/BstemAtlasDataBackup/ucsd_brain/
# wget -N -P "/media/alexn/BstemAtlasDataBackup/ucsd_brain/mxnet_models/inception-bn-blue" "https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/mxnet_models/inception-bn-blue/inception-bn-blue-0000.params"
# return code: 0
# wget -N -P "/media/alexn/BstemAtlasDataBackup/ucsd_brain/mxnet_models/inception-bn-blue" "https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/mxnet_models/inception-bn-blue/inception-bn-blue-symbol.json"
# return code: 0
# wget -N -P "/media/alexn/BstemAtlasDataBackup/ucsd_brain/mxnet_models/inception-bn-blue" "https://s3-us-west-1.amazonaws.com/mousebrainatlas-data/mxnet_models/inception-bn-blue/mean_224.npy"
# return code: 0

# %%
! python demo_compute_features_v2.py input_spec.ini
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.46}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 anchor: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/MD662_sorted_filenames.txt
# Failed to cache MD662 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 cropbox: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD662 valid_sections/filenames: MD662
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD662 image_shape: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD662/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# /home/alexn/brainDev/src/
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# xgboost is not loaded.
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# [09:03:54] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.9.4. Attempting to upgrade...
# [09:03:54] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/mxnet/module/base_module.py:53: UserWarning: You created Module with Module(..., label_names=['softmax_label']) but input with name 'softmax_label' is not found in symbol.list_arguments(). Did you mean one of:
# 	data
#   warnings.warn(msg)
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/mxnet/module/base_module.py:65: UserWarning: Data provided by label_shapes don't match names specified by label_names ([] vs. ['softmax_label'])
#   warnings.warn(msg)
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide011_2018_09_03-S1_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide011_2018_09_03-S1_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide011_2018_09_03-S1_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide011_2018_09_03-S1_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide011_2018_09_03-S1_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.08 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide011_2018_09_03-S1_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.54 seconds.
# Crop patches: 1.98 seconds.
# Extract patches: 5.54 seconds
# (58366, 1, 224, 224)
# Compute features: 96.39 seconds
# Compute features at one section, multiple locations: 102.01 seconds
# Save features: 0.93 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide011_2018_09_03-S2_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide011_2018_09_03-S2_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide011_2018_09_03-S2_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide011_2018_09_03-S2_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide011_2018_09_03-S2_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 1.01 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide011_2018_09_03-S2_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.39 seconds.
# Crop patches: 1.20 seconds.
# Extract patches: 4.62 seconds
# (39954, 1, 224, 224)
# Compute features: 65.47 seconds
# Compute features at one section, multiple locations: 70.13 seconds
# Save features: 0.60 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide011_2018_09_03-S3_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide011_2018_09_03-S3_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide011_2018_09_03-S3_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide011_2018_09_03-S3_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide011_2018_09_03-S3_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.07 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide011_2018_09_03-S3_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.33 seconds.
# Crop patches: 1.20 seconds.
# Extract patches: 4.56 seconds
# (41449, 1, 224, 224)
# (72173, 1, 224, 224)
# Load image: 3.27 seconds.
# Crop patches: 1.65 seconds.
# Extract patches: 4.94 seconds
# (59171, 1, 224, 224)
# Compute features: 98.77 seconds
# Compute features at one section, multiple locations: 103.77 seconds
# Save features: 0.85 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide112_2018_09_05-S3_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide112_2018_09_05-S3_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide112_2018_09_05-S3_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide112_2018_09_05-S3_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide112_2018_09_05-S3_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.06 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide112_2018_09_05-S3_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.28 seconds.
# Crop patches: 1.14 seconds.
# Extract patches: 4.44 seconds
# (40417, 1, 224, 224)
# Compute features: 63.13 seconds
# Compute features at one section, multiple locations: 67.62 seconds
# Save features: 0.47 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide099_2018_09_05-S2_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide099_2018_09_05-S2_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide099_2018_09_05-S2_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide099_2018_09_05-S2_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide099_2018_09_05-S2_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.07 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide099_2018_09_05-S2_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.23 seconds.
# Crop patches: 1.68 seconds.
# Extract patches: 4.93 seconds
# (60567, 1, 224, 224)
# Compute features: 99.62 seconds
# Compute features at one section, multiple locations: 104.62 seconds
# Save features: 0.75 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide099_2018_09_05-S3_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide099_2018_09_05-S3_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide099_2018_09_05-S3_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide099_2018_09_05-S3_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide099_2018_09_05-S3_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.07 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide099_2018_09_05-S3_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.28 seconds.
# Crop patches: 2.16 seconds.
# Extract patches: 5.47 seconds
# (59544, 1, 224, 224)
# Compute features: 99.82 seconds
# Compute features at one section, multiple locations: 105.37 seconds
# Save features: 0.78 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide099_2018_09_05-S1_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide099_2018_09_05-S1_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide099_2018_09_05-S1_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide099_2018_09_05-S1_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide099_2018_09_05-S1_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.07 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide099_2018_09_05-S1_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.29 seconds.
# Crop patches: 1.71 seconds.
# Extract patches: 5.02 seconds
# (60984, 1, 224, 224)
# Compute features: 100.02 seconds
# Compute features at one section, multiple locations: 105.11 seconds
# Save features: 0.92 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide002_2018_09_03-S1_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide002_2018_09_03-S1_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide002_2018_09_03-S1_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide002_2018_09_03-S1_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide002_2018_09_03-S1_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.37 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide002_2018_09_03-S1_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.28 seconds.
# Crop patches: 0.99 seconds.
# Extract patches: 4.29 seconds
# (23647, 1, 224, 224)
# Compute features: 37.52 seconds
# Compute features at one section, multiple locations: 41.84 seconds
# Save features: 0.28 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide002_2018_09_03-S2_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide002_2018_09_03-S2_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide002_2018_09_03-S2_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide002_2018_09_03-S2_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide002_2018_09_03-S2_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.06 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide002_2018_09_03-S2_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.24 seconds.
# Crop patches: 0.76 seconds.
# Extract patches: 4.03 seconds
# (21757, 1, 224, 224)
# Compute features: 34.24 seconds
# Compute features at one section, multiple locations: 38.29 seconds
# Save features: 0.27 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide002_2018_09_03-S3_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide002_2018_09_03-S3_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide002_2018_09_03-S3_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide002_2018_09_03-S3_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide002_2018_09_03-S3_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.36 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide002_2018_09_03-S3_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.32 seconds.
# Crop patches: 1.12 seconds.
# Extract patches: 4.47 seconds
# (37959, 1, 224, 224)
# Compute features: 61.08 seconds
# Compute features at one section, multiple locations: 65.59 seconds
# Save features: 0.46 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide124_2018_09_05-S3_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide124_2018_09_05-S3_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide124_2018_09_05-S3_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide124_2018_09_05-S3_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide124_2018_09_05-S3_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.35 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide124_2018_09_05-S3_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.24 seconds.
# Crop patches: 0.92 seconds.
# Extract patches: 4.18 seconds
# (22135, 1, 224, 224)
# Compute features: 35.27 seconds
# Compute features at one section, multiple locations: 39.48 seconds
# Save features: 0.32 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide124_2018_09_05-S2_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide124_2018_09_05-S2_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide124_2018_09_05-S2_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide124_2018_09_05-S2_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide124_2018_09_05-S2_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.06 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide124_2018_09_05-S2_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.22 seconds.
# Crop patches: 0.73 seconds.
# Extract patches: 3.96 seconds
# (18180, 1, 224, 224)
# Compute features: 29.12 seconds
# Compute features at one section, multiple locations: 33.11 seconds
# Save features: 0.22 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide124_2018_09_05-S1_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide124_2018_09_05-S1_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide124_2018_09_05-S1_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide124_2018_09_05-S1_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide124_2018_09_05-S1_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.21 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide124_2018_09_05-S1_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.28 seconds.
# Crop patches: 0.75 seconds.
# Extract patches: 4.05 seconds
# (25417, 1, 224, 224)
# Compute features: 40.80 seconds
# Compute features at one section, multiple locations: 44.88 seconds
# Save features: 0.31 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide066_2018_09_04-S3_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide066_2018_09_04-S3_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide066_2018_09_04-S3_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide066_2018_09_04-S3_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide066_2018_09_04-S3_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.37 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide066_2018_09_04-S3_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.43 seconds.
# Crop patches: 1.74 seconds.
# Extract patches: 5.18 seconds
# (65878, 1, 224, 224)
# Load image: 3.58 seconds.
# Crop patches: 2.62 seconds.
# Extract patches: 6.23 seconds
# (69555, 1, 224, 224)
# Compute features: 109.57 seconds
# Compute features at one section, multiple locations: 114.70 seconds
# Save features: 0.82 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide012_2018_09_03-S4_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide012_2018_09_03-S4_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide012_2018_09_03-S4_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide012_2018_09_03-S4_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide012_2018_09_03-S4_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.07 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide012_2018_09_03-S4_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.27 seconds.
# Crop patches: 1.17 seconds.
# Extract patches: 4.46 seconds
# (42810, 1, 224, 224)
# Compute features: 67.73 seconds
# Compute features at one section, multiple locations: 72.23 seconds
# Save features: 0.54 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide077_2018_09_04-S1_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide077_2018_09_04-S1_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide077_2018_09_04-S1_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide077_2018_09_04-S1_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide077_2018_09_04-S1_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.08 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide077_2018_09_04-S1_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.27 seconds.
# Crop patches: 2.11 seconds.
# Extract patches: 5.41 seconds
# (70211, 1, 224, 224)
# Compute features: 113.54 seconds
# Compute features at one section, multiple locations: 119.04 seconds
# Save features: 1.06 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide077_2018_09_04-S2_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide077_2018_09_04-S2_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide077_2018_09_04-S2_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide077_2018_09_04-S2_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide077_2018_09_04-S2_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.08 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide077_2018_09_04-S2_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.21 seconds.
# Crop patches: 1.88 seconds.
# Extract patches: 5.11 seconds
# (67922, 1, 224, 224)
# Compute features: 110.61 seconds
# Compute features at one section, multiple locations: 115.80 seconds
# Save features: 0.91 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide077_2018_09_04-S4_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide077_2018_09_04-S4_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide077_2018_09_04-S4_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide077_2018_09_04-S4_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide077_2018_09_04-S4_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.21 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide077_2018_09_04-S4_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.34 seconds.
# Crop patches: 2.44 seconds.
# Extract patches: 5.81 seconds
# (66259, 1, 224, 224)
# (66109, 1, 224, 224)
# Compute features: 105.45 seconds
# Compute features at one section, multiple locations: 111.14 seconds
# Save features: 1.02 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide067_2018_09_04-S4_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide067_2018_09_04-S4_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide067_2018_09_04-S4_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide067_2018_09_04-S4_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide067_2018_09_04-S4_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.08 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide067_2018_09_04-S4_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.53 seconds.
# Crop patches: 1.96 seconds.
# Extract patches: 5.52 seconds
# (66975, 1, 224, 224)
# Compute features: 109.16 seconds
# Compute features at one section, multiple locations: 114.76 seconds
# Save features: 1.01 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide026_2018_09_03-S2_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_thumbnail_mask/UCSD001_slide026_2018_09_03-S2_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide026_2018_09_03-S2_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep5_thumbnail_mask/UCSD001_slide026_2018_09_03-S2_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_mask/UCSD001_slide026_2018_09_03-S2_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.07 seconds
# Recompute features requested. Compute from scratch.
# Trying to load /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_prep2_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide026_2018_09_03-S2_prep2_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# Load image: 3.29 seconds.
# Crop patches: 1.71 seconds.
# Extract patches: 5.01 seconds
# (64387, 1, 224, 224)

# %% [markdown]
# # Generate Probability Volumes
#
# Need to create `DEMO998_registered_atlas_structures_wrt_wholebrainXYcropped_xysecTwoCorners.json`?
#     - Generated by '(Optional) Obtain a simple global alignment' section of preprocessing
#     - I just downloaded from S3 for this run
#
# - Create DEMO998_prep2_sectionLimits.ini. In this file specify the indices of the first and last sections that include the brainstem.
# - Download detectors. `python download_demo_data_generate_prob_volumes.py`
# - `python demo_generate_prob_volumes.py DEMO998 799 NtbNormalizedAdaptiveInvertedGammaJpeg --structure_list "[\"3N\", \"4N\", \"12N\"]"`

# %%
# To see all of the filenames and section numbers
print DataManager.load_sorted_filenames(stack)
print ''
print DataManager.load_sorted_filenames(stack)[0][files[0]]
# Out:
# ({'MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242': 225, 'MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250': 230, 'MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257': 235}, {225: 'MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242', 235: 'MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257', 230: 'MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250'})
#
# 225

# %%
# %%writefile /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_sectionLimits.ini
# [DEFAULT]
# left_section_limit = 85
# right_section_limit = 356
# Out:
# Writing /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_sectionLimits.ini

# %%
! python demo_generate_prob_volumes.py DEMO998 799 NtbNormalizedAdaptiveInvertedGammaJpeg \
--structure_list "[\"3N\", \"4N\", \"12N\"]"
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'DEMO998': 0.46}
# No vtk
# No mcubes
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# xgboost is not loaded.
# Prior structure/index map not found. Generating a new one.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_5N_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_5N_L.bp'
# Score volume for 5N_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_5N_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_5N_R.bp'
# Score volume for 5N_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_6N_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_6N_L.bp'
# Score volume for 6N_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_6N_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_6N_R.bp'
# Score volume for 6N_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7N_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7N_L.bp'
# Score volume for 7N_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7N_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7N_R.bp'
# Score volume for 7N_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7n_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7n_L.bp'
# Score volume for 7n_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7n_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_7n_R.bp'
# Score volume for 7n_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Amb_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Amb_L.bp'
# Score volume for Amb_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Amb_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Amb_R.bp'
# Score volume for Amb_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LC_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LC_L.bp'
# Score volume for LC_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LC_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LC_R.bp'
# Score volume for LC_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LRt_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LRt_L.bp'
# Score volume for LRt_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LRt_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_LRt_R.bp'
# Score volume for LRt_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Pn_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Pn_L.bp'
# Score volume for Pn_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Pn_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Pn_R.bp'
# Score volume for Pn_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Tz_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Tz_L.bp'
# Score volume for Tz_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Tz_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Tz_R.bp'
# Score volume for Tz_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VLL_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VLL_L.bp'
# Score volume for VLL_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VLL_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VLL_R.bp'
# Score volume for VLL_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_RMC_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_RMC_L.bp'
# Score volume for RMC_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_RMC_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_RMC_R.bp'
# Score volume for RMC_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNC_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNC_L.bp'
# Score volume for SNC_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNC_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNC_R.bp'
# Score volume for SNC_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNR_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNR_L.bp'
# Score volume for SNR_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNR_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SNR_R.bp'
# Score volume for SNR_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_3N_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_3N_L.bp'
# Score volume for 3N_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_3N_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_3N_R.bp'
# Score volume for 3N_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_4N_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_4N_L.bp'
# Score volume for 4N_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_4N_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_4N_R.bp'
# Score volume for 4N_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5I_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5I_L.bp'
# Score volume for Sp5I_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5I_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5I_R.bp'
# Score volume for Sp5I_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5O_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5O_L.bp'
# Score volume for Sp5O_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5O_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5O_R.bp'
# Score volume for Sp5O_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5C_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5C_L.bp'
# Score volume for Sp5C_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5C_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_Sp5C_R.bp'
# Score volume for Sp5C_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_PBG_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_PBG_L.bp'
# Score volume for PBG_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_PBG_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_PBG_R.bp'
# Score volume for PBG_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_10N_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_10N_L.bp'
# Score volume for 10N_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_10N_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_10N_R.bp'
# Score volume for 10N_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCA_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCA_L.bp'
# Score volume for VCA_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCA_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCA_R.bp'
# Score volume for VCA_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCP_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCP_L.bp'
# Score volume for VCP_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCP_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_VCP_R.bp'
# Score volume for VCP_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_DC_L.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_DC_L.bp'
# Score volume for DC_L does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_DC_R.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_DC_R.bp'
# Score volume for DC_R does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_AP.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_AP.bp'
# Score volume for AP does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_12N.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_12N.bp'
# Score volume for 12N does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_RtTg.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_RtTg.bp'
# Score volume for RtTg does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SC.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_SC.bp'
# Score volume for SC does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_IC.bp
# [Errno 2] No such file or directory: '/media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/atlasV7_10.0um_scoreVolume_IC.bp'
# Score volume for IC does not exist.
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# [13:19:03] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.9.4. Attempting to upgrade...
# [13:19:03] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/mxnet/module/base_module.py:53: UserWarning: You created Module with Module(..., label_names=['softmax_label']) but input with name 'softmax_label' is not found in symbol.list_arguments(). Did you mean one of:
# 	data
#   warnings.warn(msg)
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/mxnet/module/base_module.py:65: UserWarning: Data provided by label_shapes don't match names specified by label_names ([] vs. ['softmax_label'])
#   warnings.warn(msg)
# Setting 899: No classifier found for 5N.
# Setting 899: No classifier found for 6N.
# Setting 899: No classifier found for 7N.
# Setting 899: No classifier found for 7n.
# Setting 899: No classifier found for Amb.
# Setting 899: No classifier found for LC.
# Setting 899: No classifier found for LRt.
# Setting 899: No classifier found for Pn.
# Setting 899: No classifier found for Tz.
# Setting 899: No classifier found for VLL.
# Setting 899: No classifier found for RMC.
# Setting 899: No classifier found for SNC.
# Setting 899: No classifier found for SNR.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.18.2 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# Setting 899: No classifier found for Sp5I.
# Setting 899: No classifier found for Sp5O.
# Setting 899: No classifier found for Sp5C.
# Setting 899: No classifier found for PBG.
# Setting 899: No classifier found for 10N.
# Setting 899: No classifier found for VCA.
# Setting 899: No classifier found for VCP.
# Setting 899: No classifier found for DC.
# Setting 899: No classifier found for AP.
# Setting 899: No classifier found for RtTg.
# Setting 899: No classifier found for SC.
# Setting 899: No classifier found for IC.
# Generating score map: 3N, section 225
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.04 seconds
# 21043 ROI sampled locations
# 49675 pre-computed locations
# Load pre-computed features: 6.51 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 1.82 seconds
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Rescale background image to output resolution: 4.00 seconds
# Predict scores 3N: 0.10 seconds
# Resample scoremap 3N: 0.08 seconds
# Load and rescale background image: 0.00 seconds
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Generate scoremap overlay: 0.09 seconds.
# Scoremap size does not match background image size. Need to resize: 0.11 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 3N: 0.27 seconds
# Save scoremap: 0.04 seconds
# Save scoremap viz: 0.09 seconds
# Generating score map: 3N, section 230
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.06 seconds
# 20824 ROI sampled locations
# 49558 pre-computed locations
# Load pre-computed features: 6.05 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 2.00 seconds
# Rescale background image to output resolution: 4.29 seconds
# Predict scores 3N: 0.12 seconds
# Resample scoremap 3N: 0.10 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.08 seconds.
# Scoremap size does not match background image size. Need to resize: 0.11 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 3N: 0.24 seconds
# Save scoremap: 0.01 seconds
# Save scoremap viz: 0.08 seconds
# Generating score map: 3N, section 235
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.04 seconds
# 21022 ROI sampled locations
# 49983 pre-computed locations
# Load pre-computed features: 6.12 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 2.24 seconds
# Rescale background image to output resolution: 4.29 seconds
# Predict scores 3N: 0.10 seconds
# Resample scoremap 3N: 0.10 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.08 seconds.
# Scoremap size does not match background image size. Need to resize: 0.11 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 3N: 0.23 seconds
# Save scoremap: 0.05 seconds
# Save scoremap viz: 0.08 seconds
# Score volume ROI derived from simple global alignment does not exist. Skip generating score volume.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/setup/../src/utilities/utilities2015.py:520: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   np.floor(np.linspace(0, v.shape[1]-1, new_shape[0])).astype(np.int), indexing='ij')]
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Images to volume: 1.61 seconds
# loaded_cropbox_resolution down32
# Save score volume: 0.09 seconds
# Compute gradient: 0.71 seconds
# Save gradient: 0.23 seconds
# Generating score map: 4N, section 225
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.04 seconds
# 17540 ROI sampled locations
# 49675 pre-computed locations
# Load pre-computed features: 0.98 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 1.77 seconds
# Rescale background image to output resolution: 4.47 seconds
# Predict scores 4N: 0.08 seconds
# Resample scoremap 4N: 0.07 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.07 seconds.
# Scoremap size does not match background image size. Need to resize: 0.11 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 4N: 0.24 seconds
# Save scoremap: 0.01 seconds
# Save scoremap viz: 0.07 seconds
# Generating score map: 4N, section 230
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.03 seconds
# 17388 ROI sampled locations
# 49558 pre-computed locations
# Load pre-computed features: 0.97 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 1.90 seconds
# Rescale background image to output resolution: 4.08 seconds
# Predict scores 4N: 0.08 seconds
# Resample scoremap 4N: 0.10 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.07 seconds.
# Scoremap size does not match background image size. Need to resize: 0.10 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 4N: 0.22 seconds
# Save scoremap: 0.01 seconds
# Save scoremap viz: 0.08 seconds
# Generating score map: 4N, section 235
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.03 seconds
# 17583 ROI sampled locations
# 49983 pre-computed locations
# Load pre-computed features: 1.08 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 1.70 seconds
# Rescale background image to output resolution: 4.43 seconds
# Predict scores 4N: 0.08 seconds
# Resample scoremap 4N: 0.10 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.08 seconds.
# Scoremap size does not match background image size. Need to resize: 0.11 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 4N: 0.24 seconds
# Save scoremap: 0.01 seconds
# Save scoremap viz: 0.08 seconds
# Score volume ROI derived from simple global alignment does not exist. Skip generating score volume.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Images to volume: 1.47 seconds
# loaded_cropbox_resolution down32
# Save score volume: 0.08 seconds
# Compute gradient: 0.57 seconds
# Save gradient: 0.21 seconds
# Generating score map: 12N, section 225
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.04 seconds
# 17340 ROI sampled locations
# 49675 pre-computed locations
# Load pre-computed features: 1.00 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 1.87 seconds
# Rescale background image to output resolution: 4.81 seconds
# Predict scores 12N: 0.09 seconds
# Resample scoremap 12N: 0.10 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.08 seconds.
# Scoremap size does not match background image size. Need to resize: 0.10 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 12N: 0.23 seconds
# Save scoremap: 0.01 seconds
# Save scoremap viz: 0.08 seconds
# Generating score map: 12N, section 230
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.03 seconds
# 17276 ROI sampled locations
# 49558 pre-computed locations
# Load pre-computed features: 1.00 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 1.98 seconds
# Rescale background image to output resolution: 4.58 seconds
# Predict scores 12N: 0.10 seconds
# Resample scoremap 12N: 0.10 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.08 seconds.
# Scoremap size does not match background image size. Need to resize: 0.11 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 12N: 0.25 seconds
# Save scoremap: 0.01 seconds
# Save scoremap viz: 0.09 seconds
# Generating score map: 12N, section 235
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = 2
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# locate patches: 0.03 seconds
# 17292 ROI sampled locations
# 49983 pre-computed locations
# Load pre-computed features: 1.04 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Load background image: 1.61 seconds
# Rescale background image to output resolution: 4.26 seconds
# Predict scores 12N: 0.09 seconds
# Resample scoremap 12N: 0.07 seconds
# Load and rescale background image: 0.00 seconds
# Generate scoremap overlay: 0.08 seconds.
# Scoremap size does not match background image size. Need to resize: 0.11 seconds.
# (708, 1075, 3) (708, 1075)
# Generate scoremap overlay image 12N: 0.24 seconds
# Save scoremap: 0.01 seconds
# Save scoremap viz: 0.08 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Images to volume: 1.58 seconds
# loaded_cropbox_resolution down32
# Save score volume: 0.11 seconds
# Compute gradient: 0.80 seconds
# Save gradient: 0.21 seconds
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedBrainstemCrop
# Try to find prep5 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Failed to load prep5 mask.
# Try to find prep1 mask.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Loaded prep1 mask.
# Seems you are using operation INIs to provide cropbox.
# Images to volume: 1.63 seconds
# loaded_cropbox_resolution down32
# Save score volume: 0.10 seconds
# Compute gradient: 0.82 seconds
# Save gradient: 0.23 seconds

# %% [markdown]
# # Registration
#
# - Need to download /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_volumes/atlasV7/atlasV7_10.0um_scoreVolume/score_volumes/ bloscpack files for each structure you look at
#
# ### Register 12N individually
# - `python register_brains_demo_12N.py --use_simple_global`
# - Expected runtime of about 8 minutes
#
# ### Register 3N_R and 4N_R as a group
# - `python register_brains_demo_3N_R_4N_R.py --use_simple_global`
# - Expected runtime of about 3 minutes
#
# (Outputs displays 1000 iterations of gradient descent)

# %%
! python register_brains_demo_12N.py --use_simple_global
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'DEMO998': 0.46}
# No vtk
# No mcubes
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# upstream_warp_id                                                               None
# transform_type                                                                rigid
# grad_computation_sample_number                                               100000
# grid_search_sample_number                                                      1000
# std_tx_um                                                                        50
# std_ty_um                                                                        50
# std_tz_um                                                                        50
# std_theta_xy_degree                                                              10
# surround_weight                                                             inverse
# regularization_weight                                                           NaN
# terminate_thresh_trans                                                         0.01
# terminate_thresh_rot                                                           0.01
# history_len                                                                     100
# max_iter_num                                                                   5000
# learning_rate_trans                                                               1
# learning_rate_rot                                                              0.01
# comment                           structure registration with surround, no initi...
# Name: 7, dtype: object
# surround inverse True
# Prior structure/index map not found. Generating a new one.
# Loaded moving volumes: [u'12N', u'12N_surround_200um'].
# Prior structure/index map not found. Generating a new one.
# loaded_cropbox_resolution 10.0um
# Loaded fixed volumes: [u'12N'].
# voxel size for moving = 10.00 um
# voxel size for fixed = 10.00 um
# label_mapping_m2f {1: 1, 2: 1}
# Computing structure sizes: 0.00 s
# {1: -0.2259316876134332, 2: 1.0}
# Label weights not set, default to 1 for all structures.
# Regularization weights not set, default to 0.
# indices_f: set([1])
# Set initial transform to [ 9.63169856e-01  2.67574548e-01  2.67105543e-02  9.77742822e+02
#  -2.66505671e-01  9.63095067e-01 -3.77939704e-02  5.38443355e+02
#  -3.58373010e-02  2.92833300e-02  9.98928513e-01  4.68000000e+02].
# centroid_m: [1186.81599754  550.54401762  461.36579275], centroid_f: [1186.81599754  550.54401762  461.36579275]
# Set initial transform to [ 9.63169856e-01  2.67574548e-01  2.67105543e-02  9.77742822e+02
#  -2.66505671e-01  9.63095067e-01 -3.77939704e-02  5.38443355e+02
#  -3.58373010e-02  2.92833300e-02  9.98928513e-01  4.68000000e+02].
# centroid_m: [1186.81599754  550.54401762  461.36579275], centroid_f: [1186.81599754  550.54401762  461.36579275]
# 1: 136245 valid, 450003 out-of-bound voxels after transform.
# 2: 134601 valid, 355951 out-of-bound voxels after transform.
#
# iteration 0
# 1: 136245 valid, 450003 out-of-bound voxels after transform.
# 2: 134601 valid, 355951 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.732051
# Norm of gradient (rotation) = 1.732051
# around x=0.57; around y=0.58; around z=-0.57
# step: 0.23 seconds
# current score: -0.458800
# new_T: [ 0.9999      0.0100495   0.0099495   0.99993333 -0.0099495   0.9999
#  -0.0100495  -1.00996642 -0.0100495   0.0099495   0.9999      0.98996692]
# det: 1.00
#
# iteration 1
# 1: 136280 valid, 449968 out-of-bound voxels after transform.
# 2: 134718 valid, 355834 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.389862
# Norm of gradient (rotation) = 1.310389
# around x=1.00; around y=1.01; around z=-1.00
# step: 0.19 seconds
# current score: -0.456128
# new_T: [ 0.99969275  0.01777469  0.01727621  1.76278209 -0.01746723  0.9996892
#  -0.01778782 -1.79297445 -0.01758702  0.01748058  0.99969252  1.8462082 ]
# det: 1.00
#
# iteration 2
# 1: 136241 valid, 450007 out-of-bound voxels after transform.
# 2: 134828 valid, 355724 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.179562
# Norm of gradient (rotation) = 1.078958
# around x=1.36; around y=1.36; around z=-1.36
# step: 0.20 seconds
# current score: -0.454292
# new_T: [ 0.99943798  0.02420389  0.02319266  2.39693839 -0.02364115  0.99942664
#  -0.02423814 -2.44975009 -0.02376602  0.02367622  0.99943715  2.59017885]
# det: 1.00
#
# iteration 3
# 1: 136318 valid, 449930 out-of-bound voxels after transform.
# 2: 135049 valid, 355503 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.078058
# Norm of gradient (rotation) = 0.934087
# around x=1.67; around y=1.66; around z=-1.66
# step: 0.20 seconds
# current score: -0.452427
# new_T: [ 0.99915848  0.02985964  0.02812009  2.95450521 -0.02901631  0.99913059
#  -0.02993537 -3.03206332 -0.02898951  0.02909424  0.99915621  3.3011941 ]
# det: 1.00
#
# iteration 4
# 1: 136265 valid, 449983 out-of-bound voxels after transform.
# 2: 135195 valid, 355357 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.931964
# Norm of gradient (rotation) = 0.833819
# around x=1.94; around y=1.93; around z=-1.94
# step: 0.20 seconds
# current score: -0.450909
# new_T: [ 0.99886149  0.03493111  0.03248901  3.44743598 -0.03378966  0.99881443
#  -0.03504282 -3.55829057 -0.03367458  0.03390513  0.99885758  3.8891808 ]
# det: 1.00
#
# iteration 5
# 1: 136192 valid, 450056 out-of-bound voxels after transform.
# 2: 135307 valid, 355245 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.859382
# Norm of gradient (rotation) = 0.760498
# around x=2.19; around y=2.18; around z=-2.19
# step: 0.19 seconds
# current score: -0.449434
# new_T: [ 0.99855112  0.0395672   0.03647042  3.90440271 -0.03811428  0.99848414
#  -0.03970786 -4.04115062 -0.03798627  0.03826029  0.99854554  4.43086604]
# det: 1.00
#
# iteration 6
# 1: 136195 valid, 450053 out-of-bound voxels after transform.
# 2: 135466 valid, 355086 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.783530
# Norm of gradient (rotation) = 0.694960
# around x=2.42; around y=2.40; around z=-2.41
# step: 0.18 seconds
# current score: -0.448067
# new_T: [ 0.99823577  0.0438315   0.04005192  4.32024703 -0.04206195  0.99814548
#  -0.04400443 -4.4882377  -0.04190643  0.04224213  0.99822816  4.91952699]
# det: 1.00
#
# iteration 7
# 1: 136120 valid, 450128 out-of-bound voxels after transform.
# 2: 135627 valid, 354925 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.746234
# Norm of gradient (rotation) = 0.645360
# around x=2.64; around y=2.61; around z=-2.62
# step: 0.18 seconds
# current score: -0.446691
# new_T: [ 0.99791546  0.04780747  0.04334945  4.71389789 -0.04571629  0.99780001
#  -0.04801214 -4.90646272 -0.04554942  0.04593028  0.99790564  5.39232648]
# det: 1.00
#
# iteration 8
# 1: 136100 valid, 450148 out-of-bound voxels after transform.
# 2: 135792 valid, 354760 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.705766
# Norm of gradient (rotation) = 0.598993
# around x=2.83; around y=2.80; around z=-2.82
# step: 0.18 seconds
# current score: -0.445473
# new_T: [ 0.99759608  0.05152831  0.04633451  5.0816261  -0.04911612  0.99745033
#  -0.05177306 -5.30015899 -0.04888415  0.04937283  0.99758341  5.84406858]
# det: 1.00
#
# iteration 9
# 1: 136078 valid, 450170 out-of-bound voxels after transform.
# 2: 135919 valid, 354633 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.669083
# Norm of gradient (rotation) = 0.561188
# around x=3.02; around y=2.98; around z=-3.00
# step: 0.18 seconds
# current score: -0.444279
# new_T: [ 0.99727689  0.05503     0.04909687  5.42990344 -0.05229691  0.9970984
#  -0.05531565 -5.67223259 -0.05199843  0.05259741  0.99726109  6.27312011]
# det: 1.00
#
# iteration 10
# 1: 136012 valid, 450236 out-of-bound voxels after transform.
# 2: 136082 valid, 354470 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.640447
# Norm of gradient (rotation) = 0.522430
# around x=3.19; around y=3.14; around z=-3.17
# step: 0.19 seconds
# current score: -0.443117
# new_T: [ 0.99696493  0.0583256   0.05156605  5.75677148 -0.05527845  0.99674605
#  -0.05866522 -6.02475422 -0.05481994  0.05563668  0.996945    6.69103594]
# det: 1.00
#
# iteration 11
# 1: 135925 valid, 450323 out-of-bound voxels after transform.
# 2: 136214 valid, 354338 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.616707
# Norm of gradient (rotation) = 0.492861
# around x=3.36; around y=3.29; around z=-3.34
# step: 0.19 seconds
# current score: -0.442012
# new_T: [ 0.99665627  0.06145096  0.05385212  6.07060778 -0.05809301  0.99639359
#  -0.06184678 -6.36031233 -0.05745845  0.05851154  0.99663179  7.09662765]
# det: 1.00
#
# iteration 12
# 1: 135833 valid, 450415 out-of-bound voxels after transform.
# 2: 136366 valid, 354186 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.594266
# Norm of gradient (rotation) = 0.463512
# around x=3.52; around y=3.43; around z=-3.49
# step: 0.18 seconds
# current score: -0.440954
# new_T: [ 0.99635456  0.06441247  0.05593418  6.37057707 -0.06075052  0.99604272
#  -0.06487118 -6.6798162  -0.05989135  0.06123666  0.9963248   7.49166584]
# det: 1.00
#
# iteration 13
# 1: 135773 valid, 450475 out-of-bound voxels after transform.
# 2: 136497 valid, 354055 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.576417
# Norm of gradient (rotation) = 0.434436
# around x=3.67; around y=3.56; around z=-3.63
# step: 0.18 seconds
# current score: -0.439989
# new_T: [ 0.99606437  0.06722242  0.05776605  6.65563715 -0.06326774  0.99569366
#  -0.06775937 -6.98518504 -0.06207223  0.06383797  0.99602799  7.88190092]
# det: 1.00
#
# iteration 14
# 1: 135679 valid, 450569 out-of-bound voxels after transform.
# 2: 136629 valid, 353923 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.559877
# Norm of gradient (rotation) = 0.408663
# around x=3.81; around y=3.67; around z=-3.77
# step: 0.18 seconds
# current score: -0.439040
# new_T: [ 0.99578543  0.06989367  0.0593823   6.92879901 -0.06565749  0.99534713
#  -0.07052085 -7.27735117 -0.06403496  0.06632474  0.99574121  8.26628041]
# det: 1.00
#
# iteration 15
# 1: 135562 valid, 450686 out-of-bound voxels after transform.
# 2: 136718 valid, 353834 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.541089
# Norm of gradient (rotation) = 0.383891
# around x=3.95; around y=3.77; around z=-3.90
# step: 0.19 seconds
# current score: -0.438166
# new_T: [ 0.99551929  0.07242888  0.06078974  7.18962651 -0.06792416  0.99500462
#  -0.07315809 -7.55658773 -0.06578483  0.0687012   0.99546597  8.64181863]
# det: 1.00
#
# iteration 16
# 1: 135478 valid, 450770 out-of-bound voxels after transform.
# 2: 136821 valid, 353731 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.525340
# Norm of gradient (rotation) = 0.361736
# around x=4.08; around y=3.86; around z=-4.03
# step: 0.18 seconds
# current score: -0.437330
# new_T: [ 0.99526645  0.07484269  0.061994    7.43971736 -0.07008308  0.99466572
#  -0.0756867  -7.82443918 -0.0673279   0.07098371  0.99520263  9.01051747]
# det: 1.00
#
# iteration 17
# 1: 135424 valid, 450824 out-of-bound voxels after transform.
# 2: 136953 valid, 353599 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.510873
# Norm of gradient (rotation) = 0.339764
# around x=4.21; around y=3.94; around z=-4.15
# step: 0.18 seconds
# current score: -0.436495
# new_T: [ 0.9950301   0.07713569  0.06296968  7.67847592 -0.07213828  0.99433125
#  -0.07811168 -8.08125032 -0.06863792  0.07318095  0.99495396  9.37422806]
# det: 1.00
#
# iteration 18
# 1: 135308 valid, 450940 out-of-bound voxels after transform.
# 2: 137025 valid, 353527 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.495306
# Norm of gradient (rotation) = 0.320897
# around x=4.33; around y=4.00; around z=-4.26
# step: 0.18 seconds
# current score: -0.435761
# new_T: [ 0.99480793  0.07931851  0.06376321  7.90796076 -0.07409847  0.99400158
#  -0.08043798 -8.32766907 -0.06976095  0.07529559  0.99471804  9.72971122]
# det: 1.00
#
# iteration 19
# 1: 135197 valid, 451051 out-of-bound voxels after transform.
# 2: 137127 valid, 353425 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.483094
# Norm of gradient (rotation) = 0.302537
# around x=4.45; around y=4.05; around z=-4.37
# step: 0.18 seconds
# current score: -0.435045
# new_T: [ 0.99460397  0.08139313  0.06432804  8.12738102 -0.07597006  0.99367669
#  -0.08267518 -8.56443933 -0.07065047  0.07734206  0.99449822 10.08143108]
# det: 1.00
#
# iteration 20
# 1: 135139 valid, 451109 out-of-bound voxels after transform.
# 2: 137221 valid, 353331 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.469386
# Norm of gradient (rotation) = 0.286304
# around x=4.56; around y=4.09; around z=-4.47
# step: 0.18 seconds
# current score: -0.434382
# new_T: [ 0.9944171   0.08336442  0.06469156  8.33757166 -0.07775732  0.99335722
#  -0.08482474 -8.79180508 -0.0713332   0.07932093  0.9942936  10.42671969]
# det: 1.00
#
# iteration 21
# 1: 135056 valid, 451192 out-of-bound voxels after transform.
# 2: 137288 valid, 353264 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.456998
# Norm of gradient (rotation) = 0.272043
# around x=4.67; around y=4.12; around z=-4.57
# step: 0.21 seconds
# current score: -0.433756
# new_T: [ 0.99424832  0.08523726  0.06484503  8.53871768 -0.07946671  0.99304306
#  -0.08689375 -9.01043724 -0.07180049  0.08124094  0.99410492 10.76676892]
# det: 1.00
#
# iteration 22
# 1: 134968 valid, 451280 out-of-bound voxels after transform.
# 2: 137368 valid, 353184 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.444889
# Norm of gradient (rotation) = 0.259560
# around x=4.78; around y=4.13; around z=-4.66
# step: 0.18 seconds
# current score: -0.433182
# new_T: [ 0.99409978  0.08701107  0.06476649  8.72991601 -0.08110063  0.99273466
#  -0.08888528 -9.22058195 -0.07202994  0.08310823  0.99393396 11.10234543]
# det: 1.00
#
# iteration 23
# 1: 134911 valid, 451337 out-of-bound voxels after transform.
# 2: 137431 valid, 353121 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.433308
# Norm of gradient (rotation) = 0.249703
# around x=4.88; around y=4.13; around z=-4.75
# step: 0.21 seconds
# current score: -0.432650
# new_T: [ 0.99396917  0.08869376  0.06448809  8.91300666 -0.08266532  0.99243195
#  -0.09080346 -9.42270695 -0.07205374  0.08492491  0.99377866 11.43268207]
# det: 1.00
#
# iteration 24
# 1: 134848 valid, 451400 out-of-bound voxels after transform.
# 2: 137508 valid, 353044 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.421773
# Norm of gradient (rotation) = 0.242051
# around x=4.99; around y=4.12; around z=-4.84
# step: 0.18 seconds
# current score: -0.432129
# new_T: [ 0.9938566   0.09028769  0.06400934  9.08780231 -0.08416408  0.99213513
#  -0.09265143 -9.61713719 -0.07187119  0.08669495  0.99363903 11.75775348]
# det: 1.00
#
# iteration 25
# 1: 134778 valid, 451470 out-of-bound voxels after transform.
# 2: 137578 valid, 352974 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.410938
# Norm of gradient (rotation) = 0.237226
# around x=5.09; around y=4.10; around z=-4.92
# step: 0.19 seconds
# current score: -0.431659
# new_T: [ 0.99376364  0.09179236  0.06330866  9.25349815 -0.08559916  0.99184438
#  -0.09443259 -9.8041391  -0.07146053  0.08842451  0.99351623 12.07877155]
# det: 1.00
#
# iteration 26
# 1: 134721 valid, 451527 out-of-bound voxels after transform.
# 2: 137644 valid, 352908 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.401112
# Norm of gradient (rotation) = 0.234714
# around x=5.18; around y=4.06; around z=-5.00
# step: 0.18 seconds
# current score: -0.431222
# new_T: [ 0.99368768  0.09321617  0.06241419  9.41178549 -0.08697712  0.99155924
#  -0.09615227 -9.98429852 -0.07085031  0.09011672  0.99340788 12.39562906]
# det: 1.00
#
# iteration 27
# 1: 134685 valid, 451563 out-of-bound voxels after transform.
# 2: 137670 valid, 352882 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.391449
# Norm of gradient (rotation) = 0.234544
# around x=5.28; around y=4.02; around z=-5.08
# step: 0.19 seconds
# current score: -0.430849
# new_T: [  0.99362894   0.0945587    0.06132028   9.56224275  -0.08829887
#    0.99128007  -0.0978117  -10.157685    -0.07003452   0.09177403
#    0.993314    12.70870994]
# det: 1.00
#
# iteration 28
# 1: 134631 valid, 451617 out-of-bound voxels after transform.
# 2: 137742 valid, 352810 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.381684
# Norm of gradient (rotation) = 0.236945
# around x=5.37; around y=3.96; around z=-5.15
# step: 0.18 seconds
# current score: -0.430461
# new_T: [  0.99358734   0.09582052   0.06002183   9.70420737  -0.08956621
#    0.99100702  -0.09941318 -10.3245273   -0.06900788   0.09339975
#    0.99323431  13.01811892]
# det: 1.00
#
# iteration 29
# 1: 134585 valid, 451663 out-of-bound voxels after transform.
# 2: 137790 valid, 352762 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.372358
# Norm of gradient (rotation) = 0.240145
# around x=5.46; around y=3.89; around z=-5.22
# step: 0.17 seconds
# current score: -0.430143
# new_T: [  0.99355988   0.09700888   0.05854956   9.83891692  -0.09078402
#    0.99073975  -0.10096048 -10.4852825   -0.06780144   0.09499491
#    0.99316611  13.32337991]
# det: 1.00
#
# iteration 30
# 1: 134586 valid, 451662 out-of-bound voxels after transform.
# 2: 137834 valid, 352718 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.363088
# Norm of gradient (rotation) = 0.244210
# around x=5.55; around y=3.81; around z=-5.29
# step: 0.20 seconds
# current score: -0.429842
# new_T: [  0.99354511   0.09812593   0.0569159    9.96648634  -0.09195385
#    0.99047841  -0.10245495 -10.64008057  -0.06642746   0.09655997
#    0.99310803  13.62437435]
# det: 1.00
#
# iteration 31
# 1: 134557 valid, 451691 out-of-bound voxels after transform.
# 2: 137902 valid, 352650 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.354076
# Norm of gradient (rotation) = 0.248992
# around x=5.64; around y=3.72; around z=-5.35
# step: 0.19 seconds
# current score: -0.429557
# new_T: [  0.99354143   0.09917539   0.05513315  10.08706921  -0.09307858
#    0.99022283  -0.10389959 -10.78925919  -0.06489839   0.09809684
#    0.99305851  13.92111301]
# det: 1.00
#
# iteration 32
# 1: 134535 valid, 451713 out-of-bound voxels after transform.
# 2: 137949 valid, 352603 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.346025
# Norm of gradient (rotation) = 0.254554
# around x=5.73; around y=3.62; around z=-5.41
# step: 0.18 seconds
# current score: -0.429304
# new_T: [  0.9935477    0.10015946   0.0532076   10.20106694  -0.09416012
#    0.98997295  -0.10529687 -10.93298946  -0.06322056   0.09960742
#    0.99301638  14.21440371]
# det: 1.00
#
# iteration 33
# 1: 134537 valid, 451711 out-of-bound voxels after transform.
# 2: 138003 valid, 352549 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.337933
# Norm of gradient (rotation) = 0.260042
# around x=5.81; around y=3.52; around z=-5.47
# step: 0.18 seconds
# current score: -0.429080
# new_T: [  0.99356229   0.10108062   0.05115351  10.30853223  -0.09519984
#    0.98972883  -0.10664821 -11.07143197  -0.06140817   0.10109184
#    0.9929801   14.50402408]
# det: 1.00
#
# iteration 34
# 1: 134490 valid, 451758 out-of-bound voxels after transform.
# 2: 138057 valid, 352495 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.329631
# Norm of gradient (rotation) = 0.263987
# around x=5.90; around y=3.41; around z=-5.53
# step: 0.18 seconds
# current score: -0.428884
# new_T: [  0.99358248   0.10194448   0.04900178  10.41015495  -0.09620043
#    0.98949032  -0.10795548 -11.20486306  -0.05949225   0.10254868
#    0.99294735  14.78913151]
# det: 1.00
#
# iteration 35
# 1: 134487 valid, 451761 out-of-bound voxels after transform.
# 2: 138104 valid, 352448 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.322396
# Norm of gradient (rotation) = 0.269102
# around x=5.98; around y=3.29; around z=-5.59
# step: 0.18 seconds
# current score: -0.428716
# new_T: [  0.99360797   0.1027521    0.04674623  10.50580036  -0.09716361
#    0.9892572   -0.10922192 -11.33352187  -0.05746682   0.10398174
#    0.9929176   15.0709408 ]
# det: 1.00
#
# iteration 36
# 1: 134518 valid, 451730 out-of-bound voxels after transform.
# 2: 138148 valid, 352404 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.315094
# Norm of gradient (rotation) = 0.273119
# around x=6.06; around y=3.17; around z=-5.64
# step: 0.18 seconds
# current score: -0.428579
# new_T: [  0.99363693   0.10350695   0.04440674  10.5957832   -0.0980909
#    0.98902944  -0.11044886 -11.45757683  -0.0553518    0.10539017
#    0.99288926  15.34905199]
# det: 1.00
#
# iteration 37
# 1: 134489 valid, 451759 out-of-bound voxels after transform.
# 2: 138207 valid, 352345 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.307666
# Norm of gradient (rotation) = 0.274815
# around x=6.14; around y=3.05; around z=-5.69
# step: 0.18 seconds
# current score: -0.428435
# new_T: [  0.99366685   0.10421521   0.04201632  10.68106189  -0.09898498
#    0.98880683  -0.11163796 -11.57729801  -0.0531804    0.10677195
#    0.99286031  15.62260419]
# det: 1.00
#
# iteration 38
# 1: 134456 valid, 451792 out-of-bound voxels after transform.
# 2: 138201 valid, 352351 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.300978
# Norm of gradient (rotation) = 0.277586
# around x=6.22; around y=2.92; around z=-5.74
# step: 0.18 seconds
# current score: -0.428399
# new_T: [  0.99369778   0.10487721   0.03956638  10.7612207   -0.09984696
#    0.98858917  -0.11279198 -11.69288983  -0.05094421   0.10813055
#    0.99283054  15.89258789]
# det: 1.00
#
# iteration 39
# 1: 134438 valid, 451810 out-of-bound voxels after transform.
# 2: 138147 valid, 352405 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.294287
# Norm of gradient (rotation) = 0.278518
# around x=6.29; around y=2.79; around z=-5.79
# step: 0.18 seconds
# current score: -0.428429
# new_T: [  0.99372797   0.10549735   0.03708128  10.83701095  -0.10067855
#    0.9883764   -0.11391191 -11.80451583  -0.04866767   0.10946417
#    0.9927986   16.15846998]
# det: 1.00
#
# iteration 40
# 1: 134406 valid, 451842 out-of-bound voxels after transform.
# 2: 138177 valid, 352375 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.288173
# Norm of gradient (rotation) = 0.278464
# around x=6.37; around y=2.66; around z=-5.83
# step: 0.18 seconds
# current score: -0.428375
# new_T: [  0.99375636   0.10607951   0.03457519  10.90918392  -0.10148188
#    0.98816823  -0.11499991 -11.91238723  -0.04636524   0.11077314
#    0.99276361  16.42040777]
# det: 1.00
#
# iteration 41
# 1: 134351 valid, 451897 out-of-bound voxels after transform.
# 2: 138126 valid, 352426 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.282455
# Norm of gradient (rotation) = 0.279557
# around x=6.44; around y=2.52; around z=-5.87
# step: 0.18 seconds
# current score: -0.428411
# new_T: [  0.99378341   0.10662173   0.03203642  10.97706615  -0.10225616
#    0.98796483  -0.11605679 -12.01647528  -0.04402504   0.1120594
#    0.99272579  16.67921456]
# det: 1.00
#
# iteration 42
# 1: 134411 valid, 451837 out-of-bound voxels after transform.
# 2: 138034 valid, 352518 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.276189
# Norm of gradient (rotation) = 0.278912
# around x=6.51; around y=2.39; around z=-5.92
# step: 0.19 seconds
# current score: -0.428524
# new_T: [  0.99380808   0.10712659   0.02948548  11.04094887  -0.1030016
#    0.98776641  -0.117082   -12.11678703  -0.04166736   0.11331999
#    0.99268445  16.93403603]
# det: 1.00
#
# iteration 43
# 1: 134302 valid, 451946 out-of-bound voxels after transform.
# 2: 137980 valid, 352572 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.269869
# Norm of gradient (rotation) = 0.276582
# around x=6.58; around y=2.25; around z=-5.96
# step: 0.18 seconds
# current score: -0.428635
# new_T: [  0.99382913   0.10759981   0.02694339  11.10155856  -0.10372125
#    0.98757255  -0.11807779 -12.21368189  -0.0393137    0.11455454
#    0.99263875  17.18425448]
# det: 1.00
#
# iteration 44
# 1: 134152 valid, 452096 out-of-bound voxels after transform.
# 2: 137930 valid, 352622 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.264594
# Norm of gradient (rotation) = 0.275913
# around x=6.65; around y=2.12; around z=-6.00
# step: 0.19 seconds
# current score: -0.428741
# new_T: [  0.99384712   0.10804098   0.02439378  11.15852766  -0.10441626
#    0.98738289  -0.11904738 -12.30738125  -0.036948     0.11576779
#    0.99258887  17.43119156]
# det: 1.00
#
# iteration 45
# 1: 134179 valid, 452069 out-of-bound voxels after transform.
# 2: 137816 valid, 352736 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.260135
# Norm of gradient (rotation) = 0.275913
# around x=6.72; around y=1.98; around z=-6.04
# step: 0.22 seconds
# current score: -0.428920
# new_T: [  0.99386215   0.10845021   0.02183067  11.21192675  -0.10508724
#    0.98719728  -0.11999252 -12.39796354  -0.03456439   0.1169619
#    0.99253474  17.67570934]
# det: 1.00
#
# iteration 46
# 1: 134287 valid, 451961 out-of-bound voxels after transform.
# 2: 137697 valid, 352855 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.254385
# Norm of gradient (rotation) = 0.272511
# around x=6.79; around y=1.85; around z=-6.07
# step: 0.20 seconds
# current score: -0.429115
# new_T: [  0.9938728    0.10883333   0.01929153  11.26258231  -0.1057355
#    0.98701586  -0.12091193 -12.48553705  -0.0322003    0.11813128
#    0.99247576  17.9158002 ]
# det: 1.00
#
# iteration 47
# 1: 134155 valid, 452093 out-of-bound voxels after transform.
# 2: 137614 valid, 352938 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.249197
# Norm of gradient (rotation) = 0.269675
# around x=6.85; around y=1.71; around z=-6.11
# step: 0.18 seconds
# current score: -0.429304
# new_T: [ 9.93879036e-01  1.09193188e-01  1.67722855e-02  1.13104861e+01
#  -1.06364009e-01  9.86837956e-01 -1.21809469e-01 -1.25705388e+01
#  -2.98522921e-02  1.19279910e-01  9.92411781e-01  1.81519555e+01]
# det: 1.00
#
# iteration 48
# 1: 133910 valid, 452338 out-of-bound voxels after transform.
# 2: 137522 valid, 353030 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.244422
# Norm of gradient (rotation) = 0.267204
# around x=6.92; around y=1.58; around z=-6.14
# step: 0.18 seconds
# current score: -0.429508
# new_T: [ 9.93881139e-01  1.09529304e-01  1.42693135e-02  1.13556281e+01
#  -1.06972492e-01  9.86663637e-01 -1.22685590e-01 -1.26529392e+01
#  -2.75166800e-02  1.20408470e-01  9.92343001e-01  1.83846610e+01]
# det: 1.00
#
# iteration 49
# 1: 133889 valid, 452359 out-of-bound voxels after transform.
# 2: 137423 valid, 353129 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.239861
# Norm of gradient (rotation) = 0.264596
# around x=6.98; around y=1.44; around z=-6.18
# step: 0.18 seconds
# current score: -0.429732
# new_T: [ 9.93879268e-01  1.09841410e-01  1.17840806e-02  1.13981692e+01
#  -1.07560340e-01  9.86493122e-01 -1.23539844e-01 -1.27326298e+01
#  -2.51947051e-02  1.21516190e-01  9.92269642e-01  1.86141097e+01]
# det: 1.00
#
# iteration 50
# 1: 133905 valid, 452343 out-of-bound voxels after transform.
# 2: 137208 valid, 353344 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.235339
# Norm of gradient (rotation) = 0.261483
# around x=7.04; around y=1.31; around z=-6.21
# step: 0.18 seconds
# current score: -0.430076
# new_T: [ 9.93873180e-01  1.10132569e-01  9.32310210e-03  1.14383831e+01
#  -1.08129563e-01  9.86326069e-01 -1.24373962e-01 -1.28098685e+01
#  -2.28932425e-02  1.22603842e-01  9.92191613e-01  1.88401081e+01]
# det: 1.00
#
# iteration 51
# 1: 133843 valid, 452405 out-of-bound voxels after transform.
# 2: 137118 valid, 353434 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.231127
# Norm of gradient (rotation) = 0.258843
# around x=7.11; around y=1.18; around z=-6.24
# step: 0.18 seconds
# current score: -0.430277
# new_T: [ 9.93863056e-01  1.10403181e-01  6.88204252e-03  1.14761429e+01
#  -1.08680865e-01  9.86162300e-01 -1.25189405e-01 -1.28847817e+01
#  -2.06081195e-02  1.23673179e-01  9.92108991e-01  1.90630229e+01]
# det: 1.00
#
# iteration 52
# 1: 133730 valid, 452518 out-of-bound voxels after transform.
# 2: 136968 valid, 353584 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.226990
# Norm of gradient (rotation) = 0.256049
# around x=7.17; around y=1.05; around z=-6.27
# step: 0.18 seconds
# current score: -0.430614
# new_T: [ 9.93849125e-01  1.10652631e-01  4.46232444e-03  1.15115422e+01
#  -1.09213296e-01  9.86002102e-01 -1.25985359e-01 -1.29572289e+01
#  -1.83404726e-02  1.24723093e-01  9.92022065e-01  1.92829311e+01]
# det: 1.00
#
# iteration 53
# 1: 133684 valid, 452564 out-of-bound voxels after transform.
# 2: 136838 valid, 353714 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.222944
# Norm of gradient (rotation) = 0.253452
# around x=7.23; around y=0.92; around z=-6.30
# step: 0.18 seconds
# current score: -0.430884
# new_T: [ 9.93831086e-01  1.10885133e-01  2.06379673e-03  1.15444417e+01
#  -1.09730808e-01  9.85844583e-01 -1.26765961e-01 -1.30278101e+01
#  -1.60910432e-02  1.25757490e-01  9.91930508e-01  1.94997922e+01]
# det: 1.00
#
# iteration 54
# 1: 133583 valid, 452665 out-of-bound voxels after transform.
# 2: 136619 valid, 353933 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.219012
# Norm of gradient (rotation) = 0.248987
# around x=7.28; around y=0.80; around z=-6.33
# step: 0.18 seconds
# current score: -0.431248
# new_T: [ 9.93808745e-01  1.11103971e-01 -2.93873300e-04  1.15763072e+01
#  -1.10234027e-01  9.85689903e-01 -1.27529894e-01 -1.30964161e+01
#  -1.38794096e-02  1.26772718e-01  9.91834684e-01  1.97130775e+01]
# det: 1.00
#
# iteration 55
# 1: 133472 valid, 452776 out-of-bound voxels after transform.
# 2: 136480 valid, 354072 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.215308
# Norm of gradient (rotation) = 0.246295
# around x=7.34; around y=0.67; around z=-6.36
# step: 0.18 seconds
# current score: -0.431573
# new_T: [ 9.93782749e-01  1.11305586e-01 -2.62941896e-03  1.16060060e+01
#  -1.10721584e-01  9.85538177e-01 -1.28277949e-01 -1.31630110e+01
#  -1.16866595e-02  1.27771547e-01  9.91734770e-01  1.99235913e+01]
# det: 1.00
#
# iteration 56
# 1: 133393 valid, 452855 out-of-bound voxels after transform.
# 2: 136340 valid, 354212 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.212257
# Norm of gradient (rotation) = 0.243882
# around x=7.40; around y=0.54; around z=-6.38
# step: 0.18 seconds
# current score: -0.431880
# new_T: [ 9.93753054e-01  1.11491781e-01 -4.94482670e-03  1.16339131e+01
#  -1.11195345e-01  9.85388962e-01 -1.29012358e-01 -1.32278153e+01
#  -9.51123985e-03  1.28756266e-01  9.91630657e-01  2.01318237e+01]
# det: 1.00
#
# iteration 57
# 1: 133310 valid, 452938 out-of-bound voxels after transform.
# 2: 136164 valid, 354388 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.208418
# Norm of gradient (rotation) = 0.240298
# around x=7.45; around y=0.42; around z=-6.41
# step: 0.18 seconds
# current score: -0.432247
# new_T: [ 9.93719612e-01  1.11665093e-01 -7.22768925e-03  1.16601141e+01
#  -1.11656082e-01  9.85242298e-01 -1.29732545e-01 -1.32909361e+01
#  -7.36557146e-03  1.29724790e-01  9.91522681e-01  2.03368010e+01]
# det: 1.00
#
# iteration 58
# 1: 133199 valid, 453049 out-of-bound voxels after transform.
# 2: 135966 valid, 354586 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.204540
# Norm of gradient (rotation) = 0.236985
# around x=7.51; around y=0.30; around z=-6.44
# step: 0.18 seconds
# current score: -0.432620
# new_T: [ 9.93682815e-01  1.11823831e-01 -9.48124263e-03  1.16843231e+01
#  -1.12102372e-01  9.85098521e-01 -1.30437578e-01 -1.33522106e+01
#  -5.24607156e-03  1.30676449e-01  9.91411188e-01  2.05386569e+01]
# det: 1.00
#
# iteration 59
# 1: 133114 valid, 453134 out-of-bound voxels after transform.
# 2: 135816 valid, 354736 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.201431
# Norm of gradient (rotation) = 0.233982
# around x=7.56; around y=0.18; around z=-6.46
# step: 0.18 seconds
# current score: -0.432971
# new_T: [ 9.93642572e-01  1.11970402e-01 -1.17076497e-02  1.17070781e+01
#  -1.12536705e-01  9.84957031e-01 -1.31130228e-01 -1.34119284e+01
#  -3.15117239e-03  1.31614117e-01  9.91296017e-01  2.07379284e+01]
# det: 1.00
#
# iteration 60
# 1: 132985 valid, 453263 out-of-bound voxels after transform.
# 2: 135645 valid, 354907 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.197519
# Norm of gradient (rotation) = 0.229933
# around x=7.62; around y=0.06; around z=-6.49
# step: 0.18 seconds
# current score: -0.433341
# new_T: [ 9.93599044e-01  1.12106361e-01 -1.38961949e-02  1.17283602e+01
#  -1.12959059e-01  9.84818045e-01 -1.31809214e-01 -1.34700968e+01
#  -1.09142778e-03  1.32535210e-01  9.91177697e-01  2.09337133e+01]
# det: 1.00
#
# iteration 61
# 1: 132913 valid, 453335 out-of-bound voxels after transform.
# 2: 135411 valid, 355141 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.195243
# Norm of gradient (rotation) = 0.227890
# around x=7.67; around y=-0.05; around z=-6.51
# step: 0.18 seconds
# current score: -0.433753
# new_T: [ 9.93552345e-01  1.12230072e-01 -1.60669995e-02  1.17482835e+01
#  -1.13370320e-01  9.84681069e-01 -1.32477783e-01 -1.35268185e+01
#   9.52879141e-04  1.33445133e-01  9.91055744e-01  2.11277769e+01]
# det: 1.00
#
# iteration 62
# 1: 132850 valid, 453398 out-of-bound voxels after transform.
# 2: 135244 valid, 355308 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.191225
# Norm of gradient (rotation) = 0.223228
# around x=7.72; around y=-0.17; around z=-6.53
# step: 0.19 seconds
# current score: -0.434144
# new_T: [ 9.93502717e-01  1.12344762e-01 -1.81935440e-02  1.17671559e+01
#  -1.13770007e-01  9.84546701e-01 -1.33132185e-01 -1.35819902e+01
#   2.95569012e-03  1.34337067e-01  9.90931287e-01  2.13180563e+01]
# det: 1.00
#
# iteration 63
# 1: 132742 valid, 453506 out-of-bound voxels after transform.
# 2: 135049 valid, 355503 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.188740
# Norm of gradient (rotation) = 0.221101
# around x=7.77; around y=-0.28; around z=-6.56
# step: 0.18 seconds
# current score: -0.434544
# new_T: [ 9.93450014e-01  1.12449774e-01 -2.03006955e-02  1.17845180e+01
#  -1.14160661e-01  9.84413940e-01 -1.33777946e-01 -1.36360430e+01
#   4.94098789e-03  1.35219243e-01  9.90803383e-01  2.15063462e+01]
# det: 1.00
#
# iteration 64
# 1: 132595 valid, 453653 out-of-bound voxels after transform.
# 2: 134868 valid, 355684 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.185980
# Norm of gradient (rotation) = 0.218397
# around x=7.82; around y=-0.40; around z=-6.58
# step: 0.20 seconds
# current score: -0.434936
# new_T: [ 9.93394332e-01  1.12546562e-01 -2.23824085e-02  1.18005397e+01
#  -1.14542802e-01  9.84282797e-01 -1.34414737e-01 -1.36890301e+01
#   6.90270314e-03  1.36090582e-01  9.90672351e-01  2.16922491e+01]
# det: 1.00
#
# iteration 65
# 1: 132451 valid, 453797 out-of-bound voxels after transform.
# 2: 134694 valid, 355858 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.183008
# Norm of gradient (rotation) = 0.215537
# around x=7.87; around y=-0.51; around z=-6.60
# step: 0.20 seconds
# current score: -0.435323
# new_T: [ 9.93335911e-01  1.12634742e-01 -2.44373309e-02  1.18151153e+01
#  -1.14915743e-01  9.84153500e-01 -1.35041702e-01 -1.37408667e+01
#   8.83969748e-03  1.36950006e-01  9.90538518e-01  2.18755955e+01]
# det: 1.00
#
# iteration 66
# 1: 132371 valid, 453877 out-of-bound voxels after transform.
# 2: 134516 valid, 356036 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.180313
# Norm of gradient (rotation) = 0.213087
# around x=7.92; around y=-0.62; around z=-6.62
# step: 0.18 seconds
# current score: -0.435706
# new_T: [ 9.93274829e-01  1.12714152e-01 -2.64694844e-02  1.18281885e+01
#  -1.15279766e-01  9.84025926e-01 -1.35659693e-01 -1.37916072e+01
#   1.07558917e-02  1.37798754e-01  9.90401845e-01  2.20567007e+01]
# det: 1.00
#
# iteration 67
# 1: 132247 valid, 454001 out-of-bound voxels after transform.
# 2: 134284 valid, 356268 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.177762
# Norm of gradient (rotation) = 0.210435
# around x=7.97; around y=-0.72; around z=-6.64
# step: 0.18 seconds
# current score: -0.436148
# new_T: [ 9.93211167e-01  1.12785913e-01 -2.84765769e-02  1.18401064e+01
#  -1.15635563e-01  9.83899978e-01 -1.36269035e-01 -1.38413023e+01
#   1.26488760e-02  1.38636832e-01  9.90262508e-01  2.22355649e+01]
# det: 1.00
#
# iteration 68
# 1: 132099 valid, 454149 out-of-bound voxels after transform.
# 2: 134054 valid, 356498 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.175018
# Norm of gradient (rotation) = 0.207353
# around x=8.02; around y=-0.83; around z=-6.66
# step: 0.18 seconds
# current score: -0.436589
# new_T: [ 9.93145064e-01  1.12851362e-01 -3.04541044e-02  1.18510555e+01
#  -1.15983721e-01  9.83775635e-01 -1.36869563e-01 -1.38900112e+01
#   1.45140893e-02  1.39463512e-01  9.90120836e-01  2.24118837e+01]
# det: 1.00
#
# iteration 69
# 1: 132006 valid, 454242 out-of-bound voxels after transform.
# 2: 133825 valid, 356727 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.172447
# Norm of gradient (rotation) = 0.204531
# around x=8.07; around y=-0.94; around z=-6.68
# step: 0.18 seconds
# current score: -0.437023
# new_T: [ 9.93076610e-01  1.12910528e-01 -3.24046059e-02  1.18610149e+01
#  -1.16324514e-01  9.83652813e-01 -1.37461816e-01 -1.39377764e+01
#   1.63539955e-02  1.40279564e-01  9.89976864e-01  2.25858478e+01]
# det: 1.00
#
# iteration 70
# 1: 131887 valid, 454361 out-of-bound voxels after transform.
# 2: 133610 valid, 356942 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.170011
# Norm of gradient (rotation) = 0.201896
# around x=8.11; around y=-1.04; around z=-6.70
# step: 0.18 seconds
# current score: -0.437440
# new_T: [ 9.93005915e-01  1.12963294e-01 -3.43299598e-02  1.18699760e+01
#  -1.16657989e-01  9.83531489e-01 -1.38046094e-01 -1.39846112e+01
#   1.81704550e-02  1.41085452e-01  9.89830657e-01  2.27576095e+01]
# det: 1.00
#
# iteration 71
# 1: 131763 valid, 454485 out-of-bound voxels after transform.
# 2: 133388 valid, 357164 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.167409
# Norm of gradient (rotation) = 0.198991
# around x=8.16; around y=-1.14; around z=-6.72
# step: 0.18 seconds
# current score: -0.437869
# new_T: [ 9.92933127e-01  1.13010553e-01 -3.62273398e-02  1.18780137e+01
#  -1.16984526e-01  9.83411659e-01 -1.38622257e-01 -1.40305602e+01
#   1.99606103e-02  1.41880670e-01  9.89682499e-01  2.29269440e+01]
# det: 1.00
#
# iteration 72
# 1: 131611 valid, 454637 out-of-bound voxels after transform.
# 2: 133147 valid, 357405 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.165016
# Norm of gradient (rotation) = 0.196337
# around x=8.20; around y=-1.24; around z=-6.74
# step: 0.18 seconds
# current score: -0.438325
# new_T: [ 9.92858319e-01  1.13052231e-01 -3.80992327e-02  1.18851520e+01
#  -1.17304307e-01  9.83293258e-01 -1.39190761e-01 -1.40756441e+01
#   2.17268927e-02  1.42665909e-01  9.89532405e-01  2.30940711e+01]
# det: 1.00
#
# iteration 73
# 1: 131494 valid, 454754 out-of-bound voxels after transform.
# 2: 132899 valid, 357653 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.162677
# Norm of gradient (rotation) = 0.193762
# around x=8.25; around y=-1.34; around z=-6.76
# step: 0.18 seconds
# current score: -0.438778
# new_T: [  0.99278153   0.11308903  -0.03994624  11.8913951   -0.11761804
#    0.98317613  -0.13975223 -14.1199653    0.02346974   0.14344183
#    0.98938042  23.25902169]
# det: 1.00
#
# iteration 74
# 1: 131359 valid, 454889 out-of-bound voxels after transform.
# 2: 132647 valid, 357905 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.160283
# Norm of gradient (rotation) = 0.190898
# around x=8.29; around y=-1.44; around z=-6.77
# step: 0.18 seconds
# current score: -0.439247
# new_T: [  0.99270298   0.11312136  -0.04176551  11.89698761  -0.11792559
#    0.9830604   -0.1403061  -14.16347214   0.0251864    0.1442075
#    0.98922689  23.42165904]
# det: 1.00
#
# iteration 75
# 1: 131226 valid, 455022 out-of-bound voxels after transform.
# 2: 132388 valid, 358164 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.157912
# Norm of gradient (rotation) = 0.188077
# around x=8.34; around y=-1.54; around z=-6.79
# step: 0.18 seconds
# current score: -0.439715
# new_T: [  0.99262281   0.11314905  -0.04355754  11.90193245  -0.11822678
#    0.98294613  -0.14085218 -14.20613698   0.02687743   0.14496276
#    0.98907199  23.58201843]
# det: 1.00
#
# iteration 76
# 1: 131082 valid, 455166 out-of-bound voxels after transform.
# 2: 132124 valid, 358428 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.155830
# Norm of gradient (rotation) = 0.185517
# around x=8.38; around y=-1.64; around z=-6.81
# step: 0.18 seconds
# current score: -0.440183
# new_T: [  0.99254095   0.113173    -0.04532467  11.90634775  -0.11852276
#    0.98283301  -0.14139176 -14.24810806   0.02854485   0.14570912
#    0.98891559  23.74033756]
# det: 1.00
#
# iteration 77
# 1: 130947 valid, 455301 out-of-bound voxels after transform.
# 2: 131853 valid, 358699 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.153791
# Norm of gradient (rotation) = 0.183236
# around x=8.42; around y=-1.73; around z=-6.83
# step: 0.18 seconds
# current score: -0.440662
# new_T: [  0.99245746   0.11319295  -0.04706964  11.91002548  -0.11881362
#    0.98272099  -0.14192527 -14.28942874   0.03019139   0.1464473
#    0.98875764  23.89673403]
# det: 1.00
#
# iteration 78
# 1: 130786 valid, 455462 out-of-bound voxels after transform.
# 2: 131582 valid, 358970 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.151627
# Norm of gradient (rotation) = 0.180662
# around x=8.47; around y=-1.82; around z=-6.84
# step: 0.18 seconds
# current score: -0.441143
# new_T: [  0.99237253   0.1132092   -0.04878965  11.91312443  -0.11909912
#    0.98261021  -0.14245198 -14.33004221   0.03181433   0.14717623
#    0.98859851  24.05102812]
# det: 1.00
#
# iteration 79
# 1: 130650 valid, 455598 out-of-bound voxels after transform.
# 2: 131281 valid, 359271 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.149474
# Norm of gradient (rotation) = 0.178255
# around x=8.51; around y=-1.91; around z=-6.86
# step: 0.18 seconds
# current score: -0.441655
# new_T: [  0.9922862    0.11322212  -0.05048622  11.91550624  -0.11937981
#    0.98250054  -0.14297253 -14.37004786   0.03341508   0.14789671
#    0.98843816  24.20326131]
# det: 1.00
#
# iteration 80
# 1: 130534 valid, 455714 out-of-bound voxels after transform.
# 2: 130980 valid, 359572 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.147348
# Norm of gradient (rotation) = 0.175829
# around x=8.55; around y=-2.01; around z=-6.88
# step: 0.18 seconds
# current score: -0.442154
# new_T: [  0.99219851   0.11323228  -0.05215906  11.91724364  -0.11965612
#    0.9823919   -0.14348719 -14.40950026   0.03499326   0.14860893
#    0.98827671  24.35342502]
# det: 1.00
#
# iteration 81
# 1: 130383 valid, 455865 out-of-bound voxels after transform.
# 2: 130683 valid, 359869 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.145254
# Norm of gradient (rotation) = 0.173402
# around x=8.59; around y=-2.09; around z=-6.89
# step: 0.18 seconds
# current score: -0.442659
# new_T: [  0.99210959   0.11323972  -0.05380819  11.91839701  -0.11992804
#    0.9822843   -0.14399587 -14.44838951   0.03654889   0.1493128
#    0.9881143   24.50153777]
# det: 1.00
#
# iteration 82
# 1: 130224 valid, 456024 out-of-bound voxels after transform.
# 2: 130432 valid, 360120 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.143274
# Norm of gradient (rotation) = 0.171101
# around x=8.63; around y=-2.18; around z=-6.91
# step: 0.18 seconds
# current score: -0.443115
# new_T: [  0.99201943   0.11324501  -0.05543472  11.91900405  -0.12019622
#    0.9821776   -0.14449921 -14.48680176   0.03808292   0.15000907
#    0.98795089  24.64769076]
# det: 1.00
#
# iteration 83
# 1: 130081 valid, 456167 out-of-bound voxels after transform.
# 2: 130148 valid, 360404 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.141285
# Norm of gradient (rotation) = 0.168862
# around x=8.67; around y=-2.27; around z=-6.92
# step: 0.18 seconds
# current score: -0.443591
# new_T: [  0.9919281    0.1132483   -0.05703922  11.91900033  -0.12046084
#    0.98207176  -0.14499738 -14.5247723    0.0395959    0.15069797
#    0.98778656  24.791892  ]
# det: 1.00
#
# iteration 84
# 1: 129955 valid, 456293 out-of-bound voxels after transform.
# 2: 129826 valid, 360726 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.139354
# Norm of gradient (rotation) = 0.166490
# around x=8.71; around y=-2.35; around z=-6.94
# step: 0.18 seconds
# current score: -0.444100
# new_T: [  0.99183574   0.11324981  -0.05862043  11.91862318  -0.12072186
#    0.98196684  -0.14549007 -14.56225988   0.04108659   0.15137901
#    0.98762153  24.93413246]
# det: 1.00
#
# iteration 85
# 1: 129823 valid, 456425 out-of-bound voxels after transform.
# 2: 129537 valid, 361015 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.137506
# Norm of gradient (rotation) = 0.164274
# around x=8.75; around y=-2.44; around z=-6.95
# step: 0.18 seconds
# current score: -0.444570
# new_T: [  0.99174239   0.11324937  -0.0601799   11.9178324   -0.12097925
#    0.98186282  -0.14597745 -14.59927046   0.04255655   0.15205254
#    0.9874558   25.07452106]
# det: 1.00
#
# iteration 86
# 1: 129670 valid, 456578 out-of-bound voxels after transform.
# 2: 129240 valid, 361312 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.135712
# Norm of gradient (rotation) = 0.162143
# around x=8.79; around y=-2.52; around z=-6.97
# step: 0.18 seconds
# current score: -0.445066
# new_T: [  0.99164812   0.11324675  -0.06171857  11.91661389  -0.12123289
#    0.98175975  -0.1464595  -14.63578541   0.04400674   0.15271861
#    0.98728944  25.21312845]
# det: 1.00
#
# iteration 87
# 1: 129533 valid, 456715 out-of-bound voxels after transform.
# 2: 128908 valid, 361644 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.133883
# Norm of gradient (rotation) = 0.159937
# around x=8.83; around y=-2.60; around z=-6.98
# step: 0.18 seconds
# current score: -0.445585
# new_T: [  0.99155301   0.11324265  -0.06323556  11.91503228  -0.12148327
#    0.98165753  -0.14693639 -14.67186428   0.0454362    0.15337728
#    0.98712257  25.34988201]
# det: 1.00
#
# iteration 88
# 1: 129395 valid, 456853 out-of-bound voxels after transform.
# 2: 128556 valid, 361996 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.132088
# Norm of gradient (rotation) = 0.157777
# around x=8.87; around y=-2.69; around z=-7.00
# step: 0.17 seconds
# current score: -0.446129
# new_T: [  0.99145714   0.11323686  -0.06473143  11.91309215  -0.1217302
#    0.98155624  -0.14740799 -14.70748097   0.04684552   0.15402847
#    0.98695528  25.48482619]
# det: 1.00
#
# iteration 89
# 1: 129255 valid, 456993 out-of-bound voxels after transform.
# 2: 128230 valid, 362322 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.130280
# Norm of gradient (rotation) = 0.155543
# around x=8.91; around y=-2.76; around z=-7.01
# step: 0.18 seconds
# current score: -0.446637
# new_T: [  0.99136061   0.11322981  -0.06620538  11.91088058  -0.12197391
#    0.98145583  -0.14787431 -14.74265828   0.04823388   0.1546721
#    0.98678774  25.61791543]
# det: 1.00
#
# iteration 90
# 1: 129115 valid, 457133 out-of-bound voxels after transform.
# 2: 127891 valid, 362661 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.128560
# Norm of gradient (rotation) = 0.153465
# around x=8.95; around y=-2.84; around z=-7.03
# step: 0.18 seconds
# current score: -0.447163
# new_T: [  0.99126343   0.11322134  -0.06765899  11.90835873  -0.12221445
#    0.9813563   -0.14833558 -14.77740612   0.04960282   0.15530854
#    0.98661989  25.74925956]
# det: 1.00
#
# iteration 91
# 1: 128961 valid, 457287 out-of-bound voxels after transform.
# 2: 127508 valid, 363044 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.126884
# Norm of gradient (rotation) = 0.151269
# around x=8.98; around y=-2.92; around z=-7.04
# step: 0.18 seconds
# current score: -0.447730
# ...
#    0.97114227  -0.18742013 -17.67237143   0.13484282   0.20746849
#    0.96890363  36.65530087]
# det: 1.00
#
# iteration 969
# 1: 110403 valid, 475845 out-of-bound voxels after transform.
# 2: 78061 valid, 412491 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000745
# Norm of gradient (rotation) = 0.001637
# around x=12.09; around y=-7.75; around z=-8.56
# step: 0.15 seconds
# current score: -0.514029
# new_T: [  0.97982911   0.11764573  -0.16153763  15.49296433  -0.14750119
#    0.9711424   -0.18741889 -17.67220922   0.13482701   0.20746548
#    0.96890647  36.65519422]
# det: 1.00
#
# iteration 970
# 1: 110404 valid, 475844 out-of-bound voxels after transform.
# 2: 78061 valid, 412491 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000737
# Norm of gradient (rotation) = 0.001632
# around x=12.09; around y=-7.75; around z=-8.56
# step: 0.15 seconds
# current score: -0.514030
# new_T: [  0.97983116   0.11765     -0.16152205  15.49425705  -0.14750195
#    0.97114252  -0.18741767 -17.67204909   0.13481124   0.20746249
#    0.96890931  36.65508923]
# det: 1.00
#
# iteration 971
# 1: 110404 valid, 475844 out-of-bound voxels after transform.
# 2: 78063 valid, 412489 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000733
# Norm of gradient (rotation) = 0.001632
# around x=12.09; around y=-7.75; around z=-8.56
# step: 0.16 seconds
# current score: -0.514027
# new_T: [  0.97983322   0.11765425  -0.16150647  15.49554603  -0.14750268
#    0.97114265  -0.18741643 -17.67188675   0.13479548   0.20745949
#    0.96891214  36.6549826 ]
# det: 1.00
#
# iteration 972
# 1: 110404 valid, 475844 out-of-bound voxels after transform.
# 2: 78064 valid, 412488 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000730
# Norm of gradient (rotation) = 0.001637
# around x=12.09; around y=-7.75; around z=-8.56
# step: 0.15 seconds
# current score: -0.514026
# new_T: [  0.97983528   0.11765851  -0.16149084  15.49683525  -0.14750342
#    0.97114278  -0.18741519 -17.67172409   0.13477967   0.20745646
#    0.96891499  36.65487112]
# det: 1.00
#
# iteration 973
# 1: 110404 valid, 475844 out-of-bound voxels after transform.
# 2: 78064 valid, 412488 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000726
# Norm of gradient (rotation) = 0.001630
# around x=12.09; around y=-7.74; around z=-8.56
# step: 0.15 seconds
# current score: -0.514026
# new_T: [  0.97983734   0.11766278  -0.16147528  15.49811721  -0.14750417
#    0.9711429   -0.18741397 -17.67156591   0.13476392   0.20745348
#    0.96891782  36.65476359]
# det: 1.00
#
# iteration 974
# 1: 110405 valid, 475843 out-of-bound voxels after transform.
# 2: 78063 valid, 412489 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000719
# Norm of gradient (rotation) = 0.001627
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.16 seconds
# current score: -0.514028
# new_T: [  0.97983939   0.11766701  -0.16145975  15.4993909   -0.1475049
#    0.97114302  -0.18741274 -17.67140555   0.13474821   0.20745049
#    0.96892064  36.65465649]
# det: 1.00
#
# iteration 975
# 1: 110405 valid, 475843 out-of-bound voxels after transform.
# 2: 78063 valid, 412489 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000715
# Norm of gradient (rotation) = 0.001629
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.15 seconds
# current score: -0.514028
# new_T: [  0.97984144   0.11767127  -0.1614442   15.50066196  -0.14750566
#    0.97114314  -0.18741153 -17.67124877   0.13473248   0.20744751
#    0.96892347  36.65454581]
# det: 1.00
#
# iteration 976
# 1: 110406 valid, 475842 out-of-bound voxels after transform.
# 2: 78063 valid, 412489 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000709
# Norm of gradient (rotation) = 0.001630
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.16 seconds
# current score: -0.514028
# new_T: [  0.97984349   0.11767552  -0.16142864  15.50192809  -0.14750639
#    0.97114327  -0.1874103  -17.67109013   0.13471673   0.20744451
#    0.9689263   36.65443188]
# det: 1.00
#
# iteration 977
# 1: 110405 valid, 475843 out-of-bound voxels after transform.
# 2: 78064 valid, 412488 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000708
# Norm of gradient (rotation) = 0.001636
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.16 seconds
# current score: -0.514027
# new_T: [  0.97984556   0.11767974  -0.16141301  15.50319519  -0.14750708
#    0.97114341  -0.18740902 -17.67092524   0.13470093   0.20744146
#    0.96892915  36.65431302]
# det: 1.00
#
# iteration 978
# 1: 110406 valid, 475842 out-of-bound voxels after transform.
# 2: 78064 valid, 412488 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000709
# Norm of gradient (rotation) = 0.001632
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.15 seconds
# current score: -0.514027
# new_T: [  0.97984762   0.11768394  -0.16139742  15.50446167  -0.14750776
#    0.97114355  -0.18740775 -17.67075781   0.13468518   0.20743841
#    0.96893199  36.65419833]
# det: 1.00
#
# iteration 979
# 1: 110406 valid, 475842 out-of-bound voxels after transform.
# 2: 78065 valid, 412487 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000701
# Norm of gradient (rotation) = 0.001633
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.15 seconds
# current score: -0.514027
# new_T: [  0.97984969   0.11768815  -0.16138182  15.50572123  -0.14750845
#    0.97114369  -0.18740649 -17.67059386   0.13466942   0.20743537
#    0.96893484  36.65407948]
# det: 1.00
#
# iteration 980
# 1: 110409 valid, 475839 out-of-bound voxels after transform.
# 2: 78069 valid, 412483 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000704
# Norm of gradient (rotation) = 0.001643
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.15 seconds
# current score: -0.514021
# new_T: [  0.97985176   0.11769237  -0.16136613  15.50698818  -0.14750911
#    0.97114384  -0.18740518 -17.67042526   0.13465356   0.20743227
#    0.9689377   36.65395392]
# det: 1.00
#
# iteration 981
# 1: 110411 valid, 475837 out-of-bound voxels after transform.
# 2: 78070 valid, 412482 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000698
# Norm of gradient (rotation) = 0.001639
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.15 seconds
# current score: -0.514020
# new_T: [  0.97985383   0.11769662  -0.16135048  15.50824803  -0.14750984
#    0.97114397  -0.18740393 -17.67026598   0.13463774   0.20742924
#    0.96894055  36.65382917]
# det: 1.00
#
# iteration 982
# 1: 110412 valid, 475836 out-of-bound voxels after transform.
# 2: 78070 valid, 412482 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000699
# Norm of gradient (rotation) = 0.001637
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.16 seconds
# current score: -0.514020
# new_T: [  0.9798559    0.11770084  -0.16133484  15.50950806  -0.14751052
#    0.97114412  -0.18740265 -17.67010174   0.13462193   0.20742618
#    0.9689434   36.65370583]
# det: 1.00
#
# iteration 983
# 1: 110411 valid, 475837 out-of-bound voxels after transform.
# 2: 78072 valid, 412480 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000696
# Norm of gradient (rotation) = 0.001634
# around x=12.08; around y=-7.74; around z=-8.56
# step: 0.16 seconds
# current score: -0.514019
# new_T: [  0.97985796   0.11770503  -0.16131923  15.5107628   -0.14751119
#    0.97114426  -0.18740136 -17.66993482   0.13460616   0.20742311
#    0.96894625  36.65358443]
# det: 1.00
#
# iteration 984
# 1: 110412 valid, 475836 out-of-bound voxels after transform.
# 2: 78073 valid, 412479 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000684
# Norm of gradient (rotation) = 0.001626
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.15 seconds
# current score: -0.514017
# new_T: [  0.97986002   0.11770921  -0.1613037   15.51200305  -0.14751185
#    0.97114441  -0.1874001  -17.66977009   0.13459047   0.20742007
#    0.96894908  36.65346525]
# det: 1.00
#
# iteration 985
# 1: 110415 valid, 475833 out-of-bound voxels after transform.
# 2: 78075 valid, 412477 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000686
# Norm of gradient (rotation) = 0.001625
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.15 seconds
# current score: -0.514015
# new_T: [  0.97986207   0.11771339  -0.16128817  15.51324455  -0.14751253
#    0.97114455  -0.18739884 -17.66960684   0.13457477   0.20741704
#    0.96895191  36.65334676]
# det: 1.00
#
# iteration 986
# 1: 110415 valid, 475833 out-of-bound voxels after transform.
# 2: 78074 valid, 412478 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000686
# Norm of gradient (rotation) = 0.001620
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.16 seconds
# current score: -0.514017
# new_T: [  0.97986413   0.11771751  -0.16127269  15.51448381  -0.14751315
#    0.9711447   -0.18739755 -17.6694361    0.13455914   0.20741398
#    0.96895473  36.65323358]
# det: 1.00
#
# iteration 987
# 1: 110416 valid, 475832 out-of-bound voxels after transform.
# 2: 78078 valid, 412474 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000682
# Norm of gradient (rotation) = 0.001621
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.15 seconds
# current score: -0.514012
# new_T: [  0.97986618   0.11772165  -0.1612572   15.51571957  -0.14751379
#    0.97114485  -0.18739628 -17.66926772   0.1345435    0.20741094
#    0.96895756  36.65311814]
# det: 1.00
#
# iteration 988
# 1: 110416 valid, 475832 out-of-bound voxels after transform.
# 2: 78080 valid, 412472 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000679
# Norm of gradient (rotation) = 0.001622
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.16 seconds
# current score: -0.514010
# new_T: [  0.97986823   0.11772578  -0.1612417   15.5169528   -0.14751442
#    0.971145    -0.187395   -17.66909911   0.13452785   0.20740788
#    0.96896039  36.65300066]
# det: 1.00
#
# iteration 989
# 1: 110416 valid, 475832 out-of-bound voxels after transform.
# 2: 78082 valid, 412470 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000685
# Norm of gradient (rotation) = 0.001623
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.15 seconds
# current score: -0.514008
# new_T: [  0.97987029   0.11772993  -0.16122618  15.51819289  -0.14751506
#    0.97114515  -0.18739372 -17.66893045   0.13451218   0.20740483
#    0.96896322  36.65288405]
# det: 1.00
#
# iteration 990
# 1: 110418 valid, 475830 out-of-bound voxels after transform.
# 2: 78084 valid, 412468 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000682
# Norm of gradient (rotation) = 0.001622
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.16 seconds
# current score: -0.514006
# new_T: [  0.97987234   0.11773407  -0.16121069  15.51942903  -0.1475157
#    0.9711453   -0.18739245 -17.66876349   0.13449652   0.20740178
#    0.96896604  36.6527673 ]
# det: 1.00
#
# iteration 991
# 1: 110420 valid, 475828 out-of-bound voxels after transform.
# 2: 78085 valid, 412467 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000675
# Norm of gradient (rotation) = 0.001618
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.16 seconds
# current score: -0.514005
# new_T: [  0.97987439   0.11773821  -0.16119522  15.52065707  -0.14751634
#    0.97114544  -0.18739118 -17.6685971    0.1344809    0.20739875
#    0.96896886  36.652651  ]
# det: 1.00
#
# iteration 992
# 1: 110422 valid, 475826 out-of-bound voxels after transform.
# 2: 78085 valid, 412467 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000674
# Norm of gradient (rotation) = 0.001624
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.16 seconds
# current score: -0.514005
# new_T: [  0.97987644   0.11774237  -0.16117971  15.52188652  -0.147517
#    0.97114559  -0.18738992 -17.66843374   0.13446523   0.20739571
#    0.96897168  36.65252962]
# det: 1.00
#
# iteration 993
# 1: 110424 valid, 475824 out-of-bound voxels after transform.
# 2: 78088 valid, 412464 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000669
# Norm of gradient (rotation) = 0.001624
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.16 seconds
# current score: -0.514001
# new_T: [  0.97987849   0.11774654  -0.16116419  15.52311118  -0.14751767
#    0.97114573  -0.18738865 -17.66827145   0.13444955   0.20739267
#    0.96897451  36.65240578]
# det: 1.00
#
# iteration 994
# 1: 110423 valid, 475825 out-of-bound voxels after transform.
# 2: 78086 valid, 412466 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000663
# Norm of gradient (rotation) = 0.001617
# around x=12.08; around y=-7.73; around z=-8.56
# step: 0.15 seconds
# current score: -0.514003
# new_T: [  0.97988053   0.11775069  -0.16114874  15.5243276   -0.14751833
#    0.97114587  -0.1873874  -17.66811056   0.13443394   0.20738966
#    0.96897732  36.65228596]
# det: 1.00
#
# iteration 995
# 1: 110422 valid, 475826 out-of-bound voxels after transform.
# 2: 78087 valid, 412465 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000664
# Norm of gradient (rotation) = 0.001619
# around x=12.08; around y=-7.72; around z=-8.56
# step: 0.16 seconds
# current score: -0.514001
# new_T: [  0.97988257   0.11775487  -0.16113328  15.52554548  -0.14751902
#    0.97114601  -0.18738616 -17.66795204   0.1344183    0.20738666
#    0.96898013  36.65216457]
# det: 1.00
#
# iteration 996
# 1: 110422 valid, 475826 out-of-bound voxels after transform.
# 2: 78087 valid, 412465 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000659
# Norm of gradient (rotation) = 0.001616
# around x=12.08; around y=-7.72; around z=-8.56
# step: 0.15 seconds
# current score: -0.514001
# new_T: [  0.97988461   0.11775904  -0.16111784  15.52675702  -0.14751971
#    0.97114614  -0.18738494 -17.66779585   0.1344027    0.20738367
#    0.96898293  36.65204362]
# det: 1.00
#
# iteration 997
# 1: 110423 valid, 475825 out-of-bound voxels after transform.
# 2: 78089 valid, 412463 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000656
# Norm of gradient (rotation) = 0.001618
# around x=12.08; around y=-7.72; around z=-8.56
# step: 0.16 seconds
# current score: -0.513999
# new_T: [  0.97988665   0.11776322  -0.16110238  15.52796721  -0.14752041
#    0.97114627  -0.18738371 -17.66764064   0.13438707   0.20738068
#    0.96898574  36.65191944]
# det: 1.00
#
# iteration 998
# 1: 110426 valid, 475822 out-of-bound voxels after transform.
# 2: 78090 valid, 412462 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000649
# Norm of gradient (rotation) = 0.001608
# around x=12.08; around y=-7.72; around z=-8.56
# step: 0.16 seconds
# current score: -0.513998
# new_T: [  0.97988868   0.11776736  -0.16108702  15.52916616  -0.14752108
#    0.9711464   -0.18738249 -17.66748386   0.13437154   0.20737771
#    0.96898853  36.6518016 ]
# det: 1.00
#
# iteration 999
# 1: 110428 valid, 475820 out-of-bound voxels after transform.
# 2: 78090 valid, 412462 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000655
# Norm of gradient (rotation) = 0.001608
# around x=12.08; around y=-7.72; around z=-8.56
# step: 0.16 seconds
# current score: -0.513998
# new_T: [  0.97989071   0.1177715   -0.16107166  15.53036981  -0.14752175
#    0.97114654  -0.18738126 -17.66732468   0.13435601   0.20737473
#    0.96899132  36.65168583]
# det: 1.00
# Optimize: 161.66 seconds.
# [[ 9.18186793e-01  3.70902244e-01 -1.39176700e-01  9.94983810e+02]
#  [-3.94189322e-01  8.90346227e-01 -2.27824353e-01  5.50724891e+02]
#  [ 3.94150860e-02  2.64047117e-01  9.63704271e-01  4.73846358e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# /home/alexn/brainDev/src/utilities/registration_utilities.py:1571: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(volume_m_aligned_to_f.dtype, np.float):
# Interpolating/filling sparse volume: 0.09 seconds.
# Interpolating/filling sparse volume: 0.07 seconds.
# Interpolating/filling sparse volume: 0.10 seconds.
# Interpolating/filling sparse volume: 0.10 seconds.

# %%
! python register_brains_demo_3N_R_4N_R.py --use_simple_global
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'DEMO998': 0.46}
# No vtk
# No mcubes
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# upstream_warp_id                                                               None
# transform_type                                                                rigid
# grad_computation_sample_number                                               100000
# grid_search_sample_number                                                      1000
# std_tx_um                                                                        50
# std_ty_um                                                                        50
# std_tz_um                                                                        50
# std_theta_xy_degree                                                              10
# surround_weight                                                             inverse
# regularization_weight                                                           NaN
# terminate_thresh_trans                                                         0.01
# terminate_thresh_rot                                                           0.01
# history_len                                                                     100
# max_iter_num                                                                   5000
# learning_rate_trans                                                               1
# learning_rate_rot                                                              0.01
# comment                           structure registration with surround, no initi...
# Name: 7, dtype: object
# surround inverse True
# Prior structure/index map not found. Generating a new one.
# Loaded moving volumes: [u'3N_R', u'3N_R_surround_200um', u'4N_R', u'4N_R_surround_200um'].
# Prior structure/index map not found. Generating a new one.
# loaded_cropbox_resolution 10.0um
# loaded_cropbox_resolution 10.0um
# Loaded fixed volumes: [u'3N_R', u'4N_R'].
# voxel size for moving = 10.00 um
# voxel size for fixed = 10.00 um
# label_mapping_m2f {1: 1, 2: 2, 3: 2, 4: 1}
# Computing structure sizes: 0.00 s
# {1: 1.0, 2: -0.012881981758562729, 3: 1.0, 4: -0.07839865602303961}
# Label weights not set, default to 1 for all structures.
# Regularization weights not set, default to 0.
# indices_f: set([1, 2])
# Set initial transform to [ 9.63169856e-01  2.67574548e-01  2.67105543e-02  9.77742822e+02
#  -2.66505671e-01  9.63095067e-01 -3.77939704e-02  5.38443355e+02
#  -3.58373010e-02  2.92833300e-02  9.98928513e-01  4.68000000e+02].
# centroid_m: [826.66303359 469.03911999 485.77825423], centroid_f: [826.66303359 469.03911999 485.77825423]
# Set initial transform to [ 9.63169856e-01  2.67574548e-01  2.67105543e-02  9.77742822e+02
#  -2.66505671e-01  9.63095067e-01 -3.77939704e-02  5.38443355e+02
#  -3.58373010e-02  2.92833300e-02  9.98928513e-01  4.68000000e+02].
# centroid_m: [826.66303359 469.03911999 485.77825423], centroid_f: [826.66303359 469.03911999 485.77825423]
# 1: 30776 valid, 93500 out-of-bound voxels after transform.
# 2: 1109 valid, 71473 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score for 3: 3: No valid voxels after transform.
# 4: 36436 valid, 138567 out-of-bound voxels after transform.
#
# iteration 0
# 1: 30776 valid, 93500 out-of-bound voxels after transform.
# 2: 1109 valid, 71473 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 36436 valid, 138567 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.732051
# Norm of gradient (rotation) = 1.732051
# around x=-0.58; around y=0.57; around z=-0.58
# step: 0.05 seconds
# current score: -0.105844
# new_T: [ 0.9999      0.0099495   0.0100495   0.98996691 -0.0100495   0.9999
#   0.0099495  -1.00996642 -0.0099495  -0.0100495   0.9999     -0.99993333]
# det: 1.00
#
# iteration 1
# 1: 34297 valid, 89979 out-of-bound voxels after transform.
# 2: 2451 valid, 70131 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 41685 valid, 133318 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.409409
# Norm of gradient (rotation) = 1.397377
# around x=-1.05; around y=1.02; around z=-1.04
# step: 0.06 seconds
# current score: -0.101863
# new_T: [ 0.99967634  0.0178058   0.0181706   1.84903611 -0.01813388  0.99967256
#   0.01805368 -1.80646431 -0.01784319 -0.01837734  0.99967189 -1.78131151]
# det: 1.00
#
# iteration 2
# 1: 36274 valid, 88002 out-of-bound voxels after transform.
# 2: 3091 valid, 69491 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 44745 valid, 130258 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.150056
# Norm of gradient (rotation) = 1.143490
# around x=-1.45; around y=1.39; around z=-1.42
# step: 0.06 seconds
# current score: -0.099594
# new_T: [ 0.99939865  0.0241771   0.02485578  2.5413482  -0.02478987  0.99938879
#   0.02464788 -2.46525896 -0.02424467 -0.02524922  0.99938715 -2.41922139]
# det: 1.00
#
# iteration 3
# 1: 37814 valid, 86462 out-of-bound voxels after transform.
# 2: 3741 valid, 68841 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 46907 valid, 128096 out-of-bound voxels after transform.
# Norm of gradient (translation) = 1.015346
# Norm of gradient (rotation) = 0.865083
# around x=-1.63; around y=1.70; around z=-1.76
# step: 0.07 seconds
# current score: -0.097763
# new_T: [ 0.99908424  0.02994136  0.03056475  3.15929503 -0.03078361  0.99914857
#   0.02746813 -3.06452793 -0.02971629 -0.02838387  0.99915529 -2.95549531]
# det: 1.00
#
# iteration 4
# 1: 39069 valid, 85207 out-of-bound voxels after transform.
# 2: 4450 valid, 68132 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 48807 valid, 126196 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.908853
# Norm of gradient (rotation) = 0.946208
# around x=-1.99; around y=1.99; around z=-2.06
# step: 0.07 seconds
# current score: -0.096342
# new_T: [ 0.99874934  0.03478523  0.03591294  3.73785195 -0.03598802  0.99879369
#   0.03340693 -3.56108302 -0.03470755 -0.03465758  0.99879639 -3.4434737 ]
# det: 1.00
#
# iteration 5
# 1: 40291 valid, 83985 out-of-bound voxels after transform.
# 2: 5003 valid, 67579 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 50614 valid, 124389 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.742440
# Norm of gradient (rotation) = 0.717861
# around x=-2.22; around y=2.22; around z=-2.32
# step: 0.07 seconds
# current score: -0.094902
# new_T: [ 0.99843192  0.03887606  0.04027845  4.17434947 -0.04037887  0.99849193
#   0.03719425 -4.00109566 -0.03877174 -0.03876232  0.99849599 -3.85158671]
# det: 1.00
#
# iteration 6
# 1: 41264 valid, 83012 out-of-bound voxels after transform.
# 2: 5626 valid, 66956 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 52154 valid, 122849 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.723173
# Norm of gradient (rotation) = 0.826047
# around x=-2.58; around y=2.45; around z=-2.55
# step: 0.07 seconds
# current score: -0.093754
# new_T: [ 0.99809881  0.04251     0.04462819  4.66215834 -0.04443308  0.99808558
#   0.04302185 -4.36465231 -0.04271389 -0.04492303  0.99807687 -4.2295359 ]
# det: 1.00
#
# iteration 7
# 1: 42186 valid, 82090 out-of-bound voxels after transform.
# 2: 6156 valid, 66426 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 53511 valid, 121492 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.625421
# Norm of gradient (rotation) = 0.615891
# around x=-2.79; around y=2.64; around z=-2.76
# step: 0.06 seconds
# current score: -0.092681
# new_T: [ 0.99777592  0.04588801  0.04834773  5.04369761 -0.04813556  0.99776267
#   0.04639642 -4.72587327 -0.04611052 -0.04862047  0.99775241 -4.56604661]
# det: 1.00
#
# iteration 8
# 1: 42990 valid, 81286 out-of-bound voxels after transform.
# 2: 6617 valid, 65965 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 54643 valid, 120360 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.545233
# Norm of gradient (rotation) = 0.655710
# around x=-3.08; around y=2.82; around z=-2.94
# step: 0.06 seconds
# current score: -0.091729
# new_T: [ 0.9974781   0.04858948  0.05173488  5.39554014 -0.05123759  0.99737558
#   0.05115339 -5.00816509 -0.04911359 -0.05367516  0.9973499  -4.86307489]
# det: 1.00
#
# iteration 9
# 1: 43722 valid, 80554 out-of-bound voxels after transform.
# 2: 7060 valid, 65522 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 55704 valid, 119299 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.542981
# Norm of gradient (rotation) = 0.663901
# around x=-3.38; around y=2.98; around z=-3.11
# step: 0.06 seconds
# current score: -0.090855
# new_T: [ 0.99717152  0.0511204   0.05509681  5.78280523 -0.05420987  0.99695131
#   0.05611921 -5.24819305 -0.05206    -0.05894727  0.99690269 -5.13937985]
# det: 1.00
#
# iteration 10
# 1: 44387 valid, 79889 out-of-bound voxels after transform.
# 2: 7484 valid, 65098 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 56696 valid, 118307 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.497567
# Norm of gradient (rotation) = 0.592362
# around x=-3.65; around y=3.14; around z=-3.27
# step: 0.06 seconds
# current score: -0.090069
# new_T: [ 0.99687502  0.05343094  0.05818351  6.14457805 -0.05694151  0.99654576
#   0.06045001 -5.46019123 -0.05475263 -0.06357416  0.99647402 -5.38759768]
# det: 1.00
#
# iteration 11
# 1: 44984 valid, 79292 out-of-bound voxels after transform.
# 2: 7878 valid, 64704 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 57576 valid, 117427 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.436324
# Norm of gradient (rotation) = 0.549478
# around x=-3.91; around y=3.28; around z=-3.41
# step: 0.08 seconds
# current score: -0.089364
# new_T: [ 0.99660325  0.05537324  0.06095706  6.46300084 -0.0593007   0.99614601
#   0.0646263  -5.63406683 -0.05714356 -0.06802158  0.99604602 -5.61014888]
# det: 1.00
#
# iteration 12
# 1: 45540 valid, 78736 out-of-bound voxels after transform.
# 2: 8233 valid, 64349 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 58383 valid, 116620 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.411763
# Norm of gradient (rotation) = 0.539784
# around x=-4.17; around y=3.41; around z=-3.53
# step: 0.09 seconds
# current score: -0.088692
# new_T: [ 0.99634109  0.05708459  0.06360649  6.77407743 -0.06144589  0.99573207
#   0.0688625  -5.77229839 -0.05940404 -0.07251889  0.99559639 -5.81707089]
# det: 1.00
#
# iteration 13
# 1: 46019 valid, 78257 out-of-bound voxels after transform.
# 2: 8540 valid, 64042 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 59102 valid, 115901 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.387910
# Norm of gradient (rotation) = 0.523362
# around x=-4.42; around y=3.53; around z=-3.64
# step: 0.11 seconds
# current score: -0.088112
# new_T: [ 0.996093    0.05855132  0.06610965  7.07854683 -0.06335588  0.99531139
#   0.07308393 -5.8706839  -0.06152052 -0.07698683  0.99513228 -6.00576249]
# det: 1.00
#
# iteration 14
# 1: 46489 valid, 77787 out-of-bound voxels after transform.
# 2: 8849 valid, 63733 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 59773 valid, 115230 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.363704
# Norm of gradient (rotation) = 0.479937
# around x=-4.66; around y=3.64; around z=-3.74
# step: 0.11 seconds
# current score: -0.087556
# new_T: [ 0.9958565   0.05987653  0.06844434  7.37043153 -0.06510708  0.99490819
#   0.07693347 -5.9464044  -0.06348932 -0.0810709   0.99468418 -6.17670354]
# det: 1.00
#
# iteration 15
# 1: 46898 valid, 77378 out-of-bound voxels after transform.
# 2: 9138 valid, 63444 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 60356 valid, 114647 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.340131
# Norm of gradient (rotation) = 0.427955
# around x=-4.87; around y=3.75; around z=-3.84
# step: 0.08 seconds
# current score: -0.087061
# new_T: [ 0.99562792  0.06114282  0.07061588  7.64670612 -0.06676888  0.9945344
#   0.08026978 -6.01404395 -0.065322   -0.08463378  0.99426866 -6.33198395]
# det: 1.00
#
# iteration 16
# 1: 47261 valid, 77015 out-of-bound voxels after transform.
# 2: 9395 valid, 63187 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 60922 valid, 114081 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.326459
# Norm of gradient (rotation) = 0.410609
# around x=-5.06; around y=3.85; around z=-3.93
# step: 0.09 seconds
# current score: -0.086616
# new_T: [ 0.99540731  0.06229343  0.0726899   7.91637111 -0.06831315  0.99416356
#   0.08349923 -6.06105477 -0.0670642  -0.08808142  0.99385314 -6.47563639]
# det: 1.00
#
# iteration 17
# 1: 47599 valid, 76677 out-of-bound voxels after transform.
# 2: 9640 valid, 62942 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 61437 valid, 113566 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.318647
# Norm of gradient (rotation) = 0.405335
# around x=-5.27; around y=3.94; around z=-4.01
# step: 0.09 seconds
# current score: -0.086203
# new_T: [ 0.99519594  0.06329707  0.07468954  8.18345798 -0.06971906  0.99378633
#   0.08676395 -6.08029121 -0.06873354 -0.09155441  0.99342513 -6.60891727]
# det: 1.00
#
# iteration 18
# 1: 47919 valid, 76357 out-of-bound voxels after transform.
# 2: 9882 valid, 62700 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 61897 valid, 113106 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.306845
# Norm of gradient (rotation) = 0.377440
# around x=-5.45; around y=4.03; around z=-4.08
# step: 0.09 seconds
# current score: -0.085817
# new_T: [ 0.99499188  0.0642349   0.07658354  8.4439231  -0.07104393  0.99342462
#   0.0897791  -6.08585081 -0.07031302 -0.09477027  0.99301293 -6.72965405]
# det: 1.00
#
# iteration 19
# 1: 48210 valid, 76066 out-of-bound voxels after transform.
# 2: 10096 valid, 62486 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 62285 valid, 112718 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.295620
# Norm of gradient (rotation) = 0.347458
# around x=-5.62; around y=4.12; around z=-4.16
# step: 0.09 seconds
# current score: -0.085462
# new_T: [ 0.99479369  0.06513904  0.07837365  8.69816634 -0.07231497  0.99308268
#   0.0925059  -6.08245625 -0.07180577 -0.09769188  0.9926229  -6.83752128]
# det: 1.00
#
# iteration 20
# 1: 48462 valid, 75814 out-of-bound voxels after transform.
# 2: 10288 valid, 62294 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 62664 valid, 112339 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.283116
# Norm of gradient (rotation) = 0.324362
# around x=-5.78; around y=4.20; around z=-4.23
# step: 0.11 seconds
# current score: -0.085152
# new_T: [ 0.99460273  0.06599148  0.08006582  8.94315331 -0.07351897  0.99275579
#   0.09503105 -6.07034201 -0.07321457 -0.1004045   0.99224924 -6.93495512]
# det: 1.00
#
# iteration 21
# 1: 48669 valid, 75607 out-of-bound voxels after transform.
# 2: 10461 valid, 62121 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 62984 valid, 112019 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.270990
# Norm of gradient (rotation) = 0.305839
# around x=-5.93; around y=4.28; around z=-4.29
# step: 0.10 seconds
# current score: -0.084897
# new_T: [ 0.99441876  0.06679094  0.08167195  9.17809564 -0.07465789  0.99244078
#   0.09740374 -6.05100424 -0.07454888 -0.10295757  0.9918882  -7.02421146]
# det: 1.00
#
# iteration 22
# 1: 48864 valid, 75412 out-of-bound voxels after transform.
# 2: 10630 valid, 61952 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 63279 valid, 111724 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.257821
# Norm of gradient (rotation) = 0.280504
# around x=-6.06; around y=4.35; around z=-4.36
# step: 0.10 seconds
# current score: -0.084658
# new_T: [ 0.99423928  0.06758496  0.08318971  9.40325695 -0.07576979  0.99214641
#   0.09952107 -6.03212626 -0.07581025 -0.10525103  0.99155183 -7.10471628]
# det: 1.00
#
# iteration 23
# 1: 49040 valid, 75236 out-of-bound voxels after transform.
# 2: 10791 valid, 61791 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 63535 valid, 111468 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.251194
# Norm of gradient (rotation) = 0.256572
# around x=-6.18; around y=4.42; around z=-4.42
# step: 0.09 seconds
# current score: -0.084440
# new_T: [ 0.99405978  0.06841649  0.08464239  9.62569428 -0.07689648  0.99187372
#   0.10135804 -6.01515358 -0.07702    -0.10726465  0.99124276 -7.17522277]
# det: 1.00
#
# iteration 24
# 1: 49202 valid, 75074 out-of-bound voxels after transform.
# 2: 10931 valid, 61651 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 63745 valid, 111258 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.243864
# Norm of gradient (rotation) = 0.238331
# around x=-6.28; around y=4.48; around z=-4.49
# step: 0.09 seconds
# current score: -0.084240
# new_T: [ 0.99388444  0.06923881  0.08602156  9.84342118 -0.07799667  0.99161738
#   0.10301211 -5.99467693 -0.07816804 -0.10909153  0.99095348 -7.23589314]
# det: 1.00
#
# iteration 25
# 1: 49333 valid, 74943 out-of-bound voxels after transform.
# 2: 11055 valid, 61527 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 63931 valid, 111072 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.237772
# Norm of gradient (rotation) = 0.223059
# around x=-6.38; around y=4.55; around z=-4.55
# step: 0.10 seconds
# current score: -0.084078
# new_T: [ 0.99371102  0.07006711  0.08734425 10.05715485 -0.07908746  0.99137553
#   0.10449755 -5.97299446 -0.07926911 -0.1107482   0.99068221 -7.28851754]
# det: 1.00
#
# iteration 26
# 1: 49444 valid, 74832 out-of-bound voxels after transform.
# 2: 11165 valid, 61417 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 64090 valid, 110913 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.228400
# Norm of gradient (rotation) = 0.207052
# around x=-6.46; around y=4.61; around z=-4.61
# step: 0.09 seconds
# current score: -0.083939
# new_T: [ 0.9935397   0.07090599  0.08860705 10.26374851 -0.08017089  0.99115054
#   0.10579806 -5.95417333 -0.08032121 -0.11221827  0.99043201 -7.33461664]
# det: 1.00
#
# iteration 27
# 1: 49535 valid, 74741 out-of-bound voxels after transform.
# 2: 11265 valid, 61317 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 64217 valid, 110786 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.219224
# Norm of gradient (rotation) = 0.190982
# around x=-6.54; around y=4.66; around z=-4.68
# step: 0.11 seconds
# current score: -0.083826
# new_T: [ 0.99336879  0.0717762   0.08981438 10.463613   -0.08126467  0.9909452
#   0.10688157 -5.94163696 -0.08132958 -0.11347155  0.9902069  -7.37452191]
# det: 1.00
#
# iteration 28
# 1: 49608 valid, 74668 out-of-bound voxels after transform.
# 2: 11364 valid, 61218 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 64328 valid, 110675 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.213493
# Norm of gradient (rotation) = 0.178511
# around x=-6.60; around y=4.72; around z=-4.74
# step: 0.10 seconds
# current score: -0.083732
# new_T: [ 0.99319794  0.07267294  0.09097521 10.6595453  -0.08236693  0.99075668
#   0.10778168 -5.93253106 -0.08230149 -0.11454189  0.99000334 -7.40776547]
# det: 1.00
#
# iteration 29
# 1: 49675 valid, 74601 out-of-bound voxels after transform.
# 2: 11442 valid, 61140 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 64409 valid, 110594 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.211662
# Norm of gradient (rotation) = 0.170324
# around x=-6.66; around y=4.77; around z=-4.80
# step: 0.09 seconds
# current score: -0.083646
# new_T: [ 0.99302898  0.07356486  0.09209594 10.85436829 -0.08345376  0.99057796
#   0.10858531 -5.91945495 -0.08324015 -0.11551412  0.98981188 -7.43360542]
# det: 1.00
#
# iteration 30
# 1: 49713 valid, 74563 out-of-bound voxels after transform.
# 2: 11512 valid, 61070 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 64473 valid, 110530 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.208616
# Norm of gradient (rotation) = 0.162166
# around x=-6.71; around y=4.83; around z=-4.87
# step: 0.09 seconds
# current score: -0.083594
# new_T: [ 0.99286287  0.07444514  0.09317317 11.04660375 -0.08451824  0.99040903
#   0.10930062 -5.90273089 -0.08414265 -0.11639536  0.98963232 -7.4525838 ]
# det: 1.00
#
# iteration 31
# 1: 49741 valid, 74535 out-of-bound voxels after transform.
# 2: 11578 valid, 61004 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 64509 valid, 110494 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.206692
# Norm of gradient (rotation) = 0.155524
# around x=-6.75; around y=4.88; around z=-4.93
# step: 0.10 seconds
# current score: -0.083557
# new_T: [ 0.99269438  0.07536189  0.09422549 11.23776731 -0.08560456  0.99025364
#   0.10986172 -5.88898496 -0.08502775 -0.11712524  0.98947055 -7.46587769]
# det: 1.00
#
# iteration 32
# 1: 49755 valid, 74521 out-of-bound voxels after transform.
# 2: 11633 valid, 60949 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 64522 valid, 110481 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.201089
# Norm of gradient (rotation) = 0.147637
# around x=-6.79; around y=4.93; around z=-4.99
# step: 0.09 seconds
# current score: -0.092715
# new_T: [ 0.99252732  0.07628909  0.09523386 11.42415089 -0.08668516  0.99011291
#   0.11028196 -5.87773678 -0.08587897 -0.11771322  0.98932725 -7.47362724]
# det: 1.00
#
# iteration 33
# 1: 49751 valid, 74525 out-of-bound voxels after transform.
# 2: 11672 valid, 60910 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 64519 valid, 110484 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.197481
# Norm of gradient (rotation) = 0.142724
# around x=-6.81; around y=4.97; around z=-5.05
# step: 0.11 seconds
# current score: -0.092716
# new_T: [ 0.99235946  0.07724057  0.09621123 11.60747588 -0.08777492  0.98998578
#   0.11056096 -5.86987567 -0.08670796 -0.11816115  0.98920153 -7.47645035]
# det: 1.00
#
# iteration 34
# 1: 49741 valid, 74535 out-of-bound voxels after transform.
# 2: 11714 valid, 60868 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 64499 valid, 110504 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.194981
# Norm of gradient (rotation) = 0.138756
# around x=-6.83; around y=5.02; around z=-5.12
# step: 0.10 seconds
# current score: -0.092727
# new_T: [ 0.99219183  0.07820362  0.09715741 11.78840692 -0.08886326  0.98987009
#   0.11072722 -5.86277637 -0.08751395 -0.11849636  0.98909045 -7.47399438]
# det: 1.00
#
# iteration 35
# 1: 49719 valid, 74557 out-of-bound voxels after transform.
# 2: 11741 valid, 60841 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 64466 valid, 110537 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.194248
# Norm of gradient (rotation) = 0.137682
# around x=-6.84; around y=5.07; around z=-5.18
# step: 0.09 seconds
# current score: -0.092751
# new_T: [ 0.99202188  0.07919595  0.09808464 11.96852655 -0.08996781  0.98976581
#   0.11076745 -5.85798019 -0.08830849 -0.11870819  0.98899443 -7.46673081]
# det: 1.00
#
# iteration 36
# 1: 49686 valid, 74590 out-of-bound voxels after transform.
# 2: 11760 valid, 60822 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 64415 valid, 110588 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.193175
# Norm of gradient (rotation) = 0.136193
# around x=-6.85; around y=5.11; around z=-5.25
# step: 0.10 seconds
# current score: -0.092787
# new_T: [ 0.99185151  0.08019563  0.09899109 12.14723249 -0.09107027  0.98966947
#   0.11072731 -5.85266027 -0.08908861 -0.11884019  0.9889086  -7.45506983]
# det: 1.00
#
# iteration 37
# 1: 49637 valid, 74639 out-of-bound voxels after transform.
# 2: 11775 valid, 60807 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 64352 valid, 110651 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.190204
# Norm of gradient (rotation) = 0.135494
# around x=-6.85; around y=5.16; around z=-5.31
# step: 0.10 seconds
# current score: -0.092846
# new_T: [ 0.99168073  0.08121114  0.09987036 12.32284891 -0.09217467  0.98958497
#   0.11056858 -5.85020324 -0.08985081 -0.11885424  0.98883795 -7.43936575]
# det: 1.00
#
# iteration 38
# 1: 49587 valid, 74689 out-of-bound voxels after transform.
# 2: 11785 valid, 60797 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 64269 valid, 110734 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.188654
# Norm of gradient (rotation) = 0.136690
# around x=-6.85; around y=5.20; around z=-5.37
# step: 0.11 seconds
# current score: -0.092907
# new_T: [ 0.99150863  0.08224905  0.10072604 12.49648985 -0.09328717  0.98951235
#   0.11028512 -5.85052024 -0.09059882 -0.1187451   0.98878282 -7.41921834]
# det: 1.00
#
# iteration 39
# 1: 49522 valid, 74754 out-of-bound voxels after transform.
# 2: 11787 valid, 60795 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 64173 valid, 110830 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.188096
# Norm of gradient (rotation) = 0.135436
# around x=-6.84; around y=5.24; around z=-5.44
# step: 0.07 seconds
# current score: -0.092986
# new_T: [ 0.99133742  0.08327902  0.10156139 12.66883253 -0.09438511  0.98944461
#   0.10995826 -5.84796401 -0.09133215 -0.11859162  0.98873377 -7.3949236 ]
# det: 1.00
#
# iteration 40
# 1: 49445 valid, 74831 out-of-bound voxels after transform.
# 2: 11779 valid, 60803 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 64060 valid, 110943 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.186063
# Norm of gradient (rotation) = 0.135841
# around x=-6.83; around y=5.28; around z=-5.50
# step: 0.06 seconds
# current score: -0.093078
# new_T: [ 0.99116625  0.08431314  0.10237556 12.83864084 -0.09547749  0.9893843
#   0.1095571  -5.84614623 -0.09205167 -0.11836387  0.98869433 -7.36735336]
# det: 1.00
#
# iteration 41
# 1: 49362 valid, 74914 out-of-bound voxels after transform.
# 2: 11772 valid, 60810 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 63932 valid, 111071 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.184642
# Norm of gradient (rotation) = 0.139044
# around x=-6.81; around y=5.32; around z=-5.57
# step: 0.07 seconds
# current score: -0.093177
# new_T: [ 0.99099293  0.08536858  0.10317571 13.00653149 -0.09657988  0.98933251
#   0.10905734 -5.84754256 -0.09276502 -0.11803975  0.98866641 -7.33700095]
# det: 1.00
#
# iteration 42
# 1: 49275 valid, 75001 out-of-bound voxels after transform.
# 2: 11758 valid, 60824 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 63811 valid, 111192 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.183506
# Norm of gradient (rotation) = 0.144677
# around x=-6.78; around y=5.36; around z=-5.63
# step: 0.11 seconds
# current score: -0.093283
# new_T: [ 0.99081644  0.08645628  0.103962   13.17260291 -0.09770035  0.98929139
#   0.10843052 -5.85408997 -0.09347421 -0.11759187  0.98865298 -7.30375088]
# det: 1.00
#
# iteration 43
# 1: 49176 valid, 75100 out-of-bound voxels after transform.
# 2: 11738 valid, 60844 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 63664 valid, 111339 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.183166
# Norm of gradient (rotation) = 0.147748
# around x=-6.75; around y=5.40; around z=-5.70
# step: 0.11 seconds
# current score: -0.093402
# new_T: [ 0.990638    0.08755698  0.10473838 13.33758131 -0.09882519  0.98925592
#   0.10773254 -5.86186365 -0.09418033 -0.11707474  0.98864734 -7.26783649]
# det: 1.00
#
# iteration 44
# 1: 49075 valid, 75201 out-of-bound voxels after transform.
# 2: 11719 valid, 60863 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 63513 valid, 111490 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.181331
# Norm of gradient (rotation) = 0.150958
# around x=-6.72; around y=5.44; around z=-5.76
# step: 0.09 seconds
# current score: -0.093524
# new_T: [ 0.99045873  0.08866704  0.1054972  13.50000077 -0.09994866  0.98922776
#   0.10695189 -5.87216242 -0.09487765 -0.11647574  0.98865142 -7.22947096]
# det: 1.00
#
# iteration 45
# 1: 48964 valid, 75312 out-of-bound voxels after transform.
# 2: 11694 valid, 60888 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 63344 valid, 111659 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.180167
# Norm of gradient (rotation) = 0.152121
# around x=-6.68; around y=5.48; around z=-5.83
# step: 0.12 seconds
# current score: -0.093657
# new_T: [ 0.99027943  0.08977478  0.10624097 13.66053993 -0.10106278  0.98920358
#   0.10612535 -5.8821759  -0.09556657 -0.11583076  0.98866084 -7.18863852]
# det: 1.00
#
# iteration 46
# 1: 48857 valid, 75419 out-of-bound voxels after transform.
# 2: 11670 valid, 60912 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 63164 valid, 111839 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.180013
# Norm of gradient (rotation) = 0.151893
# around x=-6.64; around y=5.52; around z=-5.89
# step: 0.10 seconds
# current score: -0.093788
# new_T: [ 0.99010042  0.09087379  0.10697249 13.82011524 -0.10216386  0.98918101
#   0.10527804 -5.88955603 -0.09624814 -0.11516456  0.98867255 -7.14502857]
# det: 1.00
#
# iteration 47
# 1: 48733 valid, 75543 out-of-bound voxels after transform.
# 2: 11631 valid, 60951 out-of-bound voxels after transform.
# 3: 2 valid, 9175 out-of-bound voxels after transform.
# 4: 62970 valid, 112033 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.179803
# Norm of gradient (rotation) = 0.156340
# around x=-6.60; around y=5.56; around z=-5.96
# step: 0.10 seconds
# current score: -0.093939
# new_T: [ 0.9899174   0.09199409  0.10770617 13.97892283 -0.10327981  0.98916115
#   0.10437197 -5.89981876 -0.09693716 -0.11444351  0.98868897 -7.10046832]
# det: 1.00
#
# iteration 48
# 1: 48615 valid, 75661 out-of-bound voxels after transform.
# 2: 11601 valid, 60981 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 62785 valid, 112218 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.179664
# Norm of gradient (rotation) = 0.160847
# around x=-6.56; around y=5.60; around z=-6.02
# step: 0.11 seconds
# current score: -0.094087
# new_T: [ 0.98973146  0.09313201  0.10843462 14.13675473 -0.104405    0.98914542
#   0.103397   -5.91254486 -0.09762804 -0.11365638  0.98871178 -7.05407691]
# det: 1.00
#
# iteration 49
# 1: 48489 valid, 75787 out-of-bound voxels after transform.
# 2: 11562 valid, 61020 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 62567 valid, 112436 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.179436
# Norm of gradient (rotation) = 0.164394
# around x=-6.51; around y=5.64; around z=-6.09
# step: 0.10 seconds
# current score: -0.094240
# new_T: [ 0.98954217  0.09428452  0.10916371 14.2937536  -0.10553907  0.98913142
#   0.10237453 -5.92732224 -0.09832492 -0.11282495  0.98873795 -7.00671334]
# det: 1.00
#
# iteration 50
# 1: 48349 valid, 75927 out-of-bound voxels after transform.
# 2: 11522 valid, 61060 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 62356 valid, 112647 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.179102
# Norm of gradient (rotation) = 0.166765
# around x=-6.46; around y=5.68; around z=-6.15
# step: 0.11 seconds
# current score: -0.094407
# new_T: [ 0.98935051  0.09544421  0.10989076 14.44980826 -0.10667535  0.98911853
#   0.10131587 -5.94298691 -0.09902498 -0.11195954  0.98876646 -6.95815482]
# det: 1.00
#
# iteration 51
# 1: 48214 valid, 76062 out-of-bound voxels after transform.
# 2: 11485 valid, 61097 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 62143 valid, 112860 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.178251
# Norm of gradient (rotation) = 0.164114
# around x=-6.41; around y=5.72; around z=-6.22
# step: 0.09 seconds
# current score: -0.094570
# new_T: [ 0.98915866  0.09658722  0.11061672 14.60484413 -0.10779636  0.98910217
#   0.10028384 -5.95529827 -0.0997251  -0.11112071  0.98879072 -6.90887905]
# det: 1.00
#
# iteration 52
# 1: 48075 valid, 76201 out-of-bound voxels after transform.
# 2: 11443 valid, 61139 out-of-bound voxels after transform.
# 3: 1 valid, 9176 out-of-bound voxels after transform.
# 4: 61923 valid, 113080 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.177547
# Norm of gradient (rotation) = 0.162410
# around x=-6.36; around y=5.76; around z=-6.28
# step: 0.11 seconds
# current score: -0.094736
# new_T: [ 0.98896629  0.09771809  0.11134112 14.75887165 -0.10890542  0.98908329
#   0.09926658 -5.96499896 -0.1004255  -0.11029695  0.98881207 -6.85877885]
# det: 1.00
#
# iteration 53
# 1: 47937 valid, 76339 out-of-bound voxels after transform.
# 2: 11402 valid, 61180 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 61696 valid, 113307 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.177197
# Norm of gradient (rotation) = 0.161489
# around x=-6.32; around y=5.80; around z=-6.35
# step: 0.08 seconds
# current score: -0.085725
# new_T: [ 0.98877193  0.09884376  0.11207131 14.91236048 -0.11001033  0.98906111
#   0.09826422 -5.97286323 -0.10113257 -0.1094899   0.98882969 -6.80848751]
# det: 1.00
#
# iteration 54
# 1: 47797 valid, 76479 out-of-bound voxels after transform.
# 2: 11360 valid, 61222 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 61479 valid, 113524 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.175762
# Norm of gradient (rotation) = 0.161503
# around x=-6.27; around y=5.85; around z=-6.41
# step: 0.12 seconds
# current score: -0.085895
# new_T: [ 0.98857618  0.0999662   0.11280028 15.06423302 -0.11111019  0.98903778
#   0.09725632 -5.9806925  -0.10184139 -0.10867854  0.98884645 -6.75805203]
# det: 1.00
#
# iteration 55
# 1: 47654 valid, 76622 out-of-bound voxels after transform.
# 2: 11320 valid, 61262 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 61262 valid, 113741 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.174088
# Norm of gradient (rotation) = 0.165071
# around x=-6.22; around y=5.89; around z=-6.48
# step: 0.09 seconds
# current score: -0.086066
# new_T: [ 0.98837773  0.1011013   0.11352527 15.21409822 -0.11221573  0.98901669
#   0.09619575 -5.99227476 -0.10255287 -0.10781706  0.98886723 -6.70739023]
# det: 1.00
#
# iteration 56
# 1: 47508 valid, 76768 out-of-bound voxels after transform.
# 2: 11286 valid, 61296 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 61050 valid, 113953 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.172400
# Norm of gradient (rotation) = 0.166716
# around x=-6.17; around y=5.93; around z=-6.54
# step: 0.11 seconds
# current score: -0.086243
# new_T: [ 0.98817525  0.10224582  0.11426055 15.36250516 -0.11332949  0.98899331
#   0.09512443 -6.00667805 -0.10327685 -0.1069487   0.98888618 -6.65826311]
# det: 1.00
#
# iteration 57
# 1: 47372 valid, 76904 out-of-bound voxels after transform.
# 2: 11242 valid, 61340 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 60831 valid, 114172 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.170948
# Norm of gradient (rotation) = 0.165519
# around x=-6.12; around y=5.97; around z=-6.61
# step: 0.08 seconds
# current score: -0.086403
# new_T: [ 0.98797263  0.10337937  0.11499035 15.50924852 -0.11443091  0.98896856
#   0.09405714 -6.01996533 -0.10399827 -0.10608433  0.98890367 -6.60864775]
# det: 1.00
#
# iteration 58
# 1: 47240 valid, 77036 out-of-bound voxels after transform.
# 2: 11200 valid, 61382 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 60629 valid, 114374 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.169235
# Norm of gradient (rotation) = 0.162637
# around x=-6.08; around y=6.01; around z=-6.67
# step: 0.09 seconds
# current score: -0.086564
# new_T: [ 0.98776982  0.10449653  0.11572062 15.65442808 -0.1155182   0.98894004
#   0.09302221 -6.03113238 -0.10472026 -0.10525237  0.98891638 -6.55948055]
# det: 1.00
#
# iteration 59
# 1: 47093 valid, 77183 out-of-bound voxels after transform.
# 2: 11164 valid, 61418 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 60411 valid, 114592 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.166884
# Norm of gradient (rotation) = 0.157678
# around x=-6.03; around y=6.05; around z=-6.73
# step: 0.11 seconds
# current score: -0.086732
# new_T: [ 0.98756973  0.10558209  0.11644072 15.79724344 -0.11657629  0.98890861
#   0.09203118 -6.03822376 -0.10543238 -0.10446143  0.98892458 -6.5101043 ]
# det: 1.00
#
# iteration 60
# 1: 46947 valid, 77329 out-of-bound voxels after transform.
# 2: 11133 valid, 61449 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 60189 valid, 114814 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.165297
# Norm of gradient (rotation) = 0.158535
# around x=-5.98; around y=6.09; around z=-6.79
# step: 0.10 seconds
# current score: -0.086909
# new_T: [ 0.98736646  0.1066723   0.11716863 15.93874908 -0.11763833  0.98887493
#   0.09103619 -6.04720185 -0.10615408 -0.1036696   0.9889307  -6.46199813]
# det: 1.00
#
# iteration 61
# 1: 46814 valid, 77462 out-of-bound voxels after transform.
# 2: 11091 valid, 61491 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 59998 valid, 115005 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.163486
# Norm of gradient (rotation) = 0.153536
# around x=-5.94; around y=6.14; around z=-6.86
# step: 0.10 seconds
# current score: -0.087067
# new_T: [ 0.98716354  0.10773748  0.11790161 16.07883353 -0.11868195  0.98883525
#   0.09010798 -6.05221421 -0.10687726 -0.10294411  0.98892859 -6.41515541]
# det: 1.00
#
# iteration 62
# 1: 46685 valid, 77591 out-of-bound voxels after transform.
# 2: 11054 valid, 61528 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 59789 valid, 115214 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.163530
# Norm of gradient (rotation) = 0.154375
# around x=-5.90; around y=6.18; around z=-6.92
# step: 0.11 seconds
# current score: -0.087222
# new_T: [ 0.98695745  0.10880712  0.11864233 16.21879156 -0.11972941  0.98879345
#   0.08917613 -6.05709524 -0.10760976 -0.10221803  0.98892447 -6.36833202]
# det: 1.00
#
# iteration 63
# 1: 46547 valid, 77729 out-of-bound voxels after transform.
# 2: 11020 valid, 61562 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 59580 valid, 115423 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.159578
# Norm of gradient (rotation) = 0.152322
# around x=-5.86; around y=6.22; around z=-6.98
# step: 0.09 seconds
# current score: -0.087386
# new_T: [ 0.98675151  0.10986276  0.11938016 16.35550365 -0.12076356  0.98874961
#   0.08826311 -6.06325802 -0.10834026 -0.10151054  0.98891759 -6.32355962]
# det: 1.00
#
# iteration 64
# 1: 46414 valid, 77862 out-of-bound voxels after transform.
# 2: 10985 valid, 61597 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 59384 valid, 115619 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.159705
# Norm of gradient (rotation) = 0.153355
# around x=-5.82; around y=6.26; around z=-7.04
# step: 0.10 seconds
# current score: -0.087542
# new_T: [ 0.98654047  0.11092829  0.12013665 16.49256391 -0.12180962  0.98870148
#   0.08736015 -6.06992518 -0.10908857 -0.10081813  0.98890616 -6.28005135]
# det: 1.00
#
# iteration 65
# 1: 46293 valid, 77983 out-of-bound voxels after transform.
# 2: 10952 valid, 61630 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 59181 valid, 115822 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.158162
# Norm of gradient (rotation) = 0.151975
# around x=-5.78; around y=6.31; around z=-7.10
# step: 0.08 seconds
# current score: -0.087688
# new_T: [ 0.98632813  0.11198567  0.12089677 16.62830648 -0.12284909  0.98865048
#   0.08647732 -6.07598825 -0.10984043 -0.10014707  0.98889112 -6.23748285]
# det: 1.00
#
# iteration 66
# 1: 46169 valid, 78107 out-of-bound voxels after transform.
# 2: 10928 valid, 61654 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 58971 valid, 116032 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.156267
# Norm of gradient (rotation) = 0.151138
# around x=-5.74; around y=6.35; around z=-7.16
# step: 0.10 seconds
# current score: -0.087833
# new_T: [ 0.98611467  0.11303658  0.12165765 16.76239246 -0.12388213  0.98859764
#   0.08560325 -6.08239779 -0.11059416 -0.09948582  0.98887386 -6.19581611]
# det: 1.00
#
# iteration 67
# 1: 46048 valid, 78228 out-of-bound voxels after transform.
# 2: 10901 valid, 61681 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 58778 valid, 116225 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.155285
# Norm of gradient (rotation) = 0.147171
# around x=-5.71; around y=6.39; around z=-7.22
# step: 0.11 seconds
# current score: -0.087978
# new_T: [ 0.98590035  0.11406805  0.12242949 16.89580978 -0.12490338  0.98853866
#   0.08479661 -6.08494028 -0.1113537  -0.09889286  0.98884809 -6.15565431]
# det: 1.00
#
# iteration 68
# 1: 45933 valid, 78343 out-of-bound voxels after transform.
# 2: 10875 valid, 61707 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 58605 valid, 116398 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.154136
# Norm of gradient (rotation) = 0.145798
# around x=-5.68; around y=6.44; around z=-7.28
# step: 0.10 seconds
# current score: -0.088112
# new_T: [ 0.9856852   0.11509029  0.12320275 17.02811305 -0.12591663  0.98847746
#   0.08400786 -6.08633808 -0.11211465 -0.09831858  0.98881938 -6.11597024]
# det: 1.00
#
# iteration 69
# 1: 45809 valid, 78467 out-of-bound voxels after transform.
# 2: 10853 valid, 61729 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 58407 valid, 116596 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.152327
# Norm of gradient (rotation) = 0.142528
# around x=-5.65; around y=6.48; around z=-7.34
# step: 0.11 seconds
# current score: -0.088259
# new_T: [ 0.98546973  0.11609422  0.12398205 17.15897404 -0.12691732  0.9884117
#   0.08327248 -6.08536326 -0.11287785 -0.09779798  0.98878418 -6.07798006]
# det: 1.00
#
# iteration 70
# 1: 45700 valid, 78576 out-of-bound voxels after transform.
# 2: 10836 valid, 61746 out-of-bound voxels after transform.
# 3: 0 valid, 9177 out-of-bound voxels after transform.
# Error computing score/gradient for 3: 3: No valid voxels after transform.
# 4: 58223 valid, 116780 out-of-bound voxels after transform.
# ...
# 2: 34104 valid, 38478 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69304 valid, 105699 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000616
# Norm of gradient (rotation) = 0.003486
# around x=-12.56; around y=20.77; around z=-24.19
# step: 0.12 seconds
# current score: -0.082001
# new_T: [  0.8529434    0.32958521   0.40479765  43.79179574  -0.38312348
#    0.92196041   0.05661625  -3.40415603  -0.35454753  -0.20337795
#    0.91265188 -12.22361174]
# det: 1.00
#
# iteration 976
# 1: 52471 valid, 71805 out-of-bound voxels after transform.
# 2: 34101 valid, 38481 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69301 valid, 105702 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.002051
# Norm of gradient (rotation) = 0.004811
# around x=-12.56; around y=20.77; around z=-24.19
# step: 0.12 seconds
# current score: -0.082000
# new_T: [  0.85294736   0.32957922   0.4047942   43.79144163  -0.38310049
#    0.92197244   0.05657589  -3.40518793  -0.35456286  -0.20333311
#    0.91265592 -12.2241829 ]
# det: 1.00
#
# iteration 977
# 1: 52471 valid, 71805 out-of-bound voxels after transform.
# 2: 34097 valid, 38485 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69301 valid, 105702 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001555
# Norm of gradient (rotation) = 0.004436
# around x=-12.56; around y=20.77; around z=-24.19
# step: 0.11 seconds
# current score: -0.082000
# new_T: [  0.8529518    0.3295721    0.40479065  43.791092    -0.38307787
#    0.92198406   0.05653969  -3.40568313  -0.35457662  -0.20329197
#    0.91265974 -12.22472301]
# det: 1.00
#
# iteration 978
# 1: 52472 valid, 71804 out-of-bound voxels after transform.
# 2: 34097 valid, 38485 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69301 valid, 105702 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.002067
# Norm of gradient (rotation) = 0.005373
# around x=-12.55; around y=20.77; around z=-24.18
# step: 0.12 seconds
# current score: -0.081999
# new_T: [  0.85295607   0.32956658   0.40478613  43.79075739  -0.38305309
#    0.92199715   0.05649407  -3.40675339  -0.3545931   -0.20324154
#    0.91266457 -12.22468973]
# det: 1.00
#
# iteration 979
# 1: 52465 valid, 71811 out-of-bound voxels after transform.
# 2: 34097 valid, 38485 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69296 valid, 105707 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000390
# Norm of gradient (rotation) = 0.003939
# around x=-12.55; around y=20.77; around z=-24.18
# step: 0.12 seconds
# current score: -0.082007
# new_T: [  0.8529619    0.3295571    0.40478156  43.79047513  -0.38303022
#    0.92200847   0.05646438  -3.40576993  -0.35460379  -0.20320553
#    0.91266843 -12.22451986]
# det: 1.00
#
# iteration 980
# 1: 52462 valid, 71814 out-of-bound voxels after transform.
# 2: 34097 valid, 38485 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69290 valid, 105713 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000295
# Norm of gradient (rotation) = 0.003885
# around x=-12.55; around y=20.77; around z=-24.18
# step: 0.13 seconds
# current score: -0.082011
# new_T: [  0.85296698   0.32954844   0.40477791  43.79026013  -0.38300832
#    0.92201941   0.05643439  -3.40489054  -0.35461522  -0.20316998
#    0.9126719  -12.22445633]
# det: 1.00
#
# iteration 981
# 1: 52461 valid, 71815 out-of-bound voxels after transform.
# 2: 34097 valid, 38485 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69285 valid, 105718 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000814
# Norm of gradient (rotation) = 0.004380
# around x=-12.55; around y=20.77; around z=-24.18
# step: 0.12 seconds
# current score: -0.082012
# new_T: [  0.85297139   0.32954131   0.40477442  43.79003652  -0.38298591
#    0.9220309    0.05639871  -3.40475605  -0.35462882  -0.20312939
#    0.91267566 -12.22445062]
# det: 1.00
#
# iteration 982
# 1: 52458 valid, 71818 out-of-bound voxels after transform.
# 2: 34095 valid, 38487 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69282 valid, 105721 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000935
# Norm of gradient (rotation) = 0.004457
# around x=-12.54; around y=20.77; around z=-24.18
# step: 0.12 seconds
# current score: -0.082016
# new_T: [  0.85297572   0.32953439   0.40477093  43.78980629  -0.38296339
#    0.92204248   0.05636218  -3.4047472   -0.35464271  -0.20308802
#    0.91267946 -12.22446509]
# det: 1.00
#
# iteration 983
# 1: 52455 valid, 71821 out-of-bound voxels after transform.
# 2: 34092 valid, 38490 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69279 valid, 105724 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000883
# Norm of gradient (rotation) = 0.004318
# around x=-12.54; around y=20.77; around z=-24.18
# step: 0.12 seconds
# current score: -0.082019
# new_T: [  0.85297964   0.32952773   0.40476809  43.78961311  -0.38294171
#    0.92205366   0.05632665  -3.40472568  -0.35465671  -0.20304807
#    0.91268291 -12.22461191]
# det: 1.00
#
# iteration 984
# 1: 52452 valid, 71824 out-of-bound voxels after transform.
# 2: 34090 valid, 38492 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69275 valid, 105728 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000479
# Norm of gradient (rotation) = 0.003963
# around x=-12.54; around y=20.77; around z=-24.18
# step: 0.12 seconds
# current score: -0.082023
# new_T: [  0.85298359   0.32952049   0.40476565  43.78945742  -0.38292089
#    0.92206426   0.05629471  -3.40429229  -0.35466968  -0.20301169
#    0.91268597 -12.22479618]
# det: 1.00
#
# iteration 985
# 1: 52450 valid, 71826 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69273 valid, 105730 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000740
# Norm of gradient (rotation) = 0.004093
# around x=-12.54; around y=20.77; around z=-24.17
# step: 0.11 seconds
# current score: -0.082025
# new_T: [  0.85298769   0.3295133    0.40476288  43.78925254  -0.38289958
#    0.92207513   0.0562616   -3.40409195  -0.35468284  -0.20297399
#    0.91268924 -12.22504565]
# det: 1.00
#
# iteration 986
# 1: 52448 valid, 71828 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69270 valid, 105733 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000759
# Norm of gradient (rotation) = 0.004122
# around x=-12.54; around y=20.77; around z=-24.17
# step: 0.11 seconds
# current score: -0.082028
# new_T: [  0.85299169   0.32950624   0.40476018  43.78905611  -0.38287829
#    0.92208601   0.05622811  -3.40392429  -0.35469619  -0.202936
#    0.9126925  -12.22528381]
# det: 1.00
#
# iteration 987
# 1: 52445 valid, 71831 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69265 valid, 105738 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000548
# Norm of gradient (rotation) = 0.004041
# around x=-12.53; around y=20.78; around z=-24.17
# step: 0.11 seconds
# current score: -0.082031
# new_T: [  0.8529956    0.3294992    0.40475769  43.78889986  -0.38285733
#    0.92209671   0.05619533  -3.40357563  -0.35470942  -0.20289882
#    0.91269562 -12.22544168]
# det: 1.00
#
# iteration 988
# 1: 52443 valid, 71833 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69257 valid, 105746 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000362
# Norm of gradient (rotation) = 0.003818
# around x=-12.53; around y=20.78; around z=-24.17
# step: 0.12 seconds
# current score: -0.082034
# new_T: [  0.85299936   0.32949197   0.40475565  43.78877581  -0.38283711
#    0.92210698   0.05616466  -3.40302521  -0.35472221  -0.20286391
#    0.91269841 -12.22566968]
# det: 1.00
#
# iteration 989
# 1: 52440 valid, 71836 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69252 valid, 105751 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000430
# Norm of gradient (rotation) = 0.003871
# around x=-12.53; around y=20.78; around z=-24.17
# step: 0.12 seconds
# current score: -0.082037
# new_T: [  0.85300304   0.32948492   0.40475363  43.7886505   -0.38281685
#    0.92211729   0.05613338  -3.40255913  -0.35473522  -0.20282846
#    0.91270123 -12.22590624]
# det: 1.00
#
# iteration 990
# 1: 52434 valid, 71842 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69242 valid, 105761 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000511
# Norm of gradient (rotation) = 0.003890
# around x=-12.53; around y=20.78; around z=-24.17
# step: 0.11 seconds
# current score: -0.082044
# new_T: [  0.85300662   0.32947801   0.40475171  43.78852347  -0.38279665
#    0.9221276    0.05610181  -3.40217473  -0.35474841  -0.20279282
#    0.91270402 -12.22619086]
# det: 1.00
#
# iteration 991
# 1: 52430 valid, 71846 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69234 valid, 105769 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000838
# Norm of gradient (rotation) = 0.004073
# around x=-12.52; around y=20.78; around z=-24.17
# step: 0.12 seconds
# current score: -0.082048
# new_T: [  0.85300978   0.32947185   0.40475007  43.78839813  -0.38277646
#    0.92213803   0.05606804  -3.40214161  -0.35476259  -0.20275539
#    0.91270683 -12.22657092]
# det: 1.00
#
# iteration 992
# 1: 52429 valid, 71847 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69231 valid, 105772 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001081
# Norm of gradient (rotation) = 0.004227
# around x=-12.52; around y=20.78; around z=-24.17
# step: 0.11 seconds
# current score: -0.082049
# new_T: [  0.85301278   0.32946609   0.40474843  43.78826062  -0.38275607
#    0.92214865   0.0560326   -3.40235475  -0.35477738  -0.20271644
#    0.91270973 -12.22699307]
# det: 1.00
#
# iteration 993
# 1: 52430 valid, 71846 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69233 valid, 105770 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001429
# Norm of gradient (rotation) = 0.004576
# around x=-12.52; around y=20.78; around z=-24.17
# step: 0.12 seconds
# current score: -0.082048
# new_T: [  0.85301598   0.32946063   0.40474613  43.78807152  -0.38273456
#    0.92215993   0.05599387  -3.40290298  -0.35479288  -0.202674
#    0.91271313 -12.22733039]
# det: 1.00
#
# iteration 994
# 1: 52431 valid, 71845 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69235 valid, 105768 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001541
# Norm of gradient (rotation) = 0.004746
# around x=-12.52; around y=20.78; around z=-24.16
# step: 0.11 seconds
# current score: -0.082047
# new_T: [  0.85301913   0.32945548   0.40474369  43.78788473  -0.38271269
#    0.92217147   0.05595343  -3.40357194  -0.35480891  -0.20262989
#    0.91271669 -12.22758284]
# det: 1.00
#
# iteration 995
# 1: 52433 valid, 71843 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69245 valid, 105758 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001634
# Norm of gradient (rotation) = 0.004972
# around x=-12.51; around y=20.78; around z=-24.16
# step: 0.12 seconds
# current score: -0.082045
# new_T: [  0.85302228   0.32945066   0.40474097  43.78770662  -0.38269024
#    0.92218337   0.05591078  -3.40433262  -0.35482555  -0.20258356
#    0.91272051 -12.22765435]
# det: 1.00
#
# iteration 996
# 1: 52439 valid, 71837 out-of-bound voxels after transform.
# 2: 34089 valid, 38493 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69254 valid, 105749 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001796
# Norm of gradient (rotation) = 0.005178
# around x=-12.51; around y=20.78; around z=-24.16
# step: 0.12 seconds
# current score: -0.082039
# new_T: [  0.85302531   0.32944628   0.40473815  43.78753528  -0.38266743
#    0.92219555   0.05586601  -3.40524926  -0.35484287  -0.20253522
#    0.9127245  -12.22763089]
# det: 1.00
#
# iteration 997
# 1: 52443 valid, 71833 out-of-bound voxels after transform.
# 2: 34095 valid, 38487 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69257 valid, 105746 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.001580
# Norm of gradient (rotation) = 0.005040
# around x=-12.51; around y=20.78; around z=-24.16
# step: 0.12 seconds
# current score: -0.082034
# new_T: [  0.85302851   0.32944151   0.40473528  43.78737158  -0.38264475
#    0.92220758   0.05582272  -3.40594569  -0.35485963  -0.2024882
#    0.91272842 -12.22756559]
# det: 1.00
#
# iteration 998
# 1: 52447 valid, 71829 out-of-bound voxels after transform.
# 2: 34102 valid, 38480 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69263 valid, 105740 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000931
# Norm of gradient (rotation) = 0.004609
# around x=-12.51; around y=20.79; around z=-24.16
# step: 0.11 seconds
# current score: -0.082029
# new_T: [  0.85303234   0.32943538   0.40473221  43.7872215   -0.38262242
#    0.92221917   0.05578422  -3.40595394  -0.35487451  -0.20244535
#    0.91273214 -12.22738144]
# det: 1.00
#
# iteration 999
# 1: 52448 valid, 71828 out-of-bound voxels after transform.
# 2: 34110 valid, 38472 out-of-bound voxels after transform.
# 3: 4857 valid, 4320 out-of-bound voxels after transform.
# 4: 69266 valid, 105737 out-of-bound voxels after transform.
# Norm of gradient (translation) = 0.000592
# Norm of gradient (rotation) = 0.004315
# around x=-12.50; around y=20.79; around z=-24.16
# step: 0.11 seconds
# current score: -0.082028
# new_T: [  0.85303656   0.32942836   0.40472903  43.78706289  -0.38260037
#    0.92223045   0.055749    -3.40559408  -0.35488813  -0.20240541
#    0.9127357  -12.22721691]
# det: 1.00
# Optimize: 111.09 seconds.
# [[ 7.19320179e-01  5.57373512e-01  4.14630037e-01  1.01499503e+03]
#  [-6.16286683e-01  7.87453993e-01  1.06150523e-02  4.70845922e+02]
#  [-3.20585341e-01 -2.63166746e-01  9.09928165e-01  3.89659974e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# /home/alexn/brainDev/src/utilities/registration_utilities.py:1571: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(volume_m_aligned_to_f.dtype, np.float):
# Interpolating/filling sparse volume: 0.05 seconds.
# Interpolating/filling sparse volume: 0.03 seconds.
# Interpolating/filling sparse volume: 0.05 seconds.
# Interpolating/filling sparse volume: 0.04 seconds.
# Interpolating/filling sparse volume: 0.01 seconds.
# Interpolating/filling sparse volume: 0.00 seconds.
# Interpolating/filling sparse volume: 0.02 seconds.
# Interpolating/filling sparse volume: 0.02 seconds.

# %% [markdown]
# # Visualization
#
# relies on `demo_visualization_per_structure_alignment_spec.json` which was copied from Yuncong's repo. No idea how to actually generate it...
#
# - python visualize_registration_demo_3_structures.py

# %%
# FIRST we need to generate intensity volume data
! python ../src/reconstruct/construct_intensity_volume.py DEMO998 \
--tb_version NtbNormalizedAdaptiveInvertedGamma --tb_resol thumbnail --output_resol 10.0um
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'DEMO998': 0.46}
# No vtk
# No mcubes
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_NtbNormalizedAdaptiveInvertedGamma/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_NtbNormalizedAdaptiveInvertedGamma.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep5_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedWithMargin
# Cannot load mask DEMO998, section=225, fn=None, prep=alignedWithMargin
# Try finding prep1 masks.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F81-2017.06.06-12.44.40_MD661_2_0242_prep1_thumbnail_mask.png
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_NtbNormalizedAdaptiveInvertedGamma/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_NtbNormalizedAdaptiveInvertedGamma.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep5_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedWithMargin
# Cannot load mask DEMO998, section=230, fn=None, prep=alignedWithMargin
# Try finding prep1 masks.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep1_thumbnail_mask.png
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_NtbNormalizedAdaptiveInvertedGamma/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_NtbNormalizedAdaptiveInvertedGamma.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png
# File not on local disk. Download from S3.
# File /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep5_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep5_thumbnail_mask.png does not exists. Give up loading.
# Image fails to load. Trying to convert from other resol/versions.
# Resolution thumbnail is not available. Try to load raw and then downscale.
# Cannot load raw.
# prep_id = alignedWithMargin
# Cannot load mask DEMO998, section=235, fn=None, prep=alignedWithMargin
# Try finding prep1 masks.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep1_thumbnail_mask/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep1_thumbnail_mask.png
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/alexn/brainDev/mousebrainatlas_virtualenv/local/lib/python2.7/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# (729, 1658, 23)
# Seems you are using operation INIs to provide cropbox.

# %%
# %%writefile demo_visualization_per_structure_alignment_spec.json
# {
# "3N_R":
#     {
#     "stack_m":
#         {
#         "name":"atlasV7",
#         "vol_type": "score",
#         "structure":["3N_R", "4N_R"],
#         "resolution":"10.0um"
#         },
#     "stack_f":
#         {
#                 "name":"DEMO998",
#                 "vol_type": "score",
#                 "structure":["3N_R", "4N_R"],
#                 "resolution":"10.0um",
#                 "detector_id":799
#                 },
#     "warp_setting": 7
#     },
# "4N_R":
#         {
#         "stack_m":
#                 {
#                 "name":"atlasV7",
#                 "vol_type": "score",
#                 "structure":["3N_R", "4N_R"],
#                 "resolution":"10.0um"
#                 },
#         "stack_f":
#                 {
#                 "name":"DEMO998",
#                 "vol_type": "score",
#                 "structure":["3N_R", "4N_R"],
#                 "resolution":"10.0um",
#                 "detector_id":799
#                 },
#         "warp_setting": 7
#         },
#
# "12N":
#         {
#         "stack_m":
#                 {
#                 "name":"atlasV7",
#                 "vol_type": "score",
#                 "structure":["12N"],
#                 "resolution":"10.0um"
#                 },
#         "stack_f":
#                 {
#                 "name":"DEMO998",
#                 "vol_type": "score",
#                 "structure":["12N"],
#                 "resolution":"10.0um",
#                 "detector_id":799
#                 },
#         "warp_setting": 7
#         }
# }
# Out:
# Overwriting demo_visualization_per_structure_alignment_spec.json

# %%
# %%writefile demo_visualization_global_alignment_spec.json
# {
# "stack_m":
#         {
#         "name":"atlasV7",
#         "vol_type": "score",
#         "resolution":"10.0um"
#         },
# "stack_f":
#     {
#     "name":"DEMO998",
#     "vol_type": "score",
#     "resolution":"10.0um",
#     "detector_id":799
#     },
# "warp_setting": 0
# }
# Out:
# Overwriting demo_visualization_global_alignment_spec.json

# %%
! python visualize_registration_demo_3_structures.py
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'DEMO998': 0.46}
# No vtk
# No mcubes
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# 224 250
# Seems you are using operation INIs to provide cropbox.
# 2 contours of reconstructed volume is found at position 14 ([14, 3]). Use the longest one.
# 2 contours of reconstructed volume is found at position 18 ([14, 1]). Use the longest one.
# 2 contours of reconstructed volume is found at position 50 ([8, 1]). Use the longest one.
# contour has less than three vertices. Ignore.
# 2 contours of reconstructed volume is found at position 34 ([6, 1]). Use the longest one.
# [174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301]
# (71, 82, 69) [823. 434. 437.]
# Seems you are using operation INIs to provide cropbox.
# 2 contours of reconstructed volume is found at position 11 ([21, 1]). Use the longest one.
# 2 contours of reconstructed volume is found at position 41 ([22, 1]). Use the longest one.
# contour has less than three vertices. Ignore.
# 238 248
# Seems you are using operation INIs to provide cropbox.
# contour has less than three vertices. Ignore.
# 2 contours of reconstructed volume is found at position 23 ([2, 1]). Use the longest one.
# contour has less than three vertices. Ignore.
# 3 contours of reconstructed volume is found at position 9 ([3, 1, 1]). Use the longest one.
# 3 contours of reconstructed volume is found at position 21 ([3, 1, 1]). Use the longest one.
# 2 contours of reconstructed volume is found at position 11 ([2, 1]). Use the longest one.
# contour has less than three vertices. Ignore.
# [188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299]
# (29, 35, 31) [878. 438. 456.]
# Seems you are using operation INIs to provide cropbox.
# 209 251
# Seems you are using operation INIs to provide cropbox.
# 2 contours of reconstructed volume is found at position 6 ([11, 3]). Use the longest one.
# 3 contours of reconstructed volume is found at position 92 ([25, 3, 1]). Use the longest one.
# 3 contours of reconstructed volume is found at position 8 ([3, 2, 2]). Use the longest one.
# 2 contours of reconstructed volume is found at position 90 ([25, 1]). Use the longest one.
# 3 contours of reconstructed volume is found at position 88 ([20, 3, 1]). Use the longest one.
# 2 contours of reconstructed volume is found at position 14 ([15, 1]). Use the longest one.
# 2 contours of reconstructed volume is found at position 86 ([2, 1]). Use the longest one.
# contour has less than three vertices. Ignore.
# [159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302]
# (75, 151, 104) [1131.  493.  445.]
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F84-2017.06.06-14.03.51_MD661_1_0250_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
# Trying to load /media/alexn/BstemAtlasDataBackup/demo_preprocess/CSHL_data_processed/DEMO998/DEMO998_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg/MD662&661-F86-2017.06.06-14.56.48_MD661_2_0257_prep2_raw_NtbNormalizedAdaptiveInvertedGammaJpeg.jpg
