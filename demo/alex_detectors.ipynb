# %%
# Most items in this notebook are defined in metadata.py around line 505
import os
import sys
import numpy as np

sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *
from metadata import *
from data_manager import *

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'MD589': 0.46, 'MD585': 0.46, 'UCSD001': 0.325}
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD585/MD585_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD585/MD585_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# /media/alexn/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.
# Seems you are using operation INIs to provide cropbox.

# %%
DETECTOR_SETTINGS_CSV
# Out:
# '/home/alexn/brainDev/src/learning/detector_settings.csv'

# %% [markdown]
# # Detector Settings

# %%
detector_settings
# Out:
#                                   input_version  windowing_id  \
# detector_id
# 15                                         gray             5
# 19                                         gray             7
# 799          NtbNormalizedAdaptiveInvertedGamma             7
# 998                             normalized_-1_5             7
# 999                             normalized_-1_5             7
#
#                feature_network  feature_classifier_id  \
# detector_id
# 15           inception-bn-blue                     73
# 19           inception-bn-blue                     73
# 799          inception-bn-blue                    899
# 998          inception-bn-blue                    998
# 999          inception-bn-blue                    999
#
#                                                       comments
# detector_id
# 15                                                         NaN
# 19                                                         NaN
# ...

# %%
detector_ids_thionin = [15,19]
detector_ids_ntb = [799]

detector_settings.loc[19]
# Out:
# input_version                         gray
# windowing_id                             7
# feature_network          inception-bn-blue
# feature_classifier_id                   73
# comments                               NaN
# Name: 19, dtype: object

# %%
class_id = detector_settings.loc[19]['feature_classifier_id']
window_id = detector_settings.loc[19]['windowing_id']

# %% [markdown]
# # Window and Classifier Settings

# %%
windowing_settings
# Out:
# {1: {'patch_size': 224, 'spacing': 56},
#  2: {'comment': 'larger margin', 'patch_size': 224, 'spacing': 56},
#  3: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 32},
#  4: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 128},
#  5: {'comment': 'smaller spacing', 'patch_size': 224, 'spacing': 64},
#  6: {'comment': 'twice as large patch', 'patch_size': 448, 'spacing': 64},
#  7: {'comment': 'specify size/spacing in terms of microns rather than pixels',
#   'patch_size_um': 103.04,
#   'spacing_um': 30},
#  8: {'comment': 'larger patch', 'patch_size_um': 206.08, 'spacing_um': 30},
#  9: {'comment': 'larger patch', 'patch_size_um': 412.16, 'spacing_um': 30},
#  10: {'comment': 'larger patch', 'patch_size_um': 824.32, 'spacing_um': 30},
#  11: {'comment': 'larger patch', 'patch_size_um': 51.52, 'spacing_um': 30},
#  12: {'comment': 'larger patch', 'patch_size_um': 25.76, 'spacing_um': 30}}

# %%
classifier_settings
# Out:
#                                    model  margin_um       train_set_id  \
# classifier_id
# 30                                    lr        500              20/21
# 31                                    lr        500              21/22
# 32                                    lr        500              20/22
# 33                                   gb1        500              20/21
# 34                                   gb1        500              21/22
# 35                                   gb1        500              20/22
# 36                                   gb1        500              23/24
# 37                                    lr        500              23/24
# 38                                    lr        500        23/24/27/28
# 39                                    lr        200        30/31/27/28
# 40                                    lr       1000        33/34/27/28
# 41                                    lr        500        36/37/27/28
# ...

# %%
classifier_settings.loc[class_id]
# Out:
# model                                                                   lr
# margin_um                                                              500
# train_set_id                                                      66/67/68
# neg_composition                                       neg_has_all_surround
# sample_weighting                                                       NaN
# input_img_version                                                      NaN
# svm_id                                                                  73
# comment                  using mirror variations for training; use only...
# num_samples_per_class                                                  NaN
# Name: 73, dtype: object
