# %%
# %matplotlib inline

import bloscpack as bp
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import os
import sys

def get_npz_data(filename):
    filename = filename+'.npz'
    filecontents = np.load(filename)
    data = filecontents['data']
    del filecontents
    return data


def blosc_to_npz(filename):
    file = filename+".bp";

    a = bp.unpack_ndarray_file(file)
    b = np.asarray(a)

    np.savez(filename+'.npz', data=b) # Save matrix as .npz file

    print('Size of bloscpack data:')
    print(np.shape(b))
    print('')

def read_loc_into_array(filename):
    file = open(filename+'.bp', 'r')
    points = []

    for line in file:
        x, y = line.split(' ')
        x = int( x )
        y = int( y.replace('\n','') )
        points.append( [x,y] )
    return points

def change_plot_sizes( width=8, length=6):
    # Get current size
    fig_size = plt.rcParams["figure.figsize"]

    # Prints: [8.0, 6.0]
    print "Current size:", fig_size

    # Set figure width to 12 and height to 9
    fig_size[0] = width
    fig_size[1] = length
    plt.rcParams["figure.figsize"] = fig_size

# %%
stack = 'MD585'
iv_fp = os.path.join(os.environ['ROOT_DIR'], 'CSHL_volumes', stack, stack+'_wholebrainWithMargin_10.0um_intensityVolume')
iv_fn = iv_fp + '/'+stack+'_wholebrainWithMargin_10.0um_intensityVolume'

#blosc_to_npz(iv_fn)
data_iv = get_npz_data(iv_fn)
# Out:
# Size of bloscpack data:
# (911, 1531, 513)

# %%
plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
plt.imshow( data_iv[:,:,416], cmap='gray' )

# %%
plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
plt.imshow( data_iv[:,:,415]-data_iv[:,:,414], cmap='gray' )

# %%
plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
plt.imshow( data_iv[:,:,414], cmap='gray' )

# %%
plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
plt.imshow( data_iv[:,:,200], cmap='gray' )
