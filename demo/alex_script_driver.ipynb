# %% [markdown]
# # New Brain Setup

# %%
stack='UCSD001'

# %%
import os 
import subprocess
from a_driver_utilities import *
print os.environ['DATA_ROOTDIR']
print os.environ['ROOT_DIR']
print os.environ['REPO_DIR']

stack = 'UCSD001'
resolution = 0.46 # Microns per pixel
thickness = 20 # Width of slide in microns
stain = 'thionin' # thionin or ntb
# Out:
# /media/alexn/BstemAtlasDataBackup/script_test/
# /media/alexn/BstemAtlasDataBackup/script_test/
# /home/alexn/brainDev/src/

# %%
# Download raw data from S3
! aws s3 cp mousebrainatlas-rawdata/CSHL_data/MD636/*lossless.jp2 \
/media/alexn/BstemAtlasDataBackup/non_sagittal/CSHL_data_processed/MD636/MD636_raw/
# Out:
# usage: aws s3 cp <LocalPath> <S3Uri> or <S3Uri> <LocalPath> or <S3Uri> <S3Uri>
# Error: Invalid argument type

# %%
# Make brain_info file
fp = os.path.join( os.environ['ROOT_DIR'], 'brains_info', stack+'.ini' )
with open(fp, 'w') as file:
    file.write('[DEFAULT]\n')
    file.write('planar_resolution_um = '+str(resolution)+'\n')
    file.write('section_thickness_um = '+str(thickness))

# %%
# Download operation configs from S3
! aws s3 cp --recursive s3://mousebrainatlas-data/operation_configs/ \
/media/alexn/BstemAtlasDataBackup/script_test/operation_configs/
# Out:
# download: s3://mousebrainatlas-data/operation_configs/crop_orig.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/crop_orig.ini
# download: s3://mousebrainatlas-data/operation_configs/from_aligned_to_none.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_aligned_to_none.ini
# download: s3://mousebrainatlas-data/operation_configs/from_aligned_to_padded.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_aligned_to_padded.ini
# download: s3://mousebrainatlas-data/operation_configs/from_aligned_to_wholeslice.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_aligned_to_wholeslice.ini
# download: s3://mousebrainatlas-data/operation_configs/from_padded_to_brainstem.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_padded_to_brainstem.ini
# download: s3://mousebrainatlas-data/operation_configs/from_none_to_padded.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_none_to_padded.ini
# download: s3://mousebrainatlas-data/operation_configs/from_none_to_aligned.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_none_to_aligned.ini
# download: s3://mousebrainatlas-data/operation_configs/from_none_to_wholeslice.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_none_to_wholeslice.ini
# download: s3://mousebrainatlas-data/operation_configs/from_wholeslice_to_brainstem.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_wholeslice_to_brainstem.ini
# download: s3://mousebrainatlas-data/operation_configs/from_none_to_brainstem.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_none_to_brainstem.ini
# download: s3://mousebrainatlas-data/operation_configs/rotate_transverse.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/rotate_transverse.ini
# download: s3://mousebrainatlas-data/operation_configs/from_padded_to_none.ini to ../../../../media/alexn/BstemAtlasDataBackup/script_test/operation_configs/from_padded_to_none.ini

# %%
# Check files all exist in the proper format with proper naming conventions

# %%
# Moving around files etc..
files = ! ls /media/alexn/BstemAtlasDataBackup/non_sagittal/CSHL_data_processed/MD636/MD636_raw/\

for file in files:
    if not 'lossless' in file and not "lossy" in file:
        ! rm /media/alexn/BstemAtlasDataBackup/non_sagittal/CSHL_data_processed/MD636/MD636_raw/$file

# %%
get_fn_list_from_sorted_filenames('UCSD001')
# Out:
# ['UCSD001_slide064_2018_09_04-S1',
#  'UCSD001_slide063_2018_09_04-S4',
#  'UCSD001_slide066_2018_09_04-S2',
#  'UCSD001_slide067_2018_09_04-S1']

# %%
DataManager.get_image_filepath_v2(stack=stack, prep_id=prep_id, resol=resol, version=version, fn=img_name)

# %% [markdown]
# # Part 1 Pipeline
# - `[usr]` Set up environment. Enter resolution and thickness of sections into brains_info/ folder. Ensure that all raw files are named properly and located in the correct place.
# - `[script_1]`
# - `[usr]` Check slice orientations before alignment
# - `[script_2]`
# - `[usr]` Manually fix incorrect alignments
# - `[script_3]`
# - `[usr]` Manually draw initial masks
# - `[script_4]`
# - `[usr]` Inspect and correct generated masks
# - `[script_5]`
# - `[usr]` User specifies prep2 cropping box
# - `[script_6]`
# - `[usr]` Record X/Y/Z coordinates for midpoint of 12N, 3N on midplane
# - `[script_7]`
#     - Obtain simple global alignment

# %%
# TEST
! python a_script_preprocess_1.py $stack
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.
# Jobs submitted. Use wait_qsub_complete() to wait for all execution to finish.
# **************************************************************************************************
#
# Script extract_channel.py completed. Took  233.6  seconds
# Extracted BLUE channel.
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/external/tifffile/tifffile.py:2546: UserWarning: unpack: string size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide066_2018_09_04-S2_raw_Ntb.tif
# uint16
# (29808, 55646)
# Rescale: 15.10 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide063_2018_09_04-S4_raw_Ntb.tif
# uint16
# (29752, 44560)
# Rescale: 12.63 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide067_2018_09_04-S1_raw_Ntb.tif
# uint16
# (27944, 51947)
# Rescale: 12.70 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide064_2018_09_04-S1_raw_Ntb.tif
# uint16
# (31653, 57487)
# Rescale: 15.02 seconds.
# **************************************************************************************************
#
# Script rescale.py completed. Took  56.6  seconds
# Generated thumbnails.
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide066_2018_09_04-S2_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide066_2018_09_04-S2_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.17 seconds.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide063_2018_09_04-S4_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide063_2018_09_04-S4_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.08 seconds.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide067_2018_09_04-S1_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide067_2018_09_04-S1_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.08 seconds.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide064_2018_09_04-S1_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide064_2018_09_04-S1_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.12 seconds.
# **************************************************************************************************
#
# Script normalize_intensity.py completed. Took  1.6  seconds
# Normalized intensity.
#
# **************************************************************************************************
#
# Now check slice orientations before alignment, correct any mistakes.

# %%
# TEST
! python a_script_preprocess_6.py $stack

# %%
! python a_script_preprocess_1.py $stack
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.
# Jobs submitted. Use wait_qsub_complete() to wait for all execution to finish.
# **************************************************************************************************
#
# Script extract_channel.py completed. Took  293.6  seconds
# Extracted BLUE channel.
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/external/tifffile/tifffile.py:2546: UserWarning: unpack: string size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide066_2018_09_04-S2_raw_Ntb.tif
# uint16
# (29808, 55646)
# Rescale: 16.18 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide063_2018_09_04-S4_raw_Ntb.tif
# uint16
# (29752, 44560)
# Rescale: 13.63 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide067_2018_09_04-S1_raw_Ntb.tif
# uint16
# (27944, 51947)
# Rescale: 13.64 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide064_2018_09_04-S1_raw_Ntb.tif
# uint16
# (31653, 57487)
# Rescale: 15.95 seconds.
# **************************************************************************************************
#
# Script rescale.py completed. Took  60.8  seconds
# Generated thumbnails.
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide066_2018_09_04-S2_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide066_2018_09_04-S2_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.10 seconds.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide063_2018_09_04-S4_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide063_2018_09_04-S4_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.09 seconds.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide067_2018_09_04-S1_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide067_2018_09_04-S1_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.10 seconds.
# convert "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_Ntb/UCSD001_slide064_2018_09_04-S1_thumbnail_Ntb.tif" -normalize -depth 8 "/media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide064_2018_09_04-S1_thumbnail_NtbNormalized.tif"
# return code: 0
# Intensity normalize: 0.13 seconds.
# **************************************************************************************************
#
# Script normalize_intensity.py completed. Took  1.6  seconds
# Normalized intensity.
#
# **************************************************************************************************
#
# Now check slice orientations before alignment, correct any mistakes.

# %%
! python a_script_preprocess_2.py $stack
# Check and fix alignments
# subprocess.call(['python','../src/gui/preprocess_tool_v3.py',stack,'--tb_version','NtbNormalized'])
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# python align_v3.py input_spec.ini --op from_none_to_aligned
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# {'image_name_list': 'all', 'resol': 'thumbnail', 'version': 'NtbNormalized', 'prep_id': 'None', 'stack': 'UCSD001'}
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.
# Jobs submitted. Use wait_qsub_complete() to wait for all execution to finish.
# return code: 0
# python compose_v3.py input_spec.ini --op from_none_to_aligned
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Load elastix-computed transform: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_elastix_output/UCSD001_slide063_2018_09_04-S4_to_UCSD001_slide064_2018_09_04-S1/TransformParameters.0.txt
# Load elastix-computed transform: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_elastix_output/UCSD001_slide066_2018_09_04-S2_to_UCSD001_slide063_2018_09_04-S4/TransformParameters.0.txt
# Load elastix-computed transform: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_elastix_output/UCSD001_slide067_2018_09_04-S1_to_UCSD001_slide066_2018_09_04-S2/TransformParameters.0.txt
# 0 UCSD001_slide064_2018_09_04-S1 [[ 9.95617949e-01  9.35141655e-02 -1.73103772e+02]
#  [-9.35141655e-02  9.95617949e-01  1.18290797e+02]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# 1 UCSD001_slide063_2018_09_04-S4 [[ 9.99733207e-01 -2.30979457e-02 -2.28496602e+02]
#  [ 2.30979457e-02  9.99733207e-01 -2.56683368e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# 2 UCSD001_slide066_2018_09_04-S2 [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# 3 UCSD001_slide067_2018_09_04-S1 [[ 9.99931497e-01  1.17047327e-02 -1.33327403e+02]
#  [-1.17047327e-02  9.99931497e-01 -1.69329424e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# return code: 0
# ('Finished preliminary alignment. Took ', 176.1696970462799, ' seconds')
# /home/alexn/brainDev/src/
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.
# Jobs submitted. Use wait_qsub_complete() to wait for all execution to finish.
# ('Finished transformation to padded (prep1). Took ', 3.159533977508545, ' seconds')
#
# Now manually fix any incorrect alignments. Custom GUI available with the following command:
#
# `python ../src/gui/preprocess_tool_v3.py UCSD001 --tb_version NtbNormalized/gray`

# %%
# Draw initial snake contours:
# python src/gui/mask_editing_tool_v4.py $stack NtbNormalized
! python a_script_preprocess_3.py $stack
# Fix incorrect masks:
# python src/gui/mask_editing_tool_v4.py $stack NtbNormalized
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# ENABLE_DOWNLOAD_S3 is False. Skip downloading from S3.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_NtbNormalized/UCSD001_slide066_2018_09_04-S2_prep1_thumbnail_NtbNormalized.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_NtbNormalized/UCSD001_slide063_2018_09_04-S4_prep1_thumbnail_NtbNormalized.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_NtbNormalized/UCSD001_slide067_2018_09_04-S1_prep1_thumbnail_NtbNormalized.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_NtbNormalized/UCSD001_slide064_2018_09_04-S1_prep1_thumbnail_NtbNormalized.tif
# 127(1 percentile), 254(99 percentile)
# 102(1 percentile), 254(99 percentile)
# 107(1 percentile), 254(99 percentile)
# 112(1 percentile), 254(99 percentile)
# Found 1 levelsets.
#
# Contour 0
# Found 1 levelsets.
#
# Contour 0
# Found 1 levelsets.
#
# Contour 0
# Found 1 levelsets.
#
# Contour 0
# Morphsnake iter 0 Component sizes: [1131695]
# Morphsnake iter 0 Component sizes: [978935]
# Morphsnake iter 0 Component sizes: [1131695]
# Morphsnake iter 0 Component sizes: [1131695]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 1 Component sizes: [1128894, 1, 2, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 1 Component sizes: [1128066, 1, 1, 2]
# Component area is too small - nullified.
# Morphsnake iter 1 Component sizes: [975410, 2]
# Component area is too small - nullified.
# Morphsnake iter 1 Component sizes: [1129787, 1]
# Morphsnake iter 2 Component sizes: [1126050]
# Morphsnake iter 2 Component sizes: [971887]
# Morphsnake iter 2 Component sizes: [1124414]
# Morphsnake iter 2 Component sizes: [1127802]
# Morphsnake iter 3 Component sizes: [1123357]
# Component area is too small - nullified.
# Morphsnake iter 3 Component sizes: [968401, 1]
# Morphsnake iter 3 Component sizes: [1120891]
# Morphsnake iter 3 Component sizes: [1125976]
# Morphsnake iter 4 Component sizes: [1120505]
# Morphsnake iter 4 Component sizes: [964886]
# Morphsnake iter 4 Component sizes: [1117297]
# Morphsnake iter 4 Component sizes: [1123992]
# Component area is too small - nullified.
# Morphsnake iter 5 Component sizes: [1117811, 1]
# Morphsnake iter 5 Component sizes: [961401]
# Morphsnake iter 5 Component sizes: [1113821]
# Morphsnake iter 5 Component sizes: [1122232]
# Morphsnake iter 6 Component sizes: [957863]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 6 Component sizes: [1114939, 1, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 6 Component sizes: [1110271, 1]
# Morphsnake iter 7 Component sizes: [954355]
# Morphsnake iter 7 Component sizes: [1112273]
# Morphsnake iter 6 Component sizes: [1120224]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 7 Component sizes: [1106823, 1, 1, 1]
# Morphsnake iter 8 Component sizes: [950811]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 8 Component sizes: [1109387, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 7 Component sizes: [1118556, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 8 Component sizes: [1103286, 1, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 9 Component sizes: [947313, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 9 Component sizes: [1106661, 2, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 8 Component sizes: [1116590, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 9 Component sizes: [1099916, 1, 1, 2]
# Component area is too small - nullified.
# Morphsnake iter 10 Component sizes: [1103755, 2]
# Morphsnake iter 10 Component sizes: [943779]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 9 Component sizes: [1114999, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 10 Component sizes: [1096430, 1, 5]
# Component area is too small - nullified.
# Morphsnake iter 11 Component sizes: [1101105, 2]
# Component area is too small - nullified.
# Morphsnake iter 11 Component sizes: [940298, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 10 Component sizes: [1113074, 1, 2, 3]
# Morphsnake iter 12 Component sizes: [1098228]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 11 Component sizes: [1093108, 2, 1, 1]
# Morphsnake iter 12 Component sizes: [936767]
# Component area is too small - nullified.
# Morphsnake iter 11 Component sizes: [1111584, 2]
# Morphsnake iter 13 Component sizes: [933316]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 13 Component sizes: [1095561, 2, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 12 Component sizes: [1089689, 3, 1, 3, 3]
# Morphsnake iter 12 Component sizes: [1109750]
# Component area is too small - nullified.
# Morphsnake iter 14 Component sizes: [7, 929824]
# Morphsnake iter 14 Component sizes: [1092649]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 13 Component sizes: [1086374, 2, 1, 1, 7, 6]
# Component area is too small - nullified.
# Morphsnake iter 15 Component sizes: [926420, 5]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 15 Component sizes: [1089969, 1, 1, 9, 1]
# Morphsnake iter 13 Component sizes: [1108352]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 14 Component sizes: [1082940, 1, 2, 30, 2, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 16 Component sizes: [1, 922859, 76]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 16 Component sizes: [1087047, 1, 3]
# Component area is too small - nullified.
# Morphsnake iter 14 Component sizes: [1106570, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 15 Component sizes: [1078860, 2, 4, 1]
# Morphsnake iter 17 Component sizes: [919506]
# Component area is too small - nullified.
# Morphsnake iter 17 Component sizes: [1084367, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 15 Component sizes: [1105230, 1, 17]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 16 Component sizes: [1074821, 1, 1, 1, 26]
# Morphsnake iter 18 Component sizes: [916067]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 18 Component sizes: [1081436, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 17 Component sizes: [1070982, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 19 Component sizes: [912742]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 16 Component sizes: [1103442, 1, 1, 1, 1, 29, 12]
# Component area is too small - nullified.
# Morphsnake iter 19 Component sizes: [1078737, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 20 Component sizes: [1, 909319, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 18 Component sizes: [1067107, 1, 1, 27, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 20 Component sizes: [1075764, 1, 2, 2, 1, 5, 2]
# Component area is too small - nullified.
# Morphsnake iter 17 Component sizes: [1102203, 1]
# Component area is too small - nullified.
# Morphsnake iter 21 Component sizes: [906026, 1]
# Morphsnake iter 21 Component sizes: [1073156]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 19 Component sizes: [1063385, 1, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 18 Component sizes: [1100491, 25]
# Morphsnake iter 22 Component sizes: [902640]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 22 Component sizes: [1070269, 1, 6]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 20 Component sizes: [1059604, 3, 1, 1, 17, 11]
# Component area is too small - nullified.
# Morphsnake iter 19 Component sizes: [1099272, 19]
# Morphsnake iter 23 Component sizes: [899407]
# Morphsnake iter 23 Component sizes: [1067727]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 21 Component sizes: [1055922, 1, 1, 1]
# Morphsnake iter 20 Component sizes: [1097600]
# Component area is too small - nullified.
# Morphsnake iter 24 Component sizes: [896013, 3]
# Component area is too small - nullified.
# Morphsnake iter 24 Component sizes: [1064871, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 22 Component sizes: [1052200, 2, 3, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 25 Component sizes: [892784, 3, 1, 25]
# Component area is too small - nullified.
# Morphsnake iter 21 Component sizes: [1096450, 3]
# Component area is too small - nullified.
# Morphsnake iter 25 Component sizes: [1062343, 15]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 23 Component sizes: [1048575, 5, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 26 Component sizes: [1, 889466, 3]
# Component area is too small - nullified.
# Morphsnake iter 22 Component sizes: [1094768, 1]
# Component area is too small - nullified.
# Morphsnake iter 26 Component sizes: [1059493, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 24 Component sizes: [1044862, 1, 1, 2, 8]
# Morphsnake iter 27 Component sizes: [886334]
# Component area is too small - nullified.
# Morphsnake iter 27 Component sizes: [1056965, 1]
# Morphsnake iter 23 Component sizes: [1093654]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 25 Component sizes: [1041269, 2, 6, 3, 1]
# Morphsnake iter 28 Component sizes: [883071]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 28 Component sizes: [1054050, 1, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 24 Component sizes: [1091824, 120, 12]
# Morphsnake iter 29 Component sizes: [880023]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 26 Component sizes: [1037626, 3, 1, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 29 Component sizes: [1051526, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 25 Component sizes: [1090584, 108, 7]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 30 Component sizes: [876846, 1, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 27 Component sizes: [1034058, 6, 2, 1, 9, 1]
# Morphsnake iter 30 Component sizes: [1048656]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 31 Component sizes: [1, 873922, 2]
# Component area is too small - nullified.
# Morphsnake iter 26 Component sizes: [1088888, 34]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 28 Component sizes: [1030439, 17, 4, 1, 6, 1, 1]
# Morphsnake iter 31 Component sizes: [1046168]
# Morphsnake iter 32 Component sizes: [870845]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 27 Component sizes: [1087799, 1, 6]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 29 Component sizes: [1026935, 1, 4, 1, 58, 3]
# Morphsnake iter 32 Component sizes: [1043318]
# Morphsnake iter 33 Component sizes: [868003]
# Component area is too small - nullified.
# Morphsnake iter 28 Component sizes: [1086144, 13]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 30 Component sizes: [1023444, 4, 1]
# Morphsnake iter 34 Component sizes: [865011]
# Component area is too small - nullified.
# Morphsnake iter 33 Component sizes: [1040843, 1]
# Morphsnake iter 31 Component sizes: [1020066]
# Morphsnake iter 29 Component sizes: [1085080]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 35 Component sizes: [862232, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 34 Component sizes: [1038011, 1, 4, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 32 Component sizes: [1016550, 1, 4, 2, 1, 1, 1, 1, 6]
# Component area is too small - nullified.
# Morphsnake iter 36 Component sizes: [859243, 19]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 30 Component sizes: [1083459, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 35 Component sizes: [1035596, 3]
# Morphsnake iter 37 Component sizes: [856559]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 33 Component sizes: [1013155, 10, 1, 2]
# Component area is too small - nullified.
# Morphsnake iter 31 Component sizes: [1082450, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 36 Component sizes: [1032771, 2, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 38 Component sizes: [853339, 84, 221]
# Component area is too small - nullified.
# Morphsnake iter 34 Component sizes: [1009674, 1]
# Component area is too small - nullified.
# Morphsnake iter 37 Component sizes: [1030376, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 32 Component sizes: [1080828, 1, 1]
# Morphsnake iter 39 Component sizes: [850686]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 35 Component sizes: [1006261, 10, 5, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 38 Component sizes: [1027550, 10, 3, 11]
# Morphsnake iter 33 Component sizes: [1079839]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 40 Component sizes: [2, 847858, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 36 Component sizes: [1002705, 2, 3, 33, 1, 1, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 39 Component sizes: [1025191, 1, 3, 1]
# Morphsnake iter 41 Component sizes: [845294]
# Morphsnake iter 34 Component sizes: [1078238]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 37 Component sizes: [999286, 1, 1, 3, 25]
# Component area is too small - nullified.
# Morphsnake iter 40 Component sizes: [1022411, 2, 24]
# Component area is too small - nullified.
# Morphsnake iter 42 Component sizes: [842494, 16]
# Component area is too small - nullified.
# Morphsnake iter 35 Component sizes: [1077199, 75]
# Morphsnake iter 41 Component sizes: [1020118]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 38 Component sizes: [995769, 1, 3, 1, 1, 3, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 43 Component sizes: [839957, 1, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 42 Component sizes: [1017253, 140, 2]
# Morphsnake iter 36 Component sizes: [1075619]
# Morphsnake iter 44 Component sizes: [837215]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 39 Component sizes: [992350, 1, 1, 6, 8]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 43 Component sizes: [1014971, 1, 1]
# Morphsnake iter 37 Component sizes: [1074654]
# Morphsnake iter 45 Component sizes: [834791]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 40 Component sizes: [988839, 1, 2, 1, 2, 3, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 44 Component sizes: [1012260, 2, 2, 12]
# Morphsnake iter 46 Component sizes: [832112]
# Morphsnake iter 38 Component sizes: [1073072]
# Component area is too small - nullified.
# Morphsnake iter 41 Component sizes: [985462, 4]
# Component area is too small - nullified.
# Morphsnake iter 45 Component sizes: [1010012, 1]
# Component area is too small - nullified.
# Morphsnake iter 47 Component sizes: [828907, 4]
# Morphsnake iter 39 Component sizes: [1072156]
# Component area is too small - nullified.
# Morphsnake iter 46 Component sizes: [1007354, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 42 Component sizes: [981918, 1, 37, 3, 13, 1]
# Component area is too small - nullified.
# Morphsnake iter 48 Component sizes: [825695, 5]
# Component area is too small - nullified.
# Morphsnake iter 40 Component sizes: [1070581, 1]
# Component area is too small - nullified.
# Morphsnake iter 47 Component sizes: [1005115, 32]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 43 Component sizes: [978514, 1, 7, 2, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 49 Component sizes: [822821, 5, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 48 Component sizes: [1002415, 16, 12]
# Component area is too small - nullified.
# Morphsnake iter 41 Component sizes: [1069613, 67]
# Component area is too small - nullified.
# Morphsnake iter 50 Component sizes: [819810, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 44 Component sizes: [974966, 2, 3, 6, 11, 11, 5, 5, 2]
# Morphsnake iter 49 Component sizes: [1000249]
# Morphsnake iter 51 Component sizes: [817166]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 45 Component sizes: [971603, 17, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 42 Component sizes: [1068053, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 50 Component sizes: [997547, 13, 1, 2]
# Morphsnake iter 52 Component sizes: [814302]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 46 Component sizes: [968140, 3, 6, 1, 15, 1]
# Component area is too small - nullified.
# Morphsnake iter 43 Component sizes: [1067176, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 51 Component sizes: [995386, 1, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 53 Component sizes: [811801, 2, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 47 Component sizes: [964830, 7, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 52 Component sizes: [992675, 3, 1, 2, 1]
# Component area is too small - nullified.
# Morphsnake iter 44 Component sizes: [1065617, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 54 Component sizes: [809027, 1, 1, 1, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 53 Component sizes: [990536, 1, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 48 Component sizes: [961409, 1, 5, 1, 5, 1, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 45 Component sizes: [1064692, 1, 15, 40]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 55 Component sizes: [806614, 5, 1]
# Component area is too small - nullified.
# Morphsnake iter 54 Component sizes: [987881, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 49 Component sizes: [958153, 2, 1]
# Morphsnake iter 56 Component sizes: [803882]
# Component area is too small - nullified.
# Morphsnake iter 46 Component sizes: [1063108, 60]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 55 Component sizes: [984620, 1137, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 50 Component sizes: [954744, 1, 26, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 57 Component sizes: [801527, 4, 1]
# Morphsnake iter 47 Component sizes: [1062287]
# Component area is too small - nullified.
# Morphsnake iter 56 Component sizes: [981967, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 58 Component sizes: [798807, 1, 56]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 51 Component sizes: [951408, 5, 52, 7, 63]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 57 Component sizes: [979835, 1, 1, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 48 Component sizes: [1060754, 2, 24]
# Morphsnake iter 59 Component sizes: [796552]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 58 Component sizes: [977188]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 52 Component sizes: [947990, 1, 3, 11, 1, 1, 5, 6, 6, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 49 Component sizes: [1059909, 38, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 60 Component sizes: [793877, 50, 2]
# Component area is too small - nullified.
# Morphsnake iter 59 Component sizes: [975086, 4]
# Component area is too small - nullified.
# Morphsnake iter 53 Component sizes: [944802, 1]
# Morphsnake iter 50 Component sizes: [1058446]
# Component area is too small - nullified.
# Morphsnake iter 61 Component sizes: [791636, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 60 Component sizes: [972446, 3, 1, 1, 6]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 54 Component sizes: [941441, 1, 1, 1, 2, 1, 5, 2]
# Component area is too small - nullified.
# Morphsnake iter 62 Component sizes: [789051, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 51 Component sizes: [1057658, 2, 1]
# Component area is too small - nullified.
# Morphsnake iter 61 Component sizes: [970400, 3]
# Morphsnake iter 55 Component sizes: [938084]
# Component area is too small - nullified.
# Morphsnake iter 63 Component sizes: [784906, 1908]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 62 Component sizes: [967798, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 52 Component sizes: [1056101, 2, 20]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 56 Component sizes: [934367, 5, 3, 204, 10]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 64 Component sizes: [782313, 3, 2]
# Component area is too small - nullified.
# Morphsnake iter 63 Component sizes: [965804, 1]
# Morphsnake iter 53 Component sizes: [1055234]
# Morphsnake iter 65 Component sizes: [780098]
# Component area is too small - nullified.
# Morphsnake iter 57 Component sizes: [931138, 13]
# Morphsnake iter 64 Component sizes: [963239]
# Morphsnake iter 54 Component sizes: [1053681]
# Component area is too small - nullified.
# Morphsnake iter 66 Component sizes: [777548, 3]
# Morphsnake iter 65 Component sizes: [961256]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 58 Component sizes: [927360, 3, 3, 3, 2, 293, 8]
# Morphsnake iter 55 Component sizes: [1052857]
# Component area is too small - nullified.
# Morphsnake iter 67 Component sizes: [775363, 1]
# Component area is too small - nullified.
# Morphsnake iter 66 Component sizes: [958680, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 59 Component sizes: [924195, 5, 1, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 56 Component sizes: [1051254, 9, 37]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 68 Component sizes: [772794, 8, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 67 Component sizes: [956679, 26, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 60 Component sizes: [920811, 8, 10, 7]
# Morphsnake iter 69 Component sizes: [770674]
# Morphsnake iter 57 Component sizes: [1050419]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 68 Component sizes: [954105, 2, 3]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 61 Component sizes: [917766, 3, 6]
# Component area is too small - nullified.
# Morphsnake iter 70 Component sizes: [767995, 165]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 58 Component sizes: [1048836, 30, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 69 Component sizes: [952131, 1, 2, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 71 Component sizes: [765826, 75, 5, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 62 Component sizes: [914447, 1, 3, 3, 9, 2]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 70 Component sizes: [949522, 1, 3, 2]
# Morphsnake iter 59 Component sizes: [1047988]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 72 Component sizes: [763363, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 71 Component sizes: [947560, 2, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 63 Component sizes: [911513, 1, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 60 Component sizes: [1046204, 224]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 73 Component sizes: [761368, 1, 2]
# Component area is too small - nullified.
# Morphsnake iter 72 Component sizes: [944950, 6]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 64 Component sizes: [908298, 2, 1, 2, 5]
# Component area is too small - nullified.
# Morphsnake iter 61 Component sizes: [1045369, 5]
# Component area is too small - nullified.
# Morphsnake iter 74 Component sizes: [758947, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 73 Component sizes: [942995, 12, 4]
# Component area is too small - nullified.
# Morphsnake iter 65 Component sizes: [905453, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 75 Component sizes: [756988, 5, 9]
# Component area is too small - nullified.
# Morphsnake iter 62 Component sizes: [1043794, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 74 Component sizes: [940285, 15, 76]
# Component area is too small - nullified.
# Morphsnake iter 66 Component sizes: [82, 902179]
# Morphsnake iter 76 Component sizes: [754632]
# Morphsnake iter 63 Component sizes: [1042999]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 75 Component sizes: [938179, 26, 4, 158]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 77 Component sizes: [752703, 42, 18, 1]
# Component area is too small - nullified.
# Morphsnake iter 67 Component sizes: [899390, 1]
# Component area is too small - nullified.
# Morphsnake iter 64 Component sizes: [1041374, 56]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 76 Component sizes: [935559, 77, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 78 Component sizes: [750361, 3, 25]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 68 Component sizes: [896125, 4, 1, 79, 1]
# Morphsnake iter 77 Component sizes: [933659]
# Component area is too small - nullified.
# Morphsnake iter 65 Component sizes: [1040536, 31]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 79 Component sizes: [748568, 20, 1]
# Morphsnake iter 78 Component sizes: [931147]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 69 Component sizes: [893346, 1, 1, 1]
# Morphsnake iter 66 Component sizes: [1038965]
# Morphsnake iter 80 Component sizes: [746317]
# Component area is too small - nullified.
# Morphsnake iter 79 Component sizes: [929311, 2]
# Component area is too small - nullified.
# Morphsnake iter 67 Component sizes: [1038161]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 70 Component sizes: [890240, 3, 2, 1]
# Component area is too small - nullified.
# Morphsnake iter 81 Component sizes: [744646, 2]
# Component area is too small - nullified.
# Morphsnake iter 80 Component sizes: [926821, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 68 Component sizes: [1036586, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 71 Component sizes: [887534, 3, 25, 1, 6]
# Morphsnake iter 82 Component sizes: [742458]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 81 Component sizes: [924985, 3, 32]
# Morphsnake iter 69 Component sizes: [1035827]
# Component area is too small - nullified.
# Morphsnake iter 72 Component sizes: [884504, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 83 Component sizes: [740836, 2, 1, 11]
# Component area is too small - nullified.
# Morphsnake iter 82 Component sizes: [922531, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 73 Component sizes: [881902, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 70 Component sizes: [1034262, 2]
# Component area is too small - nullified.
# Morphsnake iter 83 Component sizes: [920783, 2]
# Morphsnake iter 84 Component sizes: [738684]
# Component area is too small - nullified.
# Morphsnake iter 74 Component sizes: [878891, 6]
# Morphsnake iter 71 Component sizes: [1033482]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 84 Component sizes: [917690, 646, 1, 12]
# Component area is too small - nullified.
# Morphsnake iter 85 Component sizes: [737135, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 75 Component sizes: [876282, 2, 1]
# Morphsnake iter 72 Component sizes: [1031918]
# Morphsnake iter 85 Component sizes: [915973]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 86 Component sizes: [734963, 7, 13]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 86 Component sizes: [913589, 1, 1]
# Component area is too small - nullified.
# Morphsnake iter 76 Component sizes: [873316, 2]
# Morphsnake iter 73 Component sizes: [1031180]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 87 Component sizes: [733387, 47, 1, 3]
# Component area is too small - nullified.
# Morphsnake iter 87 Component sizes: [911893, 4]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 77 Component sizes: [870680, 2, 91, 5]
# Morphsnake iter 74 Component sizes: [1029631]
# Component area is too small - nullified.
# Morphsnake iter 88 Component sizes: [731314, 1]
# Morphsnake iter 88 Component sizes: [909547]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 78 Component sizes: [867703, 1, 2, 1, 1, 11]
# Morphsnake iter 75 Component sizes: [1028913]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 89 Component sizes: [729850, 1, 1, 5]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 89 Component sizes: [907868, 3, 1]
# Component area is too small - nullified.
# Morphsnake iter 79 Component sizes: [865200, 1]
# Morphsnake iter 76 Component sizes: [1027371]
# Component area is too small - nullified.
# Morphsnake iter 90 Component sizes: [727783, 13]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 90 Component sizes: [905474, 9, 1, 2, 5, 13]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 80 Component sizes: [862278, 1, 5]
# Morphsnake iter 77 Component sizes: [1026711]
# Morphsnake iter 91 Component sizes: [726402]
# Morphsnake iter 91 Component sizes: [903810]
# Component area is too small - nullified.
# Morphsnake iter 81 Component sizes: [65, 859785]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 78 Component sizes: [1025215, 2, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 92 Component sizes: [724361, 7, 39]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 92 Component sizes: [901446, 5, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 82 Component sizes: [856917, 1, 6]
# Component area is too small - nullified.
# Morphsnake iter 93 Component sizes: [722810, 282]
# Morphsnake iter 79 Component sizes: [1024570]
# Component area is too small - nullified.
# Morphsnake iter 93 Component sizes: [899806, 2]
# Component area is too small - nullified.
# Morphsnake iter 94 Component sizes: [720893, 22]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 83 Component sizes: [854528, 11, 2, 1, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 94 Component sizes: [897451, 2, 7]
# Morphsnake iter 80 Component sizes: [1023073]
# Component area is too small - nullified.
# Morphsnake iter 95 Component sizes: [719701, 3]
# Morphsnake iter 95 Component sizes: [895843]
# Component area is too small - nullified.
# Morphsnake iter 84 Component sizes: [851711, 1]
# Morphsnake iter 81 Component sizes: [1022440]
# Component area is too small - nullified.
# Morphsnake iter 96 Component sizes: [717872, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 96 Component sizes: [893508, 10, 2, 1]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 85 Component sizes: [849388, 4, 2]
# Morphsnake iter 82 Component sizes: [1020952]
# Morphsnake iter 97 Component sizes: [716788]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 97 Component sizes: [891952, 1, 3]
# Component area is too small - nullified.
# ...
# Morphsnake iter 400 Component sizes: [913309]
# Morphsnake iter 464 Component sizes: [425501, 2249]
# Morphsnake iter 409 Component sizes: [659013]
# Morphsnake iter 465 Component sizes: [425620, 2291]
# Morphsnake iter 401 Component sizes: [914101]
# Morphsnake iter 410 Component sizes: [658361]
# Morphsnake iter 466 Component sizes: [425076, 2249]
# Morphsnake iter 402 Component sizes: [913283]
# Morphsnake iter 411 Component sizes: [658983]
# Morphsnake iter 467 Component sizes: [425205, 2291]
# Morphsnake iter 403 Component sizes: [914076]
# Morphsnake iter 412 Component sizes: [658332]
# Component area is too small - nullified.
# Component area is too small - nullified.
# Morphsnake iter 468 Component sizes: [424665, 1, 1, 2249]
# Morphsnake iter 404 Component sizes: [913262]
# Morphsnake iter 413 Component sizes: [658959]
# Morphsnake iter 469 Component sizes: [424807, 2291]
# Morphsnake iter 405 Component sizes: [914061]
# Morphsnake iter 414 Component sizes: [658311]
# Morphsnake iter 470 Component sizes: [424282, 2249]
# Morphsnake iter 406 Component sizes: [913243]
# Morphsnake iter 415 Component sizes: [658939]
# Morphsnake iter 471 Component sizes: [424434, 2291]
# Morphsnake iter 407 Component sizes: [914040]
# Morphsnake iter 416 Component sizes: [658289]
# Morphsnake iter 472 Component sizes: [423909, 2249]
# Morphsnake iter 408 Component sizes: [913229]
# Morphsnake iter 473 Component sizes: [424069, 2291]
# Morphsnake iter 417 Component sizes: [658921]
# Morphsnake iter 409 Component sizes: [914034]
# Morphsnake iter 474 Component sizes: [423551, 2249]
# Morphsnake iter 418 Component sizes: [658271]
# Morphsnake iter 410 Component sizes: [913224]
# Morphsnake iter 475 Component sizes: [423717, 2291]
# Morphsnake iter 419 Component sizes: [658903]
# Morphsnake iter 476 Component sizes: [423204, 2249]
# Morphsnake iter 411 Component sizes: [914027]
# Morphsnake iter 420 Component sizes: [658254]
# Morphsnake iter 477 Component sizes: [423381, 2291]
# Morphsnake iter 412 Component sizes: [913219]
# Morphsnake iter 421 Component sizes: [658888]
# Morphsnake iter 478 Component sizes: [422872, 2249]
# Morphsnake iter 413 Component sizes: [914022]
# Morphsnake iter 422 Component sizes: [658239]
# Morphsnake iter 479 Component sizes: [423051, 2291]
# Morphsnake iter 414 Component sizes: [913214]
# Morphsnake iter 423 Component sizes: [658871]
# Morphsnake iter 480 Component sizes: [422547, 2249]
# Snake finished at iteration 415.
# Snake: 176.90 seconds
# Final masks added.
# ENABLE_UPLOAD_S3 is False. Skip uploading to S3.
# Morphsnake iter 424 Component sizes: [658223]
# ENABLE_UPLOAD_S3 is False. Skip uploading to S3.
# Morphsnake iter 481 Component sizes: [422735, 2291]
# Morphsnake iter 425 Component sizes: [658854]
# Morphsnake iter 482 Component sizes: [422239, 2249]
# Morphsnake iter 426 Component sizes: [658205]
# Morphsnake iter 483 Component sizes: [422429, 2291]
# Morphsnake iter 427 Component sizes: [658833]
# Morphsnake iter 484 Component sizes: [421936, 2249]
# Morphsnake iter 428 Component sizes: [658178]
# Morphsnake iter 485 Component sizes: [422127, 2291]
# Morphsnake iter 429 Component sizes: [658805]
# Morphsnake iter 486 Component sizes: [421636, 2249]
# Morphsnake iter 430 Component sizes: [658149]
# Morphsnake iter 487 Component sizes: [421833, 2291]
# Morphsnake iter 431 Component sizes: [658774]
# Morphsnake iter 488 Component sizes: [421348, 2249]
# Morphsnake iter 432 Component sizes: [658109]
# Morphsnake iter 489 Component sizes: [421547, 2291]
# Morphsnake iter 433 Component sizes: [658736]
# Morphsnake iter 490 Component sizes: [421067, 2249]
# Morphsnake iter 434 Component sizes: [658078]
# Morphsnake iter 491 Component sizes: [421268, 2291]
# Morphsnake iter 435 Component sizes: [658714]
# Morphsnake iter 492 Component sizes: [420789, 2249]
# Morphsnake iter 436 Component sizes: [658061]
# Morphsnake iter 493 Component sizes: [420996, 2291]
# Morphsnake iter 437 Component sizes: [658700]
# Morphsnake iter 494 Component sizes: [420516, 2249]
# Morphsnake iter 438 Component sizes: [658047]
# Morphsnake iter 495 Component sizes: [420726, 2291]
# Morphsnake iter 439 Component sizes: [658688]
# Morphsnake iter 496 Component sizes: [420250, 2249]
# Morphsnake iter 440 Component sizes: [658036]
# Morphsnake iter 497 Component sizes: [420466, 2291]
# Morphsnake iter 441 Component sizes: [658673]
# Morphsnake iter 498 Component sizes: [419996, 2249]
# Morphsnake iter 442 Component sizes: [658023]
# Morphsnake iter 499 Component sizes: [420216, 2291]
# Morphsnake iter 443 Component sizes: [658659]
# Morphsnake iter 500 Component sizes: [419749, 2249]
# Morphsnake iter 444 Component sizes: [658005]
# Morphsnake iter 501 Component sizes: [419974, 2291]
# Morphsnake iter 445 Component sizes: [658638]
# Morphsnake iter 502 Component sizes: [419507, 2249]
# Morphsnake iter 446 Component sizes: [657980]
# Morphsnake iter 503 Component sizes: [419733, 2291]
# Component area is too small - nullified.
# Morphsnake iter 447 Component sizes: [658605, 4]
# Morphsnake iter 504 Component sizes: [419272, 2249]
# Morphsnake iter 448 Component sizes: [657944]
# Morphsnake iter 505 Component sizes: [419505, 2291]
# Morphsnake iter 449 Component sizes: [658576]
# Morphsnake iter 506 Component sizes: [419042, 2249]
# Morphsnake iter 450 Component sizes: [657912]
# Morphsnake iter 507 Component sizes: [419281, 2291]
# Morphsnake iter 451 Component sizes: [658543]
# Morphsnake iter 508 Component sizes: [418825, 2249]
# Morphsnake iter 452 Component sizes: [657880]
# Morphsnake iter 509 Component sizes: [419071, 2291]
# Morphsnake iter 453 Component sizes: [658509]
# Morphsnake iter 510 Component sizes: [418614, 2249]
# Morphsnake iter 454 Component sizes: [657847]
# Morphsnake iter 511 Component sizes: [418861, 2291]
# Morphsnake iter 455 Component sizes: [658475]
# Morphsnake iter 512 Component sizes: [418412, 2249]
# Morphsnake iter 456 Component sizes: [657808]
# Morphsnake iter 513 Component sizes: [418667, 2291]
# Morphsnake iter 457 Component sizes: [658440]
# Morphsnake iter 514 Component sizes: [418222, 2249]
# Morphsnake iter 458 Component sizes: [657772]
# Morphsnake iter 515 Component sizes: [418479, 2291]
# Morphsnake iter 459 Component sizes: [658408]
# Morphsnake iter 516 Component sizes: [418037, 2249]
# Component area is too small - nullified.
# Morphsnake iter 460 Component sizes: [657696, 46]
# Morphsnake iter 517 Component sizes: [418298, 2291]
# Morphsnake iter 461 Component sizes: [658331]
# Morphsnake iter 518 Component sizes: [417863, 2249]
# Morphsnake iter 462 Component sizes: [657671]
# Morphsnake iter 519 Component sizes: [418127, 2291]
# Morphsnake iter 463 Component sizes: [658302]
# Morphsnake iter 520 Component sizes: [417693, 2249]
# Morphsnake iter 464 Component sizes: [657638]
# Morphsnake iter 521 Component sizes: [417958, 2291]
# Morphsnake iter 465 Component sizes: [658263]
# Morphsnake iter 522 Component sizes: [417532, 2249]
# Morphsnake iter 466 Component sizes: [657591]
# Morphsnake iter 523 Component sizes: [417803, 2291]
# Morphsnake iter 467 Component sizes: [658214]
# Morphsnake iter 524 Component sizes: [417379, 2249]
# Morphsnake iter 468 Component sizes: [657536]
# Morphsnake iter 525 Component sizes: [417659, 2291]
# Component area is too small - nullified.
# Morphsnake iter 469 Component sizes: [658147, 3]
# Morphsnake iter 526 Component sizes: [417243, 2249]
# Morphsnake iter 470 Component sizes: [657463]
# Morphsnake iter 527 Component sizes: [417526, 2291]
# Morphsnake iter 471 Component sizes: [658077]
# Morphsnake iter 528 Component sizes: [417113, 2249]
# Morphsnake iter 472 Component sizes: [657397]
# Morphsnake iter 529 Component sizes: [417406, 2291]
# Component area is too small - nullified.
# Morphsnake iter 473 Component sizes: [658010, 1]
# Morphsnake iter 530 Component sizes: [416995, 2249]
# Morphsnake iter 474 Component sizes: [657338]
# Morphsnake iter 531 Component sizes: [417290, 2291]
# Morphsnake iter 475 Component sizes: [657967]
# Morphsnake iter 532 Component sizes: [416882, 2249]
# Morphsnake iter 476 Component sizes: [657290]
# Morphsnake iter 533 Component sizes: [417179, 2291]
# Morphsnake iter 477 Component sizes: [657916]
# Morphsnake iter 534 Component sizes: [416779, 2249]
# Morphsnake iter 478 Component sizes: [657239]
# Morphsnake iter 535 Component sizes: [417080, 2291]
# Morphsnake iter 479 Component sizes: [657861]
# Morphsnake iter 536 Component sizes: [416683, 2249]
# Morphsnake iter 480 Component sizes: [657186]
# Morphsnake iter 537 Component sizes: [416992, 2291]
# Morphsnake iter 481 Component sizes: [657815]
# Morphsnake iter 538 Component sizes: [416598, 2249]
# Morphsnake iter 482 Component sizes: [657136]
# Morphsnake iter 539 Component sizes: [416911, 2291]
# Morphsnake iter 483 Component sizes: [657761]
# Morphsnake iter 540 Component sizes: [416519, 2249]
# Component area is too small - nullified.
# Morphsnake iter 484 Component sizes: [657061, 20]
# Morphsnake iter 541 Component sizes: [416837, 2291]
# Morphsnake iter 485 Component sizes: [657694]
# Morphsnake iter 542 Component sizes: [416451, 2249]
# Morphsnake iter 486 Component sizes: [657021]
# Morphsnake iter 543 Component sizes: [416775, 2291]
# Morphsnake iter 487 Component sizes: [657654]
# Morphsnake iter 544 Component sizes: [416387, 2249]
# Morphsnake iter 488 Component sizes: [656987]
# Morphsnake iter 545 Component sizes: [416716, 2291]
# Morphsnake iter 489 Component sizes: [657627]
# Morphsnake iter 546 Component sizes: [416334, 2249]
# Morphsnake iter 490 Component sizes: [656960]
# Morphsnake iter 547 Component sizes: [416668, 2291]
# Morphsnake iter 491 Component sizes: [657592]
# Morphsnake iter 548 Component sizes: [416291, 2249]
# Morphsnake iter 492 Component sizes: [656921]
# Morphsnake iter 549 Component sizes: [416629, 2291]
# Morphsnake iter 493 Component sizes: [657553]
# Morphsnake iter 550 Component sizes: [416254, 2249]
# Morphsnake iter 494 Component sizes: [656886]
# Morphsnake iter 551 Component sizes: [416600, 2291]
# Morphsnake iter 495 Component sizes: [657517]
# Morphsnake iter 552 Component sizes: [416234, 2249]
# Morphsnake iter 496 Component sizes: [656843]
# Morphsnake iter 553 Component sizes: [416581, 2291]
# Morphsnake iter 497 Component sizes: [657473]
# Morphsnake iter 554 Component sizes: [416216, 2249]
# Component area is too small - nullified.
# Morphsnake iter 498 Component sizes: [656788, 5]
# Morphsnake iter 555 Component sizes: [416562, 2291]
# Morphsnake iter 499 Component sizes: [657414]
# Morphsnake iter 556 Component sizes: [416197, 2249]
# Morphsnake iter 500 Component sizes: [656739]
# Morphsnake iter 557 Component sizes: [416543, 2291]
# Morphsnake iter 501 Component sizes: [657363]
# Morphsnake iter 558 Component sizes: [416177, 2249]
# Morphsnake iter 502 Component sizes: [656685]
# Morphsnake iter 559 Component sizes: [416524, 2291]
# Morphsnake iter 503 Component sizes: [657311]
# Morphsnake iter 560 Component sizes: [416157, 2249]
# Morphsnake iter 504 Component sizes: [656636]
# Morphsnake iter 561 Component sizes: [416503, 2291]
# Morphsnake iter 505 Component sizes: [657266]
# Morphsnake iter 562 Component sizes: [416136, 2249]
# Morphsnake iter 506 Component sizes: [656589]
# Morphsnake iter 563 Component sizes: [416483, 2291]
# Morphsnake iter 507 Component sizes: [657223]
# Morphsnake iter 564 Component sizes: [416115, 2249]
# Morphsnake iter 508 Component sizes: [656548]
# Morphsnake iter 565 Component sizes: [416461, 2291]
# Morphsnake iter 509 Component sizes: [657181]
# Morphsnake iter 566 Component sizes: [416093, 2249]
# Morphsnake iter 510 Component sizes: [656511]
# Morphsnake iter 567 Component sizes: [416440, 2291]
# Morphsnake iter 511 Component sizes: [657142]
# Morphsnake iter 568 Component sizes: [416071, 2249]
# Morphsnake iter 512 Component sizes: [656469]
# Morphsnake iter 569 Component sizes: [416415, 2291]
# Morphsnake iter 513 Component sizes: [657102]
# Morphsnake iter 570 Component sizes: [416048, 2249]
# Morphsnake iter 514 Component sizes: [656429]
# Morphsnake iter 571 Component sizes: [416392, 2291]
# Morphsnake iter 515 Component sizes: [657062]
# Morphsnake iter 572 Component sizes: [416024, 2249]
# Morphsnake iter 516 Component sizes: [656393]
# Morphsnake iter 573 Component sizes: [416369, 2291]
# Morphsnake iter 517 Component sizes: [657026]
# Morphsnake iter 574 Component sizes: [416001, 2249]
# Morphsnake iter 518 Component sizes: [656351]
# Morphsnake iter 575 Component sizes: [416348, 2291]
# Morphsnake iter 519 Component sizes: [656982]
# Morphsnake iter 576 Component sizes: [415980, 2249]
# Morphsnake iter 520 Component sizes: [656308]
# Morphsnake iter 577 Component sizes: [416325, 2291]
# Morphsnake iter 521 Component sizes: [656944]
# Morphsnake iter 578 Component sizes: [415958, 2249]
# Morphsnake iter 522 Component sizes: [656271]
# Morphsnake iter 579 Component sizes: [416303, 2291]
# Morphsnake iter 523 Component sizes: [656906]
# Morphsnake iter 580 Component sizes: [415935, 2249]
# Morphsnake iter 524 Component sizes: [656233]
# Morphsnake iter 581 Component sizes: [416279, 2291]
# Morphsnake iter 525 Component sizes: [656870]
# Morphsnake iter 582 Component sizes: [415909, 2249]
# Morphsnake iter 526 Component sizes: [656197]
# Morphsnake iter 583 Component sizes: [416253, 2291]
# Morphsnake iter 527 Component sizes: [656835]
# Morphsnake iter 584 Component sizes: [415886, 2249]
# Morphsnake iter 528 Component sizes: [656164]
# Morphsnake iter 585 Component sizes: [416230, 2291]
# Morphsnake iter 529 Component sizes: [656809]
# Morphsnake iter 586 Component sizes: [415863, 2249]
# Morphsnake iter 530 Component sizes: [656144]
# Morphsnake iter 587 Component sizes: [416207, 2291]
# Morphsnake iter 531 Component sizes: [656788]
# Morphsnake iter 588 Component sizes: [415839, 2249]
# Morphsnake iter 532 Component sizes: [656122]
# Morphsnake iter 589 Component sizes: [416185, 2291]
# Morphsnake iter 533 Component sizes: [656769]
# Morphsnake iter 590 Component sizes: [415817, 2249]
# Morphsnake iter 534 Component sizes: [656095]
# Morphsnake iter 591 Component sizes: [416161, 2291]
# Morphsnake iter 535 Component sizes: [656740]
# Morphsnake iter 592 Component sizes: [415794, 2249]
# Morphsnake iter 536 Component sizes: [656072]
# Morphsnake iter 593 Component sizes: [416141, 2291]
# Morphsnake iter 537 Component sizes: [656715]
# Morphsnake iter 594 Component sizes: [415773, 2249]
# Morphsnake iter 538 Component sizes: [656045]
# Morphsnake iter 595 Component sizes: [416119, 2291]
# Morphsnake iter 539 Component sizes: [656688]
# Morphsnake iter 596 Component sizes: [415751, 2249]
# Morphsnake iter 540 Component sizes: [656022]
# Morphsnake iter 597 Component sizes: [416095, 2291]
# Morphsnake iter 541 Component sizes: [656667]
# Morphsnake iter 598 Component sizes: [415725, 2249]
# Morphsnake iter 542 Component sizes: [656004]
# Morphsnake iter 599 Component sizes: [416069, 2291]
# Morphsnake iter 543 Component sizes: [656657]
# Snake finished at iteration 599.
# Snake: 218.67 seconds
# Final masks added.
# Final masks added.
# ENABLE_UPLOAD_S3 is False. Skip uploading to S3.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep1_thumbnail_autoSubmasks/UCSD001_slide063_2018_09_04-S4/UCSD001_slide063_2018_09_04-S4_prep1_thumbnail_autoSubmask_1.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ENABLE_UPLOAD_S3 is False. Skip uploading to S3.
# ENABLE_UPLOAD_S3 is False. Skip uploading to S3.
# Morphsnake iter 544 Component sizes: [655994]
# Morphsnake iter 545 Component sizes: [656649]
# Morphsnake iter 546 Component sizes: [655987]
# Morphsnake iter 547 Component sizes: [656642]
# Morphsnake iter 548 Component sizes: [655982]
# Morphsnake iter 549 Component sizes: [656639]
# Morphsnake iter 550 Component sizes: [655978]
# Component area is too small - nullified.
# Morphsnake iter 551 Component sizes: [656629, 3]
# Morphsnake iter 552 Component sizes: [655972]
# Snake finished at iteration 553.
# Snake: 221.86 seconds
# Final masks added.
# ENABLE_UPLOAD_S3 is False. Skip uploading to S3.
# ENABLE_UPLOAD_S3 is False. Skip uploading to S3.
# Generate contours: 222.40
# ('Automatic mask creation finished. Took ', 223.68032789230347, ' seconds')
#
# Mask generation finished, check using the following command:
#
# `python ../src/gui/mask_editing_tool_v4.py $stack NtbNormalized`

# %%
# Must also create from_none_to_wholeslice.ini??????? Why? It is different than the one on S3.
! python a_script_preprocess_4.py $stack
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide066_2018_09_04-S2_thumbnail_NtbNormalized.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide063_2018_09_04-S4_thumbnail_NtbNormalized.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide067_2018_09_04-S1_thumbnail_NtbNormalized.tif
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_NtbNormalized/UCSD001_slide064_2018_09_04-S1_thumbnail_NtbNormalized.tif
# **************************************************************************************************
#
# Script generate_original_image_crop_csv.py completed. Took  1.3  seconds
# Finished generating CSV file.
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# LOADING: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/operation_configs/from_padded_to_none.ini
# LOADING: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/operation_configs/from_aligned_to_padded.ini
# LOADING: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/operation_configs/from_none_to_aligned.ini
# LOADING: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/operation_configs/crop_orig.ini
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.
# Jobs submitted. Use wait_qsub_complete() to wait for all execution to finish.
# **************************************************************************************************
#
# Script warp_crop_v3.py completed. Took  7.2  seconds
# Transforming masks back into orientation of original raw images finished.
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# xgboost is not loaded.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide066_2018_09_04-S2_raw_Ntb.tif
# Load image: 13.23 seconds.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_mask/UCSD001_slide066_2018_09_04-S2_thumbnail_mask.png
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Rescale mask: 47.75 seconds.
# Compute mean/std for sample regions: 19.96 seconds.
# Interpolate mean map: 9.46 seconds.
# /home/alexn/brainDev/src//utilities/utilities2015.py:520: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   np.floor(np.linspace(0, v.shape[1]-1, new_shape[0])).astype(np.int), indexing='ij')]
# Scale up mean map: 27.54 seconds.
# Interpolate std map: 9.48 seconds.
# Scale up std map: 27.72 seconds.
# Normalize: 26.91 seconds.
# Save float version: 25.24 seconds.
# Save float histogram: 40.14 seconds.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide063_2018_09_04-S4_raw_Ntb.tif
# Load image: 11.37 seconds.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_mask/UCSD001_slide063_2018_09_04-S4_thumbnail_mask.png
# Rescale mask: 37.87 seconds.
# Compute mean/std for sample regions: 14.13 seconds.
# Interpolate mean map: 8.78 seconds.
# Scale up mean map: 22.05 seconds.
# Interpolate std map: 8.61 seconds.
# Scale up std map: 22.40 seconds.
# Normalize: 12.84 seconds.
# Save float version: 18.33 seconds.
# Save float histogram: 27.93 seconds.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide067_2018_09_04-S1_raw_Ntb.tif
# Load image: 11.81 seconds.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_mask/UCSD001_slide067_2018_09_04-S1_thumbnail_mask.png
# Rescale mask: 42.94 seconds.
# Compute mean/std for sample regions: 21.50 seconds.
# Interpolate mean map: 9.56 seconds.
# Scale up mean map: 23.30 seconds.
# Interpolate std map: 9.69 seconds.
# Scale up std map: 24.53 seconds.
# Normalize: 19.98 seconds.
# Save float version: 20.50 seconds.
# Save float histogram: 34.99 seconds.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_raw_Ntb/UCSD001_slide064_2018_09_04-S1_raw_Ntb.tif
# Load image: 15.32 seconds.
# Trying to load /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_thumbnail_mask/UCSD001_slide064_2018_09_04-S1_thumbnail_mask.png
# Rescale mask: 54.26 seconds.
# Compute mean/std for sample regions: 26.77 seconds.
# Interpolate mean map: 11.95 seconds.
# Scale up mean map: 30.14 seconds.
# Interpolate std map: 12.02 seconds.
# Scale up std map: 30.17 seconds.
# Normalize: 24.19 seconds.
# Save float version: 25.10 seconds.
# Save float histogram: 41.93 seconds.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Rescale to uint8: 44.43 seconds.
# Load mask: 2.68 seconds.
# Rescale to uint8: 35.52 seconds.
# Load mask: 2.36 seconds.
# Rescale to uint8: 46.32 seconds.
# Load mask: 2.62 seconds.
# Rescale to uint8: 60.80 seconds.
# Load mask: 3.10 seconds.
# **************************************************************************************************
#
# Script normalize_intensity_adaptive.py completed. Took  1449.1  seconds
# Local adaptive intensity normalization finished.
#
# **************************************************************************************************
#
# Finished generating image crop csv file, transformating masks, and performing adaptive intensity normalization on images.

# %%
# Create from_aligned_to_wholeslice.ini
#  - Find dimensions of cropping box around the entire brain
make_from_x_to_y_ini( stack, x='aligned', y='wholeslice',\
                     rostral_limit=80,caudal_limit=1880,dorsal_limit=60,ventral_limit=910)

! python a_script_preprocess_5.py $stack
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/src/
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.
# Jobs submitted. Use wait_qsub_complete() to wait for all execution to finish.
# **************************************************************************************************
#
# Script warp_crop.py completed. Took  473.2  seconds
# Finished transformed images into wholeslice format (prep5).
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide066_2018_09_04-S2_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# Rescale: 7.53 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide063_2018_09_04-S4_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# Rescale: 6.47 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide067_2018_09_04-S1_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# Rescale: 8.19 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide064_2018_09_04-S1_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# Rescale: 7.95 seconds.
# **************************************************************************************************
#
# Script rescale.py completed. Took  31.4  seconds
# Finished rescaling images into thumbnail format.
#
# **************************************************************************************************

# %%
! python a_script_preprocess_5.py $stack
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/src/
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.
# Jobs submitted. Use wait_qsub_complete() to wait for all execution to finish.
# **************************************************************************************************
#
# Script warp_crop.py completed. Took  566.7  seconds
# Finished transformed images into wholeslice format (prep5).
#
# **************************************************************************************************
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# /home/alexn/brainDev/mousebrainatlas_virtualenv/lib/python2.7/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide066_2018_09_04-S2_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# (22976, 36448)
# Rescale: 7.76 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide063_2018_09_04-S4_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# (22976, 36448)
# Rescale: 6.45 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide067_2018_09_04-S1_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# (22976, 36448)
# Rescale: 8.11 seconds.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep5_raw_NtbNormalizedAdaptiveInvertedGamma/UCSD001_slide064_2018_09_04-S1_prep5_raw_NtbNormalizedAdaptiveInvertedGamma.tif
# uint8
# (22976, 36448)
# Rescale: 7.95 seconds.
# **************************************************************************************************
#
# Script rescale.py completed. Took  31.5  seconds
# Finished rescaling images into thumbnail format.
#
# **************************************************************************************************

# %%
# Create from_padded_to_wholeslice.ini
make_from_x_to_y_ini( stack, x='padded', y='wholeslice',\
                     rostral_limit=80,caudal_limit=1880,dorsal_limit=60,ventral_limit=910)
# Create from_padded_to_brainstem.ini
#  - Find dimensions of cropping box around the brainstem
make_from_x_to_y_ini( stack, x='padded', y='brainstem',\
                     rostral_limit=720,caudal_limit=1780,dorsal_limit=170,ventral_limit=860)

! python a_script_preprocess_6.py $stack
# Out:
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# ENABLE_UPLOAD_S3 is not set, default to False.
# ENABLE_DOWNLOAD_S3 is not set, default to False.
# Setting environment for Precision WorkStation for Alex Newberry
# {'UCSD001': 0.325}
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 anchor: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 sections_to_filenames:
# File does not exist: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Failed to cache MD585 filenames_to_sections:
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 cropbox: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# Failed to cache MD585 valid_sections/filenames: MD585
# No anchor.txt is found. Seems we are using the operation ini to provide anchor. Try to load operation ini.
# Failed to cache MD585 image_shape: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/MD585/operation_configs/from_none_to_aligned.ini does not exist.
# No mcubes
# Failed to cache UCSD001 section_limits: ini file /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_prep2_sectionLimits.ini does not exist.
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# Failed to cache UCSD001 valid_sections/filenames: UCSD001
# /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/UCSD001_cropbox.ini
# Seems you are using operation INIs to provide cropbox.
# LOADING: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/operation_configs/from_wholeslice_to_brainstem.ini
# LOADING: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/operation_configs/from_padded_to_wholeslice.ini
# LOADING: /media/alexn/BstemAtlasDataBackup/script_test/CSHL_data_processed/UCSD001/operation_configs/from_padded_to_brainstem.ini
# rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stderr_*; rm -f /media/alexn/BstemAtlasDataBackup/script_test/mousebrainatlas_tmp/stdout_*
# return code: 0
# Run locally.

# %%
8*37*0.6 + 8*3*0.6
# Out:
# 192.0

# %%
2*20*8
# Out:
# 320

# %%
33.5 * 2080
# Out:
# 69680.0
